# %% [markdown]
# ## 1.- Crear Base de Datos

# %% [markdown]
# * Crear con código SQL una base de datos llamada supermercado.
# * Código Python con mysql connector que ejecute el SQL para borrar y generar la base de datos vacía

# %%
# Ejercicio 1 - Crear base de datos estudiantes
import mysql.connector as con
def crear_bd(sql):
    try:
       connection = con.connect(
            host="localhost",
            port="3306",
            user="root",
            password="ADMIN",
            database='supermercado'
        )
       cursor = connection.cursor()
       cursor.execute(sql)
       
    except con.Error as error:
      print(f"Ha ocurrido un error: {error}") 
      if connection:
         connection.rollback()
         return 0
    finally:
        if cursor: 
            cursor.close()
        if connection:
            connection.close()

# %%
sql = "DROP DATABASE IF EXISTS supermercado; CREATE DATABASE IF NOT EXISTS supermercado;"

# %%
crear_bd(sql)

# %% [markdown]
# # Tablas SQL

# %% [markdown]
# * Tiendas
#
#    * id_tienda (PRIMARY KEY)
#    * nombre_tienda
#    * direccion
#    * ciudad

# %%
sql = "CREATE TABLE IF NOT EXISTS tiendas (id_tienda INT AUTO_INCREMENT PRIMARY KEY, nombre_tienda VARCHAR(100) NOT NULL, dirección VARCHAR(80), ciudad VARCHAR(50) NOT NULL);"

# %%
crear_bd(sql)

# %% [markdown]
# * Empleados
#     * id_empleado (PRIMARY KEY)
#     * nombre_empleado
#     * puesto (ej.: Cajero, Gerente, Reponedor)
#     * id_tienda (FOREIGN KEY que hace referencia a tiendas.id_tienda)

# %%
sql = "CREATE TABLE IF NOT EXISTS empleados (id_empleado INT AUTO_INCREMENT PRIMARY KEY, nombre_empleado VARCHAR(100) NOT NULL, puesto VARCHAR(60), id_tienda INT NOT NULL, FOREIGN KEY (id_tienda) REFERENCES tiendas(id_tienda) ON DELETE CASCADE);"

# %%
crear_bd(sql)

# %% [markdown]
# * Categorias
#     * id_categoria (PRIMARY KEY)
#     * nombre_categoria

# %%
sql = "CREATE TABLE IF NOT EXISTS categorias (id_categoria INT AUTO_INCREMENT PRIMARY KEY, nombre_categoria VARCHAR(60));"

# %%
crear_bd(sql)

# %% [markdown]
# * Productos
#     * id_producto (PRIMARY KEY)
#     * nombre_producto
#     * precio
#     * stock
#     * id_categoria (FOREIGN KEY que hace referencia a categorias.id_categoria)

# %%
sql = "CREATE TABLE IF NOT EXISTS productos (id_producto INT AUTO_INCREMENT PRIMARY KEY, nombre_producto VARCHAR(70), precio FLOAT(8,2), stock INT, id_categoria INT NOT NULL, FOREIGN KEY (id_categoria) REFERENCES categorias(id_categoria));"

# %%
crear_bd(sql)

# %% [markdown]
# * Clientes
#     * id_cliente (PRIMARY KEY)
#     * first_name
#     * last_name
#     * email
#     * codigo_postal

# %%
sql = "CREATE TABLE IF NOT EXISTS clientes (id_cliente INT AUTO_INCREMENT PRIMARY KEY, first_name VARCHAR(50), last_name VARCHAR(50), email VARCHAR(100), codigo_postal INT);"

# %%
crear_bd(sql)

# %% [markdown]
# * Ordenes
#     * id_orden (PRIMARY KEY)
#     * id_cliente (FOREIGN KEY que hace referencia a clientes.id_cliente)
#     * id_empleado (FOREIGN KEY que hace referencia a empleados.id_empleado)
#     * fecha_orden
#     * metodo_pago (una enum que solo admita tres valores Tarjeta, Efectivo)

# %%
sql = "CREATE TABLE IF NOT EXISTS ordenes (id_orden INT AUTO_INCREMENT PRIMARY KEY, id_cliente INT, id_empleado INT, fecha_orden DATE, metodo_pago ENUM('Tarjeta', 'Efectivo') DEFAULT 'Efectivo', FOREIGN KEY (id_cliente) REFERENCES clientes(id_cliente), FOREIGN KEY (id_empleado) REFERENCES empleados(id_empleado));"

# %%
crear_bd(sql)

# %% [markdown]
# * Detalle_orden
#     * id_detalle (PRIMARY KEY)
#     * id_orden (FOREIGN KEY que hace referencia a ordenes.id_orden) NOT NULL
#     * id_producto (FOREIGN KEY que hace referencia a productos.id_producto) NOT NULL
#     * cantidad
#     * precio_unitario: mismo precio que en la tabla producto
#     * descuento (podría ser NULL si no se aplica)

# %%
sql = "CREATE TABLE IF NOT EXISTS detalle_orden (id_detalle INT AUTO_INCREMENT PRIMARY KEY, id_orden INT NOT NULL, id_producto INT NOT NULL, cantidad FLOAT(8,2), precio_unitario FLOAT(8,2), descuento TINYINT, FOREIGN KEY (id_orden) REFERENCES ordenes(id_orden), FOREIGN KEY (id_producto) REFERENCES productos(id_producto));"

# %%
crear_bd(sql)

# %% [markdown]
# # Tablas

# %% [markdown]
# ## 2.- Generar datos demo desde Python

# %%
def insertar_dataframe(df, table_name):
    try:
        connection = con.connect(
            host="localhost",
            port="3306",
            user="root",
            password="ADMIN",
            database='supermercado'
        )
        cursor = connection.cursor()
        
        columns = ','.join(df.columns)
        placeholders = ','.join(['%s'] * len(df.columns))
        sql = f'INSERT INTO {table_name} ({columns}) VALUES ({placeholders});'
    
        rows = [tuple(row) for index, row in df.iterrows()] # lista de tuplas con los datos del dataframe

        cursor.executemany(sql, rows)
        
        connection.commit()
        return cursor.rowcount
    except con.Error as error:
        print(f"Ha ocurrido un error: {error}")
        if connection:
            connection.rollback()
        return 0
    finally:
        if cursor: 
            cursor.close()
        if connection:
            connection.close()

# %% [markdown]
# * Tabla Tiendas

# %%
import pandas as pd
import random
import datetime

tiendas = ['Tienda Centro','Tienda Norte','Tienda Sur','Tienda Poniente','Tienda Este','Tienda Oeste','Central Tiendas']
tiendas

dirección = ['Avd.Centro,nº1','Calle Norte, nº2','Calle Sur, nº3', 'Avd. Poniente, nº4','Calle Este, nº5','Calle Oeste, nº6', 'Crta.Central, Km10']
   
dirección

# Ciudad

ciudad= ['Almería','Girona','Murcia','Barcelona','Orense','Gijón','Madrid' ] 
ciudad 

# Creamos un DataFrame 

df_tiendas = pd.DataFrame(zip(tiendas, dirección, ciudad),
             columns= ['nombre_tienda', 'dirección', 'ciudad']) # El comando Zip empaqueta todas las variante hemos hecho | y con columns damos nombres a las columnas

# Añadir columna Pk:

df_tiendas = df_tiendas.reset_index().rename({'index': 'id_tienda'}, axis=1)
df_tiendas['id_tienda'] = df_tiendas['id_tienda'] + 1
df_tiendas
# Out:
#    id_tienda    nombre_tienda           dirección     ciudad
# 0          1    Tienda Centro      Avd.Centro,nº1    Almería
# 1          2     Tienda Norte    Calle Norte, nº2     Girona
# 2          3       Tienda Sur      Calle Sur, nº3     Murcia
# 3          4  Tienda Poniente  Avd. Poniente, nº4  Barcelona
# 4          5      Tienda Este     Calle Este, nº5     Orense
# 5          6     Tienda Oeste    Calle Oeste, nº6      Gijón
# 6          7  Central Tiendas  Crta.Central, Km10     Madrid

# %%
insertar_dataframe(df_tiendas, 'tiendas')
# Out:
# 7

# %% [markdown]
# * Tabla Empleados

# %%
# Creamos lista de empleados | Nombre,Apellidos,Función
empleados = list()
nombres = ['Alejandro', 'María', 'Carlos', 'Lucía', 'Fernando', 'Isabel', 'Javier', 'Ana', 'Miguel', 'Sofía', 'José', 'Clara', 'Luis', 'Elena', 'Daniel', 'Marta', 'Andrés', 'Laura', 'Raúl', 'Paula', 'Manuel', 'Sara', 'Pablo', 'Julia', 'Sergio', 'Valeria', 'Tomás', 'Adriana', 'Eduardo', 'Camila', 'Francisco', 'Diana', 'Ricardo', 'Patricia', 'Ángel', 'Carla', 'Diego', 'Irene', 'Samuel', 'Eva', 'David', 'Andrea', 'Hugo', 'Verónica', 'Cristian', 'Gabriela', 'Mario', 'Natalia', 'Jorge', 'Lorena', 'Rubén', 'Carmen']
apellidos = ['García', 'Martínez', 'López', 'Sánchez', 'Pérez', 'González', 'Rodríguez', 'Fernández', 'Hernández', 'Jiménez', 'Ruiz', 'Díaz', 'Moreno', 'Álvarez', 'Romero', 'Torres', 'Vázquez', 'Domínguez', 'Ramos', 'Ramírez', 'Castro', 'Ortiz', 'Rubio', 'Molina', 'Delgado', 'Cruz', 'Flores', 'Navarro', 'Cabrera', 'Campos', 'Peña', 'Aguilar', 'Santos', 'Reyes', 'Méndez', 'Medina', 'Paredes', 'Serrano', 'Cortés', 'Carrillo', 'Ortiz', 'Velázquez', 'Chávez', 'Guzmán', 'Salinas', 'Esquivel', 'Lara', 'Fuentes', 'Montes']
función = ["Cajero", "Reponedor", "Encargado de sección", "Gerente", "Personal de limpieza", "Panadero", "Carnicero", "Pescadero", "Frutero", "Charcutero", "Jefe de turno", "Operador logístico", "Atención al cliente", "Auxiliar de caja", "Encargado de seguridad","Responsable de zona","Jefe de compras","Encargada carnicería","encargado pescadería","Jefe de Limpieza"]
for tienda in df_tiendas['id_tienda']:
    for empleado in range(20):
        nombre_empleado = (random.choice(nombres) + ' ' + random.choice(apellidos))
        puesto = función[empleado]
        id_tienda = tienda
        empleados.append([nombre_empleado, puesto, id_tienda])
        
# Creamos un DataFrame         
df_empleados = pd.DataFrame(empleados, columns=['nombre_empleado', 'puesto', 'id_tienda'])
        
df_empleados = df_empleados.reset_index().rename({'index': 'id_empleado'}, axis=1)
df_empleados['id_empleado'] = df_empleados['id_empleado'] + 1
df_empleados
# Out:
#      id_empleado nombre_empleado                puesto  id_tienda
# 0              1   Carla Cabrera                Cajero          1
# 1              2  Raúl Hernández             Reponedor          1
# 2              3     Irene Ortiz  Encargado de sección          1
# 3              4    María Montes               Gerente          1
# 4              5  Samuel Sánchez  Personal de limpieza          1
# ..           ...             ...                   ...        ...
# 135          136        Eva Peña   Responsable de zona          7
# 136          137   Rubén Fuentes       Jefe de compras          7
# 137          138     Luis Montes  Encargada carnicería          7
# 138          139    Valeria Ruiz  encargado pescadería          7
# 139          140     Carla Reyes      Jefe de Limpieza          7
#
# [140 rows x 4 columns]

# %%
insertar_dataframe(df_empleados, "empleados")
# Out:
# 140

# %% [markdown]
# * Tabla Categorías

# %%
categorias = ['Lácteos','Pescados','Carnes','Verduras','Frutas','Bollería y Pan','Refrescos','Vinos','Alcohol','Congelados']

df_categorias= pd.DataFrame(categorias,columns= ['nombre_categoria'])

# Añadir columna pk:

df_categorias = df_categorias.reset_index().rename({'index': 'id_categoria'}, axis=1)
df_categorias['id_categoria'] = df_categorias['id_categoria'] + 1
df_categorias
# Out:
#    id_categoria nombre_categoria
# 0             1          Lácteos
# 1             2         Pescados
# 2             3           Carnes
# 3             4         Verduras
# 4             5           Frutas
# 5             6   Bollería y Pan
# 6             7        Refrescos
# 7             8            Vinos
# 8             9          Alcohol
# 9            10       Congelados

# %%
insertar_dataframe(df_categorias, 'categorias')
# Out:
# 10

# %% [markdown]
# * Productos
#
#     * id_producto: valores enteros consecutivos (1, 2, 3...).
#     * nombre_producto: nombres como “Leche Entera”, “Manzana Roja”, “Refresco de Cola”, etc.
#     * precio: valores DECIMAL entre 0.50 y 50.00, por ejemplo.
#     * stock: valores INT entre 0 y 500 (o el rango que quieras).
#     * id_categoria: debe hacer referencia a las categorías que hayas definido (1, 2, 3, etc.).

# %%
# Listado de productos

# generar columna id_producto
nombres = ["Leche", "Yogur", "Queso", "Mantequilla", "Pollo", "Carne de res", "Cerdo", "Chuletas", "Manzana", "Banana", "Naranja", "Uva", "Zanahoria", "Tomate", "Lechuga", "Cebolla", "Agua", "Jugo de naranja", "Refresco", "Cerveza", "Papas fritas", "Chocolate", "Galletas", "Chicles", "Velas", "Platos desechables", "Bolsas de basura", "Pilas", "Detergente", "Jabón líquido", "Esponjas", "Desinfectante", "Champú", "Colonia", "Crema hidratante", "Desodorante", "Tierra para macetas", "Fertilizante", "Semillas", "Regadera"]
precios, lista_categorias, stock = list(), list(), list()
cantidad = len(nombres)
for _ in range(cantidad):
    precios.append(random.uniform(0.50, 10.50))
    stock.append(random.randint(0, 500))
for categ in df_categorias['id_categoria']:
    for i in range(4):
        lista_categorias.append(categ)
lista_categorias        
df_productos = pd.DataFrame(zip(nombres, precios, stock, lista_categorias), columns=['nombre_producto', 'precio', 'stock', 'id_categoria'])    
df_productos = df_productos.reset_index().rename({'index': 'id_producto'}, axis=1)
df_productos['id_producto'] = df_productos['id_producto'] + 1
df_productos
# Out:
#     id_producto      nombre_producto     precio  stock  id_categoria
# 0             1                Leche   3.551087    288             1
# 1             2                Yogur   7.660695     53             1
# 2             3                Queso   7.430396    449             1
# 3             4          Mantequilla   8.190713    449             1
# 4             5                Pollo   1.828038    315             2
# 5             6         Carne de res  10.156211     45             2
# 6             7                Cerdo   6.515213    247             2
# 7             8             Chuletas   1.405606    487             2
# 8             9              Manzana   7.990156    320             3
# 9            10               Banana   2.103978     58             3
# 10           11              Naranja   9.180789    384             3
# 11           12                  Uva   9.013914    371             3
# 12           13            Zanahoria   5.170320    167             4
# 13           14               Tomate   1.573753    241             4
# 14           15              Lechuga   7.618319    280             4
# 15           16              Cebolla   2.011215    482             4
# 16           17                 Agua   2.362774     32             5
# 17           18      Jugo de naranja   5.607605     21             5
# 18           19             Refresco   2.910498     51             5
# 19           20              Cerveza   1.410653    252             5
# 20           21         Papas fritas   1.787206    413             6
# 21           22            Chocolate   5.744855     57             6
# 22           23             Galletas   4.632224     94             6
# 23           24              Chicles   4.737349    262             6
# 24           25                Velas   9.552156    160             7
# 25           26   Platos desechables   3.601500    421             7
# 26           27     Bolsas de basura   7.447298    291             7
# 27           28                Pilas   2.955949     75             7
# 28           29           Detergente   8.855387    166             8
# 29           30        Jabón líquido   9.897167    238             8
# 30           31             Esponjas   2.507806    213             8
# 31           32        Desinfectante   9.116388    365             8
# 32           33               Champú   9.001582    453             9
# 33           34              Colonia   2.374038    106             9
# 34           35     Crema hidratante   9.061448    192             9
# 35           36          Desodorante  10.268180    193             9
# 36           37  Tierra para macetas   1.903980    350            10
# 37           38         Fertilizante   7.691341     22            10
# 38           39             Semillas   6.742475    110            10
# 39           40             Regadera   6.881342    306            10

# %%
insertar_dataframe(df_productos, 'productos')
# Out:
# 40

# %% [markdown]
# * Clientes
#
#     * id_cliente: valores enteros consecutivos (1, 2, 3...).
#     * nombre_cliente: nombres y apellidos ficticios (p. ej. “Carlos López”, “María Gil”).
#     * email: podrías generar correos ficticios (p. ej. “carlos.lopez@test.com”).
#     * telefono: número de 9 o 10 dígitos (dependiendo del país).
#     * direccion: calles y números ficticios (p. ej. “Av. Siempre Viva 742”).

# %%
# generar columna cliente
nombre_cliente, apellido_cliente, email, postal, cliente_completo = list(), list(), list(), list(), list()
calles = ("Av. Libertad", "Calle Mayor", "Paseo de la Reforma", "Calle Real", "Av. de la Constitución", "Calle del Sol", "Calle de la Luna", "Calle los Pinos", "Calle de la Paz", "Calle Olivo", "Calle Cedro", "Calle Nogal", "Av. de las Flores", "Paseo del Prado", "Calle del Río", "Av. Central", "Calle Primavera", "Calle Otoño", "Calle Invierno", "Calle Verano", "Calle Granada", "Calle Sevilla", "Calle Córdoba", "Calle Málaga", "Calle Valencia", "Calle Zaragoza", "Calle Alicante", "Av. de los Ángeles", "Calle del Carmen", "Calle San Miguel", "Calle San Juan", "Calle del Pilar", "Calle Santa Teresa", "Calle San Francisco", "Calle de la Sierra", "Calle del Mar", "Av. del Norte", "Av. del Sur", "Calle del Este", "Calle del Oeste", "Calle Diamante", "Calle Esmeralda", "Calle Rubí", "Calle Zafiro", "Calle Ámbar", "Calle Turquesa", "Calle Topacio", "Calle Perla", "Calle Horizonte", "Calle Amanecer")
for _ in range(2000):
    nom = random.choice(nombres)
    nombre_cliente.append(nom)
    ape = random.choice(apellidos)
    apellido_cliente.append(ape)
    email.append((f'{nom}.{ape}@mail.com'))
    postal.append(random.randint(0000, 11900))
    
df_clientes = pd.DataFrame(zip(nombre_cliente, apellido_cliente, email, postal), columns=['first_name', 'last_name', 'email', 'codigo_postal']) 
df_clientes = df_clientes.reset_index().rename({'index': 'id_cliente'}, axis=1)
df_clientes['id_cliente'] = df_clientes['id_cliente'] + 1
df_clientes
# Out:
#       id_cliente        first_name last_name  \
# 0              1         Zanahoria   Fuentes
# 1              2  Bolsas de basura   Delgado
# 2              3               Uva    Torres
# 3              4   Jugo de naranja   Cabrera
# 4              5         Chocolate    Chávez
# ...          ...               ...       ...
# 1995        1996            Banana     Pérez
# 1996        1997             Queso   Jiménez
# 1997        1998               Uva     Reyes
# 1998        1999            Champú     Ortiz
# 1999        2000          Refresco    García
#
#                                   email  codigo_postal
# 0            Zanahoria.Fuentes@mail.com             76
# 1     Bolsas de basura.Delgado@mail.com            548
# 2                   Uva.Torres@mail.com           3991
# 3      Jugo de naranja.Cabrera@mail.com          11265
# 4             Chocolate.Chávez@mail.com          11475
# ...                                 ...            ...
# 1995              Banana.Pérez@mail.com           7562
# 1996             Queso.Jiménez@mail.com          11272
# 1997                 Uva.Reyes@mail.com            786
# 1998              Champú.Ortiz@mail.com           5089
# 1999           Refresco.García@mail.com           5724
#
# [2000 rows x 5 columns]

# %%
insertar_dataframe(df_clientes, 'clientes')
# Out:
# 2000

# %% [markdown]
# * Orden
#     * id_orden: Valores enteros consecutivos
#     * id_cliente: Referencias de los Ids existentes en la tabla Clientes
#     * id_empleado: Refeferencias de los Ids existentes en la tabla Empleados
#     * fecha_orden: Generar fechas aleatorias o secuenciales
#     * metodo_pago: Escoger entre tarjeta o efectivo

# %%
# generar columna id_orden
from datetime import timedelta


cliente, emplea, fecha, metodo = list(), list(), list(), list()
fechas = [datetime.datetime(year=2024, month=1, day=1) + timedelta(days=numero) for numero in range(395)]
for _ in range(10000):
    cliente.append(random.choice(df_clientes['id_cliente']))
    emplea.append(random.choice(df_empleados['id_empleado']))
    fecha.append(random.choice(fechas))
    metodo.append(random.choices(['Tarjeta', 'Efectivo'], weights=[0.65, 0.35])[0])

fecha.sort()
df_ordenes = pd.DataFrame(zip(cliente, emplea, fecha, metodo), columns=['id_cliente', 'id_empleado', 'fecha_orden', 'metodo_pago'])

df_ordenes.sort_values('fecha_orden', inplace=True)
df_ordenes = df_ordenes.reset_index().rename({'index': 'id_orden'}, axis=1)
df_ordenes['id_orden'] = df_ordenes['id_orden'] + 1
df_ordenes.sort_values('id_orden', inplace=True)
df_ordenes.head(50)
# Out:
#     id_orden  id_cliente  id_empleado fecha_orden metodo_pago
# 0          1        1490           13  2024-01-01     Tarjeta
# 18         2        1937           54  2024-01-01     Tarjeta
# 19         3        1769           48  2024-01-01     Tarjeta
# 20         4        1243          127  2024-01-01    Efectivo
# 25         5          89          104  2024-01-01     Tarjeta
# 22         6         303           51  2024-01-01     Tarjeta
# 23         7        1650           13  2024-01-01     Tarjeta
# 24         8         359            6  2024-01-01    Efectivo
# 32         9        1049          122  2024-01-01     Tarjeta
# 26        10           4           62  2024-01-01     Tarjeta
# 27        11        1427           74  2024-01-01     Tarjeta
# 28        12         558           57  2024-01-01     Tarjeta
# 29        13         577           95  2024-01-01    Efectivo
# 30        14        1696           95  2024-01-01    Efectivo
# 31        15         119            7  2024-01-01     Tarjeta
# 17        16         663           89  2024-01-01    Efectivo
# 21        17         494           15  2024-01-01     Tarjeta
# 15        18        1313            9  2024-01-01     Tarjeta
# 14        19        1932          118  2024-01-01     Tarjeta
# 13        20        1379          118  2024-01-01     Tarjeta
# 16        21         381          121  2024-01-01     Tarjeta
# 12        22         708          119  2024-01-01     Tarjeta
# 11        23         919           61  2024-01-01    Efectivo
# 10        24        1963           54  2024-01-01     Tarjeta
# 9         25         432          109  2024-01-01     Tarjeta
# 8         26         535           26  2024-01-01     Tarjeta
# 7         27         468            6  2024-01-01    Efectivo
# 6         28         785           63  2024-01-01    Efectivo
# 5         29        1873            8  2024-01-01     Tarjeta
# 4         30         447          124  2024-01-01     Tarjeta
# 3         31        1848           74  2024-01-01     Tarjeta
# 2         32        1658          110  2024-01-01     Tarjeta
# 1         33        1676          106  2024-01-01    Efectivo
# 42        34         507           89  2024-01-02    Efectivo
# 49        35        1694           22  2024-01-02     Tarjeta
# 48        36        1097           43  2024-01-02     Tarjeta
# 47        37         279          122  2024-01-02     Tarjeta
# 46        38         402          103  2024-01-02     Tarjeta
# 45        39         967          114  2024-01-02     Tarjeta
# 44        40         567          117  2024-01-02     Tarjeta
# 43        41        1355            8  2024-01-02     Tarjeta
# 50        42        1908           98  2024-01-02     Tarjeta
# 41        43         469           56  2024-01-02     Tarjeta
# 33        44        1228          117  2024-01-02     Tarjeta
# 40        45        1375           22  2024-01-02    Efectivo
# 39        46         338           14  2024-01-02     Tarjeta
# 38        47        1781          101  2024-01-02    Efectivo
# 37        48         561           34  2024-01-02    Efectivo
# 36        49        1349           26  2024-01-02     Tarjeta
# 35        50         645           67  2024-01-02    Efectivo

# %%
insertar_dataframe(df_ordenes, 'ordenes')
# Out:
# 10000

# %% [markdown]
# * Detalles de ordenes
#     * id_detalle: Valores enterors consecutivos
#     * id_orden: Referencia al Id de alguna orden válida
#     * id_producto: Referencia al ID
#     * Cantidad: Valores entre 1 y 20
#     * Precio_unitario: Usando en mismo precio está en la tabla productos
#     * Descuento: Valores Decimales bajos

# %%
# generar columna id_detalle

orden_completa = list()
productos = df_productos['id_producto']
orden_20 = df_ordenes['id_orden']

for orden in df_ordenes['id_orden']:
    ordenes = orden
    producto = (int(random.choice(productos)))
    cant = random.randint(1, 20)
    valor = float(df_productos['precio'][df_productos['id_producto'] == producto].iloc[0])
    descuento = random.uniform(0, 0.25)
    orden_completa.append([ordenes, producto, cant, round(valor, 2), round(descuento, 2)])   
    
for orden in range(20000):
    ordenes = random.choice(orden_20)
    producto = (int(random.choice(productos)))
    cant = random.randint(1, 20)
    valor = float(df_productos['precio'][df_productos['id_producto'] == producto].iloc[0])
    descuento = random.uniform(0, 0.25)
    orden_completa.append([ordenes, producto, cant, round(valor,2), round(descuento, 2)])   
    
df_detalle_orden = pd.DataFrame(orden_completa, columns=['id_orden', 'id_producto', 'cantidad', 'precio_unitario', 'descuento'])

df_detalle_orden = df_detalle_orden.reset_index().rename({'index': 'id_detalle'}, axis=1)
df_detalle_orden['id_detalle'] = df_detalle_orden['id_detalle'] + 1
df_detalle_orden
# Out:
#        id_detalle  id_orden  id_producto  cantidad  precio_unitario  descuento
# 0               1         1            6        20            10.16       0.14
# 1               2         2           39        17             6.74       0.04
# 2               3         3           40         9             6.88       0.06
# 3               4         4            2        19             7.66       0.23
# 4               5         5           37        11             1.90       0.21
# ...           ...       ...          ...       ...              ...        ...
# 29995       29996      5387           19        14             2.91       0.19
# 29996       29997      2480           32         1             9.12       0.08
# 29997       29998      8039           31        18             2.51       0.15
# 29998       29999      5139           40        16             6.88       0.23
# 29999       30000      5616           17        18             2.36       0.04
#
# [30000 rows x 6 columns]

# %%
insertar_dataframe(df_detalle_orden, 'detalle_orden')
# Out:
# 30000

# %% [markdown]
# ## 3.- Consultas SQL

# %%
def consultas(sql):
    try:
        connection = con.connect(
            host="localhost",
            port="3306",
            user="root",
            password="ADMIN",
            database='supermercado'
        )
        cursor = connection.cursor()
        cursor.execute(sql)
        return cursor.fetchall()
    except con.Error as error:
        print(f"Ha ocurrido un error: {error}")
        if connection:
            connection.rollback()
        return 0
    finally:
        if cursor: 
            cursor.close()
        if connection:
            connection.close()

# %% [markdown]
# * 1.-Listado de órdenes con detalles de cliente y empleado
#
#     * Muestra el ID de la orden, la fecha, el nombre del cliente, el nombre del empleado que atendió la compra y el método de pago.
#     * Utiliza un JOIN entre las tablas ordenes, clientes y empleados

# %%
sql = ('SELECT o.id_orden, o.fecha_orden, c.first_name, c.last_name, e.nombre_empleado, o.metodo_pago FROM ordenes o JOIN clientes c ON c.id_cliente = o.id_cliente JOIN empleados e ON e.id_empleado = o.id_empleado ORDER BY o.id_orden;') 
consultas(sql)
# Out:
# [(1,
#   datetime.date(2024, 1, 1),
#   'Esponjas',
#   'Cabrera',
#   'María Aguilar',
#   'Tarjeta'),
#  (2,
#   datetime.date(2024, 1, 1),
#   'Bolsas de basura',
#   'Cortés',
#   'Andrea Paredes',
#   'Tarjeta'),
#  (3,
#   datetime.date(2024, 1, 1),
#   'Papas fritas',
#   'Guzmán',
#   'Lucía Molina',
#   'Tarjeta'),
#  (4, datetime.date(2024, 1, 1), 'Yogur', 'Chávez', 'Rubén Castro', 'Efectivo'),
#  (5, datetime.date(2024, 1, 1), 'Cerdo', 'Rodríguez', 'Lucía Cruz', 'Tarjeta'),
#  (6,
#   datetime.date(2024, 1, 1),
#   'Pilas',
#   'Romero',
#   'Ángel Carrillo',
#   'Tarjeta'),
#  (7, datetime.date(2024, 1, 1), 'Tomate', 'Ramos', 'María Aguilar', 'Tarjeta'),
#  (8, datetime.date(2024, 1, 1), 'Uva', 'López', 'David Montes', 'Efectivo'),
#  (9,
#   datetime.date(2024, 1, 1),
#   'Chocolate',
#   'Martínez',
#   'Pablo Navarro',
#   'Tarjeta'),
#  (10,
#   datetime.date(2024, 1, 1),
#   'Jugo de naranja',
#   'Cabrera',
#   'Clara Navarro',
#   'Tarjeta'),
#  (11,
#   datetime.date(2024, 1, 1),
#   'Platos desechables',
#   'Cabrera',
#   'Carlos Rodríguez',
#   'Tarjeta'),
#  (12,
#   datetime.date(2024, 1, 1),
#   'Mantequilla',
#   'Cortés',
#   'Daniel Paredes',
#   'Tarjeta'),
#  (13,
#   datetime.date(2024, 1, 1),
#   'Uva',
#   'Esquivel',
#   'Marta Santos',
#   'Efectivo'),
#  (14,
#   datetime.date(2024, 1, 1),
#   'Pilas',
#   'Guzmán',
#   'Marta Santos',
#   'Efectivo'),
#  (15,
#   datetime.date(2024, 1, 1),
#   'Refresco',
#   'Fuentes',
#   'Lorena Chávez',
#   'Tarjeta'),
#  (16,
#   datetime.date(2024, 1, 1),
#   'Queso',
#   'Fernández',
#   'Samuel Paredes',
#   'Efectivo'),
#  (17,
#   datetime.date(2024, 1, 1),
#   'Chocolate',
#   'Rubio',
#   'Natalia Reyes',
#   'Tarjeta'),
#  (18,
#   datetime.date(2024, 1, 1),
#   'Chuletas',
#   'Cabrera',
#   'Clara Álvarez',
#   'Tarjeta'),
#  (19,
#   datetime.date(2024, 1, 1),
#   'Lechuga',
#   'Velázquez',
#   'María Ruiz',
#   'Tarjeta'),
#  (20, datetime.date(2024, 1, 1), 'Queso', 'Ruiz', 'María Ruiz', 'Tarjeta'),
#  (21,
#   datetime.date(2024, 1, 1),
#   'Fertilizante',
#   'Guzmán',
#   'Tomás Ruiz',
#   'Tarjeta'),
#  (22,
#   datetime.date(2024, 1, 1),
#   'Zanahoria',
#   'Fuentes',
#   'Natalia Campos',
#   'Tarjeta'),
#  (23,
#   datetime.date(2024, 1, 1),
#   'Chuletas',
#   'Guzmán',
#   'Patricia Castro',
#   'Efectivo'),
#  (24,
#   datetime.date(2024, 1, 1),
#   'Leche',
#   'Delgado',
#   'Andrea Paredes',
#   'Tarjeta'),
#  (25,
#   datetime.date(2024, 1, 1),
#   'Crema hidratante',
#   'Navarro',
#   'José Díaz',
#   'Tarjeta'),
#  (26,
#   datetime.date(2024, 1, 1),
#   'Detergente',
#   'Moreno',
#   'Clara Flores',
#   'Tarjeta'),
#  (27,
#   datetime.date(2024, 1, 1),
#   'Chicles',
#   'Ortiz',
#   'David Montes',
#   'Efectivo'),
#  (28,
#   datetime.date(2024, 1, 1),
#   'Esponjas',
#   'Martínez',
#   'Laura Salinas',
#   'Efectivo'),
#  (29,
#   datetime.date(2024, 1, 1),
#   'Chuletas',
#   'Romero',
#   'José Rodríguez',
#   'Tarjeta'),
#  (30,
#   datetime.date(2024, 1, 1),
#   'Crema hidratante',
#   'Moreno',
#   'Gabriela Campos',
#   'Tarjeta'),
#  (31,
#   datetime.date(2024, 1, 1),
#   'Esponjas',
#   'Cabrera',
#   'Carlos Rodríguez',
#   'Tarjeta'),
#  (32,
#   datetime.date(2024, 1, 1),
#   'Papas fritas',
#   'Ramos',
#   'Carla Martínez',
#   'Tarjeta'),
#  (33,
#   datetime.date(2024, 1, 1),
#   'Pollo',
#   'Fuentes',
#   'Jorge Ramírez',
#   'Efectivo'),
#  (34,
#   datetime.date(2024, 1, 2),
#   'Tomate',
#   'Esquivel',
#   'Samuel Paredes',
#   'Efectivo'),
#  (35,
#   datetime.date(2024, 1, 2),
#   'Cerdo',
#   'Martínez',
#   'Camila Navarro',
#   'Tarjeta'),
#  (36,
#   datetime.date(2024, 1, 2),
#   'Manzana',
#   'Carrillo',
#   'Alejandro Pérez',
#   'Tarjeta'),
#  (37,
#   datetime.date(2024, 1, 2),
#   'Chocolate',
#   'Castro',
#   'Pablo Navarro',
#   'Tarjeta'),
#  (38,
#   datetime.date(2024, 1, 2),
#   'Banana',
#   'Domínguez',
#   'Miguel Chávez',
#   'Tarjeta'),
#  (39,
#   datetime.date(2024, 1, 2),
#   'Cerveza',
#   'Fernández',
#   'Sofía Ortiz',
#   'Tarjeta'),
#  (40,
#   datetime.date(2024, 1, 2),
#   'Semillas',
#   'Torres',
#   'Adriana Ramírez',
#   'Tarjeta'),
#  (41,
#   datetime.date(2024, 1, 2),
#   'Semillas',
#   'Fernández',
#   'José Rodríguez',
#   'Tarjeta'),
#  (42,
#   datetime.date(2024, 1, 2),
#   'Jabón líquido',
#   'Vázquez',
#   'Ángel Ortiz',
#   'Tarjeta'),
#  (43,
#   datetime.date(2024, 1, 2),
#   'Chocolate',
#   'Carrillo',
#   'Valeria Ramos',
#   'Tarjeta'),
#  (44,
#   datetime.date(2024, 1, 2),
#   'Chicles',
#   'Cortés',
#   'Adriana Ramírez',
#   'Tarjeta'),
#  (45,
#   datetime.date(2024, 1, 2),
#   'Detergente',
#   'Cruz',
#   'Camila Navarro',
#   'Efectivo'),
#  (46,
#   datetime.date(2024, 1, 2),
#   'Tierra para macetas',
#   'Lara',
#   'Daniel Vázquez',
#   'Tarjeta'),
#  (47,
#   datetime.date(2024, 1, 2),
#   'Tomate',
#   'Esquivel',
#   'Patricia Castro',
#   'Efectivo'),
#  (48,
#   datetime.date(2024, 1, 2),
#   'Desinfectante',
#   'Molina',
#   'Elena Guzmán',
#   'Efectivo'),
#  (49,
#   datetime.date(2024, 1, 2),
#   'Bolsas de basura',
#   'Fuentes',
#   'Clara Flores',
#   'Tarjeta'),
#  (50,
#   datetime.date(2024, 1, 2),
#   'Carne de res',
#   'García',
#   'Andrés Castro',
#   'Efectivo'),
#  (51,
#   datetime.date(2024, 1, 2),
#   'Queso',
#   'Reyes',
#   'Daniel Velázquez',
#   'Tarjeta'),
#  (52,
#   datetime.date(2024, 1, 3),
#   'Cerveza',
#   'Castro',
#   'Verónica Fernández',
#   'Efectivo'),
#  (53,
#   datetime.date(2024, 1, 3),
#   'Uva',
#   'Álvarez',
#   'Irene Delgado',
#   'Efectivo'),
#  (54,
#   datetime.date(2024, 1, 3),
#   'Carne de res',
#   'Medina',
#   'Eduardo Ramos',
#   'Tarjeta'),
#  (55,
#   datetime.date(2024, 1, 3),
#   'Platos desechables',
#   'García',
#   'Lucía Ortiz',
#   'Tarjeta'),
#  (56, datetime.date(2024, 1, 3), 'Pilas', 'Campos', 'Irene Ortiz', 'Tarjeta'),
#  (57,
#   datetime.date(2024, 1, 3),
#   'Tierra para macetas',
#   'Jiménez',
#   'Samuel Díaz',
#   'Efectivo'),
#  (58,
#   datetime.date(2024, 1, 3),
#   'Papas fritas',
#   'Sánchez',
#   'Julia Rodríguez',
#   'Efectivo'),
#  (59,
#   datetime.date(2024, 1, 3),
#   'Detergente',
#   'Cortés',
#   'Clara Ramírez',
#   'Efectivo'),
#  (60,
#   datetime.date(2024, 1, 3),
#   'Chicles',
#   'Ortiz',
#   'Valeria Santos',
#   'Tarjeta'),
#  (61,
#   datetime.date(2024, 1, 3),
#   'Semillas',
#   'Ruiz',
#   'Laura Salinas',
#   'Tarjeta'),
#  (62,
#   datetime.date(2024, 1, 3),
#   'Carne de res',
#   'Martínez',
#   'Lucía Ortiz',
#   'Tarjeta'),
#  (63,
#   datetime.date(2024, 1, 3),
#   'Lechuga',
#   'Cabrera',
#   'Julia Rodríguez',
#   'Efectivo'),
#  (64,
#   datetime.date(2024, 1, 3),
#   'Tierra para macetas',
#   'Martínez',
#   'Irene Delgado',
#   'Tarjeta'),
#  (65,
#   datetime.date(2024, 1, 3),
#   'Banana',
#   'Paredes',
#   'Paula Cabrera',
#   'Tarjeta'),
#  (66,
#   datetime.date(2024, 1, 3),
#   'Cerveza',
#   'Hernández',
#   'Clara Navarro',
#   'Efectivo'),
#  (67,
#   datetime.date(2024, 1, 3),
#   'Mantequilla',
#   'Martínez',
#   'Clara Flores',
#   'Tarjeta'),
#  (68,
#   datetime.date(2024, 1, 3),
#   'Leche',
#   'Castro',
#   'Gabriela Fernández',
#   'Tarjeta'),
#  (69,
#   datetime.date(2024, 1, 3),
#   'Cerveza',
#   'Castro',
#   'Hugo Moreno',
#   'Tarjeta'),
#  (70, datetime.date(2024, 1, 3), 'Chicles', 'Cruz', 'Diego Peña', 'Efectivo'),
#  (71,
#   datetime.date(2024, 1, 3),
#   'Pollo',
#   'Hernández',
#   'David Montes',
#   'Tarjeta'),
#  (72,
#   datetime.date(2024, 1, 3),
#   'Uva',
#   'Velázquez',
#   'Clara Santos',
#   'Tarjeta'),
#  (73,
#   datetime.date(2024, 1, 3),
#   'Fertilizante',
#   'Molina',
#   'Eva Esquivel',
#   'Tarjeta'),
#  (74,
#   datetime.date(2024, 1, 3),
#   'Champú',
#   'Castro',
#   'Rubén Castro',
#   'Tarjeta'),
#  (75,
#   datetime.date(2024, 1, 3),
#   'Desodorante',
#   'Lara',
#   'Miguel Molina',
#   'Efectivo'),
#  (76,
#   datetime.date(2024, 1, 3),
#   'Agua',
#   'Paredes',
#   'Raúl Rodríguez',
#   'Efectivo'),
#  (77,
#   datetime.date(2024, 1, 3),
#   'Zanahoria',
#   'Cortés',
#   'Carla Cabrera',
#   'Tarjeta'),
#  (78, datetime.date(2024, 1, 3), 'Pilas', 'Molina', 'Andrea Díaz', 'Efectivo'),
#  (79,
#   datetime.date(2024, 1, 3),
#   'Cerdo',
#   'Esquivel',
#   'Raúl Hernández',
#   'Tarjeta'),
#  (80,
#   datetime.date(2024, 1, 3),
#   'Mantequilla',
#   'Cortés',
#   'Patricia Castro',
#   'Tarjeta'),
#  (81,
#   datetime.date(2024, 1, 3),
#   'Chicles',
#   'Flores',
#   'Irene Ortiz',
#   'Efectivo'),
#  (82,
#   datetime.date(2024, 1, 3),
#   'Bolsas de basura',
#   'Guzmán',
#   'Eduardo Díaz',
#   'Tarjeta'),
#  (83,
#   datetime.date(2024, 1, 3),
#   'Champú',
#   'Molina',
#   'Jorge Ramírez',
#   'Tarjeta'),
#  (84,
#   datetime.date(2024, 1, 3),
#   'Papas fritas',
#   'González',
#   'Ángel Ortiz',
#   'Efectivo'),
#  (85,
#   datetime.date(2024, 1, 3),
#   'Regadera',
#   'Romero',
#   'Irene Delgado',
#   'Efectivo'),
#  (86,
#   datetime.date(2024, 1, 3),
#   'Leche',
#   'Ramírez',
#   'Clara Flores',
#   'Tarjeta'),
#  (87,
#   datetime.date(2024, 1, 4),
#   'Detergente',
#   'Flores',
#   'Eduardo Medina',
#   'Tarjeta'),
#  (88,
#   datetime.date(2024, 1, 4),
#   'Queso',
#   'Guzmán',
#   'Jorge Ramírez',
#   'Tarjeta'),
#  (89,
#   datetime.date(2024, 1, 4),
#   'Pollo',
#   'Pérez',
#   'Patricia Castro',
#   'Tarjeta'),
#  (90,
#   datetime.date(2024, 1, 4),
#   'Desodorante',
#   'Hernández',
#   'Cristian Navarro',
#   'Tarjeta'),
#  (91,
#   datetime.date(2024, 1, 4),
#   'Esponjas',
#   'Castro',
#   'Gabriela Fernández',
#   'Tarjeta'),
#  (92,
#   datetime.date(2024, 1, 4),
#   'Tierra para macetas',
#   'Aguilar',
#   'Adriana López',
#   'Tarjeta'),
#  (93,
#   datetime.date(2024, 1, 4),
#   'Platos desechables',
#   'Campos',
#   'Miguel Molina',
#   'Tarjeta'),
#  (94,
#   datetime.date(2024, 1, 4),
#   'Zanahoria',
#   'Ramírez',
#   'Marta Santos',
#   'Tarjeta'),
#  (95,
#   datetime.date(2024, 1, 4),
#   'Champú',
#   'Navarro',
#   'Ana Navarro',
#   'Tarjeta'),
#  (96,
#   datetime.date(2024, 1, 4),
#   'Semillas',
#   'Ramos',
#   'Eduardo Moreno',
#   'Efectivo'),
#  (97,
#   datetime.date(2024, 1, 4),
#   'Pilas',
#   'Rubio',
#   'Cristian Velázquez',
#   'Tarjeta'),
#  (98,
#   datetime.date(2024, 1, 4),
#   'Desinfectante',
#   'Rodríguez',
#   'Ángel Ortiz',
#   'Tarjeta'),
#  (99,
#   datetime.date(2024, 1, 4),
#   'Fertilizante',
#   'Molina',
#   'Ricardo Campos',
#   'Tarjeta'),
#  (100, datetime.date(2024, 1, 4), 'Cerdo', 'Vázquez', 'José Díaz', 'Tarjeta'),
#  (101,
#   datetime.date(2024, 1, 4),
#   'Tomate',
#   'Flores',
#   'Pablo Navarro',
#   'Tarjeta'),
#  (102,
#   datetime.date(2024, 1, 4),
#   'Chocolate',
#   'Fuentes',
#   'David Montes',
#   'Efectivo'),
#  (103,
#   datetime.date(2024, 1, 4),
#   'Refresco',
#   'Pérez',
#   'Gabriela Salinas',
#   'Efectivo'),
#  (104,
#   datetime.date(2024, 1, 4),
#   'Semillas',
#   'Ramos',
#   'Natalia Campos',
#   'Tarjeta'),
#  (105, datetime.date(2024, 1, 4), 'Naranja', 'Pérez', 'Lucía Cruz', 'Tarjeta'),
#  (106,
#   datetime.date(2024, 1, 4),
#   'Chocolate',
#   'Chávez',
#   'Ricardo Campos',
#   'Tarjeta'),
#  (107,
#   datetime.date(2024, 1, 4),
#   'Detergente',
#   'Molina',
#   'Ana Navarro',
#   'Efectivo'),
#  (108,
#   datetime.date(2024, 1, 4),
#   'Semillas',
#   'Chávez',
#   'Lucía Ortiz',
#   'Tarjeta'),
#  (109,
#   datetime.date(2024, 1, 4),
#   'Esponjas',
#   'Medina',
#   'Camila Navarro',
#   'Efectivo'),
#  (110,
#   datetime.date(2024, 1, 4),
#   'Cerveza',
#   'Santos',
#   'Camila Campos',
#   'Tarjeta'),
#  (111,
#   datetime.date(2024, 1, 4),
#   'Tomate',
#   'López',
#   'Eduardo Moreno',
#   'Tarjeta'),
#  (112,
#   datetime.date(2024, 1, 5),
#   'Leche',
#   'Peña',
#   'Patricia Velázquez',
#   'Tarjeta'),
#  (113,
#   datetime.date(2024, 1, 5),
#   'Regadera',
#   'Moreno',
#   'Hugo Torres',
#   'Tarjeta'),
#  (114,
#   datetime.date(2024, 1, 5),
#   'Velas',
#   'Domínguez',
#   'Andrea López',
#   'Tarjeta'),
#  (115,
#   datetime.date(2024, 1, 5),
#   'Lechuga',
#   'Hernández',
#   'Tomás Ruiz',
#   'Tarjeta'),
#  (116,
#   datetime.date(2024, 1, 5),
#   'Cebolla',
#   'Esquivel',
#   'Clara Ramírez',
#   'Tarjeta'),
#  (117,
#   datetime.date(2024, 1, 5),
#   'Esponjas',
#   'Esquivel',
#   'Valeria Ruiz',
#   'Tarjeta'),
#  (118,
#   datetime.date(2024, 1, 5),
#   'Zanahoria',
#   'Flores',
#   'Cristian Navarro',
#   'Tarjeta'),
#  (119,
#   datetime.date(2024, 1, 5),
#   'Bolsas de basura',
#   'Fuentes',
#   'Miguel Ruiz',
#   'Efectivo'),
#  (120,
#   datetime.date(2024, 1, 5),
#   'Esponjas',
#   'Ramos',
#   'María Montes',
#   'Tarjeta'),
#  (121,
#   datetime.date(2024, 1, 5),
#   'Lechuga',
#   'Cabrera',
#   'Verónica Rubio',
#   'Efectivo'),
#  (122,
#   datetime.date(2024, 1, 5),
#   'Desinfectante',
#   'Díaz',
#   'David Vázquez',
#   'Tarjeta'),
#  (123,
#   datetime.date(2024, 1, 5),
#   'Regadera',
#   'Ruiz',
#   'Ángel Ortiz',
#   'Efectivo'),
#  (124,
#   datetime.date(2024, 1, 5),
#   'Pollo',
#   'Hernández',
#   'Daniel Paredes',
#   'Tarjeta'),
#  (125,
#   datetime.date(2024, 1, 5),
#   'Banana',
#   'Navarro',
#   'Laura Rubio',
#   'Tarjeta'),
#  (126,
#   datetime.date(2024, 1, 5),
#   'Jugo de naranja',
#   'Romero',
#   'Miguel Ruiz',
#   'Tarjeta'),
#  (127,
#   datetime.date(2024, 1, 5),
#   'Cerveza',
#   'Aguilar',
#   'Gabriela Salinas',
#   'Tarjeta'),
#  (128,
#   datetime.date(2024, 1, 5),
#   'Chicles',
#   'Cortés',
#   'Julia Rodríguez',
#   'Tarjeta'),
#  (129,
#   datetime.date(2024, 1, 5),
#   'Refresco',
#   'López',
#   'Eva Esquivel',
#   'Tarjeta'),
#  (130,
#   datetime.date(2024, 1, 5),
#   'Mantequilla',
#   'Medina',
#   'Raúl Rodríguez',
#   'Tarjeta'),
#  (131,
#   datetime.date(2024, 1, 5),
#   'Crema hidratante',
#   'Medina',
#   'Carmen Carrillo',
#   'Efectivo'),
#  (132,
#   datetime.date(2024, 1, 5),
#   'Manzana',
#   'Moreno',
#   'Cristian Navarro',
#   'Tarjeta'),
#  (133,
#   datetime.date(2024, 1, 5),
#   'Cerveza',
#   'Flores',
#   'Laura Salinas',
#   'Tarjeta'),
#  (134,
#   datetime.date(2024, 1, 5),
#   'Mantequilla',
#   'Ramírez',
#   'Eva Esquivel',
#   'Efectivo'),
#  (135,
#   datetime.date(2024, 1, 5),
#   'Desodorante',
#   'Moreno',
#   'Pablo Navarro',
#   'Tarjeta'),
#  (136,
#   datetime.date(2024, 1, 6),
#   'Banana',
#   'López',
#   'David Vázquez',
#   'Tarjeta'),
#  (137,
#   datetime.date(2024, 1, 6),
#   'Colonia',
#   'Serrano',
#   'Sofía Serrano',
#   'Tarjeta'),
#  (138,
#   datetime.date(2024, 1, 6),
#   'Cebolla',
#   'Guzmán',
#   'Patricia Castro',
#   'Efectivo'),
#  (139,
#   datetime.date(2024, 1, 6),
#   'Desinfectante',
#   'Rodríguez',
#   'Clara Navarro',
#   'Tarjeta'),
#  (140,
#   datetime.date(2024, 1, 6),
#   'Bolsas de basura',
#   'Fuentes',
#   'Daniel Paredes',
#   'Efectivo'),
#  (141,
#   datetime.date(2024, 1, 6),
#   'Refresco',
#   'Velázquez',
#   'Marta Campos',
#   'Efectivo'),
#  (142,
#   datetime.date(2024, 1, 6),
#   'Yogur',
#   'Serrano',
#   'Valeria Medina',
#   'Tarjeta'),
#  (143,
#   datetime.date(2024, 1, 6),
#   'Detergente',
#   'Martínez',
#   'Sergio Santos',
#   'Tarjeta'),
#  (144,
#   datetime.date(2024, 1, 6),
#   'Manzana',
#   'Aguilar',
#   'Carla Cabrera',
#   'Tarjeta'),
#  (145,
#   datetime.date(2024, 1, 6),
#   'Banana',
#   'Montes',
#   'Gabriela Fernández',
#   'Tarjeta'),
#  (146,
#   datetime.date(2024, 1, 6),
#   'Tierra para macetas',
#   'Sánchez',
#   'Andrea Chávez',
#   'Tarjeta'),
#  (147,
#   datetime.date(2024, 1, 6),
#   'Chuletas',
#   'Cruz',
#   'Valeria Medina',
#   'Efectivo'),
#  (148,
#   datetime.date(2024, 1, 6),
#   'Fertilizante',
#   'Medina',
#   'Mario Cortés',
#   'Tarjeta'),
#  (149,
#   datetime.date(2024, 1, 6),
#   'Mantequilla',
#   'Cortés',
#   'José Rodríguez',
#   'Efectivo'),
#  (150,
#   datetime.date(2024, 1, 6),
#   'Refresco',
#   'Méndez',
#   'Lucía Ortiz',
#   'Tarjeta'),
#  (151,
#   datetime.date(2024, 1, 6),
#   'Esponjas',
#   'Guzmán',
#   'Irene Delgado',
#   'Tarjeta'),
#  (152,
#   datetime.date(2024, 1, 6),
#   'Lechuga',
#   'Ramos',
#   'Clara Álvarez',
#   'Tarjeta'),
#  (153,
#   datetime.date(2024, 1, 6),
#   'Queso',
#   'Sánchez',
#   'José Rodríguez',
#   'Tarjeta'),
#  (154,
#   datetime.date(2024, 1, 6),
#   'Banana',
#   'Castro',
#   'Samuel Sánchez',
#   'Tarjeta'),
#  (155,
#   datetime.date(2024, 1, 6),
#   'Carne de res',
#   'Castro',
#   'María Paredes',
#   'Efectivo'),
#  (156, datetime.date(2024, 1, 6), 'Uva', 'Méndez', 'Andrea Chávez', 'Tarjeta'),
#  (157,
#   datetime.date(2024, 1, 6),
#   'Chicles',
#   'Cortés',
#   'Clara Flores',
#   'Tarjeta'),
#  (158,
#   datetime.date(2024, 1, 6),
#   'Lechuga',
#   'Castro',
#   'Samuel Paredes',
#   'Tarjeta'),
#  (159,
#   datetime.date(2024, 1, 6),
#   'Galletas',
#   'Salinas',
#   'Irene Ortiz',
#   'Tarjeta'),
#  (160,
#   datetime.date(2024, 1, 7),
#   'Detergente',
#   'Díaz',
#   'Valeria Ruiz',
#   'Tarjeta'),
#  (161,
#   datetime.date(2024, 1, 7),
#   'Fertilizante',
#   'Serrano',
#   'Natalia Reyes',
#   'Tarjeta'),
#  (162,
#   datetime.date(2024, 1, 7),
#   'Yogur',
#   'Guzmán',
#   'Miguel Molina',
#   'Tarjeta'),
#  (163,
#   datetime.date(2024, 1, 7),
#   'Lechuga',
#   'Romero',
#   'Raúl García',
#   'Efectivo'),
#  (164,
#   datetime.date(2024, 1, 7),
#   'Semillas',
#   'Chávez',
#   'Eduardo Díaz',
#   'Tarjeta'),
#  (165,
#   datetime.date(2024, 1, 7),
#   'Galletas',
#   'Velázquez',
#   'Clara Santos',
#   'Efectivo'),
#  (166, datetime.date(2024, 1, 7), 'Lechuga', 'Cruz', 'María Ruiz', 'Tarjeta'),
#  (167,
#   datetime.date(2024, 1, 7),
#   'Tierra para macetas',
#   'Sánchez',
#   'Alejandro Pérez',
#   'Tarjeta'),
#  (168,
#   datetime.date(2024, 1, 7),
#   'Champú',
#   'Ortiz',
#   'Carla Cabrera',
#   'Efectivo'),
#  (169,
#   datetime.date(2024, 1, 7),
#   'Desinfectante',
#   'Ramos',
#   'María Paredes',
#   'Efectivo'),
#  (170,
#   datetime.date(2024, 1, 7),
#   'Crema hidratante',
#   'Romero',
#   'Valeria Ruiz',
#   'Efectivo'),
#  (171,
#   datetime.date(2024, 1, 7),
#   'Desodorante',
#   'Domínguez',
#   'Verónica González',
#   'Tarjeta'),
#  (172,
#   datetime.date(2024, 1, 7),
#   'Cebolla',
#   'Castro',
#   'Andrés Guzmán',
#   'Tarjeta'),
#  (173,
#   datetime.date(2024, 1, 7),
#   'Detergente',
#   'Salinas',
#   'Carla Reyes',
#   'Tarjeta'),
#  (174,
#   datetime.date(2024, 1, 7),
#   'Detergente',
#   'Aguilar',
#   'Gabriela Cabrera',
#   'Tarjeta'),
#  (175,
#   datetime.date(2024, 1, 7),
#   'Desinfectante',
#   'Díaz',
#   'Gabriela Cabrera',
#   'Tarjeta'),
#  (176,
#   datetime.date(2024, 1, 7),
#   'Uva',
#   'Cabrera',
#   'Adriana Moreno',
#   'Tarjeta'),
#  (177,
#   datetime.date(2024, 1, 7),
#   'Chuletas',
#   'Díaz',
#   'Lorena Chávez',
#   'Efectivo'),
#  (178,
#   datetime.date(2024, 1, 7),
#   'Semillas',
#   'Torres',
#   'Patricia Castro',
#   'Efectivo'),
#  (179,
#   datetime.date(2024, 1, 7),
#   'Bolsas de basura',
#   'Cortés',
#   'Valeria Navarro',
#   'Tarjeta'),
#  (180,
#   datetime.date(2024, 1, 7),
#   'Refresco',
#   'Molina',
#   'María Paredes',
#   'Tarjeta'),
#  (181,
#   datetime.date(2024, 1, 7),
#   'Leche',
#   'Navarro',
#   'Rubén Fuentes',
#   'Tarjeta'),
#  (182,
#   datetime.date(2024, 1, 7),
#   'Yogur',
#   'Serrano',
#   'Marta Santos',
#   'Efectivo'),
#  (183,
#   datetime.date(2024, 1, 7),
#   'Banana',
#   'Domínguez',
#   'Cristian Navarro',
#   'Tarjeta'),
#  (184,
#   datetime.date(2024, 1, 7),
#   'Bolsas de basura',
#   'Aguilar',
#   'Francisco Cruz',
#   'Efectivo'),
#  (185,
#   datetime.date(2024, 1, 7),
#   'Naranja',
#   'Moreno',
#   'Laura Salinas',
#   'Tarjeta'),
#  (186,
#   datetime.date(2024, 1, 7),
#   'Fertilizante',
#   'Serrano',
#   'Gabriela Salinas',
#   'Efectivo'),
#  (187,
#   datetime.date(2024, 1, 8),
#   'Platos desechables',
#   'García',
#   'Eva Esquivel',
#   'Efectivo'),
#  (188,
#   datetime.date(2024, 1, 8),
#   'Zanahoria',
#   'Pérez',
#   'Andrés Castro',
#   'Tarjeta'),
#  (189,
#   datetime.date(2024, 1, 8),
#   'Jugo de naranja',
#   'Chávez',
#   'Diego Peña',
#   'Efectivo'),
#  (190,
#   datetime.date(2024, 1, 8),
#   'Detergente',
#   'Esquivel',
#   'Andrea Chávez',
#   'Efectivo'),
#  (191,
#   datetime.date(2024, 1, 8),
#   'Naranja',
#   'Delgado',
#   'Valeria Santos',
#   'Tarjeta'),
#  (192,
#   datetime.date(2024, 1, 8),
#   'Pollo',
#   'Álvarez',
#   'Valeria Salinas',
#   'Tarjeta'),
#  (193, datetime.date(2024, 1, 8), 'Uva', 'Torres', 'Valeria Ruiz', 'Efectivo'),
#  (194,
#   datetime.date(2024, 1, 8),
#   'Chuletas',
#   'Cruz',
#   'Sergio Delgado',
#   'Tarjeta'),
#  (195,
#   datetime.date(2024, 1, 8),
#   'Platos desechables',
#   'Moreno',
#   'Sofía Ortiz',
#   'Tarjeta'),
#  (196,
#   datetime.date(2024, 1, 8),
#   'Jugo de naranja',
#   'Esquivel',
#   'Clara Álvarez',
#   'Tarjeta'),
#  (197,
#   datetime.date(2024, 1, 8),
#   'Leche',
#   'Santos',
#   'Ricardo Jiménez',
#   'Tarjeta'),
#  (198,
#   datetime.date(2024, 1, 8),
#   'Chicles',
#   'Moreno',
#   'José Rodríguez',
#   'Tarjeta'),
#  (199, datetime.date(2024, 1, 8), 'Cerveza', 'Cruz', 'Diego Peña', 'Tarjeta'),
#  (200,
#   datetime.date(2024, 1, 8),
#   'Cebolla',
#   'Carrillo',
#   'Verónica Fernández',
#   'Efectivo'),
#  (201,
#   datetime.date(2024, 1, 8),
#   'Galletas',
#   'Ramos',
#   'Lucía Cruz',
#   'Efectivo'),
#  (202,
#   datetime.date(2024, 1, 8),
#   'Semillas',
#   'Paredes',
#   'Isabel Molina',
#   'Tarjeta'),
#  (203,
#   datetime.date(2024, 1, 8),
#   'Refresco',
#   'Jiménez',
#   'Verónica Fernández',
#   'Tarjeta'),
#  (204,
#   datetime.date(2024, 1, 8),
#   'Banana',
#   'Navarro',
#   'David Vázquez',
#   'Efectivo'),
#  (205,
#   datetime.date(2024, 1, 8),
#   'Galletas',
#   'Romero',
#   'Carla Cabrera',
#   'Tarjeta'),
#  (206,
#   datetime.date(2024, 1, 8),
#   'Desinfectante',
#   'Rodríguez',
#   'Ana Torres',
#   'Efectivo'),
#  (207,
#   datetime.date(2024, 1, 8),
#   'Crema hidratante',
#   'Delgado',
#   'Laura Santos',
#   'Tarjeta'),
#  (208,
#   datetime.date(2024, 1, 8),
#   'Yogur',
#   'Álvarez',
#   'Adriana López',
#   'Efectivo'),
#  (209,
#   datetime.date(2024, 1, 8),
#   'Lechuga',
#   'Cabrera',
#   'Camila Navarro',
#   'Tarjeta'),
#  (210,
#   datetime.date(2024, 1, 8),
#   'Pilas',
#   'Ortiz',
#   'Valeria Ruiz',
#   'Efectivo'),
#  (211,
#   datetime.date(2024, 1, 8),
#   'Detergente',
#   'Guzmán',
#   'Valeria Medina',
#   'Tarjeta'),
#  (212,
#   datetime.date(2024, 1, 8),
#   'Manzana',
#   'Hernández',
#   'Carla Lara',
#   'Efectivo'),
#  (213,
#   datetime.date(2024, 1, 8),
#   'Zanahoria',
#   'Jiménez',
#   'Verónica Lara',
#   'Efectivo'),
#  (214,
#   datetime.date(2024, 1, 8),
#   'Desinfectante',
#   'Vázquez',
#   'Lucía Molina',
#   'Tarjeta'),
#  (215,
#   datetime.date(2024, 1, 8),
#   'Semillas',
#   'Navarro',
#   'Gabriela Hernández',
#   'Tarjeta'),
#  (216,
#   datetime.date(2024, 1, 8),
#   'Lechuga',
#   'Sánchez',
#   'Julia Chávez',
#   'Efectivo'),
#  (217, datetime.date(2024, 1, 8), 'Banana', 'Cruz', 'Ángel Ortiz', 'Tarjeta'),
#  (218,
#   datetime.date(2024, 1, 8),
#   'Manzana',
#   'Aguilar',
#   'Irene Delgado',
#   'Tarjeta'),
#  (219,
#   datetime.date(2024, 1, 8),
#   'Tomate',
#   'Serrano',
#   'Lucía Cruz',
#   'Efectivo'),
#  (220,
#   datetime.date(2024, 1, 8),
#   'Naranja',
#   'Romero',
#   'Adriana Moreno',
#   'Tarjeta'),
#  (221, datetime.date(2024, 1, 8), 'Velas', 'Díaz', 'Ana Esquivel', 'Tarjeta'),
#  (222,
#   datetime.date(2024, 1, 9),
#   'Queso',
#   'Vázquez',
#   'Camila Navarro',
#   'Efectivo'),
#  (223,
#   datetime.date(2024, 1, 9),
#   'Naranja',
#   'Esquivel',
#   'Irene Delgado',
#   'Tarjeta'),
#  (224,
#   datetime.date(2024, 1, 9),
#   'Banana',
#   'Méndez',
#   'Gabriela Campos',
#   'Tarjeta'),
#  (225,
#   datetime.date(2024, 1, 9),
#   'Yogur',
#   'Paredes',
#   'Julia Chávez',
#   'Tarjeta'),
#  (226,
#   datetime.date(2024, 1, 9),
#   'Jugo de naranja',
#   'Moreno',
#   'Clara Santos',
#   'Tarjeta'),
#  (227,
#   datetime.date(2024, 1, 9),
#   'Papas fritas',
#   'Martínez',
#   'Natalia Reyes',
#   'Tarjeta'),
#  (228,
#   datetime.date(2024, 1, 9),
#   'Detergente',
#   'Chávez',
#   'Luis Montes',
#   'Efectivo'),
#  (229,
#   datetime.date(2024, 1, 9),
#   'Carne de res',
#   'González',
#   'Irene Delgado',
#   'Efectivo'),
#  (230,
#   datetime.date(2024, 1, 9),
#   'Colonia',
#   'Esquivel',
#   'Gabriela Cabrera',
#   'Tarjeta'),
#  (231,
#   datetime.date(2024, 1, 9),
#   'Tomate',
#   'Esquivel',
#   'Valeria Navarro',
#   'Tarjeta'),
#  (232,
#   datetime.date(2024, 1, 9),
#   'Chocolate',
#   'Chávez',
#   'Rubén Fuentes',
#   'Efectivo'),
#  (233, datetime.date(2024, 1, 9), 'Banana', 'Castro', 'Ana Torres', 'Tarjeta'),
#  (234,
#   datetime.date(2024, 1, 9),
#   'Mantequilla',
#   'Cruz',
#   'Luis Montes',
#   'Efectivo'),
#  (235,
#   datetime.date(2024, 1, 9),
#   'Champú',
#   'García',
#   'Ángel Carrillo',
#   'Efectivo'),
#  (236,
#   datetime.date(2024, 1, 9),
#   'Chicles',
#   'Ortiz',
#   'Ángel Ortiz',
#   'Efectivo'),
#  (237,
#   datetime.date(2024, 1, 9),
#   'Chocolate',
#   'Flores',
#   'Patricia Velázquez',
#   'Efectivo'),
#  (238,
#   datetime.date(2024, 1, 9),
#   'Naranja',
#   'Salinas',
#   'Julia Chávez',
#   'Efectivo'),
#  (239,
#   datetime.date(2024, 1, 9),
#   'Desinfectante',
#   'Vázquez',
#   'Samuel Velázquez',
#   'Tarjeta'),
#  (240,
#   datetime.date(2024, 1, 9),
#   'Cerdo',
#   'Romero',
#   'Gabriela Cabrera',
#   'Tarjeta'),
#  (241,
#   datetime.date(2024, 1, 9),
#   'Lechuga',
#   'Navarro',
#   'Eduardo Moreno',
#   'Tarjeta'),
#  (242,
#   datetime.date(2024, 1, 9),
#   'Tierra para macetas',
#   'Vázquez',
#   'Marta Santos',
#   'Tarjeta'),
#  (243,
#   datetime.date(2024, 1, 9),
#   'Uva',
#   'Cabrera',
#   'Julia Chávez',
#   'Efectivo'),
#  (244,
#   datetime.date(2024, 1, 9),
#   'Jabón líquido',
#   'Peña',
#   'Carlos Navarro',
#   'Efectivo'),
#  (245,
#   datetime.date(2024, 1, 9),
#   'Chocolate',
#   'Chávez',
#   'Valeria Santos',
#   'Tarjeta'),
#  (246,
#   datetime.date(2024, 1, 9),
#   'Manzana',
#   'Fernández',
#   'Lorena Chávez',
#   'Tarjeta'),
#  (247,
#   datetime.date(2024, 1, 10),
#   'Pilas',
#   'Reyes',
#   'Cristian Navarro',
#   'Efectivo'),
#  (248,
#   datetime.date(2024, 1, 10),
#   'Fertilizante',
#   'Vázquez',
#   'Miguel Sánchez',
#   'Tarjeta'),
#  (249,
#   datetime.date(2024, 1, 10),
#   'Chuletas',
#   'Domínguez',
#   'José Salinas',
#   'Tarjeta'),
#  (250,
#   datetime.date(2024, 1, 10),
#   'Crema hidratante',
#   'Ortiz',
#   'Valeria Ruiz',
#   'Efectivo'),
#  (251,
#   datetime.date(2024, 1, 10),
#   'Naranja',
#   'Navarro',
#   'María Ruiz',
#   'Tarjeta'),
#  (252,
#   datetime.date(2024, 1, 10),
#   'Galletas',
#   'González',
#   'Raúl García',
#   'Tarjeta'),
#  (253,
#   datetime.date(2024, 1, 10),
#   'Yogur',
#   'Torres',
#   'Gabriela Campos',
#   'Tarjeta'),
#  (254,
#   datetime.date(2024, 1, 10),
#   'Banana',
#   'Molina',
#   'Luis Montes',
#   'Efectivo'),
#  (255,
#   datetime.date(2024, 1, 10),
#   'Cerveza',
#   'Santos',
#   'Miguel Sánchez',
#   'Tarjeta'),
#  (256,
#   datetime.date(2024, 1, 10),
#   'Platos desechables',
#   'Salinas',
#   'Patricia Velázquez',
#   'Efectivo'),
#  (257,
#   datetime.date(2024, 1, 10),
#   'Tierra para macetas',
#   'Cruz',
#   'Carmen Carrillo',
#   'Tarjeta'),
#  (258,
#   datetime.date(2024, 1, 10),
#   'Cerdo',
#   'Méndez',
#   'Carlos Navarro',
#   'Tarjeta'),
#  (259,
#   datetime.date(2024, 1, 10),
#   'Cerveza',
#   'González',
#   'Samuel Sánchez',
#   'Tarjeta'),
#  (260,
#   datetime.date(2024, 1, 10),
#   'Lechuga',
#   'Salinas',
#   'Sergio Santos',
#   'Tarjeta'),
#  (261,
#   datetime.date(2024, 1, 10),
#   'Leche',
#   'Navarro',
#   'Raúl Rodríguez',
#   'Tarjeta'),
#  (262,
#   datetime.date(2024, 1, 10),
#   'Galletas',
#   'Castro',
#   'Lorena Chávez',
#   'Tarjeta'),
#  (263,
#   datetime.date(2024, 1, 10),
#   'Refresco',
#   'Velázquez',
#   'Andrés Guzmán',
#   'Tarjeta'),
#  (264,
#   datetime.date(2024, 1, 10),
#   'Velas',
#   'Pérez',
#   'Laura Rubio',
#   'Efectivo'),
#  (265,
#   datetime.date(2024, 1, 10),
#   'Cerdo',
#   'Ramírez',
#   'Verónica González',
#   'Tarjeta'),
#  (266,
#   datetime.date(2024, 1, 10),
#   'Agua',
#   'Medina',
#   'Sergio Delgado',
#   'Efectivo'),
#  (267,
#   datetime.date(2024, 1, 10),
#   'Cerveza',
#   'López',
#   'Valeria Salinas',
#   'Tarjeta'),
#  (268,
#   datetime.date(2024, 1, 10),
#   'Esponjas',
#   'Fuentes',
#   'Paula Cabrera',
#   'Tarjeta'),
#  (269,
#   datetime.date(2024, 1, 10),
#   'Regadera',
#   'Álvarez',
#   'Clara Ramírez',
#   'Efectivo'),
#  (270,
#   datetime.date(2024, 1, 10),
#   'Chicles',
#   'Cortés',
#   'David Vázquez',
#   'Tarjeta'),
#  (271, datetime.date(2024, 1, 10), 'Uva', 'Pérez', 'María Ruiz', 'Tarjeta'),
#  (272,
#   datetime.date(2024, 1, 10),
#   'Cerveza',
#   'Castro',
#   'Carmen Velázquez',
#   'Tarjeta'),
#  (273,
#   datetime.date(2024, 1, 10),
#   'Yogur',
#   'Medina',
#   'Luis Montes',
#   'Efectivo'),
#  (274,
#   datetime.date(2024, 1, 11),
#   'Uva',
#   'Paredes',
#   'Eduardo Moreno',
#   'Tarjeta'),
#  (275,
#   datetime.date(2024, 1, 11),
#   'Chocolate',
#   'Castro',
#   'David Vázquez',
#   'Tarjeta'),
#  (276,
#   datetime.date(2024, 1, 11),
#   'Detergente',
#   'Martínez',
#   'Marta Santos',
#   'Tarjeta'),
#  (277,
#   datetime.date(2024, 1, 11),
#   'Crema hidratante',
#   'Chávez',
#   'María Paredes',
#   'Tarjeta'),
#  (278,
#   datetime.date(2024, 1, 11),
#   'Chicles',
#   'Flores',
#   'Valeria Ramos',
#   'Tarjeta'),
#  (279,
#   datetime.date(2024, 1, 11),
#   'Uva',
#   'Ruiz',
#   'Cristian Velázquez',
#   'Efectivo'),
#  (280,
#   datetime.date(2024, 1, 11),
#   'Desinfectante',
#   'Fernández',
#   'Pablo Ortiz',
#   'Tarjeta'),
#  (281,
#   datetime.date(2024, 1, 11),
#   'Colonia',
#   'Navarro',
#   'Verónica Rubio',
#   'Tarjeta'),
#  (282,
#   datetime.date(2024, 1, 11),
#   'Naranja',
#   'Jiménez',
#   'Raúl Hernández',
#   'Efectivo'),
#  (283,
#   datetime.date(2024, 1, 11),
#   'Desinfectante',
#   'Fernández',
#   'Carmen Velázquez',
#   'Tarjeta'),
#  (284, datetime.date(2024, 1, 11), 'Queso', 'Lara', 'Samuel Díaz', 'Tarjeta'),
#  (285,
#   datetime.date(2024, 1, 11),
#   'Banana',
#   'Rodríguez',
#   'Andrés Guzmán',
#   'Tarjeta'),
#  (286,
#   datetime.date(2024, 1, 11),
#   'Tomate',
#   'Molina',
#   'Ana Navarro',
#   'Tarjeta'),
#  (287,
#   datetime.date(2024, 1, 11),
#   'Galletas',
#   'García',
#   'Verónica Rubio',
#   'Tarjeta'),
#  (288,
#   datetime.date(2024, 1, 11),
#   'Naranja',
#   'Pérez',
#   'Patricia Castro',
#   'Tarjeta'),
#  (289,
#   datetime.date(2024, 1, 11),
#   'Chocolate',
#   'Ortiz',
#   'Clara Santos',
#   'Efectivo'),
#  (290,
#   datetime.date(2024, 1, 11),
#   'Desodorante',
#   'Moreno',
#   'Sofía Ortiz',
#   'Tarjeta'),
#  (291,
#   datetime.date(2024, 1, 11),
#   'Chicles',
#   'Díaz',
#   'Pablo Navarro',
#   'Efectivo'),
#  (292,
#   datetime.date(2024, 1, 11),
#   'Lechuga',
#   'Guzmán',
#   'Miguel Chávez',
#   'Tarjeta'),
#  (293,
#   datetime.date(2024, 1, 11),
#   'Champú',
#   'Chávez',
#   'Verónica Rubio',
#   'Efectivo'),
#  (294,
#   datetime.date(2024, 1, 11),
#   'Mantequilla',
#   'Moreno',
#   'Miguel Molina',
#   'Tarjeta'),
#  (295,
#   datetime.date(2024, 1, 11),
#   'Semillas',
#   'Ortiz',
#   'Lucía Molina',
#   'Tarjeta'),
#  (296,
#   datetime.date(2024, 1, 11),
#   'Fertilizante',
#   'Rubio',
#   'Laura Peña',
#   'Tarjeta'),
#  (297,
#   datetime.date(2024, 1, 11),
#   'Semillas',
#   'Campos',
#   'Pablo Ortiz',
#   'Efectivo'),
#  (298,
#   datetime.date(2024, 1, 12),
#   'Cerdo',
#   'Aguilar',
#   'Laura Peña',
#   'Tarjeta'),
#  (299,
#   datetime.date(2024, 1, 12),
#   'Mantequilla',
#   'Santos',
#   'Luis Montes',
#   'Tarjeta'),
#  (300,
#   datetime.date(2024, 1, 12),
#   'Velas',
#   'Domínguez',
#   'Hugo Moreno',
#   'Tarjeta'),
#  (301,
#   datetime.date(2024, 1, 12),
#   'Crema hidratante',
#   'Pérez',
#   'Patricia Castro',
#   'Tarjeta'),
#  (302,
#   datetime.date(2024, 1, 12),
#   'Tomate',
#   'Ortiz',
#   'Julia Rodríguez',
#   'Tarjeta'),
#  (303,
#   datetime.date(2024, 1, 12),
#   'Tomate',
#   'Sánchez',
#   'Cristian Velázquez',
#   'Tarjeta'),
#  (304,
#   datetime.date(2024, 1, 12),
#   'Velas',
#   'Ortiz',
#   'Sergio Santos',
#   'Tarjeta'),
#  (305,
#   datetime.date(2024, 1, 12),
#   'Crema hidratante',
#   'Lara',
#   'Lucía Cruz',
#   'Efectivo'),
#  (306,
#   datetime.date(2024, 1, 12),
#   'Desinfectante',
#   'Méndez',
#   'Gabriela Cabrera',
#   'Tarjeta'),
#  (307,
#   datetime.date(2024, 1, 12),
#   'Platos desechables',
#   'Guzmán',
#   'Valeria Ruiz',
#   'Efectivo'),
#  (308,
#   datetime.date(2024, 1, 12),
#   'Tomate',
#   'Lara',
#   'Cristian Navarro',
#   'Tarjeta'),
#  (309,
#   datetime.date(2024, 1, 12),
#   'Cerveza',
#   'Cruz',
#   'Rubén Castro',
#   'Tarjeta'),
#  (310,
#   datetime.date(2024, 1, 12),
#   'Zanahoria',
#   'Torres',
#   'Andrés Castro',
#   'Tarjeta'),
#  (311,
#   datetime.date(2024, 1, 12),
#   'Crema hidratante',
#   'Martínez',
#   'Irene Ortiz',
#   'Tarjeta'),
#  (312,
#   datetime.date(2024, 1, 12),
#   'Jugo de naranja',
#   'Ortiz',
#   'Valeria Salinas',
#   'Tarjeta'),
#  (313,
#   datetime.date(2024, 1, 12),
#   'Naranja',
#   'Cabrera',
#   'Cristian Velázquez',
#   'Efectivo'),
#  (314,
#   datetime.date(2024, 1, 12),
#   'Bolsas de basura',
#   'Serrano',
#   'Ángel Flores',
#   'Tarjeta'),
#  (315,
#   datetime.date(2024, 1, 12),
#   'Refresco',
#   'Jiménez',
#   'Elena Guzmán',
#   'Tarjeta'),
#  (316,
#   datetime.date(2024, 1, 12),
#   'Chuletas',
#   'Hernández',
#   'Clara Álvarez',
#   'Efectivo'),
#  (317,
#   datetime.date(2024, 1, 12),
#   'Jabón líquido',
#   'Esquivel',
#   'Laura Reyes',
#   'Tarjeta'),
#  (318,
#   datetime.date(2024, 1, 12),
#   'Banana',
#   'Domínguez',
#   'Ana Navarro',
#   'Tarjeta'),
#  (319,
#   datetime.date(2024, 1, 12),
#   'Naranja',
#   'Reyes',
#   'Samuel Díaz',
#   'Tarjeta'),
#  (320,
#   datetime.date(2024, 1, 12),
#   'Cerdo',
#   'Aguilar',
#   'Natalia Campos',
#   'Tarjeta'),
#  (321,
#   datetime.date(2024, 1, 12),
#   'Detergente',
#   'Rodríguez',
#   'Isabel Molina',
#   'Efectivo'),
#  (322,
#   datetime.date(2024, 1, 13),
#   'Pilas',
#   'Santos',
#   'Hugo Moreno',
#   'Tarjeta'),
#  (323,
#   datetime.date(2024, 1, 13),
#   'Galletas',
#   'Chávez',
#   'Andrea Chávez',
#   'Tarjeta'),
#  (324,
#   datetime.date(2024, 1, 13),
#   'Bolsas de basura',
#   'Guzmán',
#   'Raúl Rodríguez',
#   'Efectivo'),
#  (325,
#   datetime.date(2024, 1, 13),
#   'Chicles',
#   'Cortés',
#   'David Montes',
#   'Efectivo'),
#  (326,
#   datetime.date(2024, 1, 13),
#   'Papas fritas',
#   'Campos',
#   'Gabriela Campos',
#   'Efectivo'),
#  (327,
#   datetime.date(2024, 1, 13),
#   'Pilas',
#   'García',
#   'Camila Campos',
#   'Tarjeta'),
#  (328,
#   datetime.date(2024, 1, 13),
#   'Tomate',
#   'Esquivel',
#   'Eduardo Ramos',
#   'Tarjeta'),
#  (329,
#   datetime.date(2024, 1, 13),
#   'Bolsas de basura',
#   'Ramírez',
#   'Andrea Díaz',
#   'Efectivo'),
#  (330,
#   datetime.date(2024, 1, 13),
#   'Chocolate',
#   'Fernández',
#   'Sofía Serrano',
#   'Tarjeta'),
#  (331,
#   datetime.date(2024, 1, 13),
#   'Manzana',
#   'Reyes',
#   'Cristian Velázquez',
#   'Tarjeta'),
#  (332,
#   datetime.date(2024, 1, 13),
#   'Cerdo',
#   'Sánchez',
#   'Laura Rubio',
#   'Tarjeta'),
#  (333,
#   datetime.date(2024, 1, 13),
#   'Tierra para macetas',
#   'Ramírez',
#   'Natalia Campos',
#   'Tarjeta'),
#  (334,
#   datetime.date(2024, 1, 13),
#   'Zanahoria',
#   'Lara',
#   'Carlos Rodríguez',
#   'Efectivo'),
#  (335,
#   datetime.date(2024, 1, 13),
#   'Regadera',
#   'Navarro',
#   'Marta Santos',
#   'Tarjeta'),
#  (336,
#   datetime.date(2024, 1, 13),
#   'Pilas',
#   'Rubio',
#   'Daniel Paredes',
#   'Efectivo'),
#  (337,
#   datetime.date(2024, 1, 13),
#   'Zanahoria',
#   'Lara',
#   'Daniel Vázquez',
#   'Tarjeta'),
#  (338,
#   datetime.date(2024, 1, 13),
#   'Crema hidratante',
#   'González',
#   'Clara Álvarez',
#   'Efectivo'),
#  (339,
#   datetime.date(2024, 1, 13),
#   'Manzana',
#   'Jiménez',
#   'Irene Paredes',
#   'Tarjeta'),
#  (340,
#   datetime.date(2024, 1, 13),
#   'Naranja',
#   'Ruiz',
#   'Clara Paredes',
#   'Tarjeta'),
#  (341,
#   datetime.date(2024, 1, 13),
#   'Manzana',
#   'Ortiz',
#   'Cristian Navarro',
#   'Tarjeta'),
#  (342,
#   datetime.date(2024, 1, 13),
#   'Mantequilla',
#   'Ramírez',
#   'Adriana Moreno',
#   'Efectivo'),
#  (343,
#   datetime.date(2024, 1, 13),
#   'Detergente',
#   'Martínez',
#   'Lucía Ortiz',
#   'Tarjeta'),
#  (344,
#   datetime.date(2024, 1, 13),
#   'Tomate',
#   'Serrano',
#   'Sara Cabrera',
#   'Tarjeta'),
#  (345,
#   datetime.date(2024, 1, 14),
#   'Semillas',
#   'Domínguez',
#   'Verónica González',
#   'Efectivo'),
#  (346,
#   datetime.date(2024, 1, 14),
#   'Leche',
#   'Fernández',
#   'Carlos Rodríguez',
#   'Tarjeta'),
#  (347,
#   datetime.date(2024, 1, 14),
#   'Semillas',
#   'Rubio',
#   'Carlos Rodríguez',
#   'Tarjeta'),
#  (348,
#   datetime.date(2024, 1, 14),
#   'Carne de res',
#   'Sánchez',
#   'Daniel Velázquez',
#   'Efectivo'),
#  (349,
#   datetime.date(2024, 1, 14),
#   'Tomate',
#   'Méndez',
#   'Natalia Campos',
#   'Efectivo'),
#  (350, datetime.date(2024, 1, 14), 'Uva', 'López', 'Laura Salinas', 'Tarjeta'),
#  (351,
#   datetime.date(2024, 1, 14),
#   'Pilas',
#   'Romero',
#   'Carmen Carrillo',
#   'Tarjeta'),
#  (352,
#   datetime.date(2024, 1, 14),
#   'Crema hidratante',
#   'Ramírez',
#   'Ricardo Reyes',
#   'Tarjeta'),
#  (353,
#   datetime.date(2024, 1, 14),
#   'Semillas',
#   'Díaz',
#   'Marta Santos',
#   'Tarjeta'),
#  (354,
#   datetime.date(2024, 1, 14),
#   'Leche',
#   'Chávez',
#   'Paula Cabrera',
#   'Efectivo'),
#  (355,
#   datetime.date(2024, 1, 14),
#   'Desinfectante',
#   'Flores',
#   'Eduardo Moreno',
#   'Efectivo'),
#  (356,
#   datetime.date(2024, 1, 14),
#   'Cebolla',
#   'Moreno',
#   'Samuel Ramírez',
#   'Tarjeta'),
#  (357,
#   datetime.date(2024, 1, 14),
#   'Cebolla',
#   'Guzmán',
#   'Lorena Chávez',
#   'Tarjeta'),
#  (358,
#   datetime.date(2024, 1, 14),
#   'Lechuga',
#   'Salinas',
#   'Daniel Vázquez',
#   'Tarjeta'),
#  (359,
#   datetime.date(2024, 1, 14),
#   'Carne de res',
#   'Peña',
#   'Ana Navarro',
#   'Tarjeta'),
#  (360,
#   datetime.date(2024, 1, 14),
#   'Zanahoria',
#   'Ramos',
#   'Patricia Castro',
#   'Tarjeta'),
#  (361,
#   datetime.date(2024, 1, 14),
#   'Velas',
#   'Rodríguez',
#   'Carmen Velázquez',
#   'Tarjeta'),
#  (362,
#   datetime.date(2024, 1, 14),
#   'Yogur',
#   'Chávez',
#   'Fernando Castro',
#   'Tarjeta'),
#  (363,
#   datetime.date(2024, 1, 14),
#   'Cerveza',
#   'Navarro',
#   'José Díaz',
#   'Tarjeta'),
#  (364,
#   datetime.date(2024, 1, 14),
#   'Tomate',
#   'García',
#   'Pablo Navarro',
#   'Tarjeta'),
#  (365,
#   datetime.date(2024, 1, 14),
#   'Chocolate',
#   'Molina',
#   'Gabriela Hernández',
#   'Tarjeta'),
#  (366, datetime.date(2024, 1, 14), 'Uva', 'Ramos', 'Jorge Pérez', 'Tarjeta'),
#  (367,
#   datetime.date(2024, 1, 14),
#   'Queso',
#   'Fernández',
#   'Clara Flores',
#   'Tarjeta'),
#  (368,
#   datetime.date(2024, 1, 15),
#   'Chicles',
#   'Méndez',
#   'Laura Reyes',
#   'Tarjeta'),
#  (369,
#   datetime.date(2024, 1, 15),
#   'Agua',
#   'Sánchez',
#   'Clara Santos',
#   'Efectivo'),
#  (370,
#   datetime.date(2024, 1, 15),
#   'Chicles',
#   'Ortiz',
#   'Samuel Díaz',
#   'Tarjeta'),
#  (371,
#   datetime.date(2024, 1, 15),
#   'Uva',
#   'Castro',
#   'Jorge Ramírez',
#   'Efectivo'),
#  (372,
#   datetime.date(2024, 1, 15),
#   'Uva',
#   'Martínez',
#   'Andrea López',
#   'Tarjeta'),
#  (373,
#   datetime.date(2024, 1, 15),
#   'Zanahoria',
#   'Aguilar',
#   'Ricardo Campos',
#   'Tarjeta'),
#  (374,
#   datetime.date(2024, 1, 15),
#   'Champú',
#   'Fuentes',
#   'Carmen Carrillo',
#   'Efectivo'),
#  (375,
#   datetime.date(2024, 1, 15),
#   'Detergente',
#   'Rubio',
#   'Miguel Chávez',
#   'Efectivo'),
#  (376,
#   datetime.date(2024, 1, 15),
#   'Chuletas',
#   'López',
#   'Eduardo Méndez',
#   'Efectivo'),
#  (377,
#   datetime.date(2024, 1, 15),
#   'Zanahoria',
#   'Jiménez',
#   'Eva Peña',
#   'Efectivo'),
#  (378,
#   datetime.date(2024, 1, 15),
#   'Tierra para macetas',
#   'Montes',
#   'María Paredes',
#   'Tarjeta'),
#  (379,
#   datetime.date(2024, 1, 15),
#   'Queso',
#   'Serrano',
#   'Ana Navarro',
#   'Tarjeta'),
#  (380,
#   datetime.date(2024, 1, 15),
#   'Jabón líquido',
#   'Castro',
#   'Valeria Medina',
#   'Tarjeta'),
#  (381,
#   datetime.date(2024, 1, 15),
#   'Tierra para macetas',
#   'Velázquez',
#   'Miguel Chávez',
#   'Efectivo'),
#  (382,
#   datetime.date(2024, 1, 15),
#   'Esponjas',
#   'Martínez',
#   'Clara Santos',
#   'Tarjeta'),
#  (383,
#   datetime.date(2024, 1, 15),
#   'Tomate',
#   'Delgado',
#   'Verónica Fernández',
#   'Efectivo'),
#  (384,
#   datetime.date(2024, 1, 15),
#   'Semillas',
#   'Rubio',
#   'José Salinas',
#   'Tarjeta'),
#  (385,
#   datetime.date(2024, 1, 15),
#   'Queso',
#   'Méndez',
#   'Valeria Salinas',
#   'Tarjeta'),
#  (386,
#   datetime.date(2024, 1, 15),
#   'Tierra para macetas',
#   'Vázquez',
#   'Gabriela Campos',
#   'Efectivo'),
#  (387,
#   datetime.date(2024, 1, 15),
#   'Champú',
#   'Santos',
#   'Miguel Sánchez',
#   'Efectivo'),
#  (388,
#   datetime.date(2024, 1, 15),
#   'Chuletas',
#   'Peña',
#   'Gabriela Cabrera',
#   'Efectivo'),
#  (389,
#   datetime.date(2024, 1, 15),
#   'Desodorante',
#   'Medina',
#   'Ana Navarro',
#   'Tarjeta'),
#  (390,
#   datetime.date(2024, 1, 15),
#   'Chuletas',
#   'Flores',
#   'Gabriela Campos',
#   'Tarjeta'),
#  (391,
#   datetime.date(2024, 1, 15),
#   'Queso',
#   'Fuentes',
#   'Andrea Paredes',
#   'Tarjeta'),
#  (392,
#   datetime.date(2024, 1, 15),
#   'Yogur',
#   'Cabrera',
#   'Eduardo Díaz',
#   'Tarjeta'),
#  (393,
#   datetime.date(2024, 1, 15),
#   'Zanahoria',
#   'Romero',
#   'Paula Cabrera',
#   'Efectivo'),
#  (394,
#   datetime.date(2024, 1, 16),
#   'Pilas',
#   'Delgado',
#   'Miguel Molina',
#   'Efectivo'),
#  (395,
#   datetime.date(2024, 1, 16),
#   'Cerveza',
#   'Flores',
#   'Jorge Pérez',
#   'Tarjeta'),
#  (396,
#   datetime.date(2024, 1, 16),
#   'Jugo de naranja',
#   'Molina',
#   'Irene Ortiz',
#   'Tarjeta'),
#  (397,
#   datetime.date(2024, 1, 16),
#   'Chocolate',
#   'Flores',
#   'Jorge Ramírez',
#   'Efectivo'),
#  (398,
#   datetime.date(2024, 1, 16),
#   'Manzana',
#   'Jiménez',
#   'Lucía Molina',
#   'Efectivo'),
#  (399,
#   datetime.date(2024, 1, 16),
#   'Papas fritas',
#   'Ramos',
#   'Julia Chávez',
#   'Tarjeta'),
#  (400,
#   datetime.date(2024, 1, 16),
#   'Queso',
#   'Salinas',
#   'Samuel Velázquez',
#   'Tarjeta'),
#  (401,
#   datetime.date(2024, 1, 16),
#   'Cebolla',
#   'Romero',
#   'Raúl Hernández',
#   'Tarjeta'),
#  (402,
#   datetime.date(2024, 1, 16),
#   'Pollo',
#   'Torres',
#   'Francisco Cruz',
#   'Tarjeta'),
#  (403,
#   datetime.date(2024, 1, 16),
#   'Detergente',
#   'Domínguez',
#   'Clara Paredes',
#   'Tarjeta'),
#  (404,
#   datetime.date(2024, 1, 16),
#   'Chuletas',
#   'Domínguez',
#   'Clara Santos',
#   'Tarjeta'),
#  (405,
#   datetime.date(2024, 1, 16),
#   'Cerdo',
#   'Jiménez',
#   'Irene Paredes',
#   'Tarjeta'),
#  (406,
#   datetime.date(2024, 1, 16),
#   'Detergente',
#   'Sánchez',
#   'Patricia Castro',
#   'Tarjeta'),
#  (407,
#   datetime.date(2024, 1, 16),
#   'Carne de res',
#   'García',
#   'Carla Lara',
#   'Tarjeta'),
#  (408,
#   datetime.date(2024, 1, 16),
#   'Tomate',
#   'Cabrera',
#   'Verónica Rubio',
#   'Efectivo'),
#  (409,
#   datetime.date(2024, 1, 16),
#   'Detergente',
#   'Torres',
#   'Ana Esquivel',
#   'Tarjeta'),
#  (410,
#   datetime.date(2024, 1, 16),
#   'Galletas',
#   'Montes',
#   'Gabriela Campos',
#   'Tarjeta'),
#  (411,
#   datetime.date(2024, 1, 16),
#   'Colonia',
#   'Serrano',
#   'Clara Paredes',
#   'Tarjeta'),
#  (412,
#   datetime.date(2024, 1, 16),
#   'Mantequilla',
#   'Álvarez',
#   'Miguel Molina',
#   'Tarjeta'),
#  (413,
#   datetime.date(2024, 1, 16),
#   'Chocolate',
#   'Martínez',
#   'Andrea López',
#   'Tarjeta'),
#  (414,
#   datetime.date(2024, 1, 16),
#   'Mantequilla',
#   'Cruz',
#   'Eduardo Ramos',
#   'Tarjeta'),
#  (415,
#   datetime.date(2024, 1, 17),
#   'Queso',
#   'Torres',
#   'Marta Santos',
#   'Tarjeta'),
#  (416,
#   datetime.date(2024, 1, 17),
#   'Regadera',
#   'García',
#   'Ángel Ortiz',
#   'Tarjeta'),
#  (417,
#   datetime.date(2024, 1, 17),
#   'Pollo',
#   'Paredes',
#   'Clara Álvarez',
#   'Tarjeta'),
#  (418,
#   datetime.date(2024, 1, 17),
#   'Papas fritas',
#   'Romero',
#   'Irene Ortiz',
#   'Tarjeta'),
#  (419,
#   datetime.date(2024, 1, 17),
#   'Lechuga',
#   'Cruz',
#   'Julia Rodríguez',
#   'Efectivo'),
#  (420,
#   datetime.date(2024, 1, 17),
#   'Detergente',
#   'Martínez',
#   'Ángel Ortiz',
#   'Tarjeta'),
#  (421,
#   datetime.date(2024, 1, 17),
#   'Cerveza',
#   'González',
#   'Adriana Guzmán',
#   'Tarjeta'),
#  (422,
#   datetime.date(2024, 1, 17),
#   'Bolsas de basura',
#   'Esquivel',
#   'Adriana López',
#   'Efectivo'),
#  (423,
#   datetime.date(2024, 1, 17),
#   'Carne de res',
#   'Díaz',
#   'Irene Ortiz',
#   'Tarjeta'),
#  (424,
#   datetime.date(2024, 1, 17),
#   'Uva',
#   'Fuentes',
#   'Ángel Carrillo',
#   'Efectivo'),
#  (425,
#   datetime.date(2024, 1, 17),
#   'Queso',
#   'Santos',
#   'Valeria Santos',
#   'Tarjeta'),
#  (426,
#   datetime.date(2024, 1, 17),
#   'Champú',
#   'Velázquez',
#   'Gabriela Campos',
#   'Efectivo'),
#  (427,
#   datetime.date(2024, 1, 17),
#   'Esponjas',
#   'Romero',
#   'Ángel Ortiz',
#   'Tarjeta'),
#  (428,
#   datetime.date(2024, 1, 17),
#   'Crema hidratante',
#   'Martínez',
#   'Clara Álvarez',
#   'Efectivo'),
#  (429,
#   datetime.date(2024, 1, 17),
#   'Chuletas',
#   'Torres',
#   'Camila Navarro',
#   'Tarjeta'),
#  (430,
#   datetime.date(2024, 1, 17),
#   'Chicles',
#   'Flores',
#   'Cristian Navarro',
#   'Tarjeta'),
#  (431,
#   datetime.date(2024, 1, 17),
#   'Pilas',
#   'Santos',
#   'Eduardo Díaz',
#   'Efectivo'),
#  (432,
#   datetime.date(2024, 1, 17),
#   'Jugo de naranja',
#   'Rodríguez',
#   'Raúl Rodríguez',
#   'Tarjeta'),
#  (433,
#   datetime.date(2024, 1, 17),
#   'Chicles',
#   'Aguilar',
#   'Valeria Santos',
#   'Tarjeta'),
#  (434,
#   datetime.date(2024, 1, 17),
#   'Galletas',
#   'Ruiz',
#   'Carmen Carrillo',
#   'Tarjeta'),
#  (435,
#   datetime.date(2024, 1, 17),
#   'Pollo',
#   'Ramírez',
#   'Miguel Sánchez',
#   'Efectivo'),
#  (436,
#   datetime.date(2024, 1, 17),
#   'Naranja',
#   'Serrano',
#   'Andrés Castro',
#   'Tarjeta'),
#  (437,
#   datetime.date(2024, 1, 18),
#   'Cerveza',
#   'Ruiz',
#   'José Rodríguez',
#   'Tarjeta'),
#  (438,
#   datetime.date(2024, 1, 18),
#   'Detergente',
#   'Díaz',
#   'Daniel Vázquez',
#   'Tarjeta'),
#  (439,
#   datetime.date(2024, 1, 18),
#   'Tierra para macetas',
#   'Fernández',
#   'Irene Ortiz',
#   'Tarjeta'),
#  (440,
#   datetime.date(2024, 1, 18),
#   'Bolsas de basura',
#   'Carrillo',
#   'José Salinas',
#   'Efectivo'),
#  (441,
#   datetime.date(2024, 1, 18),
#   'Pilas',
#   'Ramos',
#   'Daniel Paredes',
#   'Efectivo'),
#  (442,
#   datetime.date(2024, 1, 18),
#   'Chicles',
#   'Rodríguez',
#   'Carla Reyes',
#   'Efectivo'),
#  (443,
#   datetime.date(2024, 1, 18),
#   'Uva',
#   'Fuentes',
#   'Fernando Castro',
#   'Efectivo'),
#  (444,
#   datetime.date(2024, 1, 18),
#   'Pollo',
#   'Rodríguez',
#   'Carla Lara',
#   'Tarjeta'),
#  (445,
#   datetime.date(2024, 1, 18),
#   'Platos desechables',
#   'Vázquez',
#   'Eduardo Medina',
#   'Efectivo'),
#  (446,
#   datetime.date(2024, 1, 18),
#   'Yogur',
#   'Castro',
#   'Cristian Velázquez',
#   'Tarjeta'),
#  (447,
#   datetime.date(2024, 1, 18),
#   'Desodorante',
#   'Domínguez',
#   'Ana Navarro',
#   'Tarjeta'),
#  (448,
#   datetime.date(2024, 1, 18),
#   'Desinfectante',
#   'Campos',
#   'Julia Rodríguez',
#   'Efectivo'),
#  (449,
#   datetime.date(2024, 1, 18),
#   'Carne de res',
#   'Flores',
#   'Sofía Serrano',
#   'Tarjeta'),
#  (450,
#   datetime.date(2024, 1, 18),
#   'Cerveza',
#   'Fernández',
#   'Sergio Delgado',
#   'Efectivo'),
#  (451,
#   datetime.date(2024, 1, 18),
#   'Tierra para macetas',
#   'Moreno',
#   'María Aguilar',
#   'Tarjeta'),
#  (452,
#   datetime.date(2024, 1, 18),
#   'Chicles',
#   'Serrano',
#   'Gabriela Salinas',
#   'Tarjeta'),
#  (453,
#   datetime.date(2024, 1, 18),
#   'Naranja',
#   'Fernández',
#   'Valeria Ruiz',
#   'Tarjeta'),
#  (454,
#   datetime.date(2024, 1, 18),
#   'Detergente',
#   'Ramírez',
#   'Jorge Ruiz',
#   'Tarjeta'),
#  (455,
#   datetime.date(2024, 1, 18),
#   'Manzana',
#   'Esquivel',
#   'Daniel Paredes',
#   'Tarjeta'),
#  (456,
#   datetime.date(2024, 1, 18),
#   'Tomate',
#   'Delgado',
#   'Camila Navarro',
#   'Tarjeta'),
#  (457,
#   datetime.date(2024, 1, 18),
#   'Lechuga',
#   'López',
#   'Pablo Ortiz',
#   'Tarjeta'),
#  (458,
#   datetime.date(2024, 1, 18),
#   'Cerdo',
#   'Fuentes',
#   'Valeria Ruiz',
#   'Tarjeta'),
#  (459,
#   datetime.date(2024, 1, 18),
#   'Papas fritas',
#   'Álvarez',
#   'Carla Martínez',
#   'Tarjeta'),
#  (460,
#   datetime.date(2024, 1, 18),
#   'Uva',
#   'Fuentes',
#   'María Aguilar',
#   'Efectivo'),
#  (461,
#   datetime.date(2024, 1, 19),
#   'Desodorante',
#   'Martínez',
#   'José Díaz',
#   'Efectivo'),
#  (462,
#   datetime.date(2024, 1, 19),
#   'Champú',
#   'Campos',
#   'Gabriela Cabrera',
#   'Tarjeta'),
#  (463,
#   datetime.date(2024, 1, 19),
#   'Bolsas de basura',
#   'Cortés',
#   'Tomás Ruiz',
#   'Tarjeta'),
#  (464,
#   datetime.date(2024, 1, 19),
#   'Desinfectante',
#   'Salinas',
#   'Jorge Pérez',
#   'Tarjeta'),
#  (465,
#   datetime.date(2024, 1, 19),
#   'Champú',
#   'Cabrera',
#   'Carla Cabrera',
#   'Tarjeta'),
#  (466,
#   datetime.date(2024, 1, 19),
#   'Tierra para macetas',
#   'Salinas',
#   'Miguel Ruiz',
#   'Tarjeta'),
#  (467,
#   datetime.date(2024, 1, 19),
#   'Yogur',
#   'Jiménez',
#   'Natalia Reyes',
#   'Efectivo'),
#  (468,
#   datetime.date(2024, 1, 19),
#   'Champú',
#   'Fernández',
#   'Eduardo Méndez',
#   'Efectivo'),
#  (469,
#   datetime.date(2024, 1, 19),
#   'Banana',
#   'Paredes',
#   'Clara Paredes',
#   'Efectivo'),
#  (470,
#   datetime.date(2024, 1, 19),
#   'Papas fritas',
#   'Cabrera',
#   'Irene Paredes',
#   'Tarjeta'),
#  (471,
#   datetime.date(2024, 1, 19),
#   'Banana',
#   'Domínguez',
#   'Carmen Carrillo',
#   'Efectivo'),
#  (472,
#   datetime.date(2024, 1, 19),
#   'Desodorante',
#   'Romero',
#   'Lucía Molina',
#   'Tarjeta'),
#  (473,
#   datetime.date(2024, 1, 19),
#   'Bolsas de basura',
#   'Guzmán',
#   'Camila Campos',
#   'Efectivo'),
#  (474,
#   datetime.date(2024, 1, 19),
#   'Esponjas',
#   'Esquivel',
#   'Patricia Lara',
#   'Tarjeta'),
#  (475,
#   datetime.date(2024, 1, 19),
#   'Mantequilla',
#   'Moreno',
#   'Diego Peña',
#   'Efectivo'),
#  (476,
#   datetime.date(2024, 1, 19),
#   'Pilas',
#   'Flores',
#   'Camila Campos',
#   'Efectivo'),
#  (477,
#   datetime.date(2024, 1, 19),
#   'Chicles',
#   'Cortés',
#   'Valeria Salinas',
#   'Tarjeta'),
#  (478,
#   datetime.date(2024, 1, 19),
#   'Leche',
#   'Ortiz',
#   'Elena Guzmán',
#   'Tarjeta'),
#  (479,
#   datetime.date(2024, 1, 19),
#   'Champú',
#   'Fernández',
#   'Valeria Ramos',
#   'Efectivo'),
#  (480,
#   datetime.date(2024, 1, 19),
#   'Agua',
#   'Reyes',
#   'María Paredes',
#   'Tarjeta'),
#  (481,
#   datetime.date(2024, 1, 19),
#   'Queso',
#   'Reyes',
#   'Andrea López',
#   'Tarjeta'),
#  (482,
#   datetime.date(2024, 1, 19),
#   'Desodorante',
#   'Romero',
#   'Adriana López',
#   'Efectivo'),
#  (483,
#   datetime.date(2024, 1, 19),
#   'Chicles',
#   'Ortiz',
#   'Eva Esquivel',
#   'Tarjeta'),
#  (484,
#   datetime.date(2024, 1, 19),
#   'Tierra para macetas',
#   'Velázquez',
#   'Sergio Delgado',
#   'Tarjeta'),
#  (485,
#   datetime.date(2024, 1, 19),
#   'Chicles',
#   'Delgado',
#   'Marta Santos',
#   'Efectivo'),
#  (486,
#   datetime.date(2024, 1, 20),
#   'Platos desechables',
#   'Paredes',
#   'María Ruiz',
#   'Efectivo'),
#  (487,
#   datetime.date(2024, 1, 20),
#   'Cerveza',
#   'González',
#   'Carmen Velázquez',
#   'Tarjeta'),
#  (488,
#   datetime.date(2024, 1, 20),
#   'Champú',
#   'Domínguez',
#   'Jorge Ruiz',
#   'Efectivo'),
#  (489,
#   datetime.date(2024, 1, 20),
#   'Velas',
#   'Chávez',
#   'Gabriela Hernández',
#   'Tarjeta'),
#  (490,
#   datetime.date(2024, 1, 20),
#   'Pollo',
#   'Fernández',
#   'Carla Lara',
#   'Tarjeta'),
#  (491,
#   datetime.date(2024, 1, 20),
#   'Fertilizante',
#   'Rubio',
#   'Ángel Carrillo',
#   'Tarjeta'),
#  (492,
#   datetime.date(2024, 1, 20),
#   'Chicles',
#   'Esquivel',
#   'Ángel Ortiz',
#   'Tarjeta'),
#  (493,
#   datetime.date(2024, 1, 20),
#   'Velas',
#   'Reyes',
#   'Verónica Rubio',
#   'Efectivo'),
#  (494,
#   datetime.date(2024, 1, 20),
#   'Cebolla',
#   'Sánchez',
#   'Verónica Rubio',
#   'Tarjeta'),
#  (495,
#   datetime.date(2024, 1, 20),
#   'Chicles',
#   'Cortés',
#   'Clara Ramírez',
#   'Efectivo'),
#  (496,
#   datetime.date(2024, 1, 20),
#   'Carne de res',
#   'Carrillo',
#   'Clara Santos',
#   'Tarjeta'),
#  (497,
#   datetime.date(2024, 1, 20),
#   'Colonia',
#   'Rodríguez',
#   'Pablo Navarro',
#   'Tarjeta'),
#  (498,
# ...
#   'Ramos',
#   'Miguel Molina',
#   'Tarjeta'),
#  (834,
#   datetime.date(2024, 2, 2),
#   'Detergente',
#   'Flores',
#   'Lorena Chávez',
#   'Tarjeta'),
#  (835,
#   datetime.date(2024, 2, 2),
#   'Esponjas',
#   'Álvarez',
#   'Cristian Velázquez',
#   'Tarjeta'),
#  (836,
#   datetime.date(2024, 2, 2),
#   'Detergente',
#   'Martínez',
#   'Natalia Reyes',
#   'Tarjeta'),
#  (837,
#   datetime.date(2024, 2, 2),
#   'Yogur',
#   'Santos',
#   'Verónica González',
#   'Efectivo'),
#  (838,
#   datetime.date(2024, 2, 2),
#   'Desodorante',
#   'Ortiz',
#   'Laura Salinas',
#   'Tarjeta'),
#  (839,
#   datetime.date(2024, 2, 2),
#   'Cerdo',
#   'Serrano',
#   'Francisco Cruz',
#   'Efectivo'),
#  (840,
#   datetime.date(2024, 2, 2),
#   'Yogur',
#   'Moreno',
#   'Rubén Castro',
#   'Tarjeta'),
#  (841,
#   datetime.date(2024, 2, 2),
#   'Naranja',
#   'Campos',
#   'Ángel Ortiz',
#   'Efectivo'),
#  (842,
#   datetime.date(2024, 2, 2),
#   'Carne de res',
#   'Ortiz',
#   'José Rodríguez',
#   'Efectivo'),
#  (843,
#   datetime.date(2024, 2, 2),
#   'Platos desechables',
#   'Serrano',
#   'Adriana Ramírez',
#   'Efectivo'),
#  (844,
#   datetime.date(2024, 2, 2),
#   'Carne de res',
#   'López',
#   'Laura Peña',
#   'Tarjeta'),
#  (845,
#   datetime.date(2024, 2, 2),
#   'Colonia',
#   'Serrano',
#   'Miguel Ruiz',
#   'Tarjeta'),
#  (846,
#   datetime.date(2024, 2, 2),
#   'Galletas',
#   'Santos',
#   'Lucía Cruz',
#   'Efectivo'),
#  (847,
#   datetime.date(2024, 2, 3),
#   'Mantequilla',
#   'Velázquez',
#   'Gabriela Hernández',
#   'Tarjeta'),
#  (848,
#   datetime.date(2024, 2, 3),
#   'Manzana',
#   'Sánchez',
#   'Ana Torres',
#   'Tarjeta'),
#  (849, datetime.date(2024, 2, 3), 'Yogur', 'Díaz', 'Eduardo Díaz', 'Efectivo'),
#  (850,
#   datetime.date(2024, 2, 3),
#   'Desinfectante',
#   'Ruiz',
#   'Adriana Guzmán',
#   'Tarjeta'),
#  (851,
#   datetime.date(2024, 2, 3),
#   'Pilas',
#   'Campos',
#   'Samuel Sánchez',
#   'Tarjeta'),
#  (852,
#   datetime.date(2024, 2, 3),
#   'Desinfectante',
#   'López',
#   'Hugo Moreno',
#   'Efectivo'),
#  (853, datetime.date(2024, 2, 3), 'Pilas', 'Campos', 'Laura Peña', 'Efectivo'),
#  (854,
#   datetime.date(2024, 2, 3),
#   'Galletas',
#   'González',
#   'Miguel Ruiz',
#   'Tarjeta'),
#  (855,
#   datetime.date(2024, 2, 3),
#   'Chicles',
#   'Santos',
#   'Sergio Santos',
#   'Tarjeta'),
#  (856, datetime.date(2024, 2, 3), 'Pilas', 'Peña', 'Carla Lara', 'Tarjeta'),
#  (857,
#   datetime.date(2024, 2, 3),
#   'Regadera',
#   'Navarro',
#   'Valeria Salinas',
#   'Tarjeta'),
#  (858,
#   datetime.date(2024, 2, 3),
#   'Cebolla',
#   'Romero',
#   'Carlos Navarro',
#   'Tarjeta'),
#  (859,
#   datetime.date(2024, 2, 3),
#   'Uva',
#   'Velázquez',
#   'Marta Santos',
#   'Tarjeta'),
#  (860,
#   datetime.date(2024, 2, 3),
#   'Chuletas',
#   'Cortés',
#   'Valeria Santos',
#   'Tarjeta'),
#  (861,
#   datetime.date(2024, 2, 3),
#   'Banana',
#   'Cruz',
#   'Carlos Navarro',
#   'Tarjeta'),
#  (862,
#   datetime.date(2024, 2, 3),
#   'Jugo de naranja',
#   'Ramírez',
#   'Raúl García',
#   'Efectivo'),
#  (863,
#   datetime.date(2024, 2, 3),
#   'Uva',
#   'Álvarez',
#   'Ángel Flores',
#   'Efectivo'),
#  (864,
#   datetime.date(2024, 2, 3),
#   'Galletas',
#   'Ortiz',
#   'Daniel Vázquez',
#   'Efectivo'),
#  (865,
#   datetime.date(2024, 2, 3),
#   'Desinfectante',
#   'Ramírez',
#   'Raúl Hernández',
#   'Tarjeta'),
#  (866,
#   datetime.date(2024, 2, 3),
#   'Lechuga',
#   'Méndez',
#   'María Aguilar',
#   'Tarjeta'),
#  (867,
#   datetime.date(2024, 2, 3),
#   'Platos desechables',
#   'Santos',
#   'Carla Cabrera',
#   'Tarjeta'),
#  (868,
#   datetime.date(2024, 2, 3),
#   'Esponjas',
#   'Pérez',
#   'Lucía Ortiz',
#   'Tarjeta'),
#  (869,
#   datetime.date(2024, 2, 3),
#   'Pilas',
#   'Velázquez',
#   'Ricardo Campos',
#   'Tarjeta'),
#  (870,
#   datetime.date(2024, 2, 4),
#   'Regadera',
#   'Sánchez',
#   'Verónica Fernández',
#   'Efectivo'),
#  (871,
#   datetime.date(2024, 2, 4),
#   'Chuletas',
#   'Flores',
#   'Ángel Ortiz',
#   'Tarjeta'),
#  (872,
#   datetime.date(2024, 2, 4),
#   'Zanahoria',
#   'Vázquez',
#   'Sergio Delgado',
#   'Tarjeta'),
#  (873,
#   datetime.date(2024, 2, 4),
#   'Papas fritas',
#   'Cabrera',
#   'Ricardo Jiménez',
#   'Efectivo'),
#  (874,
#   datetime.date(2024, 2, 4),
#   'Cebolla',
#   'Jiménez',
#   'Valeria Santos',
#   'Tarjeta'),
#  (875,
#   datetime.date(2024, 2, 4),
#   'Manzana',
#   'Moreno',
#   'Laura Salinas',
#   'Tarjeta'),
#  (876,
#   datetime.date(2024, 2, 4),
#   'Esponjas',
#   'Martínez',
#   'Sofía Ortiz',
#   'Efectivo'),
#  (877,
#   datetime.date(2024, 2, 4),
#   'Mantequilla',
#   'Torres',
#   'Sara Cabrera',
#   'Efectivo'),
#  (878,
#   datetime.date(2024, 2, 4),
#   'Desodorante',
#   'Medina',
#   'Rubén Castro',
#   'Tarjeta'),
#  (879,
#   datetime.date(2024, 2, 4),
#   'Zanahoria',
#   'Pérez',
#   'Verónica González',
#   'Tarjeta'),
#  (880, datetime.date(2024, 2, 4), 'Velas', 'Díaz', 'Paula Cabrera', 'Tarjeta'),
#  (881,
#   datetime.date(2024, 2, 4),
#   'Zanahoria',
#   'Medina',
#   'Laura Santos',
#   'Tarjeta'),
#  (882,
#   datetime.date(2024, 2, 4),
#   'Naranja',
#   'Esquivel',
#   'Lucía Cruz',
#   'Tarjeta'),
#  (883,
#   datetime.date(2024, 2, 4),
#   'Chocolate',
#   'López',
#   'Daniel Vázquez',
#   'Tarjeta'),
#  (884,
#   datetime.date(2024, 2, 4),
#   'Cerveza',
#   'Flores',
#   'Gabriela Hernández',
#   'Tarjeta'),
#  (885,
#   datetime.date(2024, 2, 4),
#   'Fertilizante',
#   'Ortiz',
#   'Francisco Cruz',
#   'Efectivo'),
#  (886,
#   datetime.date(2024, 2, 4),
#   'Refresco',
#   'Pérez',
#   'Marta Santos',
#   'Tarjeta'),
#  (887,
#   datetime.date(2024, 2, 4),
#   'Leche',
#   'Jiménez',
#   'Lucía Molina',
#   'Efectivo'),
#  (888,
#   datetime.date(2024, 2, 4),
#   'Semillas',
#   'Díaz',
#   'Andrés Castro',
#   'Efectivo'),
#  (889,
#   datetime.date(2024, 2, 4),
#   'Chocolate',
#   'Méndez',
#   'Gabriela Salinas',
#   'Tarjeta'),
#  (890,
#   datetime.date(2024, 2, 4),
#   'Fertilizante',
#   'Velázquez',
#   'Irene Paredes',
#   'Tarjeta'),
#  (891,
#   datetime.date(2024, 2, 4),
#   'Banana',
#   'Aguilar',
#   'Verónica Lara',
#   'Efectivo'),
#  (892,
#   datetime.date(2024, 2, 4),
#   'Naranja',
#   'Montes',
#   'Sergio Santos',
#   'Efectivo'),
#  (893,
#   datetime.date(2024, 2, 4),
#   'Uva',
#   'Domínguez',
#   'Lucía Molina',
#   'Tarjeta'),
#  (894,
#   datetime.date(2024, 2, 4),
#   'Velas',
#   'Rodríguez',
#   'Miguel Molina',
#   'Tarjeta'),
#  (895,
#   datetime.date(2024, 2, 5),
#   'Galletas',
#   'Rodríguez',
#   'Adriana López',
#   'Tarjeta'),
#  (896,
#   datetime.date(2024, 2, 5),
#   'Pilas',
#   'López',
#   'Daniel Vázquez',
#   'Tarjeta'),
#  (897,
#   datetime.date(2024, 2, 5),
#   'Lechuga',
#   'Salinas',
#   'Clara Álvarez',
#   'Efectivo'),
#  (898,
#   datetime.date(2024, 2, 5),
#   'Lechuga',
#   'Jiménez',
#   'Carlos Rodríguez',
#   'Efectivo'),
#  (899,
#   datetime.date(2024, 2, 5),
#   'Uva',
#   'Salinas',
#   'Miguel Molina',
#   'Tarjeta'),
#  (900,
#   datetime.date(2024, 2, 5),
#   'Regadera',
#   'Ramírez',
#   'Eduardo Moreno',
#   'Efectivo'),
#  (901,
#   datetime.date(2024, 2, 5),
#   'Detergente',
#   'López',
#   'Pablo Ortiz',
#   'Tarjeta'),
#  (902,
#   datetime.date(2024, 2, 5),
#   'Chocolate',
#   'Moreno',
#   'Irene Delgado',
#   'Tarjeta'),
#  (903,
#   datetime.date(2024, 2, 5),
#   'Uva',
#   'Torres',
#   'Cristian Velázquez',
#   'Tarjeta'),
#  (904,
#   datetime.date(2024, 2, 5),
#   'Jugo de naranja',
#   'Molina',
#   'Carla Reyes',
#   'Tarjeta'),
#  (905,
#   datetime.date(2024, 2, 5),
#   'Zanahoria',
#   'Sánchez',
#   'Rubén Castro',
#   'Efectivo'),
#  (906,
#   datetime.date(2024, 2, 5),
#   'Chocolate',
#   'Carrillo',
#   'Eduardo Moreno',
#   'Tarjeta'),
#  (907,
#   datetime.date(2024, 2, 5),
#   'Mantequilla',
#   'Salinas',
#   'Clara Paredes',
#   'Tarjeta'),
#  (908,
#   datetime.date(2024, 2, 5),
#   'Mantequilla',
#   'González',
#   'Elena Guzmán',
#   'Tarjeta'),
#  (909,
#   datetime.date(2024, 2, 5),
#   'Leche',
#   'Molina',
#   'Jorge Ramírez',
#   'Tarjeta'),
#  (910,
#   datetime.date(2024, 2, 5),
#   'Tierra para macetas',
#   'Fuentes',
#   'Clara Álvarez',
#   'Tarjeta'),
#  (911, datetime.date(2024, 2, 6), 'Pollo', 'Ortiz', 'Lucía Molina', 'Tarjeta'),
#  (912,
#   datetime.date(2024, 2, 6),
#   'Esponjas',
#   'Hernández',
#   'Marta Santos',
#   'Tarjeta'),
#  (913,
#   datetime.date(2024, 2, 6),
#   'Mantequilla',
#   'Pérez',
#   'Verónica Rubio',
#   'Tarjeta'),
#  (914,
#   datetime.date(2024, 2, 6),
#   'Naranja',
#   'López',
#   'Elena Guzmán',
#   'Tarjeta'),
#  (915,
#   datetime.date(2024, 2, 6),
#   'Chuletas',
#   'Romero',
#   'Pablo Ortiz',
#   'Tarjeta'),
#  (916,
#   datetime.date(2024, 2, 6),
#   'Colonia',
#   'Ramírez',
#   'Carla Reyes',
#   'Tarjeta'),
#  (917,
#   datetime.date(2024, 2, 6),
#   'Yogur',
#   'Fuentes',
#   'Ricardo Reyes',
#   'Tarjeta'),
#  (918,
#   datetime.date(2024, 2, 6),
#   'Platos desechables',
#   'Domínguez',
#   'Gabriela Hernández',
#   'Tarjeta'),
#  (919,
#   datetime.date(2024, 2, 6),
#   'Semillas',
#   'Ramos',
#   'Eva Esquivel',
#   'Tarjeta'),
#  (920,
#   datetime.date(2024, 2, 6),
#   'Carne de res',
#   'Velázquez',
#   'Ana Esquivel',
#   'Tarjeta'),
#  (921,
#   datetime.date(2024, 2, 6),
#   'Tierra para macetas',
#   'Cruz',
#   'Daniel Paredes',
#   'Tarjeta'),
#  (922,
#   datetime.date(2024, 2, 6),
#   'Chicles',
#   'Pérez',
#   'Julia Chávez',
#   'Tarjeta'),
#  (923,
#   datetime.date(2024, 2, 6),
#   'Pilas',
#   'González',
#   'Adriana Moreno',
#   'Tarjeta'),
#  (924,
#   datetime.date(2024, 2, 6),
#   'Banana',
#   'Fuentes',
#   'Valeria Santos',
#   'Efectivo'),
#  (925,
#   datetime.date(2024, 2, 6),
#   'Naranja',
#   'Carrillo',
#   'Daniel Velázquez',
#   'Tarjeta'),
#  (926,
#   datetime.date(2024, 2, 6),
#   'Naranja',
#   'Méndez',
#   'Valeria Ruiz',
#   'Efectivo'),
#  (927,
#   datetime.date(2024, 2, 6),
#   'Jugo de naranja',
#   'López',
#   'Daniel Velázquez',
#   'Tarjeta'),
#  (928,
#   datetime.date(2024, 2, 6),
#   'Desinfectante',
#   'Pérez',
#   'Fernando Castro',
#   'Tarjeta'),
#  (929,
#   datetime.date(2024, 2, 6),
#   'Mantequilla',
#   'Medina',
#   'Ricardo Campos',
#   'Tarjeta'),
#  (930,
#   datetime.date(2024, 2, 6),
#   'Colonia',
#   'Romero',
#   'Raúl Hernández',
#   'Efectivo'),
#  (931,
#   datetime.date(2024, 2, 6),
#   'Desodorante',
#   'Castro',
#   'Marta Santos',
#   'Tarjeta'),
#  (932,
#   datetime.date(2024, 2, 6),
#   'Papas fritas',
#   'Rubio',
#   'Laura Santos',
#   'Tarjeta'),
#  (933,
#   datetime.date(2024, 2, 6),
#   'Pilas',
#   'Fuentes',
#   'Sofía Serrano',
#   'Efectivo'),
#  (934,
#   datetime.date(2024, 2, 6),
#   'Bolsas de basura',
#   'Castro',
#   'Sofía Serrano',
#   'Efectivo'),
#  (935,
#   datetime.date(2024, 2, 6),
#   'Jugo de naranja',
#   'Carrillo',
#   'Francisco Cruz',
#   'Efectivo'),
#  (936,
#   datetime.date(2024, 2, 6),
#   'Galletas',
#   'Rodríguez',
#   'Samuel Velázquez',
#   'Tarjeta'),
#  (937,
#   datetime.date(2024, 2, 6),
#   'Bolsas de basura',
#   'Guzmán',
#   'Daniel Paredes',
#   'Tarjeta'),
#  (938,
#   datetime.date(2024, 2, 6),
#   'Fertilizante',
#   'Ramos',
#   'Carlos Navarro',
#   'Efectivo'),
#  (939,
#   datetime.date(2024, 2, 6),
#   'Queso',
#   'Méndez',
#   'Laura Rubio',
#   'Efectivo'),
#  (940,
#   datetime.date(2024, 2, 7),
#   'Colonia',
#   'Méndez',
#   'Ana Esquivel',
#   'Tarjeta'),
#  (941,
#   datetime.date(2024, 2, 7),
#   'Pollo',
#   'Hernández',
#   'Gabriela Salinas',
#   'Tarjeta'),
#  (942,
#   datetime.date(2024, 2, 7),
#   'Leche',
#   'Serrano',
#   'Fernando Castro',
#   'Tarjeta'),
#  (943,
#   datetime.date(2024, 2, 7),
#   'Desinfectante',
#   'Lara',
#   'Carmen Velázquez',
#   'Tarjeta'),
#  (944,
#   datetime.date(2024, 2, 7),
#   'Regadera',
#   'Salinas',
#   'Ángel Ortiz',
#   'Tarjeta'),
#  (945, datetime.date(2024, 2, 7), 'Yogur', 'Díaz', 'Paula Cabrera', 'Tarjeta'),
#  (946,
#   datetime.date(2024, 2, 7),
#   'Cerdo',
#   'Paredes',
#   'Ángel Ortiz',
#   'Efectivo'),
#  (947, datetime.date(2024, 2, 7), 'Champú', 'Lara', 'Jorge Ruiz', 'Efectivo'),
#  (948,
#   datetime.date(2024, 2, 7),
#   'Chocolate',
#   'Esquivel',
#   'José Salinas',
#   'Efectivo'),
#  (949,
#   datetime.date(2024, 2, 7),
#   'Leche',
#   'Fernández',
#   'Valeria Medina',
#   'Tarjeta'),
#  (950,
#   datetime.date(2024, 2, 7),
#   'Desodorante',
#   'Lara',
#   'Irene Paredes',
#   'Tarjeta'),
#  (951,
#   datetime.date(2024, 2, 7),
#   'Yogur',
#   'Martínez',
#   'José Salinas',
#   'Efectivo'),
#  (952,
#   datetime.date(2024, 2, 7),
#   'Detergente',
#   'Reyes',
#   'Carmen Carrillo',
#   'Tarjeta'),
#  (953,
#   datetime.date(2024, 2, 7),
#   'Jugo de naranja',
#   'Chávez',
#   'Carmen Carrillo',
#   'Efectivo'),
#  (954,
#   datetime.date(2024, 2, 7),
#   'Lechuga',
#   'Cruz',
#   'Carmen Velázquez',
#   'Tarjeta'),
#  (955, datetime.date(2024, 2, 7), 'Uva', 'Reyes', 'Miguel Molina', 'Tarjeta'),
#  (956,
#   datetime.date(2024, 2, 7),
#   'Fertilizante',
#   'Navarro',
#   'Marta Santos',
#   'Efectivo'),
#  (957,
#   datetime.date(2024, 2, 7),
#   'Galletas',
#   'Flores',
#   'Valeria Medina',
#   'Tarjeta'),
#  (958, datetime.date(2024, 2, 7), 'Cerdo', 'Flores', 'Laura Ruiz', 'Tarjeta'),
#  (959,
#   datetime.date(2024, 2, 7),
#   'Desinfectante',
#   'Campos',
#   'Hugo Torres',
#   'Efectivo'),
#  (960,
#   datetime.date(2024, 2, 7),
#   'Papas fritas',
#   'Rubio',
#   'Marta Campos',
#   'Efectivo'),
#  (961,
#   datetime.date(2024, 2, 7),
#   'Cerdo',
#   'Santos',
#   'Ángel Ortiz',
#   'Efectivo'),
#  (962,
#   datetime.date(2024, 2, 7),
#   'Esponjas',
#   'Cortés',
#   'Marta Campos',
#   'Tarjeta'),
#  (963,
#   datetime.date(2024, 2, 7),
#   'Chocolate',
#   'Sánchez',
#   'Hugo Moreno',
#   'Tarjeta'),
#  (964,
#   datetime.date(2024, 2, 7),
#   'Chocolate',
#   'Serrano',
#   'Eduardo Ramos',
#   'Tarjeta'),
#  (965,
#   datetime.date(2024, 2, 7),
#   'Chocolate',
#   'Castro',
#   'Clara Paredes',
#   'Tarjeta'),
#  (966,
#   datetime.date(2024, 2, 8),
#   'Velas',
#   'Torres',
#   'Clara Álvarez',
#   'Efectivo'),
#  (967,
#   datetime.date(2024, 2, 8),
#   'Cerveza',
#   'López',
#   'Valeria Medina',
#   'Tarjeta'),
#  (968,
#   datetime.date(2024, 2, 8),
#   'Tomate',
#   'Ramírez',
#   'Hugo Moreno',
#   'Tarjeta'),
#  (969,
#   datetime.date(2024, 2, 8),
#   'Tierra para macetas',
#   'Cruz',
#   'Ana Esquivel',
#   'Tarjeta'),
#  (970,
#   datetime.date(2024, 2, 8),
#   'Champú',
#   'Ramos',
#   'David Vázquez',
#   'Tarjeta'),
#  (971, datetime.date(2024, 2, 8), 'Cerdo', 'Díaz', 'Lucía Ortiz', 'Tarjeta'),
#  (972,
#   datetime.date(2024, 2, 8),
#   'Regadera',
#   'Sánchez',
#   'Alejandro Pérez',
#   'Tarjeta'),
#  (973,
#   datetime.date(2024, 2, 8),
#   'Carne de res',
#   'Peña',
#   'María Paredes',
#   'Tarjeta'),
#  (974,
#   datetime.date(2024, 2, 8),
#   'Champú',
#   'Paredes',
#   'Verónica Rubio',
#   'Tarjeta'),
#  (975,
#   datetime.date(2024, 2, 8),
#   'Esponjas',
#   'Esquivel',
#   'Adriana Ramírez',
#   'Efectivo'),
#  (976,
#   datetime.date(2024, 2, 8),
#   'Leche',
#   'Ramírez',
#   'Sara Cabrera',
#   'Tarjeta'),
#  (977,
#   datetime.date(2024, 2, 8),
#   'Agua',
#   'Guzmán',
#   'Ricardo Jiménez',
#   'Tarjeta'),
#  (978,
#   datetime.date(2024, 2, 8),
#   'Queso',
#   'Castro',
#   'Verónica González',
#   'Tarjeta'),
#  (979,
#   datetime.date(2024, 2, 8),
#   'Chicles',
#   'Pérez',
#   'Raúl Rodríguez',
#   'Tarjeta'),
#  (980,
#   datetime.date(2024, 2, 8),
#   'Tomate',
#   'Salinas',
#   'Sara Cabrera',
#   'Tarjeta'),
#  (981,
#   datetime.date(2024, 2, 8),
#   'Galletas',
#   'Navarro',
#   'Camila Navarro',
#   'Tarjeta'),
#  (982,
#   datetime.date(2024, 2, 8),
#   'Cebolla',
#   'Rubio',
#   'Carla Cabrera',
#   'Efectivo'),
#  (983,
#   datetime.date(2024, 2, 8),
#   'Cebolla',
#   'Hernández',
#   'Eva Peña',
#   'Tarjeta'),
#  (984,
#   datetime.date(2024, 2, 8),
#   'Lechuga',
#   'Castro',
#   'Sara Cabrera',
#   'Efectivo'),
#  (985,
#   datetime.date(2024, 2, 8),
#   'Semillas',
#   'Rubio',
#   'Paula Cabrera',
#   'Tarjeta'),
#  (986,
#   datetime.date(2024, 2, 8),
#   'Velas',
#   'Santos',
#   'Camila Campos',
#   'Tarjeta'),
#  (987,
#   datetime.date(2024, 2, 8),
#   'Jugo de naranja',
#   'Moreno',
#   'Valeria Ruiz',
#   'Tarjeta'),
#  (988,
#   datetime.date(2024, 2, 9),
#   'Pollo',
#   'Cruz',
#   'Adriana Guzmán',
#   'Efectivo'),
#  (989,
#   datetime.date(2024, 2, 9),
#   'Refresco',
#   'Méndez',
#   'Laura Santos',
#   'Efectivo'),
#  (990,
#   datetime.date(2024, 2, 9),
#   'Manzana',
#   'Peña',
#   'Adriana Moreno',
#   'Tarjeta'),
#  (991,
#   datetime.date(2024, 2, 9),
#   'Jabón líquido',
#   'Torres',
#   'Valeria Ruiz',
#   'Efectivo'),
#  (992, datetime.date(2024, 2, 9), 'Uva', 'Castro', 'Lorena Chávez', 'Tarjeta'),
#  (993,
#   datetime.date(2024, 2, 9),
#   'Jugo de naranja',
#   'Esquivel',
#   'Hugo Torres',
#   'Efectivo'),
#  (994,
#   datetime.date(2024, 2, 9),
#   'Galletas',
#   'Rubio',
#   'Natalia Reyes',
#   'Efectivo'),
#  (995,
#   datetime.date(2024, 2, 9),
#   'Naranja',
#   'Navarro',
#   'Carmen Velázquez',
#   'Efectivo'),
#  (996,
#   datetime.date(2024, 2, 9),
#   'Detergente',
#   'Domínguez',
#   'Irene Paredes',
#   'Tarjeta'),
#  (997,
#   datetime.date(2024, 2, 9),
#   'Manzana',
#   'Esquivel',
#   'Gabriela Cabrera',
#   'Tarjeta'),
#  (998,
#   datetime.date(2024, 2, 9),
#   'Uva',
#   'Méndez',
#   'Julia Rodríguez',
#   'Efectivo'),
#  (999,
#   datetime.date(2024, 2, 9),
#   'Zanahoria',
#   'Castro',
#   'Diego Peña',
#   'Efectivo'),
#  (1000,
#   datetime.date(2024, 2, 9),
#   'Agua',
#   'Medina',
#   'Samuel Sánchez',
#   'Tarjeta'),
#  ...]

# %% [markdown]
# * 2.- Productos con stock bajo
#
#     * Filtra aquellos productos cuyo stock sea menor a 10.
#     * Muestra nombre del producto, categoría y stock.

# %%
sql = ('SELECT p.nombre_producto, c.nombre_categoria, p.stock FROM productos p JOIN categorias c ON p.id_categoria = c.id_categoria WHERE p.stock < 10;')
consultas(sql)
# Out:
# []

# %% [markdown]
# * 3.-Ventas totales por categoría
#
#     * Muestra el nombre de la categoría y la suma total de las ventas (ej.: multiplicando cantidad * precio_unitario) para cada categoría.
#     * Realiza el JOIN con detalle_orden, productos y categorias.
#     * Utiliza agrupación (GROUP BY).

# %%
sql = ('SELECT c.nombre_categoria as categoria, sum((d.precio_unitario * ( 1 - d.descuento)) * d.cantidad) as ventas FROM categorias c JOIN productos p ON p.id_categoria = c.id_categoria JOIN detalle_orden d ON d.id_producto = p.id_producto GROUP BY c.id_categoria;')
consultas(sql)
# Out:
# [('Pescados', 156525.0),
#  ('Congelados', 183160.79),
#  ('Lácteos', 222861.58),
#  ('Bollería y Pan', 136734.8),
#  ('Refrescos', 187001.49),
#  ('Alcohol', 248998.83),
#  ('Verduras', 134193.21),
#  ('Vinos', 234887.56),
#  ('Carnes', 227171.36),
#  ('Frutas', 93073.04)]

# %% [markdown]
# * 4.-Clientes con mayores gastos acumulados
#
#
#     * Muestra el nombre del cliente y el monto total que ha gastado (suma de todas sus órdenes).
#     * Asegúrate de tener en cuenta posibles descuentos (descuento) si se ha definido. Por ejemplo, la fórmula podría ser (cantidad * precio_unitario) - descuento.
#     * Ordena el resultado de mayor a menor gasto acumulado.

# %%
sql = ('SELECT c.first_name as nombre, c.last_name as apellido, sum((d.precio_unitario * ( 1 - d.descuento)) * d.cantidad) as compras FROM clientes c JOIN ordenes o ON c.id_cliente = o.id_cliente JOIN detalle_orden d ON d.id_orden = o.id_orden GROUP BY c.id_cliente ORDER BY sum((d.precio_unitario * ( 1 - d.descuento)) * d.cantidad) DESC;')
consultas(sql)
# Out:
# [('Bolsas de basura', 'Álvarez', 2980.87),
#  ('Banana', 'Castro', 2949.37),
#  ('Bolsas de basura', 'Cortés', 2836.81),
#  ('Jugo de naranja', 'Serrano', 2795.38),
#  ('Mantequilla', 'González', 2793.29),
#  ('Galletas', 'Flores', 2635.01),
#  ('Colonia', 'Romero', 2592.22),
#  ('Queso', 'Fernández', 2472.06),
#  ('Pollo', 'Moreno', 2463.62),
#  ('Cebolla', 'Santos', 2450.85),
#  ('Platos desechables', 'Domínguez', 2444.01),
#  ('Galletas', 'Navarro', 2438.21),
#  ('Queso', 'Lara', 2369.87),
#  ('Regadera', 'Ruiz', 2333.44),
#  ('Cerdo', 'Santos', 2328.45),
#  ('Semillas', 'Torres', 2314.57),
#  ('Chuletas', 'Álvarez', 2308.76),
#  ('Pollo', 'Fernández', 2298.41),
#  ('Lechuga', 'Sánchez', 2294.99),
#  ('Naranja', 'Fernández', 2289.09),
#  ('Regadera', 'Torres', 2270.53),
#  ('Crema hidratante', 'Jiménez', 2264.6),
#  ('Chicles', 'García', 2243.29),
#  ('Mantequilla', 'Medina', 2221.83),
#  ('Bolsas de basura', 'Montes', 2210.59),
#  ('Desodorante', 'Lara', 2208.13),
#  ('Lechuga', 'Jiménez', 2197.08),
#  ('Tierra para macetas', 'Jiménez', 2190.74),
#  ('Chocolate', 'Flores', 2185.32),
#  ('Chocolate', 'Cortés', 2174.84),
#  ('Tomate', 'Méndez', 2157.47),
#  ('Fertilizante', 'Ramírez', 2141.85),
#  ('Banana', 'Domínguez', 2135.73),
#  ('Chuletas', 'Aguilar', 2130.37),
#  ('Platos desechables', 'Aguilar', 2128.06),
#  ('Refresco', 'Jiménez', 2124.51),
#  ('Papas fritas', 'Ortiz', 2124.32),
#  ('Detergente', 'Fernández', 2100.18),
#  ('Banana', 'Carrillo', 2098.08),
#  ('Velas', 'Rodríguez', 2097.73),
#  ('Jugo de naranja', 'Molina', 2097.18),
#  ('Galletas', 'Rubio', 2086.11),
#  ('Yogur', 'Chávez', 2079.25),
#  ('Naranja', 'Montes', 2072.92),
#  ('Cerveza', 'Salinas', 2070.85),
#  ('Crema hidratante', 'Martínez', 2065.5),
#  ('Bolsas de basura', 'Reyes', 2057.83),
#  ('Carne de res', 'Flores', 2048.84),
#  ('Regadera', 'Navarro', 2033.26),
#  ('Leche', 'Delgado', 2026.96),
#  ('Velas', 'Reyes', 2015.2),
#  ('Desinfectante', 'Cortés', 1997.71),
#  ('Yogur', 'Serrano', 1987.05),
#  ('Jugo de naranja', 'Serrano', 1986.98),
#  ('Champú', 'Molina', 1966.05),
#  ('Regadera', 'Pérez', 1964.63),
#  ('Desinfectante', 'Domínguez', 1962.91),
#  ('Mantequilla', 'González', 1960.27),
#  ('Banana', 'Castro', 1951.8),
#  ('Chicles', 'Cortés', 1950.51),
#  ('Zanahoria', 'Aguilar', 1949.04),
#  ('Chicles', 'Aguilar', 1943.03),
#  ('Chocolate', 'Paredes', 1941.89),
#  ('Pollo', 'García', 1934.71),
#  ('Carne de res', 'Díaz', 1926.22),
#  ('Tierra para macetas', 'Lara', 1924.97),
#  ('Uva', 'Velázquez', 1924.83),
#  ('Zanahoria', 'Méndez', 1922.43),
#  ('Banana', 'Pérez', 1922.25),
#  ('Refresco', 'Chávez', 1920.25),
#  ('Chicles', 'Romero', 1914.84),
#  ('Chocolate', 'Velázquez', 1914.46),
#  ('Papas fritas', 'Vázquez', 1912.09),
#  ('Leche', 'Méndez', 1909.08),
#  ('Crema hidratante', 'Flores', 1908.03),
#  ('Champú', 'Serrano', 1893.69),
#  ('Pollo', 'Rodríguez', 1893.58),
#  ('Bolsas de basura', 'Díaz', 1874.95),
#  ('Platos desechables', 'Moreno', 1869.97),
#  ('Fertilizante', 'Molina', 1867.26),
#  ('Esponjas', 'Jiménez', 1867.21),
#  ('Regadera', 'Moreno', 1847.63),
#  ('Yogur', 'Paredes', 1846.28),
#  ('Semillas', 'Rubio', 1843.17),
#  ('Agua', 'Serrano', 1842.32),
#  ('Desinfectante', 'Fernández', 1841.61),
#  ('Desodorante', 'Castro', 1841.37),
#  ('Tierra para macetas', 'Velázquez', 1839.86),
#  ('Desinfectante', 'Moreno', 1832.68),
#  ('Tomate', 'Serrano', 1828.13),
#  ('Tierra para macetas', 'Velázquez', 1823.58),
#  ('Carne de res', 'Pérez', 1821.33),
#  ('Uva', 'Moreno', 1817.57),
#  ('Pollo', 'Velázquez', 1816.2),
#  ('Cerveza', 'Flores', 1816.17),
#  ('Chuletas', 'Velázquez', 1813.18),
#  ('Manzana', 'Fernández', 1813.14),
#  ('Chocolate', 'Serrano', 1812.32),
#  ('Lechuga', 'Hernández', 1808.59),
#  ('Chocolate', 'Flores', 1806.69),
#  ('Zanahoria', 'Jiménez', 1799.92),
#  ('Cebolla', 'Cruz', 1799.14),
#  ('Carne de res', 'Medina', 1797.4),
#  ('Tomate', 'Esquivel', 1793.83),
#  ('Galletas', 'Ramos', 1781.94),
#  ('Mantequilla', 'Pérez', 1781.63),
#  ('Galletas', 'Montes', 1772.17),
#  ('Banana', 'Jiménez', 1765.62),
#  ('Platos desechables', 'Medina', 1761.42),
#  ('Tierra para macetas', 'Guzmán', 1759.8),
#  ('Pilas', 'Jiménez', 1757.7),
#  ('Cerdo', 'Martínez', 1757.54),
#  ('Jabón líquido', 'Paredes', 1756.48),
#  ('Galletas', 'Peña', 1754.08),
#  ('Desodorante', 'Campos', 1752.2),
#  ('Regadera', 'Paredes', 1748.07),
#  ('Desinfectante', 'Díaz', 1747.77),
#  ('Mantequilla', 'González', 1746.81),
#  ('Cebolla', 'Campos', 1743.25),
#  ('Platos desechables', 'García', 1740.44),
#  ('Pollo', 'Fuentes', 1737.71),
#  ('Uva', 'Reyes', 1736.23),
#  ('Crema hidratante', 'Molina', 1735.58),
#  ('Cerveza', 'Lara', 1731.26),
#  ('Yogur', 'Álvarez', 1730.49),
#  ('Fertilizante', 'Salinas', 1727.12),
#  ('Bolsas de basura', 'Chávez', 1726.23),
#  ('Zanahoria', 'Sánchez', 1723.62),
#  ('Colonia', 'Ramos', 1720.25),
#  ('Zanahoria', 'Pérez', 1717.35),
#  ('Jabón líquido', 'Álvarez', 1717.28),
#  ('Semillas', 'Velázquez', 1714.54),
#  ('Desodorante', 'Sánchez', 1713.64),
#  ('Bolsas de basura', 'Velázquez', 1710.01),
#  ('Bolsas de basura', 'Lara', 1708.87),
#  ('Papas fritas', 'Peña', 1703.31),
#  ('Leche', 'Díaz', 1702.22),
#  ('Cerveza', 'Molina', 1700.8),
#  ('Jabón líquido', 'Peña', 1700.43),
#  ('Lechuga', 'López', 1699.5),
#  ('Jugo de naranja', 'Ortiz', 1695.66),
#  ('Esponjas', 'Álvarez', 1686.75),
#  ('Semillas', 'Campos', 1686.5),
#  ('Galletas', 'Ruiz', 1686.21),
#  ('Agua', 'Sánchez', 1686.17),
#  ('Agua', 'Ortiz', 1682.78),
#  ('Regadera', 'Ruiz', 1682.47),
#  ('Jabón líquido', 'Cortés', 1680.79),
#  ('Crema hidratante', 'Ramírez', 1680.19),
#  ('Yogur', 'Chávez', 1679.29),
#  ('Chuletas', 'Fuentes', 1679.01),
#  ('Fertilizante', 'López', 1672.67),
#  ('Uva', 'Méndez', 1670.55),
#  ('Papas fritas', 'González', 1668.09),
#  ('Galletas', 'Sánchez', 1665.73),
#  ('Banana', 'Hernández', 1658.36),
#  ('Semillas', 'Navarro', 1658.28),
#  ('Naranja', 'Navarro', 1658.12),
#  ('Uva', 'Santos', 1658.1),
#  ('Mantequilla', 'Rubio', 1655.93),
#  ('Papas fritas', 'Domínguez', 1644.45),
#  ('Chocolate', 'Molina', 1643.86),
#  ('Velas', 'Romero', 1641.4),
#  ('Regadera', 'Ramírez', 1637.97),
#  ('Chocolate', 'Chávez', 1630.63),
#  ('Carne de res', 'Velázquez', 1626.0),
#  ('Agua', 'Medina', 1625.39),
#  ('Chuletas', 'Guzmán', 1623.0),
#  ('Velas', 'Rodríguez', 1622.39),
#  ('Colonia', 'Flores', 1621.42),
#  ('Jabón líquido', 'Pérez', 1618.7),
#  ('Pilas', 'Campos', 1617.7),
#  ('Lechuga', 'Cruz', 1617.49),
#  ('Lechuga', 'López', 1614.28),
#  ('Lechuga', 'Romero', 1611.36),
#  ('Cerdo', 'Ruiz', 1610.88),
#  ('Uva', 'Ramos', 1609.69),
#  ('Cerdo', 'Pérez', 1604.74),
#  ('Mantequilla', 'Serrano', 1604.22),
#  ('Champú', 'García', 1600.53),
#  ('Semillas', 'Hernández', 1600.35),
#  ('Cebolla', 'Guzmán', 1599.09),
#  ('Naranja', 'Ortiz', 1598.34),
#  ('Crema hidratante', 'López', 1597.98),
#  ('Jugo de naranja', 'Méndez', 1595.89),
#  ('Lechuga', 'Cabrera', 1594.39),
#  ('Detergente', 'Rodríguez', 1593.07),
#  ('Desinfectante', 'Jiménez', 1592.55),
#  ('Champú', 'Cabrera', 1591.06),
#  ('Chocolate', 'Chávez', 1590.37),
#  ('Bolsas de basura', 'Guzmán', 1589.58),
#  ('Queso', 'Ruiz', 1586.39),
#  ('Uva', 'Ramos', 1583.4),
#  ('Semillas', 'Díaz', 1581.94),
#  ('Pilas', 'Guzmán', 1581.26),
#  ('Pollo', 'Hernández', 1581.0),
#  ('Mantequilla', 'Domínguez', 1579.59),
#  ('Velas', 'Romero', 1578.51),
#  ('Bolsas de basura', 'Domínguez', 1578.44),
#  ('Chicles', 'Cortés', 1577.16),
#  ('Yogur', 'Moreno', 1574.44),
#  ('Galletas', 'González', 1573.81),
#  ('Queso', 'Esquivel', 1572.48),
#  ('Desodorante', 'Hernández', 1571.79),
#  ('Chuletas', 'Sánchez', 1571.66),
#  ('Platos desechables', 'Hernández', 1570.66),
#  ('Jabón líquido', 'Esquivel', 1567.4),
#  ('Tomate', 'Lara', 1567.04),
#  ('Platos desechables', 'Guzmán', 1566.49),
#  ('Tierra para macetas', 'Fernández', 1566.05),
#  ('Pollo', 'Fuentes', 1564.91),
#  ('Regadera', 'Guzmán', 1564.79),
#  ('Jugo de naranja', 'Chávez', 1562.57),
#  ('Carne de res', 'Carrillo', 1561.52),
#  ('Detergente', 'Guzmán', 1559.92),
#  ('Champú', 'Navarro', 1558.35),
#  ('Regadera', 'Delgado', 1557.99),
#  ('Mantequilla', 'Velázquez', 1556.07),
#  ('Lechuga', 'Cruz', 1555.62),
#  ('Jabón líquido', 'Rodríguez', 1555.24),
#  ('Queso', 'Velázquez', 1553.31),
#  ('Regadera', 'Torres', 1550.82),
#  ('Cerveza', 'Ortiz', 1550.04),
#  ('Cerveza', 'Fernández', 1549.92),
#  ('Agua', 'Aguilar', 1546.76),
#  ('Galletas', 'Ortiz', 1543.99),
#  ('Tomate', 'Sánchez', 1541.68),
#  ('Manzana', 'Díaz', 1541.25),
#  ('Detergente', 'López', 1538.88),
#  ('Regadera', 'Salinas', 1538.67),
#  ('Detergente', 'Molina', 1538.26),
#  ('Desodorante', 'Ruiz', 1537.13),
#  ('Banana', 'Paredes', 1536.97),
#  ('Semillas', 'Torres', 1536.85),
#  ('Bolsas de basura', 'Fernández', 1535.49),
#  ('Refresco', 'Romero', 1535.14),
#  ('Chocolate', 'Molina', 1534.29),
#  ('Detergente', 'Moreno', 1532.23),
#  ('Leche', 'Castro', 1528.15),
#  ('Chicles', 'Cortés', 1526.19),
#  ('Queso', 'Reyes', 1522.93),
#  ('Tomate', 'Molina', 1519.6),
#  ('Detergente', 'Cortés', 1514.47),
#  ('Champú', 'Castro', 1514.1),
#  ('Velas', 'Ortiz', 1514.03),
#  ('Papas fritas', 'Martínez', 1511.37),
#  ('Mantequilla', 'González', 1509.64),
#  ('Pilas', 'Navarro', 1504.55),
#  ('Papas fritas', 'Rubio', 1503.2),
#  ('Jugo de naranja', 'Cabrera', 1502.73),
#  ('Chicles', 'Ortiz', 1500.24),
#  ('Chicles', 'Santos', 1499.64),
#  ('Bolsas de basura', 'Sánchez', 1497.2),
#  ('Tomate', 'Esquivel', 1495.5),
#  ('Cebolla', 'Cabrera', 1495.3),
#  ('Bolsas de basura', 'Serrano', 1494.89),
#  ('Tierra para macetas', 'Martínez', 1492.31),
#  ('Esponjas', 'Guzmán', 1489.89),
#  ('Zanahoria', 'Ramírez', 1489.88),
#  ('Chicles', 'Peña', 1489.87),
#  ('Desodorante', 'Fuentes', 1489.24),
#  ('Mantequilla', 'Cortés', 1487.48),
#  ('Papas fritas', 'Carrillo', 1487.08),
#  ('Papas fritas', 'Campos', 1482.73),
#  ('Champú', 'Campos', 1482.03),
#  ('Lechuga', 'Serrano', 1481.33),
#  ('Semillas', 'Medina', 1480.99),
#  ('Mantequilla', 'Cruz', 1480.32),
#  ('Desinfectante', 'Rodríguez', 1477.1),
#  ('Yogur', 'Navarro', 1476.62),
#  ('Carne de res', 'Torres', 1472.66),
#  ('Cerveza', 'Flores', 1470.86),
#  ('Leche', 'Fernández', 1468.28),
#  ('Chocolate', 'Navarro', 1466.21),
#  ('Colonia', 'Aguilar', 1465.27),
#  ('Refresco', 'López', 1464.61),
#  ('Crema hidratante', 'Ortiz', 1464.3),
#  ('Galletas', 'Rodríguez', 1464.11),
#  ('Carne de res', 'González', 1464.07),
#  ('Jugo de naranja', 'Fuentes', 1462.42),
#  ('Fertilizante', 'Ruiz', 1461.79),
#  ('Uva', 'Fuentes', 1459.59),
#  ('Zanahoria', 'Castro', 1459.16),
#  ('Mantequilla', 'Molina', 1458.09),
#  ('Detergente', 'Salinas', 1457.21),
#  ('Semillas', 'Rodríguez', 1453.33),
#  ('Desodorante', 'Lara', 1452.61),
#  ('Detergente', 'Reyes', 1451.06),
#  ('Chicles', 'Fernández', 1451.0),
#  ('Zanahoria', 'Guzmán', 1448.31),
#  ('Desinfectante', 'Ramírez', 1447.99),
#  ('Jabón líquido', 'Vázquez', 1447.01),
#  ('Queso', 'Domínguez', 1446.61),
#  ('Mantequilla', 'Montes', 1444.86),
#  ('Jugo de naranja', 'Moreno', 1443.43),
#  ('Desinfectante', 'Ortiz', 1442.5),
#  ('Fertilizante', 'Fernández', 1440.81),
#  ('Champú', 'Chávez', 1440.79),
#  ('Esponjas', 'Esquivel', 1440.73),
#  ('Lechuga', 'Cruz', 1440.34),
#  ('Carne de res', 'López', 1439.82),
#  ('Uva', 'Paredes', 1438.23),
#  ('Cerveza', 'Cruz', 1432.77),
#  ('Crema hidratante', 'Ortiz', 1431.11),
#  ('Cebolla', 'Rodríguez', 1430.86),
#  ('Jabón líquido', 'Esquivel', 1430.06),
#  ('Yogur', 'Hernández', 1429.64),
#  ('Zanahoria', 'Lara', 1429.47),
#  ('Cerveza', 'Martínez', 1427.23),
#  ('Yogur', 'Chávez', 1426.67),
#  ('Esponjas', 'Flores', 1422.1),
#  ('Banana', 'Navarro', 1419.62),
#  ('Cerveza', 'Flores', 1418.04),
#  ('Queso', 'Serrano', 1417.56),
#  ('Regadera', 'Reyes', 1417.43),
#  ('Papas fritas', 'Aguilar', 1416.32),
#  ('Platos desechables', 'Paredes', 1413.32),
#  ('Pollo', 'Álvarez', 1412.1),
#  ('Cebolla', 'Carrillo', 1410.0),
#  ('Desinfectante', 'Domínguez', 1409.69),
#  ('Banana', 'Domínguez', 1406.88),
#  ('Banana', 'Sánchez', 1403.41),
#  ('Zanahoria', 'Reyes', 1401.87),
#  ('Chicles', 'Aguilar', 1399.79),
#  ('Chocolate', 'Pérez', 1397.68),
#  ('Cerdo', 'Paredes', 1396.64),
#  ('Jabón líquido', 'Salinas', 1396.42),
#  ('Chocolate', 'Castro', 1394.29),
#  ('Platos desechables', 'Martínez', 1392.15),
#  ('Queso', 'Torres', 1391.33),
#  ('Banana', 'Fuentes', 1391.14),
#  ('Desinfectante', 'Hernández', 1389.54),
#  ('Chocolate', 'Torres', 1387.59),
#  ('Fertilizante', 'Torres', 1385.91),
#  ('Champú', 'Fuentes', 1385.77),
#  ('Leche', 'Pérez', 1383.61),
#  ('Banana', 'Romero', 1382.19),
#  ('Bolsas de basura', 'Peña', 1382.0),
#  ('Cebolla', 'Chávez', 1381.75),
#  ('Bolsas de basura', 'Guzmán', 1379.85),
#  ('Chicles', 'Salinas', 1377.83),
#  ('Queso', 'Velázquez', 1377.19),
#  ('Uva', 'Fuentes', 1376.75),
#  ('Lechuga', 'Rodríguez', 1376.56),
#  ('Esponjas', 'Cortés', 1375.76),
#  ('Leche', 'Navarro', 1375.59),
#  ('Pilas', 'Campos', 1374.25),
#  ('Lechuga', 'Salinas', 1371.89),
#  ('Cebolla', 'Moreno', 1371.69),
#  ('Tierra para macetas', 'Velázquez', 1368.62),
#  ('Esponjas', 'Martínez', 1368.55),
#  ('Naranja', 'Salinas', 1368.29),
#  ('Manzana', 'Jiménez', 1367.83),
#  ('Tomate', 'Hernández', 1364.27),
#  ('Regadera', 'González', 1363.89),
#  ('Cebolla', 'Jiménez', 1361.38),
#  ('Crema hidratante', 'Romero', 1360.7),
#  ('Crema hidratante', 'Castro', 1357.56),
#  ('Mantequilla', 'Sánchez', 1355.62),
#  ('Papas fritas', 'Cabrera', 1354.83),
#  ('Bolsas de basura', 'Moreno', 1353.85),
#  ('Chicles', 'Serrano', 1353.08),
#  ('Chuletas', 'Domínguez', 1351.44),
#  ('Tomate', 'López', 1351.01),
#  ('Manzana', 'Fernández', 1349.44),
#  ('Queso', 'Montes', 1349.37),
#  ('Chuletas', 'Cruz', 1348.11),
#  ('Agua', 'Díaz', 1347.71),
#  ('Champú', 'Ortiz', 1347.38),
#  ('Jugo de naranja', 'Lara', 1346.26),
#  ('Champú', 'Ramos', 1343.72),
#  ('Detergente', 'Rubio', 1341.42),
#  ('Semillas', 'Ramos', 1338.7),
#  ('Uva', 'Ruiz', 1337.6),
#  ('Galletas', 'Hernández', 1334.72),
#  ('Chicles', 'Romero', 1333.17),
#  ('Regadera', 'Méndez', 1331.95),
#  ('Colonia', 'Navarro', 1331.9),
#  ('Fertilizante', 'Hernández', 1331.03),
#  ('Manzana', 'Reyes', 1330.71),
#  ('Detergente', 'Ramos', 1330.05),
#  ('Chuletas', 'Rubio', 1329.08),
#  ('Detergente', 'Cortés', 1327.13),
#  ('Tomate', 'Flores', 1325.11),
#  ('Jabón líquido', 'Montes', 1324.81),
#  ('Chocolate', 'Castro', 1324.39),
#  ('Esponjas', 'Cortés', 1324.01),
#  ('Naranja', 'Reyes', 1322.51),
#  ('Fertilizante', 'Medina', 1321.01),
#  ('Yogur', 'Álvarez', 1318.02),
#  ('Leche', 'Medina', 1316.85),
#  ('Mantequilla', 'Flores', 1314.89),
#  ('Desinfectante', 'Fernández', 1314.04),
#  ('Chuletas', 'Romero', 1313.21),
#  ('Lechuga', 'Castro', 1312.44),
#  ('Fertilizante', 'García', 1312.0),
#  ('Agua', 'Paredes', 1311.93),
#  ('Banana', 'Peña', 1310.28),
#  ('Carne de res', 'Cabrera', 1309.52),
#  ('Agua', 'Martínez', 1305.79),
#  ('Cerdo', 'Esquivel', 1305.52),
#  ('Platos desechables', 'Serrano', 1303.91),
#  ('Esponjas', 'Rodríguez', 1303.91),
#  ('Cerveza', 'Ruiz', 1302.43),
#  ('Semillas', 'Esquivel', 1302.31),
#  ('Cerdo', 'Reyes', 1300.62),
#  ('Fertilizante', 'Hernández', 1298.86),
#  ('Pollo', 'Reyes', 1298.6),
#  ('Velas', 'Sánchez', 1298.53),
#  ('Desinfectante', 'Delgado', 1298.03),
#  ('Esponjas', 'Medina', 1295.27),
#  ('Desodorante', 'Ortiz', 1294.26),
#  ('Papas fritas', 'Sánchez', 1293.23),
#  ('Banana', 'Molina', 1291.25),
#  ('Chocolate', 'Medina', 1290.5),
#  ('Refresco', 'Romero', 1290.18),
#  ('Mantequilla', 'Ortiz', 1290.14),
#  ('Detergente', 'Torres', 1289.49),
#  ('Leche', 'López', 1287.88),
#  ('Uva', 'López', 1287.68),
#  ('Uva', 'Torres', 1285.42),
#  ('Papas fritas', 'Jiménez', 1284.19),
#  ('Desinfectante', 'Campos', 1280.24),
#  ('Agua', 'Martínez', 1278.35),
#  ('Chocolate', 'Velázquez', 1277.6),
#  ('Detergente', 'Domínguez', 1276.88),
#  ('Bolsas de basura', 'Esquivel', 1274.94),
#  ('Banana', 'Cruz', 1273.61),
#  ('Chocolate', 'Esquivel', 1273.14),
#  ('Galletas', 'García', 1270.54),
#  ('Jabón líquido', 'Cruz', 1269.91),
#  ('Lechuga', 'Navarro', 1269.32),
#  ('Detergente', 'Chávez', 1269.15),
#  ('Crema hidratante', 'Lara', 1266.16),
#  ('Leche', 'Molina', 1266.12),
#  ('Cerveza', 'López', 1264.33),
#  ('Chicles', 'Guzmán', 1263.21),
#  ('Chocolate', 'Chávez', 1263.14),
#  ('Pollo', 'Hernández', 1260.32),
#  ('Velas', 'Pérez', 1260.26),
#  ('Jugo de naranja', 'Romero', 1259.65),
#  ('Platos desechables', 'Fuentes', 1259.13),
#  ('Regadera', 'Sánchez', 1257.04),
#  ('Naranja', 'Romero', 1256.81),
#  ('Semillas', 'Rubio', 1256.6),
#  ('Naranja', 'Santos', 1255.63),
#  ('Zanahoria', 'Ortiz', 1254.98),
#  ('Esponjas', 'Vázquez', 1253.72),
#  ('Champú', 'Díaz', 1252.44),
#  ('Pollo', 'Ortiz', 1252.06),
#  ('Pilas', 'García', 1252.02),
#  ('Agua', 'Guzmán', 1251.68),
#  ('Tomate', 'Medina', 1251.61),
#  ('Cerveza', 'González', 1250.64),
#  ('Pollo', 'Aguilar', 1250.44),
#  ('Colonia', 'Rodríguez', 1247.11),
#  ('Semillas', 'Rubio', 1246.9),
#  ('Velas', 'Molina', 1244.38),
#  ('Lechuga', 'Moreno', 1242.98),
#  ('Leche', 'Jiménez', 1241.44),
#  ('Semillas', 'Ramos', 1241.04),
#  ('Champú', 'Rubio', 1240.27),
#  ('Esponjas', 'Romero', 1239.48),
#  ('Tomate', 'Molina', 1238.09),
#  ('Tierra para macetas', 'Álvarez', 1237.3),
#  ('Jabón líquido', 'Aguilar', 1236.98),
#  ('Semillas', 'Sánchez', 1236.94),
#  ('Desinfectante', 'Díaz', 1236.37),
#  ('Chicles', 'Rubio', 1236.3),
#  ('Desodorante', 'García', 1235.7),
#  ('Tierra para macetas', 'Vázquez', 1234.45),
#  ('Velas', 'Jiménez', 1233.79),
#  ('Semillas', 'Fernández', 1233.72),
#  ('Detergente', 'Molina', 1233.23),
#  ('Esponjas', 'Moreno', 1233.2),
#  ('Banana', 'Molina', 1233.19),
#  ('Cerdo', 'Paredes', 1231.39),
#  ('Pilas', 'López', 1230.29),
#  ('Jugo de naranja', 'Ramírez', 1227.95),
#  ('Tomate', 'Chávez', 1227.89),
#  ('Regadera', 'Salinas', 1227.09),
#  ('Platos desechables', 'López', 1226.01),
#  ('Chocolate', 'Carrillo', 1225.42),
#  ('Zanahoria', 'Medina', 1224.47),
#  ('Lechuga', 'Carrillo', 1222.34),
#  ('Desinfectante', 'Álvarez', 1220.75),
#  ('Galletas', 'Vázquez', 1220.38),
#  ('Queso', 'Salinas', 1216.91),
#  ('Chuletas', 'Sánchez', 1216.68),
#  ('Uva', 'Velázquez', 1216.37),
#  ('Cebolla', 'Esquivel', 1216.26),
#  ('Chicles', 'Sánchez', 1216.21),
#  ('Uva', 'Jiménez', 1215.69),
#  ('Pilas', 'Ramírez', 1214.96),
#  ('Cebolla', 'Fernández', 1214.33),
#  ('Crema hidratante', 'Navarro', 1214.18),
#  ('Bolsas de basura', 'Peña', 1214.04),
#  ('Galletas', 'Santos', 1213.16),
#  ('Desinfectante', 'Reyes', 1213.06),
#  ('Desodorante', 'García', 1212.45),
#  ('Manzana', 'Romero', 1208.57),
#  ('Cebolla', 'Navarro', 1207.02),
#  ('Uva', 'Castro', 1206.27),
#  ('Chuletas', 'Reyes', 1206.27),
#  ('Pilas', 'Ruiz', 1206.21),
#  ('Detergente', 'Ramos', 1203.96),
#  ('Tierra para macetas', 'Montes', 1203.69),
#  ('Leche', 'Velázquez', 1203.18),
#  ('Manzana', 'Esquivel', 1202.44),
#  ('Bolsas de basura', 'Fuentes', 1202.2),
#  ('Colonia', 'Martínez', 1201.88),
#  ('Tierra para macetas', 'Santos', 1197.39),
#  ('Platos desechables', 'Fuentes', 1197.39),
#  ('Banana', 'Campos', 1196.67),
#  ('Cebolla', 'Romero', 1196.56),
#  ('Cerveza', 'González', 1196.09),
#  ('Detergente', 'Martínez', 1194.3),
#  ('Cerveza', 'Santos', 1193.13),
#  ('Banana', 'Guzmán', 1193.05),
#  ('Pollo', 'Paredes', 1192.68),
#  ('Desodorante', 'Martínez', 1191.44),
#  ('Jugo de naranja', 'Salinas', 1189.52),
#  ('Esponjas', 'Reyes', 1187.82),
#  ('Chuletas', 'Ruiz', 1187.47),
#  ('Jugo de naranja', 'Rodríguez', 1185.1),
#  ('Cebolla', 'Sánchez', 1184.77),
#  ('Jabón líquido', 'Pérez', 1184.7),
#  ('Carne de res', 'Chávez', 1184.69),
#  ('Pollo', 'Jiménez', 1182.12),
#  ('Esponjas', 'Ortiz', 1181.48),
#  ('Bolsas de basura', 'Méndez', 1181.46),
#  ('Cerdo', 'Peña', 1180.57),
#  ('Yogur', 'Méndez', 1180.13),
#  ('Detergente', 'Torres', 1179.29),
#  ('Refresco', 'Navarro', 1178.44),
#  ('Uva', 'Esquivel', 1178.23),
#  ('Cebolla', 'Castro', 1177.09),
#  ('Chocolate', 'Esquivel', 1175.81),
#  ('Bolsas de basura', 'Cortés', 1174.93),
#  ('Colonia', 'Molina', 1174.69),
#  ('Desodorante', 'Chávez', 1174.53),
#  ('Chocolate', 'Castro', 1173.21),
#  ('Pollo', 'Cruz', 1172.96),
#  ('Velas', 'Chávez', 1172.84),
#  ('Cerdo', 'Reyes', 1170.64),
#  ('Banana', 'Montes', 1170.54),
#  ('Leche', 'Peña', 1168.98),
#  ('Semillas', 'Paredes', 1167.0),
#  ('Agua', 'Rubio', 1166.09),
#  ('Lechuga', 'Martínez', 1166.0),
#  ('Desinfectante', 'López', 1166.0),
#  ('Yogur', 'Hernández', 1165.91),
#  ('Galletas', 'Reyes', 1164.6),
#  ('Tomate', 'Ramírez', 1163.91),
#  ('Cerdo', 'Reyes', 1162.25),
#  ('Pilas', 'Jiménez', 1161.52),
#  ('Yogur', 'Cortés', 1159.96),
#  ('Detergente', 'Ramírez', 1159.74),
#  ('Jabón líquido', 'Campos', 1158.96),
#  ('Champú', 'Paredes', 1158.01),
#  ('Champú', 'Navarro', 1157.14),
#  ('Tierra para macetas', 'Sánchez', 1156.72),
#  ('Velas', 'Chávez', 1156.71),
#  ('Detergente', 'Navarro', 1156.71),
#  ('Lechuga', 'Moreno', 1153.8),
#  ('Desodorante', 'Paredes', 1151.73),
#  ('Galletas', 'Martínez', 1151.73),
#  ('Regadera', 'Hernández', 1151.02),
#  ('Uva', 'Méndez', 1150.6),
#  ('Cerdo', 'Hernández', 1149.25),
#  ('Galletas', 'Salinas', 1146.8),
#  ('Platos desechables', 'García', 1146.07),
#  ('Jabón líquido', 'Montes', 1145.52),
#  ('Carne de res', 'Ruiz', 1145.27),
#  ('Crema hidratante', 'Cruz', 1145.19),
#  ('Lechuga', 'Jiménez', 1142.32),
#  ('Carne de res', 'López', 1141.91),
#  ('Semillas', 'Díaz', 1141.08),
#  ('Chicles', 'Sánchez', 1140.44),
#  ('Zanahoria', 'Ortiz', 1140.33),
#  ('Yogur', 'Cabrera', 1140.32),
#  ('Desodorante', 'Domínguez', 1139.45),
#  ('Desodorante', 'Hernández', 1137.67),
#  ('Cebolla', 'Campos', 1137.02),
#  ('Queso', 'Flores', 1135.57),
#  ('Colonia', 'Cruz', 1135.48),
#  ('Detergente', 'Torres', 1132.53),
#  ('Uva', 'Reyes', 1132.33),
#  ('Desodorante', 'Medina', 1132.18),
#  ('Chicles', 'Romero', 1131.8),
#  ('Agua', 'López', 1131.77),
#  ('Chuletas', 'Campos', 1131.54),
#  ('Detergente', 'Cortés', 1131.49),
#  ('Desodorante', 'Fuentes', 1130.02),
#  ('Esponjas', 'Fernández', 1128.39),
#  ('Chicles', 'Peña', 1128.32),
#  ('Jugo de naranja', 'Pérez', 1128.13),
#  ('Desodorante', 'Sánchez', 1127.85),
#  ('Champú', 'Serrano', 1127.84),
#  ('Banana', 'Rodríguez', 1126.02),
#  ('Papas fritas', 'Ramos', 1124.79),
#  ('Bolsas de basura', 'Fuentes', 1124.25),
#  ('Leche', 'Ortiz', 1123.74),
#  ('Lechuga', 'Cabrera', 1123.1),
#  ('Cerveza', 'Ortiz', 1122.74),
#  ('Carne de res', 'Hernández', 1121.25),
#  ('Crema hidratante', 'González', 1119.12),
#  ('Carne de res', 'Flores', 1118.73),
#  ('Leche', 'Pérez', 1118.16),
#  ('Chicles', 'Cruz', 1118.0),
#  ('Galletas', 'Rodríguez', 1117.34),
#  ('Cerdo', 'Esquivel', 1116.86),
#  ('Crema hidratante', 'Serrano', 1116.13),
#  ('Lechuga', 'Aguilar', 1115.06),
#  ('Uva', 'Hernández', 1114.05),
#  ('Desinfectante', 'González', 1113.97),
#  ('Banana', 'Peña', 1112.87),
#  ('Chicles', 'Rodríguez', 1112.74),
#  ('Chuletas', 'Cruz', 1111.51),
#  ('Bolsas de basura', 'García', 1111.43),
#  ('Champú', 'Vázquez', 1110.54),
#  ('Pollo', 'López', 1109.02),
#  ('Galletas', 'Campos', 1108.58),
#  ('Tierra para macetas', 'Navarro', 1108.5),
#  ('Cebolla', 'Delgado', 1106.45),
#  ('Yogur', 'Méndez', 1106.07),
#  ('Mantequilla', 'Martínez', 1105.49),
#  ('Tomate', 'Salinas', 1105.37),
#  ('Yogur', 'Moreno', 1104.96),
#  ('Cebolla', 'Hernández', 1104.11),
#  ('Leche', 'Ramírez', 1104.09),
#  ('Velas', 'Ramírez', 1103.9),
#  ('Chocolate', 'Carrillo', 1103.75),
#  ('Bolsas de basura', 'Jiménez', 1103.52),
#  ('Champú', 'Moreno', 1101.32),
#  ('Chicles', 'Moreno', 1101.23),
#  ('Fertilizante', 'Torres', 1100.46),
#  ('Chicles', 'Vázquez', 1100.2),
#  ('Cebolla', 'Rubio', 1099.5),
#  ('Cerveza', 'Domínguez', 1098.38),
#  ('Leche', 'Ortiz', 1098.18),
#  ('Manzana', 'Aguilar', 1097.68),
#  ('Lechuga', 'Salinas', 1097.53),
#  ('Colonia', 'Cortés', 1097.33),
#  ('Cebolla', 'Rubio', 1097.32),
#  ('Desinfectante', 'Chávez', 1097.32),
#  ('Bolsas de basura', 'Guzmán', 1096.89),
#  ('Carne de res', 'Delgado', 1096.45),
#  ('Bolsas de basura', 'Lara', 1096.21),
#  ('Desinfectante', 'Vázquez', 1093.53),
#  ('Tierra para macetas', 'Sánchez', 1093.18),
#  ('Cerveza', 'Vázquez', 1092.73),
#  ('Yogur', 'Esquivel', 1092.14),
#  ('Zanahoria', 'Rodríguez', 1091.99),
#  ('Detergente', 'Paredes', 1091.55),
#  ('Cerveza', 'Rubio', 1089.71),
#  ('Cebolla', 'Fernández', 1088.48),
#  ('Cerveza', 'Domínguez', 1088.44),
#  ('Cerveza', 'Hernández', 1087.21),
#  ('Tomate', 'García', 1085.77),
#  ('Uva', 'Álvarez', 1084.61),
#  ('Detergente', 'Domínguez', 1084.48),
#  ('Carne de res', 'Cabrera', 1084.23),
#  ('Chuletas', 'Chávez', 1083.83),
#  ('Chuletas', 'Rubio', 1083.65),
#  ('Uva', 'Méndez', 1083.39),
#  ('Manzana', 'Chávez', 1080.45),
#  ('Chuletas', 'Peña', 1079.0),
#  ('Chuletas', 'Domínguez', 1077.34),
#  ('Jugo de naranja', 'Campos', 1076.59),
#  ('Yogur', 'Guzmán', 1075.91),
#  ('Cerveza', 'Castro', 1075.74),
#  ('Tomate', 'Díaz', 1075.18),
#  ('Naranja', 'Esquivel', 1072.46),
#  ('Tomate', 'Paredes', 1072.01),
#  ('Jugo de naranja', 'López', 1070.68),
#  ('Cerveza', 'Domínguez', 1069.78),
#  ('Chocolate', 'Fernández', 1068.43),
#  ('Manzana', 'Ortiz', 1068.43),
#  ('Regadera', 'Rubio', 1068.37),
#  ('Desinfectante', 'Castro', 1068.35),
#  ('Cebolla', 'Castro', 1068.18),
#  ('Lechuga', 'Méndez', 1067.88),
#  ('Zanahoria', 'Vázquez', 1067.02),
#  ('Esponjas', 'Cortés', 1066.99),
#  ('Galletas', 'Pérez', 1065.94),
#  ('Chicles', 'Ruiz', 1065.64),
#  ('Queso', 'Jiménez', 1065.14),
#  ('Jugo de naranja', 'Romero', 1063.81),
#  ('Lechuga', 'Salinas', 1063.32),
#  ('Pilas', 'Cortés', 1063.26),
#  ('Cerveza', 'Domínguez', 1060.71),
#  ('Queso', 'Molina', 1060.26),
#  ('Papas fritas', 'Delgado', 1059.05),
#  ('Platos desechables', 'Cruz', 1058.28),
#  ('Banana', 'Chávez', 1057.58),
#  ('Champú', 'Molina', 1056.77),
#  ('Queso', 'Martínez', 1056.02),
#  ('Bolsas de basura', 'Aguilar', 1055.96),
#  ('Regadera', 'Navarro', 1055.71),
#  ('Lechuga', 'Ramos', 1055.41),
#  ('Cerdo', 'Vázquez', 1055.23),
#  ('Mantequilla', 'Ramírez', 1053.86),
#  ('Platos desechables', 'Serrano', 1053.44),
#  ('Chocolate', 'Castro', 1052.13),
#  ('Desodorante', 'Carrillo', 1050.92),
#  ('Chuletas', 'Hernández', 1050.72),
#  ('Carne de res', 'Carrillo', 1048.82),
#  ('Pilas', 'Velázquez', 1048.81),
#  ('Tierra para macetas', 'Ramírez', 1048.77),
#  ('Refresco', 'Navarro', 1048.1),
#  ('Queso', 'Ortiz', 1045.01),
#  ('Chocolate', 'Martínez', 1045.01),
#  ('Crema hidratante', 'Delgado', 1044.95),
#  ('Refresco', 'Molina', 1044.49),
#  ('Pilas', 'Chávez', 1044.22),
#  ('Tomate', 'Campos', 1044.18),
#  ('Galletas', 'Chávez', 1044.05),
#  ('Leche', 'Serrano', 1044.04),
#  ('Mantequilla', 'Ramírez', 1043.45),
#  ('Chocolate', 'Moreno', 1043.13),
#  ('Esponjas', 'Romero', 1041.64),
#  ('Regadera', 'Hernández', 1041.55),
#  ('Platos desechables', 'Cabrera', 1040.76),
#  ('Jabón líquido', 'González', 1040.69),
#  ('Detergente', 'Cruz', 1038.63),
#  ('Bolsas de basura', 'Aguilar', 1036.14),
#  ('Tierra para macetas', 'Moreno', 1034.35),
#  ('Colonia', 'Esquivel', 1033.0),
#  ('Pollo', 'Ortiz', 1031.59),
#  ('Velas', 'Díaz', 1031.21),
#  ('Chicles', 'Paredes', 1030.9),
#  ('Queso', 'Santos', 1030.69),
#  ('Chocolate', 'Fuentes', 1030.36),
#  ('Chuletas', 'Flores', 1029.96),
#  ('Velas', 'Carrillo', 1028.3),
#  ('Tierra para macetas', 'Álvarez', 1027.05),
#  ('Banana', 'Campos', 1026.59),
#  ('Regadera', 'Moreno', 1026.05),
#  ('Chuletas', 'Montes', 1024.56),
#  ('Lechuga', 'Sánchez', 1023.72),
#  ('Galletas', 'Ramos', 1021.24),
#  ('Chicles', 'Méndez', 1020.38),
#  ('Crema hidratante', 'Moreno', 1019.39),
#  ('Velas', 'Salinas', 1018.99),
#  ('Colonia', 'Santos', 1018.63),
#  ('Yogur', 'González', 1018.62),
#  ('Cerveza', 'Fernández', 1017.73),
#  ('Desodorante', 'Méndez', 1015.18),
#  ('Mantequilla', 'Santos', 1013.03),
#  ('Tomate', 'Romero', 1012.95),
#  ('Cebolla', 'Guzmán', 1012.74),
#  ('Agua', 'Pérez', 1010.18),
#  ('Chicles', 'Torres', 1008.13),
#  ('Chuletas', 'Flores', 1008.11),
#  ('Pilas', 'Carrillo', 1007.7),
#  ('Colonia', 'Jiménez', 1007.54),
#  ('Pollo', 'Montes', 1006.61),
#  ('Semillas', 'Rubio', 1006.57),
#  ('Chicles', 'Carrillo', 1005.54),
#  ('Bolsas de basura', 'Pérez', 1004.24),
#  ('Naranja', 'Delgado', 1003.91),
#  ('Desinfectante', 'Molina', 1003.87),
#  ('Cerdo', 'González', 1003.55),
#  ('Colonia', 'Chávez', 1002.93),
#  ('Chocolate', 'Fuentes', 1002.83),
#  ('Tomate', 'Serrano', 1002.8),
#  ('Regadera', 'Jiménez', 1001.63),
#  ('Naranja', 'Velázquez', 1000.26),
#  ('Zanahoria', 'Chávez', 999.69),
#  ('Pilas', 'Flores', 998.79),
#  ('Carne de res', 'Sánchez', 998.62),
#  ('Semillas', 'Ruiz', 997.93),
#  ('Desodorante', 'Castro', 997.7),
#  ('Tomate', 'Sánchez', 997.35),
#  ('Banana', 'Ortiz', 996.41),
#  ('Cebolla', 'López', 995.86),
#  ('Fertilizante', 'Serrano', 994.8),
#  ('Mantequilla', 'Salinas', 994.54),
#  ('Regadera', 'Jiménez', 992.69),
#  ('Chuletas', 'Sánchez', 992.37),
#  ('Refresco', 'Velázquez', 991.87),
#  ('Banana', 'Pérez', 990.71),
#  ('Esponjas', 'Molina', 990.7),
#  ('Crema hidratante', 'Pérez', 990.29),
#  ('Cerveza', 'Ramos', 990.16),
#  ('Pilas', 'González', 989.93),
#  ('Carne de res', 'Cortés', 988.86),
#  ('Zanahoria', 'Peña', 988.83),
#  ('Bolsas de basura', 'Velázquez', 988.61),
#  ('Velas', 'Fuentes', 988.4),
#  ('Zanahoria', 'Cortés', 987.84),
#  ('Manzana', 'Ortiz', 987.25),
#  ('Yogur', 'Hernández', 985.58),
#  ('Regadera', 'Esquivel', 985.11),
#  ('Chuletas', 'Díaz', 984.56),
#  ('Bolsas de basura', 'Carrillo', 983.38),
#  ('Crema hidratante', 'Delgado', 983.19),
#  ('Galletas', 'García', 982.35),
#  ('Tierra para macetas', 'Campos', 982.13),
#  ('Fertilizante', 'Delgado', 981.91),
#  ('Bolsas de basura', 'Castro', 981.8),
#  ('Cebolla', 'Montes', 979.86),
#  ('Zanahoria', 'Ramos', 979.5),
#  ('Manzana', 'Sánchez', 978.07),
#  ('Bolsas de basura', 'Salinas', 977.87),
#  ('Chocolate', 'Paredes', 977.24),
#  ('Zanahoria', 'Méndez', 975.52),
#  ('Lechuga', 'López', 975.34),
#  ('Semillas', 'Molina', 973.79),
#  ('Cerdo', 'Sánchez', 971.91),
#  ('Detergente', 'Peña', 968.73),
#  ('Papas fritas', 'Méndez', 967.39),
#  ('Galletas', 'Hernández', 966.81),
#  ('Desinfectante', 'Lara', 965.82),
#  ('Cerdo', 'Guzmán', 965.77),
#  ('Detergente', 'Díaz', 964.93),
#  ('Cerveza', 'Aguilar', 964.86),
#  ('Yogur', 'Martínez', 964.17),
#  ('Galletas', 'Álvarez', 962.55),
#  ('Leche', 'Serrano', 962.43),
#  ('Desodorante', 'Méndez', 962.3),
#  ('Crema hidratante', 'Romero', 962.04),
#  ('Tierra para macetas', 'Romero', 962.0),
#  ('Galletas', 'Ramírez', 961.85),
#  ('Esponjas', 'Pérez', 961.37),
#  ('Desodorante', 'Jiménez', 961.17),
#  ('Manzana', 'Torres', 961.08),
#  ('Bolsas de basura', 'Fernández', 960.07),
#  ('Naranja', 'Romero', 959.35),
#  ('Detergente', 'Martínez', 958.95),
#  ('Semillas', 'Campos', 958.9),
#  ('Cerveza', 'Jiménez', 958.86),
#  ('Uva', 'Velázquez', 958.57),
#  ('Papas fritas', 'Delgado', 957.55),
#  ('Regadera', 'Santos', 957.11),
#  ('Regadera', 'Cruz', 956.51),
#  ('Uva', 'Hernández', 955.53),
#  ('Crema hidratante', 'Álvarez', 955.15),
#  ('Zanahoria', 'Ruiz', 953.36),
#  ('Regadera', 'García', 952.37),
#  ('Naranja', 'Vázquez', 951.44),
#  ('Naranja', 'Pérez', 950.15),
#  ('Queso', 'Fernández', 950.15),
#  ('Tierra para macetas', 'Lara', 949.08),
#  ('Manzana', 'Carrillo', 948.64),
#  ('Jugo de naranja', 'García', 948.17),
#  ('Jabón líquido', 'Molina', 946.88),
#  ('Manzana', 'Peña', 945.08),
#  ('Fertilizante', 'Vázquez', 943.45),
#  ('Yogur', 'Montes', 942.39),
#  ('Queso', 'Castro', 941.83),
#  ('Cerveza', 'Pérez', 941.08),
#  ('Yogur', 'Jiménez', 940.78),
#  ('Cerveza', 'Lara', 939.92),
#  ('Esponjas', 'Chávez', 939.87),
#  ('Yogur', 'Ortiz', 939.65),
#  ('Tierra para macetas', 'Aguilar', 938.48),
#  ('Fertilizante', 'Sánchez', 937.8),
#  ('Colonia', 'Navarro', 935.85),
#  ('Desinfectante', 'Domínguez', 935.15),
#  ('Galletas', 'Delgado', 934.19),
#  ('Cerveza', 'Domínguez', 933.15),
#  ('Lechuga', 'Hernández', 932.86),
#  ('Refresco', 'Castro', 932.51),
#  ('Pilas', 'Rubio', 931.81),
#  ('Bolsas de basura', 'Fuentes', 931.17),
#  ('Desodorante', 'Cabrera', 929.6),
#  ('Leche', 'Rubio', 929.27),
#  ('Banana', 'Méndez', 929.22),
#  ('Jugo de naranja', 'Molina', 928.68),
#  ('Crema hidratante', 'Vázquez', 928.67),
#  ('Manzana', 'Santos', 928.37),
#  ('Galletas', 'Álvarez', 927.53),
#  ('Leche', 'Romero', 927.29),
#  ('Cebolla', 'Fernández', 926.65),
#  ('Banana', 'Ruiz', 925.78),
#  ('Tomate', 'Ramos', 925.66),
#  ('Velas', 'Domínguez', 923.96),
#  ('Crema hidratante', 'Lara', 921.18),
#  ('Naranja', 'Moreno', 921.12),
#  ('Refresco', 'Molina', 920.9),
#  ('Colonia', 'Rodríguez', 919.9),
#  ('Chicles', 'Cortés', 919.86),
#  ('Bolsas de basura', 'Molina', 919.6),
#  ('Papas fritas', 'Esquivel', 917.6),
#  ('Carne de res', 'Pérez', 917.45),
#  ('Fertilizante', 'Lara', 917.12),
#  ('Zanahoria', 'Cortés', 916.52),
#  ('Cerdo', 'Serrano', 916.27),
#  ('Crema hidratante', 'Pérez', 916.24),
#  ('Pilas', 'Molina', 915.74),
#  ('Pilas', 'Jiménez', 915.16),
#  ('Fertilizante', 'Vázquez', 913.54),
#  ('Desodorante', 'Lara', 912.04),
#  ('Champú', 'Ortiz', 910.81),
#  ('Velas', 'Jiménez', 909.8),
#  ('Tierra para macetas', 'Cruz', 909.08),
#  ('Zanahoria', 'Esquivel', 908.76),
#  ('Esponjas', 'Reyes', 907.64),
#  ('Chuletas', 'Cortés', 904.8),
#  ('Queso', 'Guzmán', 904.57),
#  ('Jugo de naranja', 'Chávez', 904.54),
#  ('Semillas', 'Ruiz', 904.25),
#  ('Colonia', 'Fernández', 904.07),
#  ('Refresco', 'Jiménez', 901.43),
#  ('Uva', 'Domínguez', 901.42),
#  ('Jugo de naranja', 'Romero', 901.12),
#  ('Detergente', 'Aguilar', 900.03),
#  ('Yogur', 'Ortiz', 899.57),
#  ('Semillas', 'Molina', 899.3),
#  ('Desinfectante', 'Méndez', 899.06),
#  ('Jabón líquido', 'Medina', 898.69),
#  ('Cerdo', 'Méndez', 898.65),
#  ('Fertilizante', 'López', 896.99),
#  ('Mantequilla', 'Ramírez', 896.94),
#  ('Fertilizante', 'Guzmán', 893.64),
#  ('Crema hidratante', 'González', 893.63),
#  ('Agua', 'Sánchez', 892.51),
#  ('Pilas', 'Martínez', 891.49),
#  ('Fertilizante', 'Cabrera', 891.48),
#  ('Refresco', 'Delgado', 890.14),
#  ('Chuletas', 'Santos', 889.63),
#  ('Carne de res', 'Carrillo', 888.8),
#  ('Bolsas de basura', 'García', 887.37),
#  ('Bolsas de basura', 'García', 887.07),
#  ('Cerdo', 'López', 886.0),
#  ('Jabón líquido', 'Díaz', 885.54),
#  ('Queso', 'López', 884.53),
#  ('Agua', 'Ramos', 884.35),
#  ('Banana', 'Sánchez', 883.58),
#  ('Jugo de naranja', 'Flores', 882.54),
#  ('Semillas', 'Díaz', 881.18),
#  ('Pilas', 'Flores', 880.93),
#  ('Desodorante', 'Álvarez', 880.86),
#  ('Velas', 'Ramírez', 880.44),
#  ('Chocolate', 'López', 880.35),
#  ('Velas', 'Pérez', 880.32),
#  ('Tierra para macetas', 'Campos', 880.24),
#  ('Bolsas de basura', 'Fernández', 879.98),
#  ('Pilas', 'Fuentes', 879.14),
#  ('Yogur', 'Rodríguez', 879.13),
#  ('Refresco', 'Chávez', 878.9),
#  ('Chocolate', 'Castro', 878.1),
#  ('Leche', 'Navarro', 877.49),
#  ('Lechuga', 'Velázquez', 877.26),
#  ('Agua', 'Ruiz', 876.47),
#  ('Chicles', 'Pérez', 876.4),
#  ('Chicles', 'Flores', 876.27),
#  ('Mantequilla', 'González', 875.58),
#  ('Refresco', 'Sánchez', 875.35),
#  ('Yogur', 'Fernández', 875.31),
#  ('Pilas', 'Martínez', 874.49),
#  ('Cebolla', 'Ramírez', 874.26),
#  ('Refresco', 'Méndez', 874.09),
#  ('Uva', 'Méndez', 873.06),
#  ('Regadera', 'Serrano', 872.79),
#  ('Velas', 'Navarro', 872.48),
#  ('Velas', 'Paredes', 872.32),
#  ('Pollo', 'Méndez', 871.11),
#  ('Agua', 'Serrano', 871.06),
#  ('Tomate', 'Chávez', 870.77),
#  ('Chuletas', 'Fuentes', 870.63),
#  ('Bolsas de basura', 'Torres', 870.52),
#  ('Platos desechables', 'López', 870.0),
#  ('Queso', 'Rubio', 869.94),
#  ('Pollo', 'Ramírez', 869.74),
#  ('Jugo de naranja', 'Esquivel', 869.56),
#  ('Detergente', 'González', 867.28),
#  ('Chocolate', 'Montes', 867.13),
#  ('Chicles', 'Cruz', 867.11),
#  ('Uva', 'Reyes', 865.99),
#  ('Cerveza', 'Cruz', 865.14),
#  ('Refresco', 'Fuentes', 864.4),
#  ('Detergente', 'Pérez', 863.58),
#  ('Pollo', 'Carrillo', 862.84),
#  ('Papas fritas', 'Martínez', 862.23),
#  ('Carne de res', 'Vázquez', 861.97),
#  ('Yogur', 'Ramírez', 861.51),
#  ('Cebolla', 'Ortiz', 861.28),
#  ('Refresco', 'Cortés', 861.23),
#  ('Esponjas', 'Pérez', 861.08),
#  ('Agua', 'Torres', 859.29),
#  ('Agua', 'Delgado', 858.61),
#  ('Desinfectante', 'Álvarez', 857.05),
#  ('Detergente', 'Chávez', 856.07),
#  ('Chuletas', 'Serrano', 855.78),
#  ('Semillas', 'Romero', 854.33),
#  ('Cebolla', 'Martínez', 853.83),
#  ('Agua', 'Cruz', 853.45),
#  ('Zanahoria', 'Santos', 853.07),
#  ('Platos desechables', 'Serrano', 851.12),
#  ('Desodorante', 'Méndez', 850.75),
#  ('Velas', 'González', 850.4),
#  ('Velas', 'Domínguez', 850.32),
#  ('Naranja', 'Navarro', 850.08),
#  ('Mantequilla', 'Esquivel', 850.07),
#  ('Mantequilla', 'Álvarez', 850.05),
#  ('Chuletas', 'Romero', 849.42),
#  ('Papas fritas', 'Castro', 849.33),
#  ...]

# %% [markdown]
# * 5.-Empleados y número de órdenes gestionadas
#
#     * Muestra el nombre del empleado, el puesto y la cantidad de órdenes que ha gestionado.
#     * Utiliza GROUP BY y COUNT.

# %%
sql = ('SELECT e.nombre_empleado AS EMPLEADO, e.puesto AS PUESTO, count(o.id_empleado) AS ORDENES FROM empleados e JOIN ordenes o ON o.id_empleado = e.id_empleado GROUP BY e.id_empleado')
consultas(sql)
# Out:
# [('Carla Cabrera', 'Cajero', 79),
#  ('Raúl Hernández', 'Reponedor', 84),
#  ('Irene Ortiz', 'Encargado de sección', 72),
#  ('María Montes', 'Gerente', 68),
#  ('Samuel Sánchez', 'Personal de limpieza', 72),
#  ('David Montes', 'Panadero', 76),
#  ('Lorena Chávez', 'Carnicero', 76),
#  ('José Rodríguez', 'Pescadero', 78),
#  ('Clara Álvarez', 'Frutero', 74),
#  ('Irene Paredes', 'Charcutero', 82),
#  ('Ana Torres', 'Jefe de turno', 63),
#  ('Patricia Lara', 'Operador logístico', 57),
#  ('María Aguilar', 'Atención al cliente', 72),
#  ('Daniel Vázquez', 'Auxiliar de caja', 61),
#  ('Natalia Reyes', 'Encargado de seguridad', 89),
#  ('Marta Campos', 'Responsable de zona', 74),
#  ('Samuel Velázquez', 'Jefe de compras', 72),
#  ('Carla Ramos', 'Encargada carnicería', 72),
#  ('Miguel Sánchez', 'encargado pescadería', 69),
#  ('Eva Esquivel', 'Jefe de Limpieza', 67),
#  ('Clara Paredes', 'Cajero', 60),
#  ('Camila Navarro', 'Reponedor', 82),
#  ('Daniel Velázquez', 'Encargado de sección', 74),
#  ('Laura Santos', 'Gerente', 69),
#  ('Eduardo Ramos', 'Personal de limpieza', 71),
#  ('Clara Flores', 'Panadero', 87),
#  ('Eduardo Díaz', 'Carnicero', 71),
#  ('Sergio Santos', 'Pescadero', 91),
#  ('Gabriela Salinas', 'Frutero', 69),
#  ('Gabriela Cabrera', 'Charcutero', 71),
#  ('Andrea Chávez', 'Jefe de turno', 81),
#  ('Adriana Guzmán', 'Operador logístico', 75),
#  ('Valeria Medina', 'Atención al cliente', 64),
#  ('Elena Guzmán', 'Auxiliar de caja', 72),
#  ('Verónica González', 'Encargado de seguridad', 84),
#  ('Clara Ramírez', 'Responsable de zona', 82),
#  ('Ricardo Campos', 'Jefe de compras', 66),
#  ('Ricardo Jiménez', 'Encargada carnicería', 65),
#  ('Andrea Díaz', 'encargado pescadería', 73),
#  ('Verónica Fernández', 'Jefe de Limpieza', 67),
#  ('Sofía Serrano', 'Cajero', 70),
#  ('Miguel Molina', 'Reponedor', 70),
#  ('Alejandro Pérez', 'Encargado de sección', 97),
#  ('Gabriela Hernández', 'Gerente', 73),
#  ('Valeria Santos', 'Personal de limpieza', 72),
#  ('Verónica Rubio', 'Panadero', 69),
#  ('Ángel Ortiz', 'Carnicero', 83),
#  ('Lucía Molina', 'Pescadero', 80),
#  ('Irene Delgado', 'Frutero', 63),
#  ('Mario Cortés', 'Charcutero', 80),
#  ('Ángel Carrillo', 'Jefe de turno', 67),
#  ('Cristian Velázquez', 'Operador logístico', 65),
#  ('Julia Rodríguez', 'Atención al cliente', 76),
#  ('Andrea Paredes', 'Auxiliar de caja', 59),
#  ('Carlos Navarro', 'Encargado de seguridad', 90),
#  ('Valeria Ramos', 'Responsable de zona', 59),
#  ('Daniel Paredes', 'Jefe de compras', 71),
#  ('Jorge Ruiz', 'Encargada carnicería', 89),
#  ('Ana Navarro', 'encargado pescadería', 61),
#  ('Gabriela Hernández', 'Jefe de Limpieza', 56),
#  ('Patricia Castro', 'Cajero', 83),
#  ('Clara Navarro', 'Reponedor', 59),
#  ('Laura Salinas', 'Encargado de sección', 64),
#  ('Samuel Díaz', 'Gerente', 61),
#  ('Raúl García', 'Personal de limpieza', 71),
#  ('Verónica Lara', 'Panadero', 60),
#  ('Andrés Castro', 'Carnicero', 75),
#  ('Irene Delgado', 'Pescadero', 67),
#  ('Laura Ruiz', 'Frutero', 68),
#  ('Verónica Rubio', 'Charcutero', 65),
#  ('David Vázquez', 'Jefe de turno', 84),
#  ('Ricardo Reyes', 'Operador logístico', 72),
#  ('Adriana López', 'Atención al cliente', 74),
#  ('Carlos Rodríguez', 'Auxiliar de caja', 68),
#  ('Valeria Salinas', 'Encargado de seguridad', 72),
#  ('Eduardo Moreno', 'Responsable de zona', 72),
#  ('Andrea López', 'Jefe de compras', 69),
#  ('Adriana Moreno', 'Encargada carnicería', 75),
#  ('Diego Peña', 'encargado pescadería', 69),
#  ('Sara Cabrera', 'Jefe de Limpieza', 62),
#  ('Laura Peña', 'Cajero', 74),
#  ('Eva Moreno', 'Reponedor', 51),
#  ('Valeria Navarro', 'Encargado de sección', 68),
#  ('María Paredes', 'Gerente', 65),
#  ('Ángel Flores', 'Personal de limpieza', 76),
#  ('Carmen Carrillo', 'Panadero', 67),
#  ('Sergio Delgado', 'Carnicero', 76),
#  ('Irene Ortiz', 'Pescadero', 61),
#  ('Samuel Paredes', 'Frutero', 61),
#  ('Francisco Cruz', 'Charcutero', 65),
#  ('Clara Santos', 'Jefe de turno', 72),
#  ('Gabriela Fernández', 'Operador logístico', 62),
#  ('Paula Cabrera', 'Atención al cliente', 77),
#  ('Carla Lara', 'Auxiliar de caja', 69),
#  ('Marta Santos', 'Encargado de seguridad', 70),
#  ('Fernando Castro', 'Responsable de zona', 80),
#  ('Laura Rubio', 'Jefe de compras', 70),
#  ('Ángel Ortiz', 'Encargada carnicería', 61),
#  ('Isabel Molina', 'encargado pescadería', 71),
#  ('José Salinas', 'Jefe de Limpieza', 68),
#  ('Patricia Castro', 'Cajero', 57),
#  ('Cristian Navarro', 'Reponedor', 79),
#  ('Miguel Chávez', 'Encargado de sección', 71),
#  ('Lucía Cruz', 'Gerente', 54),
#  ('Patricia Velázquez', 'Personal de limpieza', 80),
#  ('Jorge Ramírez', 'Panadero', 76),
#  ('Julia Chávez', 'Carnicero', 60),
#  ('Camila Campos', 'Pescadero', 73),
#  ('José Díaz', 'Frutero', 77),
#  ('Carla Martínez', 'Charcutero', 80),
#  ('Eduardo Medina', 'Jefe de turno', 61),
#  ('Marta Santos', 'Operador logístico', 68),
#  ('Pablo Martínez', 'Atención al cliente', 71),
#  ('Sofía Ortiz', 'Auxiliar de caja', 69),
#  ('Samuel Ramírez', 'Encargado de seguridad', 59),
#  ('Pablo Ortiz', 'Responsable de zona', 60),
#  ('Adriana Ramírez', 'Jefe de compras', 92),
#  ('María Ruiz', 'Encargada carnicería', 79),
#  ('Natalia Campos', 'encargado pescadería', 76),
#  ('Carmen Velázquez', 'Jefe de Limpieza', 68),
#  ('Tomás Ruiz', 'Cajero', 71),
#  ('Pablo Navarro', 'Reponedor', 72),
#  ('Valeria Ruiz', 'Encargado de sección', 85),
#  ('Gabriela Campos', 'Gerente', 78),
#  ('Jorge Pérez', 'Personal de limpieza', 63),
#  ('Miguel Ruiz', 'Panadero', 81),
#  ('Rubén Castro', 'Carnicero', 66),
#  ('Lucía Ortiz', 'Pescadero', 71),
#  ('Hugo Torres', 'Frutero', 81),
#  ('Raúl Rodríguez', 'Charcutero', 65),
#  ('Laura Reyes', 'Jefe de turno', 73),
#  ('Andrés Guzmán', 'Operador logístico', 71),
#  ('Ana Esquivel', 'Atención al cliente', 84),
#  ('Eduardo Méndez', 'Auxiliar de caja', 76),
#  ('Hugo Moreno', 'Encargado de seguridad', 72),
#  ('Eva Peña', 'Responsable de zona', 74),
#  ('Rubén Fuentes', 'Jefe de compras', 66),
#  ('Luis Montes', 'Encargada carnicería', 78),
#  ('Valeria Ruiz', 'encargado pescadería', 65),
#  ('Carla Reyes', 'Jefe de Limpieza', 63)]

# %% [markdown]
# * 6.-Ordenes filtradas por fecha y tienda
#
#     * Muestra todas las órdenes que se realizaron en un rango de fechas determinado (ej.: del 1 de enero de 2025 al 31 de enero de 2025) y en una tienda específica.
#     * Incluye datos de la tienda y del cliente.

# %%
sql = ("SELECT t.id_tienda, t.nombre_tienda AS tienda, o.id_orden AS factura, o.fecha_orden AS fecha, concat(c.first_name,' ',c.last_name) AS cliente FROM tiendas t JOIN empleados e ON t.id_tienda = e.id_tienda JOIN ordenes o ON o.id_empleado = e.id_empleado JOIN clientes c ON c.id_cliente = o.id_cliente WHERE T.id_tienda = 1 and o.fecha_orden > '2024-01-31' and o.fecha_orden < '2024-03-01' ORDER BY o.fecha_orden;")
consultas(sql)
# Out:
# [(1, 'Tienda Centro', 810, datetime.date(2024, 2, 1), 'Yogur Méndez'),
#  (1, 'Tienda Centro', 805, datetime.date(2024, 2, 1), 'Colonia García'),
#  (1, 'Tienda Centro', 809, datetime.date(2024, 2, 1), 'Semillas Romero'),
#  (1,
#   'Tienda Centro',
#   794,
#   datetime.date(2024, 2, 1),
#   'Jugo de naranja Salinas'),
#  (1, 'Tienda Centro', 806, datetime.date(2024, 2, 1), 'Naranja López'),
#  (1, 'Tienda Centro', 795, datetime.date(2024, 2, 1), 'Papas fritas Aguilar'),
#  (1, 'Tienda Centro', 834, datetime.date(2024, 2, 2), 'Detergente Flores'),
#  (1, 'Tienda Centro', 842, datetime.date(2024, 2, 2), 'Carne de res Ortiz'),
#  (1, 'Tienda Centro', 822, datetime.date(2024, 2, 2), 'Desodorante Hernández'),
#  (1, 'Tienda Centro', 832, datetime.date(2024, 2, 2), 'Semillas Rubio'),
#  (1, 'Tienda Centro', 836, datetime.date(2024, 2, 2), 'Detergente Martínez'),
#  (1,
#   'Tienda Centro',
#   867,
#   datetime.date(2024, 2, 3),
#   'Platos desechables Santos'),
#  (1, 'Tienda Centro', 865, datetime.date(2024, 2, 3), 'Desinfectante Ramírez'),
#  (1, 'Tienda Centro', 851, datetime.date(2024, 2, 3), 'Pilas Campos'),
#  (1, 'Tienda Centro', 848, datetime.date(2024, 2, 3), 'Manzana Sánchez'),
#  (1, 'Tienda Centro', 866, datetime.date(2024, 2, 3), 'Lechuga Méndez'),
#  (1, 'Tienda Centro', 864, datetime.date(2024, 2, 3), 'Galletas Ortiz'),
#  (1,
#   'Tienda Centro',
#   890,
#   datetime.date(2024, 2, 4),
#   'Fertilizante Velázquez'),
#  (1, 'Tienda Centro', 883, datetime.date(2024, 2, 4), 'Chocolate López'),
#  (1, 'Tienda Centro', 897, datetime.date(2024, 2, 5), 'Lechuga Salinas'),
#  (1,
#   'Tienda Centro',
#   910,
#   datetime.date(2024, 2, 5),
#   'Tierra para macetas Fuentes'),
#  (1, 'Tienda Centro', 896, datetime.date(2024, 2, 5), 'Pilas López'),
#  (1, 'Tienda Centro', 930, datetime.date(2024, 2, 6), 'Colonia Romero'),
#  (1, 'Tienda Centro', 936, datetime.date(2024, 2, 6), 'Galletas Rodríguez'),
#  (1, 'Tienda Centro', 919, datetime.date(2024, 2, 6), 'Semillas Ramos'),
#  (1, 'Tienda Centro', 950, datetime.date(2024, 2, 7), 'Desodorante Lara'),
#  (1, 'Tienda Centro', 960, datetime.date(2024, 2, 7), 'Papas fritas Rubio'),
#  (1, 'Tienda Centro', 962, datetime.date(2024, 2, 7), 'Esponjas Cortés'),
#  (1, 'Tienda Centro', 982, datetime.date(2024, 2, 8), 'Cebolla Rubio'),
#  (1, 'Tienda Centro', 966, datetime.date(2024, 2, 8), 'Velas Torres'),
#  (1, 'Tienda Centro', 1000, datetime.date(2024, 2, 9), 'Agua Medina'),
#  (1, 'Tienda Centro', 992, datetime.date(2024, 2, 9), 'Uva Castro'),
#  (1, 'Tienda Centro', 996, datetime.date(2024, 2, 9), 'Detergente Domínguez'),
#  (1, 'Tienda Centro', 994, datetime.date(2024, 2, 9), 'Galletas Rubio'),
#  (1, 'Tienda Centro', 1007, datetime.date(2024, 2, 9), 'Semillas Serrano'),
#  (1, 'Tienda Centro', 1011, datetime.date(2024, 2, 10), 'Desodorante Álvarez'),
#  (1, 'Tienda Centro', 1042, datetime.date(2024, 2, 11), 'Mantequilla Rubio'),
#  (1,
#   'Tienda Centro',
#   1051,
#   datetime.date(2024, 2, 11),
#   'Jabón líquido Ramírez'),
#  (1,
#   'Tienda Centro',
#   1054,
#   datetime.date(2024, 2, 11),
#   'Bolsas de basura Velázquez'),
#  (1, 'Tienda Centro', 1043, datetime.date(2024, 2, 11), 'Champú Cortés'),
#  (1,
#   'Tienda Centro',
#   1060,
#   datetime.date(2024, 2, 11),
#   'Fertilizante Vázquez'),
#  (1, 'Tienda Centro', 1067, datetime.date(2024, 2, 12), 'Semillas Navarro'),
#  (1, 'Tienda Centro', 1068, datetime.date(2024, 2, 12), 'Naranja Serrano'),
#  (1, 'Tienda Centro', 1069, datetime.date(2024, 2, 12), 'Banana Ortiz'),
#  (1,
#   'Tienda Centro',
#   1076,
#   datetime.date(2024, 2, 12),
#   'Crema hidratante Ortiz'),
#  (1, 'Tienda Centro', 1065, datetime.date(2024, 2, 12), 'Colonia Aguilar'),
#  (1, 'Tienda Centro', 1070, datetime.date(2024, 2, 12), 'Esponjas Castro'),
#  (1, 'Tienda Centro', 1087, datetime.date(2024, 2, 13), 'Banana Méndez'),
#  (1, 'Tienda Centro', 1090, datetime.date(2024, 2, 13), 'Champú Chávez'),
#  (1,
#   'Tienda Centro',
#   1098,
#   datetime.date(2024, 2, 13),
#   'Jabón líquido Navarro'),
#  (1, 'Tienda Centro', 1084, datetime.date(2024, 2, 13), 'Lechuga Sánchez'),
#  (1, 'Tienda Centro', 1112, datetime.date(2024, 2, 14), 'Velas Navarro'),
#  (1, 'Tienda Centro', 1116, datetime.date(2024, 2, 14), 'Semillas Fernández'),
#  (1, 'Tienda Centro', 1127, datetime.date(2024, 2, 14), 'Champú Navarro'),
#  (1, 'Tienda Centro', 1124, datetime.date(2024, 2, 14), 'Chicles Sánchez'),
#  (1, 'Tienda Centro', 1140, datetime.date(2024, 2, 15), 'Colonia Santos'),
#  (1, 'Tienda Centro', 1139, datetime.date(2024, 2, 15), 'Zanahoria Fuentes'),
#  (1,
#   'Tienda Centro',
#   1141,
#   datetime.date(2024, 2, 15),
#   'Crema hidratante González'),
#  (1, 'Tienda Centro', 1178, datetime.date(2024, 2, 17), 'Queso Vázquez'),
#  (1,
#   'Tienda Centro',
#   1194,
#   datetime.date(2024, 2, 17),
#   'Jugo de naranja Lara'),
#  (1, 'Tienda Centro', 1188, datetime.date(2024, 2, 17), 'Semillas Ruiz'),
#  (1, 'Tienda Centro', 1189, datetime.date(2024, 2, 17), 'Chicles Cortés'),
#  (1, 'Tienda Centro', 1209, datetime.date(2024, 2, 18), 'Yogur Moreno'),
#  (1,
#   'Tienda Centro',
#   1207,
#   datetime.date(2024, 2, 18),
#   'Crema hidratante Delgado'),
#  (1, 'Tienda Centro', 1214, datetime.date(2024, 2, 18), 'Leche Romero'),
#  (1,
#   'Tienda Centro',
#   1220,
#   datetime.date(2024, 2, 18),
#   'Crema hidratante Lara'),
#  (1, 'Tienda Centro', 1237, datetime.date(2024, 2, 19), 'Pilas Campos'),
#  (1, 'Tienda Centro', 1243, datetime.date(2024, 2, 19), 'Agua Sánchez'),
#  (1, 'Tienda Centro', 1236, datetime.date(2024, 2, 19), 'Papas fritas Rubio'),
#  (1,
#   'Tienda Centro',
#   1231,
#   datetime.date(2024, 2, 19),
#   'Jugo de naranja García'),
#  (1,
#   'Tienda Centro',
#   1253,
#   datetime.date(2024, 2, 20),
#   'Mantequilla González'),
#  (1, 'Tienda Centro', 1254, datetime.date(2024, 2, 20), 'Cerdo Esquivel'),
#  (1, 'Tienda Centro', 1264, datetime.date(2024, 2, 20), 'Queso Torres'),
#  (1, 'Tienda Centro', 1255, datetime.date(2024, 2, 20), 'Velas Chávez'),
#  (1, 'Tienda Centro', 1280, datetime.date(2024, 2, 21), 'Detergente Peña'),
#  (1, 'Tienda Centro', 1277, datetime.date(2024, 2, 21), 'Banana Molina'),
#  (1, 'Tienda Centro', 1282, datetime.date(2024, 2, 21), 'Agua Serrano'),
#  (1, 'Tienda Centro', 1283, datetime.date(2024, 2, 21), 'Agua López'),
#  (1, 'Tienda Centro', 1285, datetime.date(2024, 2, 21), 'Galletas Sánchez'),
#  (1, 'Tienda Centro', 1290, datetime.date(2024, 2, 21), 'Lechuga Vázquez'),
#  (1, 'Tienda Centro', 1316, datetime.date(2024, 2, 22), 'Manzana Cabrera'),
#  (1, 'Tienda Centro', 1304, datetime.date(2024, 2, 22), 'Galletas Campos'),
#  (1, 'Tienda Centro', 1323, datetime.date(2024, 2, 22), 'Refresco Aguilar'),
#  (1, 'Tienda Centro', 1308, datetime.date(2024, 2, 22), 'Uva Méndez'),
#  (1, 'Tienda Centro', 1341, datetime.date(2024, 2, 23), 'Velas Rodríguez'),
#  (1, 'Tienda Centro', 1345, datetime.date(2024, 2, 24), 'Agua Sánchez'),
#  (1, 'Tienda Centro', 1357, datetime.date(2024, 2, 24), 'Semillas Rubio'),
#  (1, 'Tienda Centro', 1350, datetime.date(2024, 2, 24), 'Champú Díaz'),
#  (1, 'Tienda Centro', 1363, datetime.date(2024, 2, 24), 'Papas fritas Méndez'),
#  (1, 'Tienda Centro', 1359, datetime.date(2024, 2, 24), 'Chocolate Méndez'),
#  (1,
#   'Tienda Centro',
#   1353,
#   datetime.date(2024, 2, 24),
#   'Jugo de naranja Fuentes'),
#  (1, 'Tienda Centro', 1361, datetime.date(2024, 2, 24), 'Colonia Ortiz'),
#  (1,
#   'Tienda Centro',
#   1380,
#   datetime.date(2024, 2, 25),
#   'Tierra para macetas Campos'),
#  (1, 'Tienda Centro', 1409, datetime.date(2024, 2, 26), 'Champú Paredes'),
#  (1, 'Tienda Centro', 1406, datetime.date(2024, 2, 26), 'Naranja Esquivel'),
#  (1, 'Tienda Centro', 1394, datetime.date(2024, 2, 26), 'Banana Paredes'),
#  (1, 'Tienda Centro', 1399, datetime.date(2024, 2, 26), 'Cerveza Domínguez'),
#  (1, 'Tienda Centro', 1436, datetime.date(2024, 2, 27), 'Refresco Méndez'),
#  (1,
#   'Tienda Centro',
#   1414,
#   datetime.date(2024, 2, 27),
#   'Desinfectante Domínguez'),
#  (1, 'Tienda Centro', 1419, datetime.date(2024, 2, 27), 'Carne de res Medina'),
#  (1, 'Tienda Centro', 1426, datetime.date(2024, 2, 27), 'Regadera Paredes'),
#  (1,
#   'Tienda Centro',
#   1442,
#   datetime.date(2024, 2, 28),
#   'Jugo de naranja Álvarez'),
#  (1, 'Tienda Centro', 1462, datetime.date(2024, 2, 28), 'Galletas Salinas'),
#  (1, 'Tienda Centro', 1456, datetime.date(2024, 2, 28), 'Pollo Serrano'),
#  (1, 'Tienda Centro', 1472, datetime.date(2024, 2, 29), 'Refresco Esquivel'),
#  (1, 'Tienda Centro', 1464, datetime.date(2024, 2, 29), 'Leche Velázquez'),
#  (1,
#   'Tienda Centro',
#   1485,
#   datetime.date(2024, 2, 29),
#   'Platos desechables Ortiz')]

# %% [markdown]
# * 7.-Ranking de productos más vendidos en cada tienda
#
#
#     * Para cada tienda, muestra los 3 productos más vendidos (en términos de cantidad total).
#     * Tendrás que unir tiendas, empleados, ordenes y detalle_orden, además de productos.
#     * Usa GROUP BY y ordena por la cantidad sumada (y opcionalmente, un LIMIT 3).

# %%
		
sql = ('WITH ranking_productos AS (SELECT t.nombre_tienda, p.nombre_producto, SUM(do.cantidad) AS total_vendido, ROW_NUMBER() OVER (PARTITION BY t.id_tienda ORDER BY SUM(do.cantidad) DESC) AS ranking FROM tiendas t JOIN empleados e ON t.id_tienda = e.id_tienda JOIN ordenes o ON e.id_empleado = o.id_empleado JOIN detalle_orden do ON o.id_orden = do.id_orden JOIN productos p ON do.id_producto = p.id_producto GROUP BY t.id_tienda, t.nombre_tienda, p.id_producto, p.nombre_producto) SELECT nombre_tienda, nombre_producto, total_vendido FROM ranking_productos WHERE ranking <= 3 ORDER BY nombre_tienda, ranking;')
consultas(sql)
# Out:
# [('Central Tiendas', 'Mantequilla', 1454.0),
#  ('Central Tiendas', 'Chocolate', 1448.0),
#  ('Central Tiendas', 'Queso', 1360.0),
#  ('Tienda Centro', 'Galletas', 1501.0),
#  ('Tienda Centro', 'Champú', 1336.0),
#  ('Tienda Centro', 'Pilas', 1320.0),
#  ('Tienda Este', 'Pilas', 1340.0),
#  ('Tienda Este', 'Manzana', 1334.0),
#  ('Tienda Este', 'Champú', 1310.0),
#  ('Tienda Norte', 'Queso', 1385.0),
#  ('Tienda Norte', 'Lechuga', 1382.0),
#  ('Tienda Norte', 'Fertilizante', 1370.0),
#  ('Tienda Oeste', 'Banana', 1422.0),
#  ('Tienda Oeste', 'Queso', 1359.0),
#  ('Tienda Oeste', 'Desodorante', 1336.0),
#  ('Tienda Poniente', 'Pilas', 1404.0),
#  ('Tienda Poniente', 'Bolsas de basura', 1331.0),
#  ('Tienda Poniente', 'Mantequilla', 1312.0),
#  ('Tienda Sur', 'Semillas', 1477.0),
#  ('Tienda Sur', 'Queso', 1404.0),
#  ('Tienda Sur', 'Velas', 1365.0)]
