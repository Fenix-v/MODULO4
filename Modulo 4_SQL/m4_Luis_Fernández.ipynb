# %% [markdown]
# ## 1.- Crear Base de Datos

# %% [markdown]
# * Crear con código SQL una base de datos llamada supermercado.
# * Código Python con mysql connector que ejecute el SQL para borrar y generar la base de datos vacía

# %%
# Ejercicio 1 - Crear base de datos estudiantes
import mysql.connector as con
def crear_bd(sql):
    try:
       connection = con.connect(
            host="localhost",
            port="3306",
            user="root",
            password="ADMIN",
            database='supermercado'
        )
       cursor = connection.cursor()
       cursor.execute(sql)
       
    except con.Error as error:
      print(f"Ha ocurrido un error: {error}") 
      if connection:
         connection.rollback()
         return 0
    finally:
        if cursor: 
            cursor.close()
        if connection:
            connection.close()

# %%
sql = "DROP DATABASE IF EXISTS supermercado; CREATE DATABASE IF NOT EXISTS supermercado;"

# %%
crear_bd(sql)

# %% [markdown]
# # Tablas SQL

# %% [markdown]
# * Tiendas
#
#    * id_tienda (PRIMARY KEY)
#    * nombre_tienda
#    * direccion
#    * ciudad

# %%
sql = "CREATE TABLE IF NOT EXISTS tiendas (id_tienda INT AUTO_INCREMENT PRIMARY KEY, nombre_tienda VARCHAR(100) NOT NULL, dirección VARCHAR(80), ciudad VARCHAR(50) NOT NULL);"

# %%
crear_bd(sql)

# %% [markdown]
# * Empleados
#     * id_empleado (PRIMARY KEY)
#     * nombre_empleado
#     * puesto (ej.: Cajero, Gerente, Reponedor)
#     * id_tienda (FOREIGN KEY que hace referencia a tiendas.id_tienda)

# %%
sql = "CREATE TABLE IF NOT EXISTS empleados (id_empleado INT AUTO_INCREMENT PRIMARY KEY, nombre_empleado VARCHAR(100) NOT NULL, puesto VARCHAR(60), id_tienda INT NOT NULL, FOREIGN KEY (id_tienda) REFERENCES tiendas(id_tienda) ON DELETE CASCADE);"

# %%
crear_bd(sql)

# %% [markdown]
# * Categorias
#     * id_categoria (PRIMARY KEY)
#     * nombre_categoria

# %%
sql = "CREATE TABLE IF NOT EXISTS categorias (id_categoria INT AUTO_INCREMENT PRIMARY KEY, nombre_categoria VARCHAR(60));"

# %%
crear_bd(sql)

# %% [markdown]
# * Productos
#     * id_producto (PRIMARY KEY)
#     * nombre_producto
#     * precio
#     * stock
#     * id_categoria (FOREIGN KEY que hace referencia a categorias.id_categoria)

# %%
sql = "CREATE TABLE IF NOT EXISTS productos (id_producto INT AUTO_INCREMENT PRIMARY KEY, nombre_producto VARCHAR(70), precio FLOAT(8,2), stock INT, id_categoria INT NOT NULL, FOREIGN KEY (id_categoria) REFERENCES categorias(id_categoria));"

# %%
crear_bd(sql)

# %% [markdown]
# * Clientes
#     * id_cliente (PRIMARY KEY)
#     * first_name
#     * last_name
#     * email
#     * codigo_postal

# %%
sql = "CREATE TABLE IF NOT EXISTS clientes (id_cliente INT AUTO_INCREMENT PRIMARY KEY, first_name VARCHAR(50), last_name VARCHAR(50), email VARCHAR(100), codigo_postal INT);"

# %%
crear_bd(sql)

# %% [markdown]
# * Ordenes
#     * id_orden (PRIMARY KEY)
#     * id_cliente (FOREIGN KEY que hace referencia a clientes.id_cliente)
#     * id_empleado (FOREIGN KEY que hace referencia a empleados.id_empleado)
#     * fecha_orden
#     * metodo_pago (una enum que solo admita tres valores Tarjeta, Efectivo)

# %%
sql = "CREATE TABLE IF NOT EXISTS ordenes (id_orden INT AUTO_INCREMENT PRIMARY KEY, id_cliente INT, id_empleado INT, fecha_orden DATE, metodo_pago ENUM('Tarjeta', 'Efectivo') DEFAULT 'Efectivo', FOREIGN KEY (id_cliente) REFERENCES clientes(id_cliente), FOREIGN KEY (id_empleado) REFERENCES empleados(id_empleado));"

# %%
crear_bd(sql)

# %% [markdown]
# * Detalle_orden
#     * id_detalle (PRIMARY KEY)
#     * id_orden (FOREIGN KEY que hace referencia a ordenes.id_orden) NOT NULL
#     * id_producto (FOREIGN KEY que hace referencia a productos.id_producto) NOT NULL
#     * cantidad
#     * precio_unitario: mismo precio que en la tabla producto
#     * descuento (podría ser NULL si no se aplica)

# %%
sql = "CREATE TABLE IF NOT EXISTS detalle_orden (id_detalle INT AUTO_INCREMENT PRIMARY KEY, id_orden INT NOT NULL, id_producto INT NOT NULL, cantidad FLOAT(8,2), precio_unitario FLOAT(8,2), descuento TINYINT, FOREIGN KEY (id_orden) REFERENCES ordenes(id_orden), FOREIGN KEY (id_producto) REFERENCES productos(id_producto));"

# %%
crear_bd(sql)

# %% [markdown]
# # Tablas

# %% [markdown]
# ## 2.- Generar datos demo desde Python

# %%
def insertar_dataframe(df, table_name):
    try:
        connection = con.connect(
            host="localhost",
            port="3306",
            user="root",
            password="ADMIN",
            database='supermercado'
        )
        cursor = connection.cursor()
        
        columns = ','.join(df.columns)
        placeholders = ','.join(['%s'] * len(df.columns))
        sql = f'INSERT INTO {table_name} ({columns}) VALUES ({placeholders});'
    
        rows = [tuple(row) for index, row in df.iterrows()] # lista de tuplas con los datos del dataframe

        cursor.executemany(sql, rows)
        
        connection.commit()
        return cursor.rowcount
    except con.Error as error:
        print(f"Ha ocurrido un error: {error}")
        if connection:
            connection.rollback()
        return 0
    finally:
        if cursor: 
            cursor.close()
        if connection:
            connection.close()

# %% [markdown]
# * Tabla Tiendas

# %%
import pandas as pd
import random
import datetime

tiendas = ['Tienda Centro','Tienda Norte','Tienda Sur','Tienda Poniente','Tienda Este','Tienda Oeste','Central Tiendas']
tiendas

dirección = ['Avd.Centro,nº1','Calle Norte, nº2','Calle Sur, nº3', 'Avd. Poniente, nº4','Calle Este, nº5','Calle Oeste, nº6', 'Crta.Central, Km10']
   
dirección

# Ciudad

ciudad= ['Almería','Girona','Murcia','Barcelona','Orense','Gijón','Madrid' ] 
ciudad 

# Creamos un DataFrame 

df_tiendas = pd.DataFrame(zip(tiendas, dirección, ciudad),
             columns= ['nombre_tienda', 'dirección', 'ciudad']) # El comando Zip empaqueta todas las variante hemos hecho | y con columns damos nombres a las columnas

# Añadir columna Pk:

df_tiendas = df_tiendas.reset_index().rename({'index': 'id_tienda'}, axis=1)
df_tiendas['id_tienda'] = df_tiendas['id_tienda'] + 1
df_tiendas
# Out:
#    id_tienda    nombre_tienda           dirección     ciudad
# 0          1    Tienda Centro      Avd.Centro,nº1    Almería
# 1          2     Tienda Norte    Calle Norte, nº2     Girona
# 2          3       Tienda Sur      Calle Sur, nº3     Murcia
# 3          4  Tienda Poniente  Avd. Poniente, nº4  Barcelona
# 4          5      Tienda Este     Calle Este, nº5     Orense
# 5          6     Tienda Oeste    Calle Oeste, nº6      Gijón
# 6          7  Central Tiendas  Crta.Central, Km10     Madrid

# %%
insertar_dataframe(df_tiendas, 'tiendas')
# Out:
# 7

# %% [markdown]
# * Tabla Empleados

# %%
# Creamos lista de empleados | Nombre,Apellidos,Función
empleados = list()
nombres = ['Alejandro', 'María', 'Carlos', 'Lucía', 'Fernando', 'Isabel', 'Javier', 'Ana', 'Miguel', 'Sofía', 'José', 'Clara', 'Luis', 'Elena', 'Daniel', 'Marta', 'Andrés', 'Laura', 'Raúl', 'Paula', 'Manuel', 'Sara', 'Pablo', 'Julia', 'Sergio', 'Valeria', 'Tomás', 'Adriana', 'Eduardo', 'Camila', 'Francisco', 'Diana', 'Ricardo', 'Patricia', 'Ángel', 'Carla', 'Diego', 'Irene', 'Samuel', 'Eva', 'David', 'Andrea', 'Hugo', 'Verónica', 'Cristian', 'Gabriela', 'Mario', 'Natalia', 'Jorge', 'Lorena', 'Rubén', 'Carmen']
apellidos = ['García', 'Martínez', 'López', 'Sánchez', 'Pérez', 'González', 'Rodríguez', 'Fernández', 'Hernández', 'Jiménez', 'Ruiz', 'Díaz', 'Moreno', 'Álvarez', 'Romero', 'Torres', 'Vázquez', 'Domínguez', 'Ramos', 'Ramírez', 'Castro', 'Ortiz', 'Rubio', 'Molina', 'Delgado', 'Cruz', 'Flores', 'Navarro', 'Cabrera', 'Campos', 'Peña', 'Aguilar', 'Santos', 'Reyes', 'Méndez', 'Medina', 'Paredes', 'Serrano', 'Cortés', 'Carrillo', 'Ortiz', 'Velázquez', 'Chávez', 'Guzmán', 'Salinas', 'Esquivel', 'Lara', 'Fuentes', 'Montes']
función = ["Cajero", "Reponedor", "Encargado de sección", "Gerente", "Personal de limpieza", "Panadero", "Carnicero", "Pescadero", "Frutero", "Charcutero", "Jefe de turno", "Operador logístico", "Atención al cliente", "Auxiliar de caja", "Encargado de seguridad","Responsable de zona","Jefe de compras","Encargada carnicería","encargado pescadería","Jefe de Limpieza"]
for tienda in df_tiendas['id_tienda']:
    for empleado in range(20):
        nombre_empleado = (random.choice(nombres) + ' ' + random.choice(apellidos))
        puesto = función[empleado]
        id_tienda = tienda
        empleados.append([nombre_empleado, puesto, id_tienda])
        
# Creamos un DataFrame         
df_empleados = pd.DataFrame(empleados, columns=['nombre_empleado', 'puesto', 'id_tienda'])
        
df_empleados = df_empleados.reset_index().rename({'index': 'id_empleado'}, axis=1)
df_empleados['id_empleado'] = df_empleados['id_empleado'] + 1
df_empleados
# Out:
#      id_empleado nombre_empleado                puesto  id_tienda
# 0              1    Mario Guzmán                Cajero          1
# 1              2     Irene Ortiz             Reponedor          1
# 2              3  Adriana Cortés  Encargado de sección          1
# 3              4      David Lara               Gerente          1
# 4              5   Laura Aguilar  Personal de limpieza          1
# ..           ...             ...                   ...        ...
# 135          136  Carlos Delgado   Responsable de zona          7
# 136          137    David Castro       Jefe de compras          7
# 137          138   Daniel Guzmán  Encargada carnicería          7
# 138          139    Raúl Sánchez  encargado pescadería          7
# 139          140      Ángel Díaz      Jefe de Limpieza          7
#
# [140 rows x 4 columns]

# %%
insertar_dataframe(df_empleados, "empleados")
# Out:
# 140

# %% [markdown]
# * Tabla Categorías

# %%
categorias = ['Lácteos','Pescados','Carnes','Verduras','Frutas','Bollería y Pan','Refrescos','Vinos','Alcohol','Congelados']

df_categorias= pd.DataFrame(categorias,columns= ['nombre_categoria'])

# Añadir columna pk:

df_categorias = df_categorias.reset_index().rename({'index': 'id_categoria'}, axis=1)
df_categorias['id_categoria'] = df_categorias['id_categoria'] + 1
df_categorias
# Out:
#    id_categoria nombre_categoria
# 0             1          Lácteos
# 1             2         Pescados
# 2             3           Carnes
# 3             4         Verduras
# 4             5           Frutas
# 5             6   Bollería y Pan
# 6             7        Refrescos
# 7             8            Vinos
# 8             9          Alcohol
# 9            10       Congelados

# %%
insertar_dataframe(df_categorias, 'categorias')
# Out:
# 10

# %% [markdown]
# * Productos
#
#     * id_producto: valores enteros consecutivos (1, 2, 3...).
#     * nombre_producto: nombres como “Leche Entera”, “Manzana Roja”, “Refresco de Cola”, etc.
#     * precio: valores DECIMAL entre 0.50 y 50.00, por ejemplo.
#     * stock: valores INT entre 0 y 500 (o el rango que quieras).
#     * id_categoria: debe hacer referencia a las categorías que hayas definido (1, 2, 3, etc.).

# %%
# Listado de productos

# generar columna id_producto
nombres = ["Leche", "Yogur", "Queso", "Mantequilla", "Pollo", "Carne de res", "Cerdo", "Chuletas", "Manzana", "Banana", "Naranja", "Uva", "Zanahoria", "Tomate", "Lechuga", "Cebolla", "Agua", "Jugo de naranja", "Refresco", "Cerveza", "Papas fritas", "Chocolate", "Galletas", "Chicles", "Velas", "Platos desechables", "Bolsas de basura", "Pilas", "Detergente", "Jabón líquido", "Esponjas", "Desinfectante", "Champú", "Colonia", "Crema hidratante", "Desodorante", "Tierra para macetas", "Fertilizante", "Semillas", "Regadera"]
precios, lista_categorias, stock = list(), list(), list()
cantidad = len(nombres)
for _ in range(cantidad):
    precios.append(random.uniform(0.50, 10.50))
    stock.append(random.randint(0, 500))
for categ in df_categorias['id_categoria']:
    for i in range(4):
        lista_categorias.append(categ)
lista_categorias        
df_productos = pd.DataFrame(zip(nombres, precios, stock, lista_categorias), columns=['nombre_producto', 'precio', 'stock', 'id_categoria'])    
df_productos = df_productos.reset_index().rename({'index': 'id_producto'}, axis=1)
df_productos['id_producto'] = df_productos['id_producto'] + 1
df_productos
# Out:
#     id_producto      nombre_producto     precio  stock  id_categoria
# 0             1                Leche   8.721590    466             1
# 1             2                Yogur  10.416025    473             1
# 2             3                Queso   1.239585    392             1
# 3             4          Mantequilla   9.487563    381             1
# 4             5                Pollo   2.292598     46             2
# 5             6         Carne de res   1.938636     76             2
# 6             7                Cerdo   4.912155     18             2
# 7             8             Chuletas   2.185210    353             2
# 8             9              Manzana   8.674072    240             3
# 9            10               Banana   2.389311    156             3
# 10           11              Naranja   5.044126    287             3
# 11           12                  Uva   1.774004    232             3
# 12           13            Zanahoria   8.790556     62             4
# 13           14               Tomate   5.660863    188             4
# 14           15              Lechuga   5.385882     58             4
# 15           16              Cebolla   7.074938    474             4
# 16           17                 Agua   1.568330    275             5
# 17           18      Jugo de naranja   0.657495     24             5
# 18           19             Refresco  10.075998    246             5
# 19           20              Cerveza   9.097374    307             5
# 20           21         Papas fritas   2.751051    344             6
# 21           22            Chocolate   1.658155    161             6
# 22           23             Galletas   7.325983    442             6
# 23           24              Chicles   7.125372    271             6
# 24           25                Velas   7.492604     60             7
# 25           26   Platos desechables   7.433215    265             7
# 26           27     Bolsas de basura   3.210476     63             7
# 27           28                Pilas   8.452576    248             7
# 28           29           Detergente   9.842059    145             8
# 29           30        Jabón líquido   5.207559    486             8
# 30           31             Esponjas  10.239464    345             8
# 31           32        Desinfectante   5.755577    463             8
# 32           33               Champú   2.434375    106             9
# 33           34              Colonia   5.608289    236             9
# 34           35     Crema hidratante  10.177449    386             9
# 35           36          Desodorante   7.003743     57             9
# 36           37  Tierra para macetas   8.562235     22            10
# 37           38         Fertilizante   8.631579    179            10
# 38           39             Semillas   6.792684    420            10
# 39           40             Regadera   4.591716    172            10

# %%
insertar_dataframe(df_productos, 'productos')
# Out:
# 40

# %% [markdown]
# * Clientes
#
#     * id_cliente: valores enteros consecutivos (1, 2, 3...).
#     * nombre_cliente: nombres y apellidos ficticios (p. ej. “Carlos López”, “María Gil”).
#     * email: podrías generar correos ficticios (p. ej. “carlos.lopez@test.com”).
#     * telefono: número de 9 o 10 dígitos (dependiendo del país).
#     * direccion: calles y números ficticios (p. ej. “Av. Siempre Viva 742”).

# %%
# generar columna cliente
nombre_cliente, apellido_cliente, email, postal, cliente_completo = list(), list(), list(), list(), list()
calles = ("Av. Libertad", "Calle Mayor", "Paseo de la Reforma", "Calle Real", "Av. de la Constitución", "Calle del Sol", "Calle de la Luna", "Calle los Pinos", "Calle de la Paz", "Calle Olivo", "Calle Cedro", "Calle Nogal", "Av. de las Flores", "Paseo del Prado", "Calle del Río", "Av. Central", "Calle Primavera", "Calle Otoño", "Calle Invierno", "Calle Verano", "Calle Granada", "Calle Sevilla", "Calle Córdoba", "Calle Málaga", "Calle Valencia", "Calle Zaragoza", "Calle Alicante", "Av. de los Ángeles", "Calle del Carmen", "Calle San Miguel", "Calle San Juan", "Calle del Pilar", "Calle Santa Teresa", "Calle San Francisco", "Calle de la Sierra", "Calle del Mar", "Av. del Norte", "Av. del Sur", "Calle del Este", "Calle del Oeste", "Calle Diamante", "Calle Esmeralda", "Calle Rubí", "Calle Zafiro", "Calle Ámbar", "Calle Turquesa", "Calle Topacio", "Calle Perla", "Calle Horizonte", "Calle Amanecer")
for _ in range(2000):
    nom = random.choice(nombres)
    nombre_cliente.append(nom)
    ape = random.choice(apellidos)
    apellido_cliente.append(ape)
    email.append((f'{nom}.{ape}@mail.com'))
    postal.append(random.randint(0000, 11900))
    
df_clientes = pd.DataFrame(zip(nombre_cliente, apellido_cliente, email, postal), columns=['first_name', 'last_name', 'email', 'codigo_postal']) 
df_clientes = df_clientes.reset_index().rename({'index': 'id_cliente'}, axis=1)
df_clientes['id_cliente'] = df_clientes['id_cliente'] + 1
df_clientes
# Out:
#       id_cliente           first_name last_name  \
# 0              1         Fertilizante    Flores
# 1              2              Colonia    Guzmán
# 2              3         Papas fritas      Cruz
# 3              4         Fertilizante   Fuentes
# 4              5         Papas fritas    Moreno
# ...          ...                  ...       ...
# 1995        1996            Chocolate     Ramos
# 1996        1997              Colonia    Medina
# 1997        1998  Tierra para macetas   Navarro
# 1998        1999                Leche   Ramírez
# 1999        2000                Pollo   Álvarez
#
#                                      email  codigo_postal
# 0             Fertilizante.Flores@mail.com           3032
# 1                  Colonia.Guzmán@mail.com          10242
# 2               Papas fritas.Cruz@mail.com             66
# 3            Fertilizante.Fuentes@mail.com           5890
# 4             Papas fritas.Moreno@mail.com           3774
# ...                                    ...            ...
# 1995              Chocolate.Ramos@mail.com            399
# 1996               Colonia.Medina@mail.com           5431
# 1997  Tierra para macetas.Navarro@mail.com           6542
# 1998                Leche.Ramírez@mail.com           7242
# 1999                Pollo.Álvarez@mail.com           8901
#
# [2000 rows x 5 columns]

# %%
insertar_dataframe(df_clientes, 'clientes')
# Out:
# 2000

# %% [markdown]
# * Orden
#     * id_orden: Valores enteros consecutivos
#     * id_cliente: Referencias de los Ids existentes en la tabla Clientes
#     * id_empleado: Refeferencias de los Ids existentes en la tabla Empleados
#     * fecha_orden: Generar fechas aleatorias o secuenciales
#     * metodo_pago: Escoger entre tarjeta o efectivo

# %%
# generar columna id_orden
from datetime import timedelta


cliente, emplea, fecha, metodo = list(), list(), list(), list()
fechas = [datetime.datetime(year=2024, month=1, day=1) + timedelta(days=numero) for numero in range(395)]
for _ in range(10000):
    cliente.append(random.choice(df_clientes['id_cliente']))
    emplea.append(random.choice(df_empleados['id_empleado']))
    fecha.append(random.choice(fechas))
    metodo.append(random.choices(['Tarjeta', 'Efectivo'], weights=[0.65, 0.35])[0])

fecha.sort()
df_ordenes = pd.DataFrame(zip(cliente, emplea, fecha, metodo), columns=['id_cliente', 'id_empleado', 'fecha_orden', 'metodo_pago'])

df_ordenes.sort_values('fecha_orden', inplace=True)
df_ordenes = df_ordenes.reset_index().rename({'index': 'id_orden'}, axis=1)
df_ordenes['id_orden'] = df_ordenes['id_orden'] + 1
df_ordenes.sort_values('id_orden', inplace=True)
df_ordenes.head(50)
# Out:
#     id_orden  id_cliente  id_empleado fecha_orden metodo_pago
# 0          1        1757            5  2024-01-01     Tarjeta
# 18         2        1358           35  2024-01-01     Tarjeta
# 19         3         656          124  2024-01-01    Efectivo
# 25         4         120           30  2024-01-01     Tarjeta
# 21         5         290           94  2024-01-01     Tarjeta
# 22         6        1522           44  2024-01-01    Efectivo
# 23         7         610            5  2024-01-01     Tarjeta
# 24         8         409           70  2024-01-01     Tarjeta
# 31         9        1855           12  2024-01-01     Tarjeta
# 26        10        1022          117  2024-01-01    Efectivo
# 27        11        1207           53  2024-01-01    Efectivo
# 28        12         384          117  2024-01-01     Tarjeta
# 29        13         801          130  2024-01-01     Tarjeta
# 30        14        1775           39  2024-01-01     Tarjeta
# 17        15         101           76  2024-01-01     Tarjeta
# 20        16        1423            4  2024-01-01    Efectivo
# 15        17        1597           51  2024-01-01     Tarjeta
# 14        18        1456           13  2024-01-01     Tarjeta
# 13        19         245           54  2024-01-01     Tarjeta
# 12        20         725           29  2024-01-01     Tarjeta
# 11        21         366          116  2024-01-01    Efectivo
# 16        22        1158          111  2024-01-01     Tarjeta
# 10        23         245           37  2024-01-01     Tarjeta
# 9         24        1994           15  2024-01-01    Efectivo
# 8         25         172          107  2024-01-01     Tarjeta
# 7         26         405           54  2024-01-01    Efectivo
# 6         27         219           26  2024-01-01     Tarjeta
# 5         28        1359           56  2024-01-01    Efectivo
# 4         29        1365           55  2024-01-01     Tarjeta
# 3         30         480           91  2024-01-01     Tarjeta
# 2         31        1310          100  2024-01-01     Tarjeta
# 1         32        1044           53  2024-01-01    Efectivo
# 53        33         585          126  2024-01-02     Tarjeta
# 43        34         387           26  2024-01-02    Efectivo
# 52        35        1109           27  2024-01-02    Efectivo
# 51        36        1498           27  2024-01-02    Efectivo
# 50        37         314           28  2024-01-02     Tarjeta
# 49        38         305           61  2024-01-02     Tarjeta
# 48        39        1124           41  2024-01-02    Efectivo
# 47        40         397          114  2024-01-02    Efectivo
# 46        41         961           43  2024-01-02    Efectivo
# 45        42        1459           94  2024-01-02    Efectivo
# 44        43        1338           37  2024-01-02    Efectivo
# 54        44        1707           24  2024-01-02     Tarjeta
# 42        45         526          110  2024-01-02     Tarjeta
# 40        46         657           89  2024-01-02     Tarjeta
# 32        47         901           91  2024-01-02     Tarjeta
# 33        48        1897           53  2024-01-02     Tarjeta
# 34        49         837           36  2024-01-02     Tarjeta
# 35        50          26            2  2024-01-02     Tarjeta

# %%
insertar_dataframe(df_ordenes, 'ordenes')
# Out:
# 10000

# %% [markdown]
# * Detalles de ordenes
#     * id_detalle: Valores enterors consecutivos
#     * id_orden: Referencia al Id de alguna orden válida
#     * id_producto: Referencia al ID
#     * Cantidad: Valores entre 1 y 20
#     * Precio_unitario: Usando en mismo precio está en la tabla productos
#     * Descuento: Valores Decimales bajos

# %%
# generar columna id_detalle

orden_completa = list()
productos = df_productos['id_producto']
orden_20 = df_ordenes['id_orden']

for orden in df_ordenes['id_orden']:
    ordenes = orden
    producto = (int(random.choice(productos)))
    cant = random.randint(1, 20)
    valor = float(df_productos['precio'][df_productos['id_producto'] == producto].iloc[0])
    descuento = random.uniform(0, 0.25)
    orden_completa.append([ordenes, producto, cant, round(valor, 2), round(descuento, 2)])   
    
for orden in range(20000):
    ordenes = random.choice(orden_20)
    producto = (int(random.choice(productos)))
    cant = random.randint(1, 20)
    valor = float(df_productos['precio'][df_productos['id_producto'] == producto].iloc[0])
    descuento = random.uniform(0, 0.25)
    orden_completa.append([ordenes, producto, cant, round(valor,2), round(descuento, 2)])   
    
df_detalle_orden = pd.DataFrame(orden_completa, columns=['id_orden', 'id_producto', 'cantidad', 'precio_unitario', 'descuento'])

df_detalle_orden = df_detalle_orden.reset_index().rename({'index': 'id_detalle'}, axis=1)
df_detalle_orden['id_detalle'] = df_detalle_orden['id_detalle'] + 1
df_detalle_orden
# Out:
#        id_detalle  id_orden  id_producto  cantidad  precio_unitario  descuento
# 0               1         1           12        11             1.77       0.17
# 1               2         2           13        15             8.79       0.22
# 2               3         3           28        13             8.45       0.15
# 3               4         4            8        14             2.19       0.01
# 4               5         5           35         3            10.18       0.05
# ...           ...       ...          ...       ...              ...        ...
# 29995       29996      5283           21        10             2.75       0.16
# 29996       29997      4004           27        12             3.21       0.01
# 29997       29998      8316            3        20             1.24       0.21
# 29998       29999      3784           13        15             8.79       0.11
# 29999       30000      1195           36        10             7.00       0.07
#
# [30000 rows x 6 columns]

# %%
insertar_dataframe(df_detalle_orden, 'detalle_orden')
# Out:
# 30000

# %% [markdown]
# ## 3.- Consultas SQL

# %%
def consultas(sql):
    try:
        connection = con.connect(
            host="localhost",
            port="3306",
            user="root",
            password="ADMIN",
            database='supermercado'
        )
        cursor = connection.cursor()
        cursor.execute(sql)
        return cursor.fetchall()
    except con.Error as error:
        print(f"Ha ocurrido un error: {error}")
        if connection:
            connection.rollback()
        return 0
    finally:
        if cursor: 
            cursor.close()
        if connection:
            connection.close()

# %% [markdown]
# * 1.-Listado de órdenes con detalles de cliente y empleado
#
#     * Muestra el ID de la orden, la fecha, el nombre del cliente, el nombre del empleado que atendió la compra y el método de pago.
#     * Utiliza un JOIN entre las tablas ordenes, clientes y empleados

# %%
sql = ('SELECT o.id_orden, o.fecha_orden, c.first_name, c.last_name, e.nombre_empleado, o.metodo_pago FROM ordenes o JOIN clientes c ON c.id_cliente = o.id_cliente JOIN empleados e ON e.id_empleado = o.id_empleado ORDER BY o.id_orden;') 
consultas(sql)
# Out:
# [(1,
#   datetime.date(2024, 1, 1),
#   'Colonia',
#   'Martínez',
#   'Laura Aguilar',
#   'Tarjeta'),
#  (2,
#   datetime.date(2024, 1, 1),
#   'Semillas',
#   'Cruz',
#   'Paula Martínez',
#   'Tarjeta'),
#  (3,
#   datetime.date(2024, 1, 1),
#   'Uva',
#   'González',
#   'Gabriela Cruz',
#   'Efectivo'),
#  (4,
#   datetime.date(2024, 1, 1),
#   'Detergente',
#   'Martínez',
#   'Fernando Pérez',
#   'Tarjeta'),
#  (5,
#   datetime.date(2024, 1, 1),
#   'Chocolate',
#   'Fernández',
#   'Carlos González',
#   'Tarjeta'),
#  (6, datetime.date(2024, 1, 1), 'Uva', 'Cabrera', 'María García', 'Efectivo'),
#  (7,
#   datetime.date(2024, 1, 1),
#   'Platos desechables',
#   'Castro',
#   'Laura Aguilar',
#   'Tarjeta'),
#  (8,
#   datetime.date(2024, 1, 1),
#   'Mantequilla',
#   'Sánchez',
#   'Carlos Castro',
#   'Tarjeta'),
#  (9,
#   datetime.date(2024, 1, 1),
#   'Manzana',
#   'Fernández',
#   'Cristian Reyes',
#   'Tarjeta'),
#  (10, datetime.date(2024, 1, 1), 'Uva', 'Peña', 'Mario Serrano', 'Efectivo'),
#  (11,
#   datetime.date(2024, 1, 1),
#   'Cerveza',
#   'Molina',
#   'David Peña',
#   'Efectivo'),
#  (12,
#   datetime.date(2024, 1, 1),
#   'Bolsas de basura',
#   'Ortiz',
#   'Mario Serrano',
#   'Tarjeta'),
#  (13,
#   datetime.date(2024, 1, 1),
#   'Tierra para macetas',
#   'Sánchez',
#   'Gabriela Sánchez',
#   'Tarjeta'),
#  (14,
#   datetime.date(2024, 1, 1),
#   'Galletas',
#   'Cabrera',
#   'Diego Carrillo',
#   'Tarjeta'),
#  (15,
#   datetime.date(2024, 1, 1),
#   'Tierra para macetas',
#   'Cabrera',
#   'Gabriela Reyes',
#   'Tarjeta'),
#  (16,
#   datetime.date(2024, 1, 1),
#   'Regadera',
#   'Ramos',
#   'David Lara',
#   'Efectivo'),
#  (17, datetime.date(2024, 1, 1), 'Leche', 'Romero', 'Clara Torres', 'Tarjeta'),
#  (18, datetime.date(2024, 1, 1), 'Queso', 'Santos', 'Jorge Montes', 'Tarjeta'),
#  (19,
#   datetime.date(2024, 1, 1),
#   'Leche',
#   'Hernández',
#   'Cristian Ortiz',
#   'Tarjeta'),
#  (20,
#   datetime.date(2024, 1, 1),
#   'Mantequilla',
#   'Peña',
#   'Tomás Flores',
#   'Tarjeta'),
#  (21,
#   datetime.date(2024, 1, 1),
#   'Cebolla',
#   'Cabrera',
#   'Cristian Fernández',
#   'Efectivo'),
#  (22,
#   datetime.date(2024, 1, 1),
#   'Cerveza',
#   'Vázquez',
#   'Patricia Santos',
#   'Tarjeta'),
#  (23,
#   datetime.date(2024, 1, 1),
#   'Leche',
#   'Hernández',
#   'Irene Chávez',
#   'Tarjeta'),
#  (24,
#   datetime.date(2024, 1, 1),
#   'Galletas',
#   'Campos',
#   'Ricardo Fernández',
#   'Efectivo'),
#  (25,
#   datetime.date(2024, 1, 1),
#   'Bolsas de basura',
#   'Medina',
#   'Pablo Reyes',
#   'Tarjeta'),
#  (26,
#   datetime.date(2024, 1, 1),
#   'Banana',
#   'Martínez',
#   'Cristian Ortiz',
#   'Efectivo'),
#  (27,
#   datetime.date(2024, 1, 1),
#   'Fertilizante',
#   'Delgado',
#   'Irene Torres',
#   'Tarjeta'),
#  (28,
#   datetime.date(2024, 1, 1),
#   'Bolsas de basura',
#   'Ortiz',
#   'Manuel Méndez',
#   'Efectivo'),
#  (29,
#   datetime.date(2024, 1, 1),
#   'Banana',
#   'Vázquez',
#   'Carla González',
#   'Tarjeta'),
#  (30,
#   datetime.date(2024, 1, 1),
#   'Bolsas de basura',
#   'Esquivel',
#   'Natalia Hernández',
#   'Tarjeta'),
#  (31, datetime.date(2024, 1, 1), 'Champú', 'Reyes', 'Camila Ruiz', 'Tarjeta'),
#  (32, datetime.date(2024, 1, 1), 'Banana', 'Ortiz', 'David Peña', 'Efectivo'),
#  (33,
#   datetime.date(2024, 1, 2),
#   'Platos desechables',
#   'Hernández',
#   'María Ortiz',
#   'Tarjeta'),
#  (34,
#   datetime.date(2024, 1, 2),
#   'Bolsas de basura',
#   'González',
#   'Irene Torres',
#   'Efectivo'),
#  (35,
#   datetime.date(2024, 1, 2),
#   'Chuletas',
#   'Delgado',
#   'Natalia Díaz',
#   'Efectivo'),
#  (36,
#   datetime.date(2024, 1, 2),
#   'Chuletas',
#   'Jiménez',
#   'Natalia Díaz',
#   'Efectivo'),
#  (37,
#   datetime.date(2024, 1, 2),
#   'Chocolate',
#   'Hernández',
#   'Valeria Domínguez',
#   'Tarjeta'),
#  (38, datetime.date(2024, 1, 2), 'Agua', 'Cruz', 'Natalia Navarro', 'Tarjeta'),
#  (39, datetime.date(2024, 1, 2), 'Yogur', 'Ramos', 'Daniel Lara', 'Efectivo'),
#  (40,
#   datetime.date(2024, 1, 2),
#   'Desinfectante',
#   'Serrano',
#   'David Castro',
#   'Efectivo'),
#  (41,
#   datetime.date(2024, 1, 2),
#   'Cebolla',
#   'Romero',
#   'Sara Fernández',
#   'Efectivo'),
#  (42,
#   datetime.date(2024, 1, 2),
#   'Tomate',
#   'Castro',
#   'Carlos González',
#   'Efectivo'),
#  (43,
#   datetime.date(2024, 1, 2),
#   'Tierra para macetas',
#   'Ramírez',
#   'Irene Chávez',
#   'Efectivo'),
#  (44,
#   datetime.date(2024, 1, 2),
#   'Crema hidratante',
#   'Domínguez',
#   'Ricardo Ortiz',
#   'Tarjeta'),
#  (45,
#   datetime.date(2024, 1, 2),
#   'Chuletas',
#   'Ortiz',
#   'Paula Cortés',
#   'Tarjeta'),
#  (46,
#   datetime.date(2024, 1, 2),
#   'Champú',
#   'Pérez',
#   'Daniel Sánchez',
#   'Tarjeta'),
#  (47,
#   datetime.date(2024, 1, 2),
#   'Bolsas de basura',
#   'Santos',
#   'Natalia Hernández',
#   'Tarjeta'),
#  (48, datetime.date(2024, 1, 2), 'Colonia', 'Ortiz', 'David Peña', 'Tarjeta'),
#  (49,
#   datetime.date(2024, 1, 2),
#   'Chuletas',
#   'Jiménez',
#   'Sofía Campos',
#   'Tarjeta'),
#  (50,
#   datetime.date(2024, 1, 2),
#   'Desinfectante',
#   'García',
#   'Irene Ortiz',
#   'Tarjeta'),
#  (51, datetime.date(2024, 1, 2), 'Agua', 'Navarro', 'David Lara', 'Tarjeta'),
#  (52,
#   datetime.date(2024, 1, 2),
#   'Colonia',
#   'Navarro',
#   'Camila Paredes',
#   'Tarjeta'),
#  (53,
#   datetime.date(2024, 1, 2),
#   'Tomate',
#   'Guzmán',
#   'Sergio Rodríguez',
#   'Tarjeta'),
#  (54,
#   datetime.date(2024, 1, 2),
#   'Queso',
#   'Álvarez',
#   'Paula Cortés',
#   'Efectivo'),
#  (55,
#   datetime.date(2024, 1, 2),
#   'Tierra para macetas',
#   'Rodríguez',
#   'Miguel Cabrera',
#   'Efectivo'),
#  (56,
#   datetime.date(2024, 1, 3),
#   'Crema hidratante',
#   'Chávez',
#   'María García',
#   'Efectivo'),
#  (57,
#   datetime.date(2024, 1, 3),
#   'Desodorante',
#   'Romero',
#   'Ángel Molina',
#   'Tarjeta'),
#  (58,
#   datetime.date(2024, 1, 3),
#   'Platos desechables',
#   'González',
#   'Camila Esquivel',
#   'Efectivo'),
#  (59,
#   datetime.date(2024, 1, 3),
#   'Cerveza',
#   'Navarro',
#   'Ana Ortiz',
#   'Efectivo'),
#  (60,
#   datetime.date(2024, 1, 3),
#   'Galletas',
#   'Campos',
#   'Francisco Carrillo',
#   'Tarjeta'),
#  (61, datetime.date(2024, 1, 3), 'Yogur', 'Ramos', 'David Castro', 'Tarjeta'),
#  (62,
#   datetime.date(2024, 1, 3),
#   'Semillas',
#   'Jiménez',
#   'Irene Esquivel',
#   'Tarjeta'),
#  (63,
#   datetime.date(2024, 1, 3),
#   'Semillas',
#   'Medina',
#   'Tomás Domínguez',
#   'Efectivo'),
#  (64,
#   datetime.date(2024, 1, 3),
#   'Tierra para macetas',
#   'Flores',
#   'Tomás Flores',
#   'Tarjeta'),
#  (65,
#   datetime.date(2024, 1, 3),
#   'Papas fritas',
#   'Ramírez',
#   'Ana Chávez',
#   'Tarjeta'),
#  (66,
#   datetime.date(2024, 1, 3),
#   'Velas',
#   'Jiménez',
#   'Elena López',
#   'Efectivo'),
#  (67,
#   datetime.date(2024, 1, 3),
#   'Papas fritas',
#   'Martínez',
#   'Manuel Sánchez',
#   'Efectivo'),
#  (68,
#   datetime.date(2024, 1, 3),
#   'Cerdo',
#   'Ramírez',
#   'Irene Chávez',
#   'Efectivo'),
#  (69,
#   datetime.date(2024, 1, 3),
#   'Papas fritas',
#   'Navarro',
#   'Miguel Reyes',
#   'Tarjeta'),
#  (70,
#   datetime.date(2024, 1, 3),
#   'Cerdo',
#   'Peña',
#   'Valeria Domínguez',
#   'Efectivo'),
#  (71,
#   datetime.date(2024, 1, 3),
#   'Pilas',
#   'Cabrera',
#   'Carla González',
#   'Tarjeta'),
#  (72,
#   datetime.date(2024, 1, 3),
#   'Chicles',
#   'Delgado',
#   'Cristian Reyes',
#   'Efectivo'),
#  (73,
#   datetime.date(2024, 1, 3),
#   'Papas fritas',
#   'Montes',
#   'María Velázquez',
#   'Tarjeta'),
#  (74, datetime.date(2024, 1, 3), 'Banana', 'Ortiz', 'Irene Ortiz', 'Efectivo'),
#  (75,
#   datetime.date(2024, 1, 3),
#   'Semillas',
#   'Santos',
#   'Mario Serrano',
#   'Tarjeta'),
#  (76,
#   datetime.date(2024, 1, 3),
#   'Jugo de naranja',
#   'Carrillo',
#   'Adriana Cortés',
#   'Tarjeta'),
#  (77,
#   datetime.date(2024, 1, 3),
#   'Semillas',
#   'Campos',
#   'Irene Esquivel',
#   'Efectivo'),
#  (78,
#   datetime.date(2024, 1, 3),
#   'Tierra para macetas',
#   'Hernández',
#   'María Delgado',
#   'Tarjeta'),
#  (79,
#   datetime.date(2024, 1, 3),
#   'Queso',
#   'Esquivel',
#   'Eva Delgado',
#   'Efectivo'),
#  (80,
#   datetime.date(2024, 1, 3),
#   'Detergente',
#   'Ramírez',
#   'Irene Navarro',
#   'Efectivo'),
#  (81,
#   datetime.date(2024, 1, 3),
#   'Refresco',
#   'López',
#   'Laura Sánchez',
#   'Tarjeta'),
#  (82,
#   datetime.date(2024, 1, 3),
#   'Desodorante',
#   'Lara',
#   'Jorge Martínez',
#   'Tarjeta'),
#  (83,
#   datetime.date(2024, 1, 4),
#   'Detergente',
#   'Velázquez',
#   'Laura Aguilar',
#   'Tarjeta'),
#  (84,
#   datetime.date(2024, 1, 4),
#   'Desinfectante',
#   'Molina',
#   'David Lara',
#   'Efectivo'),
#  (85,
#   datetime.date(2024, 1, 4),
#   'Banana',
#   'Cruz',
#   'Cristian Ortiz',
#   'Tarjeta'),
#  (86, datetime.date(2024, 1, 4), 'Leche', 'Méndez', 'Pablo Reyes', 'Efectivo'),
#  (87,
#   datetime.date(2024, 1, 4),
#   'Papas fritas',
#   'Carrillo',
#   'Irene Navarro',
#   'Tarjeta'),
#  (88,
#   datetime.date(2024, 1, 4),
#   'Velas',
#   'Álvarez',
#   'Laura Jiménez',
#   'Tarjeta'),
#  (89,
#   datetime.date(2024, 1, 4),
#   'Papas fritas',
#   'Rodríguez',
#   'Diego Lara',
#   'Tarjeta'),
#  (90,
#   datetime.date(2024, 1, 4),
#   'Zanahoria',
#   'Ortiz',
#   'Carla López',
#   'Efectivo'),
#  (91,
#   datetime.date(2024, 1, 4),
#   'Semillas',
#   'Cruz',
#   'Laura Sánchez',
#   'Tarjeta'),
#  (92,
#   datetime.date(2024, 1, 4),
#   'Naranja',
#   'Romero',
#   'Patricia Santos',
#   'Tarjeta'),
#  (93, datetime.date(2024, 1, 4), 'Agua', 'Ortiz', 'Andrés Montes', 'Tarjeta'),
#  (94,
#   datetime.date(2024, 1, 4),
#   'Uva',
#   'Paredes',
#   'María Delgado',
#   'Efectivo'),
#  (95,
#   datetime.date(2024, 1, 4),
#   'Leche',
#   'Rubio',
#   'Javier Martínez',
#   'Tarjeta'),
#  (96,
#   datetime.date(2024, 1, 4),
#   'Pilas',
#   'Salinas',
#   'David Castro',
#   'Efectivo'),
#  (97,
#   datetime.date(2024, 1, 4),
#   'Agua',
#   'Rodríguez',
#   'Cristian Fernández',
#   'Tarjeta'),
#  (98, datetime.date(2024, 1, 4), 'Leche', 'Aguilar', 'Diana Ramos', 'Tarjeta'),
#  (99,
#   datetime.date(2024, 1, 4),
#   'Banana',
#   'Medina',
#   'Ricardo Fernández',
#   'Efectivo'),
#  (100,
#   datetime.date(2024, 1, 4),
#   'Carne de res',
#   'Rubio',
#   'Pablo Reyes',
#   'Tarjeta'),
#  (101,
#   datetime.date(2024, 1, 4),
#   'Bolsas de basura',
#   'Flores',
#   'Javier Martínez',
#   'Tarjeta'),
#  (102, datetime.date(2024, 1, 4), 'Uva', 'Ortiz', 'Carmen García', 'Tarjeta'),
#  (103,
#   datetime.date(2024, 1, 4),
#   'Refresco',
#   'Fuentes',
#   'Miguel Pérez',
#   'Efectivo'),
#  (104,
#   datetime.date(2024, 1, 4),
#   'Agua',
#   'Montes',
#   'Eduardo Cabrera',
#   'Efectivo'),
#  (105,
#   datetime.date(2024, 1, 4),
#   'Desodorante',
#   'Guzmán',
#   'Clara Torres',
#   'Efectivo'),
#  (106,
#   datetime.date(2024, 1, 4),
#   'Platos desechables',
#   'Domínguez',
#   'Sara Fernández',
#   'Tarjeta'),
#  (107,
#   datetime.date(2024, 1, 5),
#   'Papas fritas',
#   'Ortiz',
#   'Camila López',
#   'Efectivo'),
#  (108,
#   datetime.date(2024, 1, 5),
#   'Naranja',
#   'García',
#   'Adriana Velázquez',
#   'Efectivo'),
#  (109,
#   datetime.date(2024, 1, 5),
#   'Velas',
#   'Carrillo',
#   'Irene Esquivel',
#   'Efectivo'),
#  (110, datetime.date(2024, 1, 5), 'Velas', 'Ruiz', 'David Peña', 'Tarjeta'),
#  (111,
#   datetime.date(2024, 1, 5),
#   'Champú',
#   'Álvarez',
#   'Paula Martínez',
#   'Tarjeta'),
#  (112,
#   datetime.date(2024, 1, 5),
#   'Bolsas de basura',
#   'Velázquez',
#   'Verónica Jiménez',
#   'Tarjeta'),
#  (113,
#   datetime.date(2024, 1, 5),
#   'Colonia',
#   'Cortés',
#   'Irene Torres',
#   'Tarjeta'),
#  (114,
#   datetime.date(2024, 1, 5),
#   'Leche',
#   'Reyes',
#   'Jorge Martínez',
#   'Efectivo'),
#  (115,
#   datetime.date(2024, 1, 5),
#   'Bolsas de basura',
#   'Navarro',
#   'Sofía Campos',
#   'Tarjeta'),
#  (116,
#   datetime.date(2024, 1, 5),
#   'Mantequilla',
#   'Romero',
#   'Sergio Carrillo',
#   'Tarjeta'),
#  (117,
#   datetime.date(2024, 1, 5),
#   'Jugo de naranja',
#   'Serrano',
#   'Fernando Romero',
#   'Tarjeta'),
#  (118,
#   datetime.date(2024, 1, 5),
#   'Carne de res',
#   'Méndez',
#   'Francisco Martínez',
#   'Efectivo'),
#  (119,
#   datetime.date(2024, 1, 5),
#   'Bolsas de basura',
#   'Esquivel',
#   'Lorena Esquivel',
#   'Tarjeta'),
#  (120, datetime.date(2024, 1, 5), 'Cerdo', 'Pérez', 'Carmen Ortiz', 'Tarjeta'),
#  (121,
#   datetime.date(2024, 1, 5),
#   'Jabón líquido',
#   'Ramos',
#   'Ricardo Jiménez',
#   'Tarjeta'),
#  (122,
#   datetime.date(2024, 1, 5),
#   'Manzana',
#   'Sánchez',
#   'Laura Ramírez',
#   'Efectivo'),
#  (123,
#   datetime.date(2024, 1, 5),
#   'Chocolate',
#   'Lara',
#   'Jorge Montes',
#   'Tarjeta'),
#  (124,
#   datetime.date(2024, 1, 5),
#   'Chicles',
#   'Peña',
#   'Samuel González',
#   'Efectivo'),
#  (125,
#   datetime.date(2024, 1, 5),
#   'Fertilizante',
#   'Aguilar',
#   'Eduardo Cabrera',
#   'Tarjeta'),
#  (126,
#   datetime.date(2024, 1, 5),
#   'Mantequilla',
#   'Domínguez',
#   'Laura Jiménez',
#   'Efectivo'),
#  (127,
#   datetime.date(2024, 1, 5),
#   'Platos desechables',
#   'Salinas',
#   'Raúl Carrillo',
#   'Tarjeta'),
#  (128,
#   datetime.date(2024, 1, 5),
#   'Papas fritas',
#   'Martínez',
#   'Laura Jiménez',
#   'Efectivo'),
#  (129,
#   datetime.date(2024, 1, 5),
#   'Pollo',
#   'García',
#   'Francisco Carrillo',
#   'Efectivo'),
#  (130,
#   datetime.date(2024, 1, 5),
#   'Leche',
#   'Domínguez',
#   'Sergio Carrillo',
#   'Efectivo'),
#  (131,
#   datetime.date(2024, 1, 5),
#   'Chuletas',
#   'Sánchez',
#   'Elena López',
#   'Tarjeta'),
#  (132,
#   datetime.date(2024, 1, 5),
#   'Pilas',
#   'Cabrera',
#   'María Delgado',
#   'Tarjeta'),
#  (133,
#   datetime.date(2024, 1, 5),
#   'Esponjas',
#   'Pérez',
#   'Carla López',
#   'Tarjeta'),
#  (134,
#   datetime.date(2024, 1, 6),
#   'Colonia',
#   'Carrillo',
#   'Gabriela Ramírez',
#   'Tarjeta'),
#  (135,
#   datetime.date(2024, 1, 6),
#   'Galletas',
#   'Pérez',
#   'Andrés Molina',
#   'Tarjeta'),
#  (136,
#   datetime.date(2024, 1, 6),
#   'Galletas',
#   'Campos',
#   'Tomás Peña',
#   'Tarjeta'),
#  (137,
#   datetime.date(2024, 1, 6),
#   'Semillas',
#   'Romero',
#   'Paula Serrano',
#   'Tarjeta'),
#  (138,
#   datetime.date(2024, 1, 6),
#   'Semillas',
#   'Fuentes',
#   'Gabriela Sánchez',
#   'Tarjeta'),
#  (139,
#   datetime.date(2024, 1, 6),
#   'Uva',
#   'Paredes',
#   'Miguel Reyes',
#   'Efectivo'),
#  (140,
#   datetime.date(2024, 1, 6),
#   'Velas',
#   'Aguilar',
#   'José González',
#   'Tarjeta'),
#  (141,
#   datetime.date(2024, 1, 6),
#   'Mantequilla',
#   'Campos',
#   'Valeria Méndez',
#   'Efectivo'),
#  (142,
#   datetime.date(2024, 1, 6),
#   'Lechuga',
#   'Lara',
#   'Javier Pérez',
#   'Efectivo'),
#  (143,
#   datetime.date(2024, 1, 6),
#   'Refresco',
#   'Campos',
#   'Lorena Esquivel',
#   'Efectivo'),
#  (144,
#   datetime.date(2024, 1, 6),
#   'Yogur',
#   'Hernández',
#   'Sofía Montes',
#   'Tarjeta'),
#  (145,
#   datetime.date(2024, 1, 6),
#   'Desinfectante',
#   'Medina',
#   'Carmen Serrano',
#   'Efectivo'),
#  (146,
#   datetime.date(2024, 1, 6),
#   'Pilas',
#   'Domínguez',
#   'Laura Sánchez',
#   'Tarjeta'),
#  (147,
#   datetime.date(2024, 1, 6),
#   'Velas',
#   'Álvarez',
#   'Mario Serrano',
#   'Tarjeta'),
#  (148,
#   datetime.date(2024, 1, 6),
#   'Banana',
#   'Martínez',
#   'Irene Torres',
#   'Tarjeta'),
#  (149, datetime.date(2024, 1, 6), 'Uva', 'González', 'Hugo Montes', 'Tarjeta'),
#  (150,
#   datetime.date(2024, 1, 6),
#   'Zanahoria',
#   'Peña',
#   'Gabriela Ramírez',
#   'Efectivo'),
#  (151,
#   datetime.date(2024, 1, 6),
#   'Semillas',
#   'Díaz',
#   'Mario Guzmán',
#   'Tarjeta'),
#  (152, datetime.date(2024, 1, 7), 'Uva', 'Ramírez', 'Julia Santos', 'Tarjeta'),
#  (153,
#   datetime.date(2024, 1, 7),
#   'Semillas',
#   'Vázquez',
#   'Fernando Pérez',
#   'Tarjeta'),
#  (154,
#   datetime.date(2024, 1, 7),
#   'Tomate',
#   'Romero',
#   'Gabriela Reyes',
#   'Tarjeta'),
#  (155,
#   datetime.date(2024, 1, 7),
#   'Cerdo',
#   'Méndez',
#   'Francisco Martínez',
#   'Efectivo'),
#  (156,
#   datetime.date(2024, 1, 7),
#   'Fertilizante',
#   'Serrano',
#   'Mario Serrano',
#   'Efectivo'),
#  (157,
#   datetime.date(2024, 1, 7),
#   'Lechuga',
#   'Flores',
#   'Carlos Delgado',
#   'Efectivo'),
#  (158,
#   datetime.date(2024, 1, 7),
#   'Mantequilla',
#   'Fernández',
#   'Jorge Jiménez',
#   'Tarjeta'),
#  (159,
#   datetime.date(2024, 1, 7),
#   'Papas fritas',
#   'Martínez',
#   'Sergio Delgado',
#   'Tarjeta'),
#  (160,
#   datetime.date(2024, 1, 7),
#   'Lechuga',
#   'Vázquez',
#   'Laura Aguilar',
#   'Tarjeta'),
#  (161,
#   datetime.date(2024, 1, 7),
#   'Refresco',
#   'González',
#   'Carla González',
#   'Efectivo'),
#  (162,
#   datetime.date(2024, 1, 7),
#   'Velas',
#   'Romero',
#   'Carmen Delgado',
#   'Tarjeta'),
#  (163,
#   datetime.date(2024, 1, 7),
#   'Desinfectante',
#   'García',
#   'Sergio Rodríguez',
#   'Efectivo'),
#  (164,
#   datetime.date(2024, 1, 7),
#   'Semillas',
#   'Aguilar',
#   'Lorena Esquivel',
#   'Efectivo'),
#  (165,
#   datetime.date(2024, 1, 7),
#   'Chocolate',
#   'González',
#   'José Flores',
#   'Tarjeta'),
#  (166,
#   datetime.date(2024, 1, 7),
#   'Platos desechables',
#   'González',
#   'Laura Aguilar',
#   'Tarjeta'),
#  (167,
#   datetime.date(2024, 1, 7),
#   'Pilas',
#   'Castro',
#   'Camila Esquivel',
#   'Tarjeta'),
#  (168,
#   datetime.date(2024, 1, 7),
#   'Lechuga',
#   'Medina',
#   'Eva Delgado',
#   'Tarjeta'),
#  (169,
#   datetime.date(2024, 1, 7),
#   'Papas fritas',
#   'Guzmán',
#   'Cristian Fernández',
#   'Efectivo'),
#  (170,
#   datetime.date(2024, 1, 8),
#   'Platos desechables',
#   'Cruz',
#   'Cristian Cruz',
#   'Tarjeta'),
#  (171,
#   datetime.date(2024, 1, 8),
#   'Manzana',
#   'Salinas',
#   'Jorge Martínez',
#   'Tarjeta'),
#  (172,
#   datetime.date(2024, 1, 8),
#   'Manzana',
#   'Cruz',
#   'Sergio Delgado',
#   'Tarjeta'),
#  (173,
#   datetime.date(2024, 1, 8),
#   'Chocolate',
#   'Cortés',
#   'Daniel Lara',
#   'Tarjeta'),
#  (174,
#   datetime.date(2024, 1, 8),
#   'Desinfectante',
#   'Fuentes',
#   'Francisco Martínez',
#   'Tarjeta'),
#  (175,
#   datetime.date(2024, 1, 8),
#   'Cerveza',
#   'Pérez',
#   'Laura Jiménez',
#   'Tarjeta'),
#  (176,
#   datetime.date(2024, 1, 8),
#   'Agua',
#   'Santos',
#   'Natalia Paredes',
#   'Efectivo'),
#  (177,
#   datetime.date(2024, 1, 8),
#   'Detergente',
#   'Domínguez',
#   'Ángel Carrillo',
#   'Efectivo'),
#  (178,
#   datetime.date(2024, 1, 8),
#   'Papas fritas',
#   'Ortiz',
#   'Natalia Hernández',
#   'Tarjeta'),
#  (179,
#   datetime.date(2024, 1, 8),
#   'Fertilizante',
#   'Fuentes',
#   'Marta Montes',
#   'Tarjeta'),
#  (180,
#   datetime.date(2024, 1, 8),
#   'Pilas',
#   'Ortiz',
#   'Cristian Ortiz',
#   'Tarjeta'),
#  (181,
#   datetime.date(2024, 1, 8),
#   'Velas',
#   'Cruz',
#   'Ricardo Fernández',
#   'Tarjeta'),
#  (182,
#   datetime.date(2024, 1, 8),
#   'Mantequilla',
#   'Ortiz',
#   'Ana Ortiz',
#   'Tarjeta'),
#  (183,
#   datetime.date(2024, 1, 8),
#   'Banana',
#   'Cruz',
#   'Daniel Guzmán',
#   'Efectivo'),
#  (184,
#   datetime.date(2024, 1, 8),
#   'Cerveza',
#   'Vázquez',
#   'Valeria Torres',
#   'Tarjeta'),
#  (185,
#   datetime.date(2024, 1, 8),
#   'Queso',
#   'Reyes',
#   'Natalia Hernández',
#   'Tarjeta'),
#  (186,
#   datetime.date(2024, 1, 8),
#   'Colonia',
#   'Delgado',
#   'Julia Santos',
#   'Efectivo'),
#  (187,
#   datetime.date(2024, 1, 8),
#   'Lechuga',
#   'Vázquez',
#   'Carlos González',
#   'Efectivo'),
#  (188,
#   datetime.date(2024, 1, 8),
#   'Desodorante',
#   'Ramos',
#   'Natalia Navarro',
#   'Tarjeta'),
#  (189,
#   datetime.date(2024, 1, 8),
#   'Cerdo',
#   'Reyes',
#   'Valeria Torres',
#   'Efectivo'),
#  (190,
#   datetime.date(2024, 1, 8),
#   'Cerveza',
#   'Vázquez',
#   'Ángel Carrillo',
#   'Tarjeta'),
#  (191,
#   datetime.date(2024, 1, 8),
#   'Cerdo',
#   'Álvarez',
#   'Paula Serrano',
#   'Efectivo'),
#  (192,
#   datetime.date(2024, 1, 8),
#   'Velas',
#   'Martínez',
#   'Francisco Carrillo',
#   'Efectivo'),
#  (193,
#   datetime.date(2024, 1, 8),
#   'Velas',
#   'Montes',
#   'Raúl Carrillo',
#   'Efectivo'),
#  (194,
#   datetime.date(2024, 1, 8),
#   'Manzana',
#   'Ramos',
#   'Natalia Hernández',
#   'Tarjeta'),
#  (195,
#   datetime.date(2024, 1, 8),
#   'Jabón líquido',
#   'Esquivel',
#   'Irene Esquivel',
#   'Tarjeta'),
#  (196,
#   datetime.date(2024, 1, 8),
#   'Platos desechables',
#   'Díaz',
#   'Ana Ortiz',
#   'Tarjeta'),
#  (197,
#   datetime.date(2024, 1, 8),
#   'Desodorante',
#   'Pérez',
#   'Raúl Sánchez',
#   'Tarjeta'),
#  (198,
#   datetime.date(2024, 1, 8),
#   'Cerdo',
#   'Ortiz',
#   'María Delgado',
#   'Tarjeta'),
#  (199,
#   datetime.date(2024, 1, 8),
#   'Papas fritas',
#   'Rubio',
#   'Sofía Campos',
#   'Tarjeta'),
#  (200,
#   datetime.date(2024, 1, 8),
#   'Cebolla',
#   'Campos',
#   'Carla López',
#   'Tarjeta'),
#  (201,
#   datetime.date(2024, 1, 8),
#   'Velas',
#   'López',
#   'Sara Fernández',
#   'Tarjeta'),
#  (202, datetime.date(2024, 1, 9), 'Uva', 'Torres', 'David Castro', 'Efectivo'),
#  (203,
#   datetime.date(2024, 1, 9),
#   'Champú',
#   'Hernández',
#   'Daniel Guzmán',
#   'Tarjeta'),
#  (204,
#   datetime.date(2024, 1, 9),
#   'Galletas',
#   'Montes',
#   'Daniel Cabrera',
#   'Tarjeta'),
#  (205,
#   datetime.date(2024, 1, 9),
#   'Fertilizante',
#   'Ramírez',
#   'Carmen García',
#   'Tarjeta'),
#  (206,
#   datetime.date(2024, 1, 9),
#   'Chuletas',
#   'Carrillo',
#   'Hugo Montes',
#   'Efectivo'),
#  (207,
#   datetime.date(2024, 1, 9),
#   'Chuletas',
#   'Lara',
#   'Mario Serrano',
#   'Tarjeta'),
#  (208, datetime.date(2024, 1, 9), 'Agua', 'Ortiz', 'Tomás Peña', 'Efectivo'),
#  (209, datetime.date(2024, 1, 9), 'Uva', 'Rubio', 'Tomás Flores', 'Efectivo'),
#  (210, datetime.date(2024, 1, 9), 'Manzana', 'Cruz', 'Carla López', 'Tarjeta'),
#  (211,
#   datetime.date(2024, 1, 9),
#   'Desodorante',
#   'Guzmán',
#   'Hugo Moreno',
#   'Tarjeta'),
#  (212,
#   datetime.date(2024, 1, 9),
#   'Platos desechables',
#   'Fernández',
#   'Valeria Méndez',
#   'Tarjeta'),
#  (213,
#   datetime.date(2024, 1, 9),
#   'Tierra para macetas',
#   'Ramírez',
#   'Pablo Lara',
#   'Efectivo'),
#  (214,
#   datetime.date(2024, 1, 9),
#   'Chuletas',
#   'Carrillo',
#   'Raúl Sánchez',
#   'Tarjeta'),
#  (215,
#   datetime.date(2024, 1, 9),
#   'Refresco',
#   'Salinas',
#   'Daniel Guzmán',
#   'Tarjeta'),
#  (216,
#   datetime.date(2024, 1, 9),
#   'Naranja',
#   'Guzmán',
#   'Irene Ortiz',
#   'Tarjeta'),
#  (217,
#   datetime.date(2024, 1, 9),
#   'Colonia',
#   'Delgado',
#   'Tomás Flores',
#   'Tarjeta'),
#  (218,
#   datetime.date(2024, 1, 9),
#   'Tierra para macetas',
#   'Jiménez',
#   'Irene Navarro',
#   'Efectivo'),
#  (219,
#   datetime.date(2024, 1, 9),
#   'Champú',
#   'Martínez',
#   'Cristian Reyes',
#   'Tarjeta'),
#  (220,
#   datetime.date(2024, 1, 9),
#   'Refresco',
#   'González',
#   'Manuel Méndez',
#   'Tarjeta'),
#  (221,
#   datetime.date(2024, 1, 9),
#   'Regadera',
#   'Pérez',
#   'Eduardo Cabrera',
#   'Tarjeta'),
#  (222,
#   datetime.date(2024, 1, 9),
#   'Chicles',
#   'Rodríguez',
#   'David López',
#   'Efectivo'),
#  (223,
#   datetime.date(2024, 1, 9),
#   'Zanahoria',
#   'Domínguez',
#   'Adriana Velázquez',
#   'Tarjeta'),
#  (224,
#   datetime.date(2024, 1, 9),
#   'Esponjas',
#   'Reyes',
#   'Camila Ruiz',
#   'Tarjeta'),
#  (225,
#   datetime.date(2024, 1, 9),
#   'Velas',
#   'Guzmán',
#   'Laura Ramírez',
#   'Efectivo'),
#  (226,
#   datetime.date(2024, 1, 9),
#   'Galletas',
#   'Rodríguez',
#   'Sergio Ortiz',
#   'Tarjeta'),
#  (227,
#   datetime.date(2024, 1, 10),
#   'Cerdo',
#   'González',
#   'Daniel Guzmán',
#   'Tarjeta'),
#  (228,
#   datetime.date(2024, 1, 10),
#   'Cerdo',
#   'Montes',
#   'Cristian Fernández',
#   'Efectivo'),
#  (229,
#   datetime.date(2024, 1, 10),
#   'Banana',
#   'Martínez',
#   'David Castro',
#   'Tarjeta'),
#  (230,
#   datetime.date(2024, 1, 10),
#   'Agua',
#   'Domínguez',
#   'Lorena Esquivel',
#   'Efectivo'),
#  (231,
#   datetime.date(2024, 1, 10),
#   'Papas fritas',
#   'Serrano',
#   'Ana Ortiz',
#   'Tarjeta'),
#  (232,
#   datetime.date(2024, 1, 10),
#   'Platos desechables',
#   'Hernández',
#   'Laura Sánchez',
#   'Tarjeta'),
#  (233,
#   datetime.date(2024, 1, 10),
#   'Agua',
#   'Jiménez',
#   'Ricardo Ortiz',
#   'Tarjeta'),
#  (234,
#   datetime.date(2024, 1, 10),
#   'Chocolate',
#   'Chávez',
#   'Raúl Sánchez',
#   'Tarjeta'),
#  (235,
#   datetime.date(2024, 1, 10),
#   'Leche',
#   'Aguilar',
#   'Camila Carrillo',
#   'Tarjeta'),
#  (236,
#   datetime.date(2024, 1, 10),
#   'Agua',
#   'Navarro',
#   'Paula Serrano',
#   'Tarjeta'),
#  (237,
#   datetime.date(2024, 1, 10),
#   'Velas',
#   'Guzmán',
#   'Camila Carrillo',
#   'Tarjeta'),
#  (238,
#   datetime.date(2024, 1, 10),
#   'Naranja',
#   'Vázquez',
#   'Ricardo Fernández',
#   'Tarjeta'),
#  (239,
#   datetime.date(2024, 1, 10),
#   'Pilas',
#   'Navarro',
#   'Sergio Delgado',
#   'Tarjeta'),
#  (240,
#   datetime.date(2024, 1, 10),
#   'Refresco',
#   'Ruiz',
#   'María Delgado',
#   'Tarjeta'),
#  (241,
#   datetime.date(2024, 1, 10),
#   'Papas fritas',
#   'Serrano',
#   'Jorge Montes',
#   'Tarjeta'),
#  (242,
#   datetime.date(2024, 1, 10),
#   'Mantequilla',
#   'Paredes',
#   'Mario Guzmán',
#   'Tarjeta'),
#  (243,
#   datetime.date(2024, 1, 10),
#   'Champú',
#   'Díaz',
#   'Miguel Castro',
#   'Efectivo'),
#  (244,
#   datetime.date(2024, 1, 10),
#   'Zanahoria',
#   'García',
#   'Fernando Romero',
#   'Tarjeta'),
#  (245,
#   datetime.date(2024, 1, 10),
#   'Refresco',
#   'Rubio',
#   'Raúl Sánchez',
#   'Tarjeta'),
#  (246,
#   datetime.date(2024, 1, 10),
#   'Yogur',
#   'García',
#   'Sergio Rodríguez',
#   'Efectivo'),
#  (247,
#   datetime.date(2024, 1, 10),
#   'Pilas',
#   'Navarro',
#   'Camila Esquivel',
#   'Efectivo'),
#  (248,
#   datetime.date(2024, 1, 10),
#   'Banana',
#   'Medina',
#   'Carmen Serrano',
#   'Efectivo'),
#  (249,
#   datetime.date(2024, 1, 10),
#   'Tierra para macetas',
#   'Montes',
#   'Ricardo Jiménez',
#   'Efectivo'),
#  (250,
#   datetime.date(2024, 1, 10),
#   'Esponjas',
#   'Navarro',
#   'Gabriela Santos',
#   'Tarjeta'),
#  (251,
#   datetime.date(2024, 1, 11),
#   'Chocolate',
#   'Méndez',
#   'Irene Navarro',
#   'Efectivo'),
#  (252,
#   datetime.date(2024, 1, 11),
#   'Galletas',
#   'Castro',
#   'Camila Paredes',
#   'Tarjeta'),
#  (253,
#   datetime.date(2024, 1, 11),
#   'Bolsas de basura',
#   'Ruiz',
#   'Natalia Paredes',
#   'Tarjeta'),
#  (254,
#   datetime.date(2024, 1, 11),
#   'Tomate',
#   'Torres',
#   'María García',
#   'Tarjeta'),
#  (255,
#   datetime.date(2024, 1, 11),
#   'Chuletas',
#   'Castro',
#   'Marta Montes',
#   'Tarjeta'),
#  (256,
#   datetime.date(2024, 1, 11),
#   'Desinfectante',
#   'Fuentes',
#   'Gabriela Torres',
#   'Efectivo'),
#  (257,
#   datetime.date(2024, 1, 11),
#   'Yogur',
#   'Navarro',
#   'Ricardo Ortiz',
#   'Efectivo'),
#  (258,
#   datetime.date(2024, 1, 11),
#   'Desodorante',
#   'Carrillo',
#   'Miguel Castro',
#   'Efectivo'),
#  (259,
#   datetime.date(2024, 1, 11),
#   'Queso',
#   'Esquivel',
#   'María Delgado',
#   'Tarjeta'),
#  (260,
#   datetime.date(2024, 1, 11),
#   'Lechuga',
#   'Salinas',
#   'Gabriela Ramírez',
#   'Tarjeta'),
#  (261,
#   datetime.date(2024, 1, 11),
#   'Cebolla',
#   'Peña',
#   'Cristian Cruz',
#   'Tarjeta'),
#  (262,
#   datetime.date(2024, 1, 11),
#   'Cerveza',
#   'Cortés',
#   'Gabriela Ramírez',
#   'Tarjeta'),
#  (263,
#   datetime.date(2024, 1, 11),
#   'Champú',
#   'Ramírez',
#   'David López',
#   'Tarjeta'),
#  (264,
#   datetime.date(2024, 1, 11),
#   'Agua',
#   'Hernández',
#   'Irene Esquivel',
#   'Efectivo'),
#  (265,
#   datetime.date(2024, 1, 11),
#   'Desodorante',
#   'Peña',
#   'Ángel Molina',
#   'Efectivo'),
#  (266,
#   datetime.date(2024, 1, 11),
#   'Jabón líquido',
#   'Fuentes',
#   'Carlos Delgado',
#   'Tarjeta'),
#  (267,
#   datetime.date(2024, 1, 11),
#   'Chicles',
#   'Hernández',
#   'Valeria Torres',
#   'Efectivo'),
#  (268,
#   datetime.date(2024, 1, 11),
#   'Zanahoria',
#   'Díaz',
#   'Irene Chávez',
#   'Tarjeta'),
#  (269,
#   datetime.date(2024, 1, 11),
#   'Agua',
#   'Álvarez',
#   'Mario Guzmán',
#   'Tarjeta'),
#  (270,
#   datetime.date(2024, 1, 11),
#   'Desodorante',
#   'Moreno',
#   'Tomás Flores',
#   'Tarjeta'),
#  (271,
#   datetime.date(2024, 1, 12),
#   'Queso',
#   'Romero',
#   'Paula Cortés',
#   'Tarjeta'),
#  (272,
#   datetime.date(2024, 1, 12),
#   'Fertilizante',
#   'Guzmán',
#   'Adriana Torres',
#   'Tarjeta'),
#  (273,
#   datetime.date(2024, 1, 12),
#   'Colonia',
#   'Romero',
#   'Camila Paredes',
#   'Tarjeta'),
#  (274,
#   datetime.date(2024, 1, 12),
#   'Desodorante',
#   'González',
#   'Gabriela Santos',
#   'Tarjeta'),
#  (275,
#   datetime.date(2024, 1, 12),
#   'Queso',
#   'Ramos',
#   'Irene Navarro',
#   'Tarjeta'),
#  (276,
#   datetime.date(2024, 1, 12),
#   'Semillas',
#   'Martínez',
#   'Diana Ramos',
#   'Efectivo'),
#  (277,
#   datetime.date(2024, 1, 12),
#   'Naranja',
#   'Romero',
#   'Miguel Castro',
#   'Tarjeta'),
#  (278,
#   datetime.date(2024, 1, 12),
#   'Semillas',
#   'Méndez',
#   'Miguel Reyes',
#   'Efectivo'),
#  (279,
#   datetime.date(2024, 1, 12),
#   'Agua',
#   'Ramos',
#   'Carmen Delgado',
#   'Tarjeta'),
#  (280,
#   datetime.date(2024, 1, 12),
#   'Crema hidratante',
#   'Cabrera',
#   'Ricardo Jiménez',
#   'Tarjeta'),
#  (281,
#   datetime.date(2024, 1, 12),
#   'Uva',
#   'Navarro',
#   'Tomás Flores',
#   'Tarjeta'),
#  (282,
#   datetime.date(2024, 1, 12),
#   'Platos desechables',
#   'García',
#   'Valeria Torres',
#   'Tarjeta'),
#  (283,
#   datetime.date(2024, 1, 12),
#   'Lechuga',
#   'Lara',
#   'Camila Esquivel',
#   'Tarjeta'),
#  (284,
#   datetime.date(2024, 1, 12),
#   'Fertilizante',
#   'Peña',
#   'Carla López',
#   'Tarjeta'),
#  (285,
#   datetime.date(2024, 1, 12),
#   'Desodorante',
#   'Peña',
#   'Cristian Cruz',
#   'Tarjeta'),
#  (286,
#   datetime.date(2024, 1, 12),
#   'Naranja',
#   'Esquivel',
#   'David Peña',
#   'Tarjeta'),
#  (287,
#   datetime.date(2024, 1, 12),
#   'Chicles',
#   'Lara',
#   'Gabriela Santos',
#   'Tarjeta'),
#  (288,
#   datetime.date(2024, 1, 13),
#   'Detergente',
#   'Rodríguez',
#   'Diana Chávez',
#   'Efectivo'),
#  (289,
#   datetime.date(2024, 1, 13),
#   'Colonia',
#   'Jiménez',
#   'Fernando Pérez',
#   'Tarjeta'),
#  (290,
#   datetime.date(2024, 1, 13),
#   'Chocolate',
#   'Fuentes',
#   'Camila López',
#   'Tarjeta'),
#  (291,
#   datetime.date(2024, 1, 13),
#   'Champú',
#   'Rodríguez',
#   'Sofía Campos',
#   'Efectivo'),
#  (292,
#   datetime.date(2024, 1, 13),
#   'Cerdo',
#   'González',
#   'Lucía Fuentes',
#   'Tarjeta'),
#  (293,
#   datetime.date(2024, 1, 13),
#   'Mantequilla',
#   'Méndez',
#   'Laura Ramírez',
#   'Tarjeta'),
#  (294,
#   datetime.date(2024, 1, 13),
#   'Zanahoria',
#   'Castro',
#   'Fernando Pérez',
#   'Efectivo'),
#  (295,
#   datetime.date(2024, 1, 13),
#   'Queso',
#   'Vázquez',
#   'Tomás Peña',
#   'Tarjeta'),
#  (296,
#   datetime.date(2024, 1, 13),
#   'Uva',
#   'Ramírez',
#   'Paula Serrano',
#   'Tarjeta'),
#  (297,
#   datetime.date(2024, 1, 13),
#   'Desodorante',
#   'Peña',
#   'Gabriela Ramírez',
#   'Tarjeta'),
#  (298,
#   datetime.date(2024, 1, 13),
#   'Lechuga',
#   'López',
#   'David Lara',
#   'Efectivo'),
#  (299,
#   datetime.date(2024, 1, 13),
#   'Mantequilla',
#   'Cabrera',
#   'Sara Fernández',
#   'Tarjeta'),
#  (300,
#   datetime.date(2024, 1, 13),
#   'Mantequilla',
#   'Domínguez',
#   'Clara Torres',
#   'Tarjeta'),
#  (301,
#   datetime.date(2024, 1, 13),
#   'Refresco',
#   'Ramírez',
#   'Paula Cortés',
#   'Tarjeta'),
#  (302,
#   datetime.date(2024, 1, 13),
#   'Jabón líquido',
#   'López',
#   'María Delgado',
#   'Tarjeta'),
#  (303,
#   datetime.date(2024, 1, 13),
#   'Manzana',
#   'Serrano',
#   'Carlos Delgado',
#   'Tarjeta'),
#  (304,
#   datetime.date(2024, 1, 13),
#   'Crema hidratante',
#   'Díaz',
#   'Cristian Fernández',
#   'Efectivo'),
#  (305,
#   datetime.date(2024, 1, 13),
#   'Champú',
#   'Romero',
#   'Elena Montes',
#   'Efectivo'),
#  (306, datetime.date(2024, 1, 13), 'Leche', 'Ruiz', 'Luis Moreno', 'Tarjeta'),
#  (307,
#   datetime.date(2024, 1, 13),
#   'Fertilizante',
#   'Vázquez',
#   'Gabriela Sánchez',
#   'Efectivo'),
#  (308,
#   datetime.date(2024, 1, 13),
#   'Chuletas',
#   'Santos',
#   'Clara Torres',
#   'Efectivo'),
#  (309,
#   datetime.date(2024, 1, 13),
#   'Tierra para macetas',
#   'Serrano',
#   'Hugo Torres',
#   'Tarjeta'),
#  (310,
#   datetime.date(2024, 1, 13),
#   'Leche',
#   'Rubio',
#   'Cristian Cruz',
#   'Efectivo'),
#  (311,
#   datetime.date(2024, 1, 14),
#   'Galletas',
#   'Cabrera',
#   'Carla López',
#   'Tarjeta'),
#  (312,
#   datetime.date(2024, 1, 14),
#   'Refresco',
#   'Velázquez',
#   'Mario Serrano',
#   'Efectivo'),
#  (313,
#   datetime.date(2024, 1, 14),
#   'Cerdo',
#   'Álvarez',
#   'Cristian Cruz',
#   'Efectivo'),
#  (314,
#   datetime.date(2024, 1, 14),
#   'Fertilizante',
#   'Reyes',
#   'Tomás Domínguez',
#   'Efectivo'),
#  (315,
#   datetime.date(2024, 1, 14),
#   'Platos desechables',
#   'Serrano',
#   'Natalia Paredes',
#   'Tarjeta'),
#  (316,
#   datetime.date(2024, 1, 14),
#   'Manzana',
#   'Flores',
#   'José González',
#   'Tarjeta'),
#  (317,
#   datetime.date(2024, 1, 14),
#   'Velas',
#   'Álvarez',
#   'Camila Esquivel',
#   'Tarjeta'),
#  (318,
#   datetime.date(2024, 1, 14),
#   'Cebolla',
#   'Ortiz',
#   'Diego Carrillo',
#   'Efectivo'),
#  (319,
#   datetime.date(2024, 1, 14),
#   'Detergente',
#   'Martínez',
#   'Irene Esquivel',
#   'Tarjeta'),
#  (320,
#   datetime.date(2024, 1, 14),
#   'Champú',
#   'Hernández',
#   'Pablo Lara',
#   'Efectivo'),
#  (321,
#   datetime.date(2024, 1, 14),
#   'Chuletas',
#   'Álvarez',
#   'Ángel Carrillo',
#   'Tarjeta'),
#  (322,
#   datetime.date(2024, 1, 14),
#   'Crema hidratante',
#   'Álvarez',
#   'Miguel Pérez',
#   'Tarjeta'),
#  (323,
#   datetime.date(2024, 1, 14),
#   'Detergente',
#   'Carrillo',
#   'Luis Moreno',
#   'Tarjeta'),
#  (324,
#   datetime.date(2024, 1, 14),
#   'Carne de res',
#   'Esquivel',
#   'Ana Chávez',
#   'Efectivo'),
#  (325,
#   datetime.date(2024, 1, 14),
#   'Uva',
#   'Carrillo',
#   'Gabriela Santos',
#   'Tarjeta'),
#  (326,
#   datetime.date(2024, 1, 14),
#   'Cerdo',
#   'Jiménez',
#   'Adriana Cortés',
#   'Tarjeta'),
#  (327,
#   datetime.date(2024, 1, 14),
#   'Chocolate',
#   'Rodríguez',
#   'Gabriela Santos',
#   'Tarjeta'),
#  (328,
#   datetime.date(2024, 1, 14),
#   'Leche',
#   'Flores',
#   'Sergio Delgado',
#   'Tarjeta'),
#  (329,
#   datetime.date(2024, 1, 14),
#   'Chicles',
#   'Salinas',
#   'Cristian Díaz',
#   'Tarjeta'),
#  (330,
#   datetime.date(2024, 1, 14),
#   'Manzana',
#   'Medina',
#   'Mario Guzmán',
#   'Tarjeta'),
#  (331,
#   datetime.date(2024, 1, 14),
#   'Cerdo',
#   'Jiménez',
#   'Hugo Montes',
#   'Tarjeta'),
#  (332,
#   datetime.date(2024, 1, 14),
#   'Champú',
#   'Montes',
#   'Jorge Montes',
#   'Tarjeta'),
#  (333,
#   datetime.date(2024, 1, 14),
#   'Leche',
#   'Santos',
#   'Lorena Esquivel',
#   'Efectivo'),
#  (334,
#   datetime.date(2024, 1, 14),
#   'Carne de res',
#   'Hernández',
#   'Gabriela Ramírez',
#   'Efectivo'),
#  (335,
#   datetime.date(2024, 1, 14),
#   'Tomate',
#   'Rodríguez',
#   'David Peña',
#   'Tarjeta'),
#  (336,
#   datetime.date(2024, 1, 14),
#   'Cerveza',
#   'Carrillo',
#   'Gabriela Sánchez',
#   'Tarjeta'),
#  (337,
#   datetime.date(2024, 1, 15),
#   'Colonia',
#   'Ortiz',
#   'Daniel Lara',
#   'Efectivo'),
#  (338,
#   datetime.date(2024, 1, 15),
#   'Galletas',
#   'Méndez',
#   'Carlos González',
#   'Tarjeta'),
#  (339,
#   datetime.date(2024, 1, 15),
#   'Colonia',
#   'Serrano',
#   'Ana Ortiz',
#   'Tarjeta'),
#  (340,
#   datetime.date(2024, 1, 15),
#   'Zanahoria',
#   'López',
#   'David Castro',
#   'Tarjeta'),
#  (341,
#   datetime.date(2024, 1, 15),
#   'Bolsas de basura',
#   'Domínguez',
#   'Gabriela Torres',
#   'Efectivo'),
#  (342,
#   datetime.date(2024, 1, 15),
#   'Regadera',
#   'Santos',
#   'Laura Sánchez',
#   'Efectivo'),
#  (343,
#   datetime.date(2024, 1, 15),
#   'Galletas',
#   'Cabrera',
#   'Ricardo Ortiz',
#   'Tarjeta'),
#  (344,
#   datetime.date(2024, 1, 15),
#   'Bolsas de basura',
#   'Torres',
#   'Cristian Ortiz',
#   'Efectivo'),
#  (345,
#   datetime.date(2024, 1, 15),
#   'Regadera',
#   'Molina',
#   'Verónica Jiménez',
#   'Efectivo'),
#  (346,
#   datetime.date(2024, 1, 15),
#   'Platos desechables',
#   'Salinas',
#   'Manuel Sánchez',
#   'Efectivo'),
#  (347,
#   datetime.date(2024, 1, 15),
#   'Esponjas',
#   'Reyes',
#   'Adriana Torres',
#   'Tarjeta'),
#  (348,
#   datetime.date(2024, 1, 15),
#   'Crema hidratante',
#   'Ortiz',
#   'Sergio Ortiz',
#   'Tarjeta'),
#  (349,
#   datetime.date(2024, 1, 15),
#   'Bolsas de basura',
#   'González',
#   'Carmen Ortiz',
#   'Efectivo'),
#  (350, datetime.date(2024, 1, 15), 'Leche', 'Ruiz', 'Irene Ortiz', 'Efectivo'),
#  (351,
#   datetime.date(2024, 1, 15),
#   'Cerdo',
#   'Rodríguez',
#   'Gabriela Ramírez',
#   'Efectivo'),
#  (352,
#   datetime.date(2024, 1, 15),
#   'Regadera',
#   'Fernández',
#   'Clara Torres',
#   'Tarjeta'),
#  (353,
#   datetime.date(2024, 1, 15),
#   'Colonia',
#   'Chávez',
#   'Elena López',
#   'Efectivo'),
#  (354,
#   datetime.date(2024, 1, 15),
#   'Agua',
#   'Hernández',
#   'Mario Paredes',
#   'Tarjeta'),
#  (355,
#   datetime.date(2024, 1, 15),
#   'Chocolate',
#   'Romero',
#   'Sofía Romero',
#   'Tarjeta'),
#  (356,
#   datetime.date(2024, 1, 15),
#   'Queso',
#   'Flores',
#   'Isabel Santos',
#   'Tarjeta'),
#  (357,
#   datetime.date(2024, 1, 15),
#   'Cerdo',
#   'Ramírez',
#   'Jorge Montes',
#   'Tarjeta'),
#  (358,
#   datetime.date(2024, 1, 15),
#   'Regadera',
#   'Castro',
#   'David López',
#   'Tarjeta'),
#  (359,
#   datetime.date(2024, 1, 15),
#   'Detergente',
#   'González',
#   'Paula Cortés',
#   'Tarjeta'),
#  (360,
#   datetime.date(2024, 1, 15),
#   'Bolsas de basura',
#   'Ruiz',
#   'Andrés Montes',
#   'Tarjeta'),
#  (361,
#   datetime.date(2024, 1, 15),
#   'Naranja',
#   'Cruz',
#   'Carmen Delgado',
#   'Efectivo'),
#  (362,
#   datetime.date(2024, 1, 15),
#   'Semillas',
#   'Medina',
#   'Hugo Torres',
#   'Tarjeta'),
#  (363,
#   datetime.date(2024, 1, 15),
#   'Carne de res',
#   'Velázquez',
#   'Ana Chávez',
#   'Tarjeta'),
#  (364,
#   datetime.date(2024, 1, 15),
#   'Fertilizante',
#   'Fuentes',
#   'Camila Ruiz',
#   'Efectivo'),
#  (365,
#   datetime.date(2024, 1, 15),
#   'Manzana',
#   'Romero',
#   'Irene Ortiz',
#   'Efectivo'),
#  (366,
#   datetime.date(2024, 1, 15),
#   'Fertilizante',
#   'Vázquez',
#   'Irene Esquivel',
#   'Efectivo'),
#  (367,
#   datetime.date(2024, 1, 15),
#   'Jugo de naranja',
#   'Ramos',
#   'Andrés Montes',
#   'Tarjeta'),
#  (368,
#   datetime.date(2024, 1, 15),
#   'Mantequilla',
#   'Molina',
#   'Natalia Paredes',
#   'Tarjeta'),
#  (369,
#   datetime.date(2024, 1, 15),
#   'Semillas',
#   'Esquivel',
#   'Irene Torres',
#   'Tarjeta'),
#  (370,
#   datetime.date(2024, 1, 16),
#   'Platos desechables',
#   'Medina',
#   'Hugo Montes',
#   'Tarjeta'),
#  (371,
#   datetime.date(2024, 1, 16),
#   'Chuletas',
#   'Reyes',
#   'David Lara',
#   'Tarjeta'),
#  (372,
#   datetime.date(2024, 1, 16),
#   'Esponjas',
#   'Cruz',
#   'Andrés Molina',
#   'Efectivo'),
#  (373,
#   datetime.date(2024, 1, 16),
#   'Carne de res',
#   'Peña',
#   'Sergio Rodríguez',
#   'Tarjeta'),
#  (374,
#   datetime.date(2024, 1, 16),
#   'Agua',
#   'Vázquez',
#   'Gabriela Ramírez',
#   'Tarjeta'),
#  (375,
#   datetime.date(2024, 1, 16),
#   'Jabón líquido',
#   'Velázquez',
#   'Irene Navarro',
#   'Tarjeta'),
#  (376,
#   datetime.date(2024, 1, 16),
#   'Crema hidratante',
#   'Hernández',
#   'Camila Paredes',
#   'Efectivo'),
#  (377,
#   datetime.date(2024, 1, 16),
#   'Chocolate',
#   'Fuentes',
#   'Valeria Torres',
#   'Efectivo'),
#  (378,
#   datetime.date(2024, 1, 16),
#   'Manzana',
#   'González',
#   'Irene Navarro',
#   'Efectivo'),
#  (379,
#   datetime.date(2024, 1, 16),
#   'Refresco',
#   'Campos',
#   'Raúl Carrillo',
#   'Efectivo'),
#  (380,
#   datetime.date(2024, 1, 16),
#   'Chuletas',
#   'Serrano',
#   'Manuel Méndez',
#   'Tarjeta'),
#  (381,
#   datetime.date(2024, 1, 16),
#   'Papas fritas',
#   'Romero',
#   'Sergio Rodríguez',
#   'Tarjeta'),
#  (382,
#   datetime.date(2024, 1, 16),
#   'Fertilizante',
#   'Medina',
#   'Carmen Delgado',
#   'Tarjeta'),
#  (383,
#   datetime.date(2024, 1, 16),
#   'Cerveza',
#   'Rodríguez',
#   'David Castro',
#   'Tarjeta'),
#  (384,
#   datetime.date(2024, 1, 16),
#   'Crema hidratante',
#   'Cabrera',
#   'Julia Santos',
#   'Efectivo'),
#  (385,
#   datetime.date(2024, 1, 16),
#   'Cerveza',
#   'Moreno',
#   'Cristian Díaz',
#   'Efectivo'),
#  (386,
#   datetime.date(2024, 1, 16),
#   'Semillas',
#   'Lara',
#   'Sergio Rodríguez',
#   'Tarjeta'),
#  (387,
#   datetime.date(2024, 1, 16),
#   'Desinfectante',
#   'Martínez',
#   'Carlos Delgado',
#   'Efectivo'),
#  (388,
#   datetime.date(2024, 1, 16),
#   'Chocolate',
#   'Reyes',
#   'Francisco Martínez',
#   'Tarjeta'),
#  (389,
#   datetime.date(2024, 1, 16),
#   'Chuletas',
#   'Flores',
#   'Ana Ortiz',
#   'Tarjeta'),
#  (390,
#   datetime.date(2024, 1, 16),
#   'Carne de res',
#   'Romero',
#   'María Ortiz',
#   'Efectivo'),
#  (391,
#   datetime.date(2024, 1, 17),
#   'Chocolate',
#   'Jiménez',
#   'Irene Ortiz',
#   'Efectivo'),
#  (392,
#   datetime.date(2024, 1, 17),
#   'Esponjas',
#   'Reyes',
#   'María García',
#   'Tarjeta'),
#  (393,
#   datetime.date(2024, 1, 17),
#   'Tomate',
#   'Cruz',
#   'Patricia Santos',
#   'Tarjeta'),
#  (394,
#   datetime.date(2024, 1, 17),
#   'Refresco',
#   'Jiménez',
#   'Jorge Jiménez',
#   'Tarjeta'),
#  (395,
#   datetime.date(2024, 1, 17),
#   'Semillas',
#   'Chávez',
#   'Irene Ortiz',
#   'Tarjeta'),
#  (396,
#   datetime.date(2024, 1, 17),
#   'Mantequilla',
#   'Ortiz',
#   'Javier Martínez',
#   'Tarjeta'),
#  (397,
#   datetime.date(2024, 1, 17),
#   'Jabón líquido',
#   'López',
#   'Eva Delgado',
#   'Tarjeta'),
#  (398,
#   datetime.date(2024, 1, 17),
#   'Papas fritas',
#   'Moreno',
#   'Sofía Campos',
#   'Tarjeta'),
#  (399,
#   datetime.date(2024, 1, 17),
#   'Chicles',
#   'Montes',
#   'Cristian Fernández',
#   'Tarjeta'),
#  (400,
#   datetime.date(2024, 1, 17),
#   'Papas fritas',
#   'Lara',
#   'Miguel Castro',
#   'Efectivo'),
#  (401,
#   datetime.date(2024, 1, 17),
#   'Galletas',
#   'Navarro',
#   'María Delgado',
#   'Tarjeta'),
#  (402,
#   datetime.date(2024, 1, 17),
#   'Desinfectante',
#   'López',
#   'Miguel Méndez',
#   'Tarjeta'),
#  (403,
#   datetime.date(2024, 1, 17),
#   'Manzana',
#   'Serrano',
#   'María Velázquez',
#   'Tarjeta'),
#  (404,
#   datetime.date(2024, 1, 17),
#   'Yogur',
#   'Paredes',
#   'Ángel Molina',
#   'Tarjeta'),
#  (405,
#   datetime.date(2024, 1, 17),
#   'Desinfectante',
#   'Rodríguez',
#   'María García',
#   'Tarjeta'),
#  (406,
#   datetime.date(2024, 1, 17),
#   'Champú',
#   'López',
#   'Camila Esquivel',
#   'Tarjeta'),
#  (407,
#   datetime.date(2024, 1, 17),
#   'Bolsas de basura',
#   'Díaz',
#   'Laura Sánchez',
#   'Tarjeta'),
#  (408,
#   datetime.date(2024, 1, 17),
#   'Zanahoria',
#   'Sánchez',
#   'Daniel Sánchez',
#   'Efectivo'),
#  (409,
#   datetime.date(2024, 1, 17),
#   'Bolsas de basura',
#   'Vázquez',
#   'Sergio Rodríguez',
#   'Tarjeta'),
#  (410,
#   datetime.date(2024, 1, 17),
#   'Mantequilla',
#   'Santos',
#   'Camila Paredes',
#   'Tarjeta'),
#  (411,
#   datetime.date(2024, 1, 17),
#   'Leche',
#   'Santos',
#   'Valeria Méndez',
#   'Tarjeta'),
#  (412,
#   datetime.date(2024, 1, 17),
#   'Yogur',
#   'Cabrera',
#   'Diego Lara',
#   'Tarjeta'),
#  (413,
#   datetime.date(2024, 1, 17),
#   'Champú',
#   'Navarro',
#   'Sergio Ortiz',
#   'Efectivo'),
#  (414,
#   datetime.date(2024, 1, 17),
#   'Mantequilla',
#   'Santos',
#   'Sofía Campos',
#   'Tarjeta'),
#  (415,
#   datetime.date(2024, 1, 17),
#   'Desodorante',
#   'Navarro',
#   'Paula Cortés',
#   'Efectivo'),
#  (416,
#   datetime.date(2024, 1, 18),
#   'Leche',
#   'Méndez',
#   'Gabriela Torres',
#   'Tarjeta'),
#  (417,
#   datetime.date(2024, 1, 18),
#   'Pollo',
#   'Cabrera',
#   'Andrea Hernández',
#   'Efectivo'),
#  (418,
#   datetime.date(2024, 1, 18),
#   'Mantequilla',
#   'Cabrera',
#   'Lorena Esquivel',
#   'Tarjeta'),
#  (419,
#   datetime.date(2024, 1, 18),
#   'Jabón líquido',
#   'Velázquez',
#   'Patricia Santos',
#   'Tarjeta'),
#  (420,
#   datetime.date(2024, 1, 18),
#   'Cerdo',
#   'Rodríguez',
#   'Mario Serrano',
#   'Tarjeta'),
#  (421,
#   datetime.date(2024, 1, 18),
#   'Queso',
#   'Rodríguez',
#   'Natalia Díaz',
#   'Efectivo'),
#  (422,
#   datetime.date(2024, 1, 18),
#   'Detergente',
#   'Méndez',
#   'Irene Esquivel',
#   'Efectivo'),
#  (423,
#   datetime.date(2024, 1, 18),
#   'Refresco',
#   'Ramírez',
#   'Carla López',
#   'Efectivo'),
#  (424,
#   datetime.date(2024, 1, 18),
#   'Agua',
#   'Domínguez',
#   'Natalia Hernández',
#   'Tarjeta'),
#  (425,
#   datetime.date(2024, 1, 18),
#   'Chuletas',
#   'Díaz',
#   'Manuel Méndez',
#   'Tarjeta'),
#  (426,
#   datetime.date(2024, 1, 18),
#   'Desinfectante',
#   'López',
#   'Natalia Navarro',
#   'Tarjeta'),
#  (427,
#   datetime.date(2024, 1, 18),
#   'Manzana',
#   'Cruz',
#   'Irene Ortiz',
#   'Tarjeta'),
#  (428,
#   datetime.date(2024, 1, 18),
#   'Chuletas',
#   'Castro',
#   'Daniel Lara',
#   'Tarjeta'),
#  (429,
#   datetime.date(2024, 1, 18),
#   'Lechuga',
#   'Molina',
#   'Laura Sánchez',
#   'Tarjeta'),
#  (430,
#   datetime.date(2024, 1, 18),
#   'Colonia',
#   'Romero',
#   'José González',
#   'Efectivo'),
#  (431, datetime.date(2024, 1, 18), 'Pilas', 'Cortés', 'David Lara', 'Tarjeta'),
#  (432,
#   datetime.date(2024, 1, 18),
#   'Fertilizante',
#   'López',
#   'Andrés Molina',
#   'Tarjeta'),
#  (433,
#   datetime.date(2024, 1, 18),
#   'Leche',
#   'Santos',
#   'Valeria Rodríguez',
#   'Efectivo'),
#  (434,
#   datetime.date(2024, 1, 18),
#   'Fertilizante',
#   'Rubio',
#   'Ricardo Fernández',
#   'Tarjeta'),
#  (435,
#   datetime.date(2024, 1, 18),
#   'Uva',
#   'Paredes',
#   'María García',
#   'Tarjeta'),
#  (436,
#   datetime.date(2024, 1, 18),
#   'Zanahoria',
#   'García',
#   'Valeria Torres',
#   'Efectivo'),
#  (437,
#   datetime.date(2024, 1, 18),
#   'Pollo',
#   'Torres',
#   'Diana Ramos',
#   'Tarjeta'),
#  (438,
#   datetime.date(2024, 1, 18),
#   'Leche',
#   'Molina',
#   'Paula Martínez',
#   'Tarjeta'),
#  (439,
#   datetime.date(2024, 1, 18),
#   'Yogur',
#   'Cabrera',
#   'Paula Martínez',
#   'Tarjeta'),
#  (440,
#   datetime.date(2024, 1, 18),
#   'Papas fritas',
#   'Montes',
#   'Sara Fernández',
#   'Efectivo'),
#  (441,
#   datetime.date(2024, 1, 18),
#   'Uva',
#   'Navarro',
#   'Fernando Romero',
#   'Efectivo'),
#  (442,
#   datetime.date(2024, 1, 18),
#   'Detergente',
#   'Álvarez',
#   'José Aguilar',
#   'Efectivo'),
#  (443,
#   datetime.date(2024, 1, 19),
#   'Semillas',
#   'Rubio',
#   'Laura Ramírez',
#   'Efectivo'),
#  (444,
#   datetime.date(2024, 1, 19),
#   'Banana',
#   'Salinas',
#   'Clara Torres',
#   'Tarjeta'),
#  (445,
#   datetime.date(2024, 1, 19),
#   'Cerdo',
#   'Romero',
#   'Clara Torres',
#   'Efectivo'),
#  (446,
#   datetime.date(2024, 1, 19),
#   'Platos desechables',
#   'Paredes',
#   'Ángel Molina',
#   'Tarjeta'),
#  (447,
#   datetime.date(2024, 1, 19),
#   'Queso',
#   'González',
#   'Daniel Cabrera',
#   'Efectivo'),
#  (448,
#   datetime.date(2024, 1, 19),
#   'Platos desechables',
#   'Lara',
#   'Ana Chávez',
#   'Tarjeta'),
#  (449,
#   datetime.date(2024, 1, 19),
#   'Cebolla',
#   'Romero',
#   'Irene Ortiz',
#   'Efectivo'),
#  (450,
#   datetime.date(2024, 1, 19),
#   'Regadera',
#   'Sánchez',
#   'Mario Guzmán',
#   'Tarjeta'),
#  (451,
#   datetime.date(2024, 1, 19),
#   'Jugo de naranja',
#   'Hernández',
#   'Jorge Jiménez',
#   'Tarjeta'),
#  (452,
#   datetime.date(2024, 1, 19),
#   'Tierra para macetas',
#   'Peña',
#   'Carmen Ortiz',
#   'Efectivo'),
#  (453,
#   datetime.date(2024, 1, 19),
#   'Platos desechables',
#   'Navarro',
#   'Verónica Jiménez',
#   'Tarjeta'),
#  (454,
#   datetime.date(2024, 1, 19),
#   'Fertilizante',
#   'Hernández',
#   'Mario Guzmán',
#   'Tarjeta'),
#  (455,
#   datetime.date(2024, 1, 19),
#   'Tierra para macetas',
#   'Cruz',
#   'Daniel Lara',
#   'Tarjeta'),
#  (456,
#   datetime.date(2024, 1, 19),
#   'Tierra para macetas',
#   'Rubio',
#   'Ricardo Jiménez',
#   'Tarjeta'),
#  (457,
#   datetime.date(2024, 1, 19),
#   'Chocolate',
#   'Martínez',
#   'Daniel Cabrera',
#   'Tarjeta'),
#  (458,
#   datetime.date(2024, 1, 19),
#   'Bolsas de basura',
#   'Flores',
#   'Pablo Reyes',
#   'Tarjeta'),
#  (459,
#   datetime.date(2024, 1, 19),
#   'Esponjas',
#   'Medina',
#   'Gabriela Santos',
#   'Efectivo'),
#  (460,
#   datetime.date(2024, 1, 19),
#   'Galletas',
#   'Cortés',
#   'Mario Guzmán',
#   'Tarjeta'),
#  (461,
#   datetime.date(2024, 1, 19),
#   'Pollo',
#   'Cabrera',
#   'Carmen Serrano',
#   'Tarjeta'),
#  (462,
#   datetime.date(2024, 1, 19),
#   'Cebolla',
#   'Campos',
#   'Elena Montes',
#   'Tarjeta'),
#  (463, datetime.date(2024, 1, 19), 'Agua', 'Lara', 'Ana Cruz', 'Tarjeta'),
#  (464,
#   datetime.date(2024, 1, 20),
#   'Champú',
#   'Rubio',
#   'Lorena Esquivel',
#   'Efectivo'),
#  (465,
#   datetime.date(2024, 1, 20),
#   'Regadera',
#   'Álvarez',
#   'Sofía Montes',
#   'Efectivo'),
#  (466,
#   datetime.date(2024, 1, 20),
#   'Fertilizante',
#   'Molina',
#   'Gabriela Cruz',
#   'Tarjeta'),
#  (467,
#   datetime.date(2024, 1, 20),
#   'Cerdo',
#   'Ortiz',
#   'Daniel Guzmán',
#   'Efectivo'),
#  (468,
#   datetime.date(2024, 1, 20),
#   'Galletas',
#   'Guzmán',
#   'Javier Pérez',
#   'Tarjeta'),
#  (469,
#   datetime.date(2024, 1, 20),
#   'Detergente',
#   'Cabrera',
#   'Tomás Flores',
#   'Tarjeta'),
#  (470,
#   datetime.date(2024, 1, 20),
#   'Fertilizante',
#   'Torres',
#   'Adriana Velázquez',
#   'Tarjeta'),
#  (471,
#   datetime.date(2024, 1, 20),
#   'Regadera',
#   'Medina',
#   'Javier Velázquez',
#   'Tarjeta'),
#  (472,
#   datetime.date(2024, 1, 20),
#   'Fertilizante',
#   'Esquivel',
#   'Valeria Torres',
#   'Efectivo'),
#  (473,
#   datetime.date(2024, 1, 20),
#   'Semillas',
#   'Ramos',
#   'Ángel Díaz',
#   'Tarjeta'),
#  (474,
#   datetime.date(2024, 1, 20),
#   'Leche',
#   'Álvarez',
#   'Ana Chávez',
#   'Tarjeta'),
#  (475,
#   datetime.date(2024, 1, 20),
#   'Regadera',
#   'Ruiz',
#   'Diego Lara',
#   'Tarjeta'),
#  (476,
#   datetime.date(2024, 1, 20),
#   'Carne de res',
#   'Hernández',
#   'Gabriela Santos',
#   'Tarjeta'),
#  (477,
#   datetime.date(2024, 1, 20),
#   'Detergente',
#   'Jiménez',
#   'Cristian Vázquez',
#   'Tarjeta'),
#  (478,
#   datetime.date(2024, 1, 20),
#   'Mantequilla',
#   'Domínguez',
#   'Laura Ramírez',
#   'Tarjeta'),
#  (479,
#   datetime.date(2024, 1, 20),
#   'Yogur',
#   'Vázquez',
#   'Carla López',
#   'Efectivo'),
#  (480,
#   datetime.date(2024, 1, 20),
#   'Chocolate',
#   'Ortiz',
#   'Laura Jiménez',
#   'Tarjeta'),
#  (481,
#   datetime.date(2024, 1, 20),
#   'Yogur',
#   'González',
#   'Laura Sánchez',
#   'Tarjeta'),
#  (482,
#   datetime.date(2024, 1, 20),
#   'Papas fritas',
#   'Martínez',
#   'José Flores',
#   'Tarjeta'),
#  (483,
#   datetime.date(2024, 1, 20),
#   'Chuletas',
#   'Medina',
#   'Ángel Carrillo',
#   'Efectivo'),
#  (484,
#   datetime.date(2024, 1, 20),
#   'Bolsas de basura',
#   'Esquivel',
#   'Gabriela Torres',
#   'Efectivo'),
#  (485,
#   datetime.date(2024, 1, 20),
#   'Galletas',
#   'Delgado',
#   'Ángel Díaz',
#   'Efectivo'),
#  (486,
#   datetime.date(2024, 1, 20),
#   'Crema hidratante',
#   'Chávez',
#   'Paula Serrano',
#   'Efectivo'),
#  (487,
#   datetime.date(2024, 1, 21),
#   'Lechuga',
#   'Molina',
#   'Valeria Torres',
#   'Efectivo'),
#  (488,
#   datetime.date(2024, 1, 21),
#   'Yogur',
#   'Pérez',
#   'Hugo Torres',
#   'Efectivo'),
#  (489,
#   datetime.date(2024, 1, 21),
#   'Fertilizante',
#   'Navarro',
#   'Camila Paredes',
#   'Efectivo'),
#  (490,
#   datetime.date(2024, 1, 21),
#   'Banana',
#   'García',
#   'María Ortiz',
#   'Efectivo'),
#  (491,
#   datetime.date(2024, 1, 21),
#   'Carne de res',
#   'Fuentes',
#   'Sofía Romero',
#   'Efectivo'),
#  (492,
#   datetime.date(2024, 1, 21),
#   'Mantequilla',
#   'Domínguez',
#   'Gabriela Ramírez',
#   'Efectivo'),
#  (493,
#   datetime.date(2024, 1, 21),
#   'Velas',
#   'Jiménez',
#   'Francisco Martínez',
#   'Tarjeta'),
#  (494,
#   datetime.date(2024, 1, 21),
#   'Chicles',
#   'Álvarez',
#   'Raúl Carrillo',
#   'Tarjeta'),
#  (495,
#   datetime.date(2024, 1, 21),
#   'Pilas',
#   'Martínez',
#   'María García',
#   'Tarjeta'),
#  (496,
#   datetime.date(2024, 1, 21),
#   'Detergente',
#   'Peña',
#   'Adriana Cortés',
#   'Tarjeta'),
#  (497,
# ...
#   'Detergente',
#   'Aguilar',
#   'Ángel Díaz',
#   'Efectivo'),
#  (836,
#   datetime.date(2024, 2, 3),
#   'Refresco',
#   'Díaz',
#   'Adriana Cortés',
#   'Efectivo'),
#  (837, datetime.date(2024, 2, 3), 'Yogur', 'Peña', 'Irene Navarro', 'Tarjeta'),
#  (838,
#   datetime.date(2024, 2, 3),
#   'Jabón líquido',
#   'Fuentes',
#   'Tomás Peña',
#   'Tarjeta'),
#  (839,
#   datetime.date(2024, 2, 3),
#   'Cerdo',
#   'Díaz',
#   'Valeria Méndez',
#   'Tarjeta'),
#  (840,
#   datetime.date(2024, 2, 3),
#   'Bolsas de basura',
#   'Fernández',
#   'Adriana Velázquez',
#   'Efectivo'),
#  (841,
#   datetime.date(2024, 2, 3),
#   'Bolsas de basura',
#   'López',
#   'Irene Navarro',
#   'Tarjeta'),
#  (842,
#   datetime.date(2024, 2, 3),
#   'Tierra para macetas',
#   'Ramos',
#   'Carlos González',
#   'Tarjeta'),
#  (843,
#   datetime.date(2024, 2, 3),
#   'Leche',
#   'Paredes',
#   'Manuel Méndez',
#   'Efectivo'),
#  (844,
#   datetime.date(2024, 2, 3),
#   'Carne de res',
#   'Esquivel',
#   'Ana Chávez',
#   'Tarjeta'),
#  (845,
#   datetime.date(2024, 2, 3),
#   'Galletas',
#   'Rodríguez',
#   'Diana Chávez',
#   'Tarjeta'),
#  (846,
#   datetime.date(2024, 2, 3),
#   'Jugo de naranja',
#   'Flores',
#   'Gabriela Ramírez',
#   'Efectivo'),
#  (847,
#   datetime.date(2024, 2, 3),
#   'Yogur',
#   'Álvarez',
#   'Mario Paredes',
#   'Efectivo'),
#  (848,
#   datetime.date(2024, 2, 3),
#   'Galletas',
#   'González',
#   'José González',
#   'Tarjeta'),
#  (849,
#   datetime.date(2024, 2, 3),
#   'Detergente',
#   'González',
#   'Carlos Castro',
#   'Efectivo'),
#  (850,
#   datetime.date(2024, 2, 3),
#   'Chocolate',
#   'Rodríguez',
#   'Diana Ramos',
#   'Tarjeta'),
#  (851,
#   datetime.date(2024, 2, 3),
#   'Pilas',
#   'Delgado',
#   'María Velázquez',
#   'Efectivo'),
#  (852,
#   datetime.date(2024, 2, 3),
#   'Banana',
#   'Aguilar',
#   'David Castro',
#   'Tarjeta'),
#  (853,
#   datetime.date(2024, 2, 3),
#   'Desodorante',
#   'Santos',
#   'Camila Paredes',
#   'Efectivo'),
#  (854, datetime.date(2024, 2, 4), 'Uva', 'Vázquez', 'Raúl Sánchez', 'Tarjeta'),
#  (855,
#   datetime.date(2024, 2, 4),
#   'Cerveza',
#   'Ramírez',
#   'David Castro',
#   'Tarjeta'),
#  (856,
#   datetime.date(2024, 2, 4),
#   'Pilas',
#   'Campos',
#   'Mario Serrano',
#   'Efectivo'),
#  (857,
#   datetime.date(2024, 2, 4),
#   'Leche',
#   'Ruiz',
#   'Cristian Cruz',
#   'Efectivo'),
#  (858,
#   datetime.date(2024, 2, 4),
#   'Pollo',
#   'Fuentes',
#   'José Aguilar',
#   'Efectivo'),
#  (859,
#   datetime.date(2024, 2, 4),
#   'Bolsas de basura',
#   'López',
#   'José Flores',
#   'Tarjeta'),
#  (860,
#   datetime.date(2024, 2, 4),
#   'Fertilizante',
#   'Flores',
#   'Adriana Torres',
#   'Efectivo'),
#  (861,
#   datetime.date(2024, 2, 4),
#   'Jugo de naranja',
#   'Cruz',
#   'Sara Fernández',
#   'Tarjeta'),
#  (862,
#   datetime.date(2024, 2, 4),
#   'Chicles',
#   'Pérez',
#   'Francisco Martínez',
#   'Tarjeta'),
#  (863,
#   datetime.date(2024, 2, 4),
#   'Desinfectante',
#   'Serrano',
#   'Diana Ramos',
#   'Tarjeta'),
#  (864,
#   datetime.date(2024, 2, 4),
#   'Pilas',
#   'Salinas',
#   'Mario Serrano',
#   'Tarjeta'),
#  (865,
#   datetime.date(2024, 2, 4),
#   'Fertilizante',
#   'Ramírez',
#   'Marta Montes',
#   'Efectivo'),
#  (866,
#   datetime.date(2024, 2, 4),
#   'Naranja',
#   'Lara',
#   'Javier Pérez',
#   'Tarjeta'),
#  (867,
#   datetime.date(2024, 2, 4),
#   'Chocolate',
#   'Chávez',
#   'Ángel Díaz',
#   'Tarjeta'),
#  (868,
#   datetime.date(2024, 2, 4),
#   'Cerveza',
#   'Pérez',
#   'Natalia Paredes',
#   'Efectivo'),
#  (869,
#   datetime.date(2024, 2, 4),
#   'Tierra para macetas',
#   'Peña',
#   'David Peña',
#   'Tarjeta'),
#  (870,
#   datetime.date(2024, 2, 4),
#   'Pilas',
#   'Romero',
#   'Irene Torres',
#   'Efectivo'),
#  (871,
#   datetime.date(2024, 2, 4),
#   'Pollo',
#   'Lara',
#   'Ricardo Fernández',
#   'Tarjeta'),
#  (872,
#   datetime.date(2024, 2, 5),
#   'Cerveza',
#   'García',
#   'Raúl Carrillo',
#   'Efectivo'),
#  (873,
#   datetime.date(2024, 2, 5),
#   'Esponjas',
#   'Ramírez',
#   'Sofía Campos',
#   'Efectivo'),
#  (874, datetime.date(2024, 2, 5), 'Banana', 'Cruz', 'Diego Lara', 'Tarjeta'),
#  (875,
#   datetime.date(2024, 2, 5),
#   'Champú',
#   'Ramírez',
#   'Carmen Serrano',
#   'Tarjeta'),
#  (876,
#   datetime.date(2024, 2, 5),
#   'Velas',
#   'López',
#   'Ricardo Cabrera',
#   'Tarjeta'),
#  (877,
#   datetime.date(2024, 2, 5),
#   'Fertilizante',
#   'Ortiz',
#   'Ángel Carrillo',
#   'Tarjeta'),
#  (878,
#   datetime.date(2024, 2, 5),
#   'Colonia',
#   'Serrano',
#   'David Lara',
#   'Tarjeta'),
#  (879,
#   datetime.date(2024, 2, 5),
#   'Jugo de naranja',
#   'Serrano',
#   'Tomás Moreno',
#   'Tarjeta'),
#  (880,
#   datetime.date(2024, 2, 5),
#   'Regadera',
#   'Ruiz',
#   'Carlos Castro',
#   'Efectivo'),
#  (881,
#   datetime.date(2024, 2, 5),
#   'Yogur',
#   'Vázquez',
#   'Cristian Fernández',
#   'Tarjeta'),
#  (882,
#   datetime.date(2024, 2, 5),
#   'Esponjas',
#   'Pérez',
#   'Sara Fernández',
#   'Tarjeta'),
#  (883,
#   datetime.date(2024, 2, 5),
#   'Lechuga',
#   'Fuentes',
#   'Tomás Flores',
#   'Efectivo'),
#  (884,
#   datetime.date(2024, 2, 5),
#   'Tomate',
#   'Romero',
#   'Paula Martínez',
#   'Tarjeta'),
#  (885,
#   datetime.date(2024, 2, 5),
#   'Bolsas de basura',
#   'Vázquez',
#   'Verónica Jiménez',
#   'Tarjeta'),
#  (886,
#   datetime.date(2024, 2, 5),
#   'Cerveza',
#   'Carrillo',
#   'Raúl Sánchez',
#   'Tarjeta'),
#  (887,
#   datetime.date(2024, 2, 5),
#   'Zanahoria',
#   'García',
#   'Jorge Castro',
#   'Tarjeta'),
#  (888,
#   datetime.date(2024, 2, 5),
#   'Jugo de naranja',
#   'Moreno',
#   'Sergio Delgado',
#   'Efectivo'),
#  (889,
#   datetime.date(2024, 2, 5),
#   'Cerveza',
#   'Rodríguez',
#   'Andrés Molina',
#   'Efectivo'),
#  (890,
#   datetime.date(2024, 2, 5),
#   'Semillas',
#   'Fuentes',
#   'Laura Jiménez',
#   'Efectivo'),
#  (891,
#   datetime.date(2024, 2, 5),
#   'Papas fritas',
#   'Ramírez',
#   'Gabriela Santos',
#   'Tarjeta'),
#  (892, datetime.date(2024, 2, 5), 'Uva', 'Vázquez', 'Carmen Ortiz', 'Tarjeta'),
#  (893,
#   datetime.date(2024, 2, 5),
#   'Mantequilla',
#   'Moreno',
#   'Diana Ramos',
#   'Tarjeta'),
#  (894,
#   datetime.date(2024, 2, 5),
#   'Galletas',
#   'Serrano',
#   'Raúl Sánchez',
#   'Tarjeta'),
#  (895,
#   datetime.date(2024, 2, 5),
#   'Velas',
#   'González',
#   'Andrea Hernández',
#   'Tarjeta'),
#  (896,
#   datetime.date(2024, 2, 5),
#   'Banana',
#   'Carrillo',
#   'Francisco Carrillo',
#   'Tarjeta'),
#  (897,
#   datetime.date(2024, 2, 5),
#   'Desinfectante',
#   'Moreno',
#   'Hugo Torres',
#   'Tarjeta'),
#  (898,
#   datetime.date(2024, 2, 5),
#   'Chocolate',
#   'Reyes',
#   'Fernando Romero',
#   'Tarjeta'),
#  (899,
#   datetime.date(2024, 2, 6),
#   'Colonia',
#   'Aguilar',
#   'Manuel Sánchez',
#   'Tarjeta'),
#  (900,
#   datetime.date(2024, 2, 6),
#   'Mantequilla',
#   'Domínguez',
#   'Hugo Torres',
#   'Efectivo'),
#  (901,
#   datetime.date(2024, 2, 6),
#   'Chocolate',
#   'Fernández',
#   'Irene Torres',
#   'Tarjeta'),
#  (902,
#   datetime.date(2024, 2, 6),
#   'Jugo de naranja',
#   'Medina',
#   'Camila López',
#   'Efectivo'),
#  (903,
#   datetime.date(2024, 2, 6),
#   'Chuletas',
#   'Esquivel',
#   'Sofía Romero',
#   'Efectivo'),
#  (904,
#   datetime.date(2024, 2, 6),
#   'Fertilizante',
#   'Paredes',
#   'Carlos Delgado',
#   'Tarjeta'),
#  (905,
#   datetime.date(2024, 2, 6),
#   'Queso',
#   'López',
#   'Sergio Delgado',
#   'Tarjeta'),
#  (906,
#   datetime.date(2024, 2, 6),
#   'Jabón líquido',
#   'García',
#   'Natalia Navarro',
#   'Tarjeta'),
#  (907,
#   datetime.date(2024, 2, 6),
#   'Manzana',
#   'Martínez',
#   'Diana Ramos',
#   'Efectivo'),
#  (908,
#   datetime.date(2024, 2, 6),
#   'Zanahoria',
#   'Domínguez',
#   'Andrés Montes',
#   'Tarjeta'),
#  (909,
#   datetime.date(2024, 2, 6),
#   'Champú',
#   'Chávez',
#   'Ángel Carrillo',
#   'Efectivo'),
#  (910,
#   datetime.date(2024, 2, 6),
#   'Zanahoria',
#   'Ruiz',
#   'Irene Torres',
#   'Tarjeta'),
#  (911,
#   datetime.date(2024, 2, 6),
#   'Mantequilla',
#   'Campos',
#   'Diego Carrillo',
#   'Efectivo'),
#  (912,
#   datetime.date(2024, 2, 6),
#   'Semillas',
#   'Medina',
#   'David Castro',
#   'Tarjeta'),
#  (913,
#   datetime.date(2024, 2, 6),
#   'Fertilizante',
#   'Flores',
#   'Andrés Molina',
#   'Tarjeta'),
#  (914,
#   datetime.date(2024, 2, 6),
#   'Pilas',
#   'Rubio',
#   'Sergio Rodríguez',
#   'Tarjeta'),
#  (915,
#   datetime.date(2024, 2, 6),
#   'Refresco',
#   'Reyes',
#   'Fernando Pérez',
#   'Tarjeta'),
#  (916,
#   datetime.date(2024, 2, 6),
#   'Crema hidratante',
#   'Montes',
#   'Mario Paredes',
#   'Efectivo'),
#  (917,
#   datetime.date(2024, 2, 6),
#   'Cerveza',
#   'Rodríguez',
#   'Isabel Santos',
#   'Tarjeta'),
#  (918,
#   datetime.date(2024, 2, 6),
#   'Detergente',
#   'Rodríguez',
#   'Mario Guzmán',
#   'Tarjeta'),
#  (919,
#   datetime.date(2024, 2, 6),
#   'Cerdo',
#   'Domínguez',
#   'Fernando Romero',
#   'Efectivo'),
#  (920,
#   datetime.date(2024, 2, 6),
#   'Chocolate',
#   'Ramos',
#   'Natalia Paredes',
#   'Tarjeta'),
#  (921,
#   datetime.date(2024, 2, 6),
#   'Detergente',
#   'Rodríguez',
#   'Adriana Velázquez',
#   'Tarjeta'),
#  (922,
#   datetime.date(2024, 2, 6),
#   'Jugo de naranja',
#   'Santos',
#   'Sergio Ortiz',
#   'Tarjeta'),
#  (923,
#   datetime.date(2024, 2, 6),
#   'Chocolate',
#   'Campos',
#   'Jorge Martínez',
#   'Tarjeta'),
#  (924,
#   datetime.date(2024, 2, 6),
#   'Desinfectante',
#   'Díaz',
#   'Marta Montes',
#   'Efectivo'),
#  (925,
#   datetime.date(2024, 2, 7),
#   'Fertilizante',
#   'Chávez',
#   'Adriana Velázquez',
#   'Tarjeta'),
#  (926,
#   datetime.date(2024, 2, 7),
#   'Cerveza',
#   'Rodríguez',
#   'Francisco Carrillo',
#   'Efectivo'),
#  (927,
#   datetime.date(2024, 2, 7),
#   'Refresco',
#   'Reyes',
#   'Gabriela Torres',
#   'Tarjeta'),
#  (928,
#   datetime.date(2024, 2, 7),
#   'Jugo de naranja',
#   'Reyes',
#   'Raúl Sánchez',
#   'Tarjeta'),
#  (929,
#   datetime.date(2024, 2, 7),
#   'Leche',
#   'Méndez',
#   'Sergio Ortiz',
#   'Efectivo'),
#  (930,
#   datetime.date(2024, 2, 7),
#   'Queso',
#   'Ramos',
#   'Valeria Méndez',
#   'Efectivo'),
#  (931,
#   datetime.date(2024, 2, 7),
#   'Chicles',
#   'Díaz',
#   'Cristian Díaz',
#   'Efectivo'),
#  (932,
#   datetime.date(2024, 2, 7),
#   'Chuletas',
#   'Carrillo',
#   'Miguel Reyes',
#   'Tarjeta'),
#  (933,
#   datetime.date(2024, 2, 7),
#   'Bolsas de basura',
#   'Reyes',
#   'Natalia Díaz',
#   'Tarjeta'),
#  (934,
#   datetime.date(2024, 2, 7),
#   'Detergente',
#   'Salinas',
#   'David Castro',
#   'Tarjeta'),
#  (935,
#   datetime.date(2024, 2, 7),
#   'Chicles',
#   'López',
#   'Raúl Sánchez',
#   'Efectivo'),
#  (936,
#   datetime.date(2024, 2, 7),
#   'Tomate',
#   'Hernández',
#   'Andrea Hernández',
#   'Efectivo'),
#  (937,
#   datetime.date(2024, 2, 7),
#   'Velas',
#   'López',
#   'Irene Esquivel',
#   'Efectivo'),
#  (938, datetime.date(2024, 2, 7), 'Agua', 'Santos', 'Ángel Molina', 'Tarjeta'),
#  (939,
#   datetime.date(2024, 2, 7),
#   'Naranja',
#   'Medina',
#   'Hugo Montes',
#   'Tarjeta'),
#  (940,
#   datetime.date(2024, 2, 7),
#   'Tierra para macetas',
#   'Paredes',
#   'Tomás Peña',
#   'Efectivo'),
#  (941,
#   datetime.date(2024, 2, 7),
#   'Uva',
#   'Sánchez',
#   'Sara Fernández',
#   'Efectivo'),
#  (942,
#   datetime.date(2024, 2, 7),
#   'Crema hidratante',
#   'Montes',
#   'Isabel Santos',
#   'Efectivo'),
#  (943,
#   datetime.date(2024, 2, 7),
#   'Jugo de naranja',
#   'Carrillo',
#   'Jorge Castro',
#   'Tarjeta'),
#  (944,
#   datetime.date(2024, 2, 7),
#   'Refresco',
#   'Torres',
#   'Eduardo Cabrera',
#   'Tarjeta'),
#  (945,
#   datetime.date(2024, 2, 7),
#   'Champú',
#   'Montes',
#   'Ángel Carrillo',
#   'Tarjeta'),
#  (946,
#   datetime.date(2024, 2, 7),
#   'Tomate',
#   'Rubio',
#   'Daniel Sánchez',
#   'Tarjeta'),
#  (947,
#   datetime.date(2024, 2, 8),
#   'Velas',
#   'Jiménez',
#   'Eduardo Cabrera',
#   'Tarjeta'),
#  (948,
#   datetime.date(2024, 2, 8),
#   'Naranja',
#   'López',
#   'Irene Esquivel',
#   'Tarjeta'),
#  (949,
#   datetime.date(2024, 2, 8),
#   'Zanahoria',
#   'Velázquez',
#   'Eva Delgado',
#   'Tarjeta'),
#  (950,
#   datetime.date(2024, 2, 8),
#   'Tierra para macetas',
#   'Serrano',
#   'Cristian Cruz',
#   'Tarjeta'),
#  (951,
#   datetime.date(2024, 2, 8),
#   'Mantequilla',
#   'Cabrera',
#   'David Castro',
#   'Tarjeta'),
#  (952,
#   datetime.date(2024, 2, 8),
#   'Regadera',
#   'Flores',
#   'Carlos Delgado',
#   'Tarjeta'),
#  (953,
#   datetime.date(2024, 2, 8),
#   'Zanahoria',
#   'Ortiz',
#   'Fernando Romero',
#   'Efectivo'),
#  (954,
#   datetime.date(2024, 2, 8),
#   'Banana',
#   'Jiménez',
#   'Carmen Ortiz',
#   'Efectivo'),
#  (955,
#   datetime.date(2024, 2, 8),
#   'Queso',
#   'Esquivel',
#   'Elena López',
#   'Tarjeta'),
#  (956,
#   datetime.date(2024, 2, 8),
#   'Pilas',
#   'Díaz',
#   'Ricardo Jiménez',
#   'Tarjeta'),
#  (957,
#   datetime.date(2024, 2, 8),
#   'Chocolate',
#   'Velázquez',
#   'Gabriela Ramírez',
#   'Tarjeta'),
#  (958,
#   datetime.date(2024, 2, 8),
#   'Semillas',
#   'Montes',
#   'Irene Navarro',
#   'Tarjeta'),
#  (959,
#   datetime.date(2024, 2, 8),
#   'Regadera',
#   'Moreno',
#   'Carmen García',
#   'Tarjeta'),
#  (960,
#   datetime.date(2024, 2, 8),
#   'Fertilizante',
#   'Moreno',
#   'Ana Chávez',
#   'Tarjeta'),
#  (961,
#   datetime.date(2024, 2, 8),
#   'Fertilizante',
#   'Navarro',
#   'Gabriela Torres',
#   'Tarjeta'),
#  (962,
#   datetime.date(2024, 2, 8),
#   'Crema hidratante',
#   'Ortiz',
#   'Mario Serrano',
#   'Tarjeta'),
#  (963,
#   datetime.date(2024, 2, 8),
#   'Papas fritas',
#   'Romero',
#   'Miguel Pérez',
#   'Tarjeta'),
#  (964,
#   datetime.date(2024, 2, 8),
#   'Queso',
#   'Álvarez',
#   'Fernando Romero',
#   'Tarjeta'),
#  (965,
#   datetime.date(2024, 2, 8),
#   'Papas fritas',
#   'Ortiz',
#   'Laura Aguilar',
#   'Tarjeta'),
#  (966,
#   datetime.date(2024, 2, 8),
#   'Galletas',
#   'Romero',
#   'Eva Delgado',
#   'Efectivo'),
#  (967,
#   datetime.date(2024, 2, 8),
#   'Velas',
#   'Martínez',
#   'José Aguilar',
#   'Tarjeta'),
#  (968,
#   datetime.date(2024, 2, 8),
#   'Tierra para macetas',
#   'Fernández',
#   'Diana Chávez',
#   'Tarjeta'),
#  (969,
#   datetime.date(2024, 2, 8),
#   'Chuletas',
#   'Torres',
#   'Pablo Reyes',
#   'Efectivo'),
#  (970,
#   datetime.date(2024, 2, 8),
#   'Papas fritas',
#   'Martínez',
#   'Patricia Santos',
#   'Tarjeta'),
#  (971,
#   datetime.date(2024, 2, 8),
#   'Cerveza',
#   'García',
#   'Hugo Moreno',
#   'Tarjeta'),
#  (972,
#   datetime.date(2024, 2, 8),
#   'Regadera',
#   'Vázquez',
#   'Natalia Paredes',
#   'Tarjeta'),
#  (973,
#   datetime.date(2024, 2, 8),
#   'Chocolate',
#   'Ortiz',
#   'Andrea Hernández',
#   'Efectivo'),
#  (974,
#   datetime.date(2024, 2, 8),
#   'Colonia',
#   'Lara',
#   'Laura Sánchez',
#   'Tarjeta'),
#  (975,
#   datetime.date(2024, 2, 8),
#   'Pollo',
#   'Serrano',
#   'Raúl Sánchez',
#   'Tarjeta'),
#  (976,
#   datetime.date(2024, 2, 9),
#   'Pollo',
#   'García',
#   'Carla González',
#   'Tarjeta'),
#  (977,
#   datetime.date(2024, 2, 9),
#   'Chicles',
#   'Delgado',
#   'Fernando Romero',
#   'Efectivo'),
#  (978,
#   datetime.date(2024, 2, 9),
#   'Esponjas',
#   'Esquivel',
#   'Ricardo Fernández',
#   'Tarjeta'),
#  (979,
#   datetime.date(2024, 2, 9),
#   'Zanahoria',
#   'Álvarez',
#   'Miguel Méndez',
#   'Efectivo'),
#  (980,
#   datetime.date(2024, 2, 9),
#   'Esponjas',
#   'Vázquez',
#   'Sofía Montes',
#   'Tarjeta'),
#  (981,
#   datetime.date(2024, 2, 9),
#   'Queso',
#   'Esquivel',
#   'María García',
#   'Tarjeta'),
#  (982,
#   datetime.date(2024, 2, 9),
#   'Leche',
#   'Molina',
#   'Camila Paredes',
#   'Efectivo'),
#  (983,
#   datetime.date(2024, 2, 9),
#   'Galletas',
#   'Aguilar',
#   'Jorge Montes',
#   'Tarjeta'),
#  (984,
#   datetime.date(2024, 2, 9),
#   'Esponjas',
#   'Campos',
#   'Miguel Cabrera',
#   'Tarjeta'),
#  (985, datetime.date(2024, 2, 9), 'Uva', 'López', 'Jorge Montes', 'Tarjeta'),
#  (986, datetime.date(2024, 2, 9), 'Uva', 'Romero', 'Irene Navarro', 'Tarjeta'),
#  (987,
#   datetime.date(2024, 2, 9),
#   'Crema hidratante',
#   'López',
#   'Ricardo Ortiz',
#   'Tarjeta'),
#  (988,
#   datetime.date(2024, 2, 9),
#   'Manzana',
#   'Martínez',
#   'Laura Aguilar',
#   'Efectivo'),
#  (989,
#   datetime.date(2024, 2, 9),
#   'Manzana',
#   'Martínez',
#   'Carmen Ortiz',
#   'Tarjeta'),
#  (990,
#   datetime.date(2024, 2, 9),
#   'Fertilizante',
#   'Hernández',
#   'Sergio Rodríguez',
#   'Efectivo'),
#  (991,
#   datetime.date(2024, 2, 9),
#   'Platos desechables',
#   'Salinas',
#   'Mario Serrano',
#   'Tarjeta'),
#  (992,
#   datetime.date(2024, 2, 9),
#   'Papas fritas',
#   'Castro',
#   'Pablo Reyes',
#   'Efectivo'),
#  (993,
#   datetime.date(2024, 2, 9),
#   'Cebolla',
#   'Fernández',
#   'Miguel Pérez',
#   'Tarjeta'),
#  (994,
#   datetime.date(2024, 2, 9),
#   'Platos desechables',
#   'Molina',
#   'Sofía Romero',
#   'Tarjeta'),
#  (995,
#   datetime.date(2024, 2, 9),
#   'Desinfectante',
#   'Romero',
#   'Jorge Castro',
#   'Efectivo'),
#  (996, datetime.date(2024, 2, 9), 'Manzana', 'Cruz', 'Diego Lara', 'Efectivo'),
#  (997,
#   datetime.date(2024, 2, 9),
#   'Cerdo',
#   'Serrano',
#   'Sergio Rodríguez',
#   'Tarjeta'),
#  (998,
#   datetime.date(2024, 2, 10),
#   'Naranja',
#   'Fuentes',
#   'Gabriela Torres',
#   'Tarjeta'),
#  (999,
#   datetime.date(2024, 2, 10),
#   'Manzana',
#   'González',
#   'Carla López',
#   'Efectivo'),
#  (1000,
#   datetime.date(2024, 2, 10),
#   'Refresco',
#   'Esquivel',
#   'Gabriela Reyes',
#   'Tarjeta'),
#  ...]

# %% [markdown]
# * 2.- Productos con stock bajo
#
#     * Filtra aquellos productos cuyo stock sea menor a 10.
#     * Muestra nombre del producto, categoría y stock.

# %%
sql = ('SELECT p.nombre_producto, c.nombre_categoria, p.stock FROM productos p JOIN categorias c ON p.id_categoria = c.id_categoria WHERE p.stock < 10;')
consultas(sql)
# Out:
# []

# %% [markdown]
# * 3.-Ventas totales por categoría
#
#     * Muestra el nombre de la categoría y la suma total de las ventas (ej.: multiplicando cantidad * precio_unitario) para cada categoría.
#     * Realiza el JOIN con detalle_orden, productos y categorias.
#     * Utiliza agrupación (GROUP BY).

# %%
sql = ('SELECT c.nombre_categoria as categoria, sum((d.precio_unitario * ( 1 - d.descuento)) * d.cantidad) as ventas FROM categorias c JOIN productos p ON p.id_categoria = c.id_categoria JOIN detalle_orden d ON d.id_producto = p.id_producto GROUP BY c.id_categoria;')
consultas(sql)
# Out:
# [('Carnes', 133396.9),
#  ('Verduras', 217190.08),
#  ('Refrescos', 206642.67),
#  ('Pescados', 90440.2),
#  ('Alcohol', 200158.52),
#  ('Congelados', 225867.91),
#  ('Lácteos', 230800.17),
#  ('Frutas', 172432.35),
#  ('Bollería y Pan', 146404.7),
#  ('Vinos', 254856.44)]

# %% [markdown]
# * 4.-Clientes con mayores gastos acumulados
#
#
#     * Muestra el nombre del cliente y el monto total que ha gastado (suma de todas sus órdenes).
#     * Asegúrate de tener en cuenta posibles descuentos (descuento) si se ha definido. Por ejemplo, la fórmula podría ser (cantidad * precio_unitario) - descuento.
#     * Ordena el resultado de mayor a menor gasto acumulado.

# %%
sql = ('SELECT c.first_name as nombre, c.last_name as apellido, sum((d.precio_unitario * ( 1 - d.descuento)) * d.cantidad) as compras FROM clientes c JOIN ordenes o ON c.id_cliente = o.id_cliente JOIN detalle_orden d ON d.id_orden = o.id_orden GROUP BY c.id_cliente ORDER BY sum((d.precio_unitario * ( 1 - d.descuento)) * d.cantidad) DESC;')
consultas(sql)
# Out:
# [('Cerdo', 'Jiménez', 2979.22),
#  ('Pilas', 'Domínguez', 2934.05),
#  ('Tierra para macetas', 'Rubio', 2860.61),
#  ('Chocolate', 'Rodríguez', 2781.4),
#  ('Mantequilla', 'Domínguez', 2707.46),
#  ('Fertilizante', 'Ortiz', 2694.12),
#  ('Galletas', 'Cortés', 2658.16),
#  ('Tierra para macetas', 'Navarro', 2597.72),
#  ('Banana', 'García', 2587.74),
#  ('Semillas', 'Medina', 2577.9),
#  ('Uva', 'López', 2570.9),
#  ('Detergente', 'Peña', 2555.82),
#  ('Galletas', 'García', 2550.04),
#  ('Chicles', 'Flores', 2548.3),
#  ('Carne de res', 'Ortiz', 2542.73),
#  ('Tomate', 'Castro', 2524.14),
#  ('Detergente', 'Martínez', 2496.52),
#  ('Chuletas', 'Domínguez', 2495.05),
#  ('Refresco', 'López', 2481.41),
#  ('Platos desechables', 'Vázquez', 2457.98),
#  ('Desodorante', 'Guzmán', 2431.24),
#  ('Carne de res', 'Medina', 2424.46),
#  ('Cerveza', 'Rodríguez', 2403.49),
#  ('Chuletas', 'González', 2402.6),
#  ('Champú', 'Montes', 2400.01),
#  ('Crema hidratante', 'Domínguez', 2396.32),
#  ('Naranja', 'Medina', 2390.5),
#  ('Uva', 'González', 2386.11),
#  ('Chicles', 'Vázquez', 2371.62),
#  ('Semillas', 'Romero', 2352.37),
#  ('Velas', 'Jiménez', 2350.82),
#  ('Chuletas', 'Esquivel', 2344.79),
#  ('Galletas', 'Navarro', 2339.09),
#  ('Champú', 'Ramírez', 2329.79),
#  ('Uva', 'Ramírez', 2319.29),
#  ('Fertilizante', 'Vázquez', 2311.78),
#  ('Semillas', 'Fuentes', 2310.39),
#  ('Naranja', 'Molina', 2300.49),
#  ('Pilas', 'Navarro', 2281.21),
#  ('Cerveza', 'Vázquez', 2280.65),
#  ('Queso', 'González', 2272.33),
#  ('Desinfectante', 'Serrano', 2255.72),
#  ('Velas', 'Ortiz', 2253.54),
#  ('Queso', 'Campos', 2252.34),
#  ('Cerdo', 'Rubio', 2237.33),
#  ('Chocolate', 'Hernández', 2232.71),
#  ('Chicles', 'Delgado', 2228.51),
#  ('Chuletas', 'Carrillo', 2213.39),
#  ('Galletas', 'Campos', 2202.67),
#  ('Esponjas', 'Navarro', 2201.47),
#  ('Desinfectante', 'Molina', 2178.91),
#  ('Esponjas', 'Pérez', 2143.44),
#  ('Semillas', 'Hernández', 2141.81),
#  ('Regadera', 'Moreno', 2127.77),
#  ('Zanahoria', 'Ortiz', 2124.19),
#  ('Agua', 'Santos', 2109.32),
#  ('Papas fritas', 'González', 2102.68),
#  ('Velas', 'Reyes', 2098.95),
#  ('Pilas', 'Cortés', 2096.01),
#  ('Crema hidratante', 'Aguilar', 2092.06),
#  ('Naranja', 'Lara', 2092.03),
#  ('Esponjas', 'Cruz', 2089.15),
#  ('Queso', 'Ramos', 2088.95),
#  ('Bolsas de basura', 'Cortés', 2070.77),
#  ('Desinfectante', 'Moreno', 2062.11),
#  ('Chocolate', 'Ortiz', 2056.53),
#  ('Platos desechables', 'Ramírez', 2055.59),
#  ('Carne de res', 'Ortiz', 2051.51),
#  ('Yogur', 'Ortiz', 2048.82),
#  ('Leche', 'Hernández', 2045.18),
#  ('Refresco', 'Montes', 2038.98),
#  ('Yogur', 'Paredes', 2032.78),
#  ('Queso', 'Salinas', 2029.22),
#  ('Banana', 'Ruiz', 2027.54),
#  ('Desinfectante', 'Flores', 2025.28),
#  ('Pollo', 'Lara', 2015.08),
#  ('Jabón líquido', 'Fernández', 2003.26),
#  ('Banana', 'Medina', 1996.28),
#  ('Chocolate', 'Reyes', 1992.66),
#  ('Cerdo', 'Santos', 1992.46),
#  ('Leche', 'Paredes', 1989.12),
#  ('Carne de res', 'Peña', 1982.21),
#  ('Chocolate', 'Martínez', 1980.08),
#  ('Crema hidratante', 'Cortés', 1978.67),
#  ('Agua', 'Hernández', 1977.01),
#  ('Papas fritas', 'Álvarez', 1975.4),
#  ('Banana', 'Cruz', 1970.95),
#  ('Lechuga', 'Medina', 1967.63),
#  ('Cebolla', 'Peña', 1960.75),
#  ('Bolsas de basura', 'López', 1957.22),
#  ('Detergente', 'Aguilar', 1951.25),
#  ('Bolsas de basura', 'Torres', 1944.15),
#  ('Uva', 'Vázquez', 1939.8),
#  ('Lechuga', 'Chávez', 1935.7),
#  ('Galletas', 'Medina', 1929.23),
#  ('Pilas', 'Campos', 1915.33),
#  ('Colonia', 'Navarro', 1904.4),
#  ('Pollo', 'García', 1902.98),
#  ('Tomate', 'Díaz', 1902.53),
#  ('Platos desechables', 'Santos', 1898.69),
#  ('Leche', 'Martínez', 1898.09),
#  ('Semillas', 'Méndez', 1896.45),
#  ('Cerdo', 'González', 1896.45),
#  ('Queso', 'Álvarez', 1891.78),
#  ('Esponjas', 'Reyes', 1885.0),
#  ('Tomate', 'Romero', 1881.93),
#  ('Papas fritas', 'Salinas', 1877.44),
#  ('Chocolate', 'Hernández', 1876.44),
#  ('Colonia', 'Pérez', 1873.17),
#  ('Zanahoria', 'Pérez', 1872.14),
#  ('Platos desechables', 'Salinas', 1871.96),
#  ('Queso', 'Fuentes', 1871.65),
#  ('Fertilizante', 'Delgado', 1859.81),
#  ('Uva', 'Martínez', 1858.98),
#  ('Cerveza', 'Castro', 1856.6),
#  ('Tierra para macetas', 'Serrano', 1854.35),
#  ('Carne de res', 'Fernández', 1850.15),
#  ('Fertilizante', 'Cruz', 1840.61),
#  ('Pollo', 'Chávez', 1838.14),
#  ('Zanahoria', 'Montes', 1837.57),
#  ('Zanahoria', 'Ruiz', 1833.09),
#  ('Colonia', 'Torres', 1830.68),
#  ('Chuletas', 'Castro', 1827.75),
#  ('Lechuga', 'Salinas', 1824.45),
#  ('Platos desechables', 'Torres', 1823.96),
#  ('Pilas', 'Cabrera', 1823.84),
#  ('Jabón líquido', 'Reyes', 1816.29),
#  ('Refresco', 'Montes', 1811.65),
#  ('Uva', 'González', 1810.58),
#  ('Yogur', 'Díaz', 1809.95),
#  ('Crema hidratante', 'Cabrera', 1808.71),
#  ('Yogur', 'García', 1808.55),
#  ('Velas', 'Álvarez', 1806.75),
#  ('Tierra para macetas', 'Pérez', 1805.48),
#  ('Chuletas', 'Castro', 1802.58),
#  ('Tierra para macetas', 'Rodríguez', 1802.51),
#  ('Lechuga', 'Medina', 1800.39),
#  ('Agua', 'Navarro', 1793.17),
#  ('Tomate', 'Serrano', 1790.95),
#  ('Leche', 'Rubio', 1786.2),
#  ('Papas fritas', 'Martínez', 1784.69),
#  ('Leche', 'Montes', 1780.58),
#  ('Chocolate', 'Méndez', 1779.66),
#  ('Desodorante', 'Moreno', 1777.77),
#  ('Fertilizante', 'Peña', 1777.25),
#  ('Agua', 'Álvarez', 1775.98),
#  ('Chocolate', 'Moreno', 1775.27),
#  ('Fertilizante', 'Méndez', 1774.94),
#  ('Chocolate', 'Moreno', 1768.64),
#  ('Platos desechables', 'Ortiz', 1763.47),
#  ('Cebolla', 'Ruiz', 1763.16),
#  ('Cebolla', 'Méndez', 1760.58),
#  ('Esponjas', 'Ramírez', 1759.92),
#  ('Papas fritas', 'Carrillo', 1757.56),
#  ('Chuletas', 'Ortiz', 1757.07),
#  ('Banana', 'Díaz', 1757.03),
#  ('Detergente', 'Jiménez', 1756.47),
#  ('Detergente', 'Velázquez', 1755.69),
#  ('Colonia', 'Pérez', 1753.26),
#  ('Crema hidratante', 'Delgado', 1749.78),
#  ('Banana', 'Domínguez', 1749.48),
#  ('Esponjas', 'Reyes', 1747.54),
#  ('Velas', 'Jiménez', 1743.54),
#  ('Papas fritas', 'Guzmán', 1738.75),
#  ('Jabón líquido', 'López', 1734.07),
#  ('Tomate', 'Carrillo', 1730.83),
#  ('Zanahoria', 'Sánchez', 1729.04),
#  ('Carne de res', 'Pérez', 1723.62),
#  ('Papas fritas', 'Martínez', 1722.02),
#  ('Agua', 'Ortiz', 1713.31),
#  ('Banana', 'Ortiz', 1712.78),
#  ('Bolsas de basura', 'González', 1712.14),
#  ('Papas fritas', 'Castro', 1710.71),
#  ('Chocolate', 'Rubio', 1706.01),
#  ('Fertilizante', 'Navarro', 1705.42),
#  ('Desinfectante', 'Romero', 1705.27),
#  ('Agua', 'Ramos', 1705.16),
#  ('Pollo', 'Moreno', 1701.7),
#  ('Cerdo', 'Serrano', 1701.23),
#  ('Semillas', 'Ramos', 1699.66),
#  ('Platos desechables', 'Romero', 1696.73),
#  ('Semillas', 'Aguilar', 1696.7),
#  ('Naranja', 'Ruiz', 1692.84),
#  ('Crema hidratante', 'Fuentes', 1687.78),
#  ('Queso', 'Esquivel', 1684.82),
#  ('Esponjas', 'Vázquez', 1684.63),
#  ('Queso', 'González', 1684.41),
#  ('Champú', 'Paredes', 1683.04),
#  ('Chocolate', 'González', 1681.61),
#  ('Yogur', 'Molina', 1680.95),
#  ('Desodorante', 'Carrillo', 1678.73),
#  ('Pilas', 'Carrillo', 1677.94),
#  ('Cerdo', 'Rodríguez', 1673.7),
#  ('Regadera', 'Peña', 1672.59),
#  ('Cerdo', 'Ortiz', 1669.79),
#  ('Pollo', 'González', 1668.37),
#  ('Galletas', 'Pérez', 1666.76),
#  ('Chuletas', 'Carrillo', 1663.7),
#  ('Bolsas de basura', 'Santos', 1661.09),
#  ('Zanahoria', 'López', 1660.31),
#  ('Velas', 'Lara', 1659.78),
#  ('Chuletas', 'Reyes', 1653.7),
#  ('Esponjas', 'Medina', 1653.42),
#  ('Tierra para macetas', 'Fernández', 1653.01),
#  ('Fertilizante', 'Moreno', 1650.73),
#  ('Manzana', 'Martínez', 1650.2),
#  ('Chocolate', 'Chávez', 1641.25),
#  ('Crema hidratante', 'Álvarez', 1639.23),
#  ('Semillas', 'Jiménez', 1636.4),
#  ('Velas', 'Álvarez', 1634.89),
#  ('Queso', 'Ramos', 1632.25),
#  ('Regadera', 'Vázquez', 1629.53),
#  ('Colonia', 'Flores', 1628.81),
#  ('Uva', 'Moreno', 1628.4),
#  ('Naranja', 'Guzmán', 1621.33),
#  ('Refresco', 'Sánchez', 1620.89),
#  ('Banana', 'Álvarez', 1619.05),
#  ('Chicles', 'Salinas', 1617.89),
#  ('Lechuga', 'Serrano', 1611.67),
#  ('Mantequilla', 'Paredes', 1608.51),
#  ('Tierra para macetas', 'López', 1605.38),
#  ('Refresco', 'Reyes', 1605.25),
#  ('Cebolla', 'López', 1604.66),
#  ('Mantequilla', 'Medina', 1604.48),
#  ('Queso', 'Reyes', 1604.37),
#  ('Fertilizante', 'López', 1604.03),
#  ('Champú', 'Montes', 1602.02),
#  ('Chicles', 'Pérez', 1597.66),
#  ('Jabón líquido', 'Velázquez', 1595.77),
#  ('Yogur', 'Navarro', 1590.35),
#  ('Refresco', 'Velázquez', 1590.24),
#  ('Champú', 'Navarro', 1589.0),
#  ('Galletas', 'Ramos', 1588.79),
#  ('Platos desechables', 'Molina', 1588.76),
#  ('Desinfectante', 'García', 1587.29),
#  ('Agua', 'Domínguez', 1584.88),
#  ('Papas fritas', 'Romero', 1580.97),
#  ('Leche', 'Reyes', 1580.91),
#  ('Carne de res', 'Esquivel', 1580.41),
#  ('Uva', 'Torres', 1579.65),
#  ('Cebolla', 'Fuentes', 1579.34),
#  ('Tomate', 'Díaz', 1578.92),
#  ('Refresco', 'Jiménez', 1575.56),
#  ('Platos desechables', 'Sánchez', 1574.19),
#  ('Champú', 'Ramírez', 1573.6),
#  ('Manzana', 'Cruz', 1573.0),
#  ('Zanahoria', 'Cabrera', 1569.85),
#  ('Regadera', 'Torres', 1569.07),
#  ('Regadera', 'Moreno', 1568.94),
#  ('Regadera', 'Ortiz', 1568.93),
#  ('Manzana', 'Fuentes', 1567.03),
#  ('Jabón líquido', 'Flores', 1566.02),
#  ('Mantequilla', 'Martínez', 1565.35),
#  ('Chocolate', 'González', 1563.72),
#  ('Galletas', 'Montes', 1562.35),
#  ('Jugo de naranja', 'Martínez', 1560.7),
#  ('Colonia', 'Martínez', 1560.19),
#  ('Esponjas', 'Romero', 1559.64),
#  ('Carne de res', 'Paredes', 1555.02),
#  ('Mantequilla', 'Domínguez', 1552.56),
#  ('Champú', 'Fuentes', 1552.24),
#  ('Desodorante', 'Ruiz', 1550.85),
#  ('Manzana', 'Ortiz', 1549.72),
#  ('Bolsas de basura', 'Carrillo', 1547.29),
#  ('Yogur', 'Esquivel', 1545.59),
#  ('Colonia', 'Aguilar', 1541.43),
#  ('Cerdo', 'Paredes', 1540.58),
#  ('Champú', 'Aguilar', 1539.41),
#  ('Naranja', 'Rodríguez', 1538.87),
#  ('Colonia', 'Delgado', 1538.33),
#  ('Semillas', 'Romero', 1535.92),
#  ('Pollo', 'Torres', 1533.98),
#  ('Yogur', 'Cruz', 1528.63),
#  ('Naranja', 'Reyes', 1525.07),
#  ('Velas', 'Lara', 1524.35),
#  ('Pilas', 'Romero', 1522.95),
#  ('Pollo', 'Cortés', 1522.83),
#  ('Papas fritas', 'Castro', 1519.49),
#  ('Esponjas', 'Ramírez', 1518.0),
#  ('Tierra para macetas', 'Chávez', 1515.71),
#  ('Pilas', 'Delgado', 1515.14),
#  ('Banana', 'Aguilar', 1513.64),
#  ('Detergente', 'González', 1513.54),
#  ('Chicles', 'Hernández', 1512.73),
#  ('Champú', 'Peña', 1512.01),
#  ('Esponjas', 'Campos', 1509.94),
#  ('Chuletas', 'Medina', 1508.92),
#  ('Tierra para macetas', 'Montes', 1505.02),
#  ('Papas fritas', 'Aguilar', 1500.68),
#  ('Banana', 'Chávez', 1495.56),
#  ('Chocolate', 'Flores', 1491.91),
#  ('Fertilizante', 'Ramírez', 1488.32),
#  ('Champú', 'Cortés', 1487.76),
#  ('Platos desechables', 'Castro', 1487.29),
#  ('Papas fritas', 'Serrano', 1486.15),
#  ('Detergente', 'Molina', 1485.9),
#  ('Crema hidratante', 'Campos', 1485.78),
#  ('Queso', 'López', 1485.5),
#  ('Carne de res', 'Rubio', 1484.25),
#  ('Pilas', 'García', 1483.26),
#  ('Papas fritas', 'Martínez', 1483.1),
#  ('Pilas', 'Díaz', 1479.85),
#  ('Fertilizante', 'Rubio', 1479.06),
#  ('Cerveza', 'Domínguez', 1478.3),
#  ('Chicles', 'Montes', 1477.0),
#  ('Chicles', 'González', 1474.54),
#  ('Queso', 'Rodríguez', 1473.94),
#  ('Cebolla', 'Peña', 1471.75),
#  ('Carne de res', 'Flores', 1469.72),
#  ('Pilas', 'Cortés', 1468.88),
#  ('Galletas', 'Ramos', 1468.41),
#  ('Tierra para macetas', 'Cruz', 1465.22),
#  ('Velas', 'Moreno', 1462.55),
#  ('Platos desechables', 'Medina', 1458.9),
#  ('Zanahoria', 'Hernández', 1458.88),
#  ('Lechuga', 'Lara', 1458.68),
#  ('Carne de res', 'Hernández', 1456.23),
#  ('Desinfectante', 'López', 1455.83),
#  ('Refresco', 'Velázquez', 1454.23),
#  ('Mantequilla', 'Pérez', 1451.61),
#  ('Banana', 'Medina', 1450.99),
#  ('Banana', 'Ruiz', 1450.34),
#  ('Tomate', 'Hernández', 1449.91),
#  ('Desodorante', 'Lara', 1447.92),
#  ('Naranja', 'Lara', 1444.49),
#  ('Platos desechables', 'González', 1444.29),
#  ('Galletas', 'Ortiz', 1443.58),
#  ('Galletas', 'Navarro', 1440.74),
#  ('Papas fritas', 'Romero', 1440.41),
#  ('Esponjas', 'Méndez', 1440.1),
#  ('Bolsas de basura', 'Martínez', 1439.65),
#  ('Fertilizante', 'Vázquez', 1438.68),
#  ('Uva', 'Medina', 1437.73),
#  ('Queso', 'Rubio', 1436.11),
#  ('Chocolate', 'Salinas', 1435.74),
#  ('Fertilizante', 'Cabrera', 1434.77),
#  ('Uva', 'Vázquez', 1431.43),
#  ('Bolsas de basura', 'Fernández', 1430.72),
#  ('Manzana', 'Martínez', 1428.83),
#  ('Chuletas', 'Flores', 1424.94),
#  ('Desinfectante', 'Martínez', 1422.18),
#  ('Manzana', 'Reyes', 1422.14),
#  ('Semillas', 'Díaz', 1419.54),
#  ('Refresco', 'Ramírez', 1418.99),
#  ('Cebolla', 'Paredes', 1418.06),
#  ('Mantequilla', 'Peña', 1415.22),
#  ('Yogur', 'Ortiz', 1413.62),
#  ('Mantequilla', 'Méndez', 1413.17),
#  ('Pilas', 'Ortiz', 1410.75),
#  ('Chocolate', 'García', 1409.68),
#  ('Agua', 'Cruz', 1409.55),
#  ('Naranja', 'Jiménez', 1407.32),
#  ('Yogur', 'Hernández', 1407.1),
#  ('Refresco', 'Salinas', 1406.65),
#  ('Lechuga', 'Paredes', 1404.28),
#  ('Esponjas', 'Montes', 1403.66),
#  ('Platos desechables', 'Lara', 1402.27),
#  ('Jugo de naranja', 'Chávez', 1402.02),
#  ('Champú', 'Martínez', 1397.55),
#  ('Lechuga', 'González', 1396.85),
#  ('Mantequilla', 'Díaz', 1396.11),
#  ('Chuletas', 'Sánchez', 1393.47),
#  ('Leche', 'Cortés', 1393.29),
#  ('Naranja', 'García', 1392.98),
#  ('Champú', 'Cabrera', 1391.18),
#  ('Cebolla', 'Jiménez', 1389.99),
#  ('Zanahoria', 'García', 1389.58),
#  ('Pilas', 'Díaz', 1389.06),
#  ('Semillas', 'Montes', 1388.65),
#  ('Uva', 'Salinas', 1387.87),
#  ('Refresco', 'Torres', 1387.63),
#  ('Colonia', 'Carrillo', 1386.02),
#  ('Carne de res', 'Peña', 1384.48),
#  ('Mantequilla', 'Fuentes', 1384.48),
#  ('Semillas', 'Montes', 1383.16),
#  ('Papas fritas', 'Moreno', 1382.01),
#  ('Tierra para macetas', 'Ramírez', 1380.73),
#  ('Cebolla', 'Martínez', 1374.9),
#  ('Pilas', 'Rubio', 1371.49),
#  ('Pilas', 'Castro', 1371.01),
#  ('Velas', 'López', 1367.26),
#  ('Platos desechables', 'Cruz', 1366.3),
#  ('Chuletas', 'Ortiz', 1365.89),
#  ('Detergente', 'Salinas', 1363.41),
#  ('Desinfectante', 'Torres', 1362.46),
#  ('Colonia', 'Molina', 1360.83),
#  ('Champú', 'López', 1360.61),
#  ('Velas', 'Romero', 1359.59),
#  ('Detergente', 'Sánchez', 1357.86),
#  ('Carne de res', 'Romero', 1356.24),
#  ('Mantequilla', 'Hernández', 1354.03),
#  ('Pollo', 'López', 1354.02),
#  ('Queso', 'Ortiz', 1353.95),
#  ('Papas fritas', 'Salinas', 1353.36),
#  ('Zanahoria', 'Ruiz', 1352.67),
#  ('Leche', 'Romero', 1352.23),
#  ('Leche', 'Peña', 1352.13),
#  ('Platos desechables', 'Rubio', 1350.84),
#  ('Agua', 'Ortiz', 1348.23),
#  ('Semillas', 'Cruz', 1345.51),
#  ('Semillas', 'López', 1342.36),
#  ('Leche', 'García', 1341.63),
#  ('Regadera', 'Santos', 1341.04),
#  ('Crema hidratante', 'López', 1340.26),
#  ('Semillas', 'Cruz', 1339.26),
#  ('Chuletas', 'Lara', 1339.02),
#  ('Pollo', 'Ruiz', 1338.31),
#  ('Lechuga', 'Lara', 1338.19),
#  ('Crema hidratante', 'Chávez', 1336.4),
#  ('Crema hidratante', 'Montes', 1333.23),
#  ('Naranja', 'Esquivel', 1332.41),
#  ('Esponjas', 'Rubio', 1331.95),
#  ('Regadera', 'Moreno', 1331.28),
#  ('Carne de res', 'González', 1330.86),
#  ('Crema hidratante', 'Paredes', 1330.63),
#  ('Esponjas', 'Carrillo', 1327.81),
#  ('Mantequilla', 'Flores', 1327.37),
#  ('Agua', 'Vázquez', 1325.76),
#  ('Semillas', 'Lara', 1325.58),
#  ('Galletas', 'Cabrera', 1325.27),
#  ('Leche', 'Paredes', 1323.11),
#  ('Chuletas', 'Medina', 1322.95),
#  ('Chicles', 'González', 1318.67),
#  ('Platos desechables', 'Montes', 1317.15),
#  ('Cerveza', 'Ramírez', 1315.88),
#  ('Galletas', 'Serrano', 1315.7),
#  ('Lechuga', 'Medina', 1315.14),
#  ('Banana', 'Martínez', 1314.43),
#  ('Papas fritas', 'Guzmán', 1313.44),
#  ('Mantequilla', 'Jiménez', 1311.26),
#  ('Queso', 'Cabrera', 1310.9),
#  ('Galletas', 'Castro', 1308.23),
#  ('Chuletas', 'Cabrera', 1308.01),
#  ('Chocolate', 'Pérez', 1307.23),
#  ('Uva', 'Serrano', 1306.74),
#  ('Mantequilla', 'Velázquez', 1305.61),
#  ('Papas fritas', 'Domínguez', 1305.28),
#  ('Champú', 'Romero', 1304.04),
#  ('Jabón líquido', 'Rodríguez', 1303.62),
#  ('Pollo', 'Fuentes', 1303.33),
#  ('Tomate', 'Ramírez', 1303.12),
#  ('Jugo de naranja', 'Chávez', 1302.32),
#  ('Tomate', 'Cruz', 1301.89),
#  ('Chuletas', 'Flores', 1301.83),
#  ('Zanahoria', 'Paredes', 1301.41),
#  ('Detergente', 'Carrillo', 1301.32),
#  ('Velas', 'Romero', 1301.11),
#  ('Velas', 'Delgado', 1301.03),
#  ('Papas fritas', 'Rubio', 1299.36),
#  ('Refresco', 'Montes', 1298.23),
#  ('Lechuga', 'González', 1297.73),
#  ('Bolsas de basura', 'Cruz', 1297.67),
#  ('Chuletas', 'Ruiz', 1297.3),
#  ('Platos desechables', 'Santos', 1297.21),
#  ('Velas', 'Flores', 1296.77),
#  ('Galletas', 'Romero', 1295.54),
#  ('Chicles', 'Rodríguez', 1295.02),
#  ('Detergente', 'Rodríguez', 1293.94),
#  ('Cerdo', 'Díaz', 1292.02),
#  ('Carne de res', 'Velázquez', 1291.66),
#  ('Cerveza', 'Rubio', 1286.8),
#  ('Cebolla', 'Campos', 1285.77),
#  ('Fertilizante', 'Cabrera', 1285.47),
#  ('Jugo de naranja', 'Flores', 1284.12),
#  ('Jugo de naranja', 'Pérez', 1284.05),
#  ('Chocolate', 'Romero', 1283.38),
#  ('Galletas', 'Cortés', 1283.24),
#  ('Desinfectante', 'Fernández', 1281.4),
#  ('Naranja', 'Delgado', 1276.89),
#  ('Desinfectante', 'Ruiz', 1276.15),
#  ('Banana', 'Carrillo', 1275.81),
#  ('Fertilizante', 'Molina', 1275.24),
#  ('Regadera', 'Flores', 1272.64),
#  ('Semillas', 'Peña', 1270.74),
#  ('Detergente', 'Martínez', 1270.63),
#  ('Colonia', 'Romero', 1270.53),
#  ('Desodorante', 'Sánchez', 1268.74),
#  ('Detergente', 'Campos', 1267.83),
#  ('Naranja', 'Navarro', 1267.26),
#  ('Colonia', 'Díaz', 1266.81),
#  ('Tomate', 'Velázquez', 1266.63),
#  ('Naranja', 'Vázquez', 1266.06),
#  ('Lechuga', 'Medina', 1263.43),
#  ('Chicles', 'Medina', 1262.81),
#  ('Pollo', 'Martínez', 1261.09),
#  ('Yogur', 'Álvarez', 1259.52),
#  ('Fertilizante', 'Ortiz', 1259.48),
#  ('Platos desechables', 'Torres', 1259.26),
#  ('Velas', 'Cortés', 1257.98),
#  ('Colonia', 'Serrano', 1257.39),
#  ('Refresco', 'García', 1257.22),
#  ('Jugo de naranja', 'Serrano', 1254.67),
#  ('Chuletas', 'Sánchez', 1254.63),
#  ('Fertilizante', 'Fuentes', 1254.41),
#  ('Queso', 'Esquivel', 1252.39),
#  ('Chocolate', 'Fuentes', 1252.04),
#  ('Cerveza', 'Carrillo', 1250.64),
#  ('Champú', 'Pérez', 1249.35),
#  ('Yogur', 'Pérez', 1248.27),
#  ('Bolsas de basura', 'López', 1247.24),
#  ('Platos desechables', 'Peña', 1246.99),
#  ('Chuletas', 'Romero', 1246.77),
#  ('Yogur', 'Medina', 1246.65),
#  ('Tomate', 'Chávez', 1245.74),
#  ('Carne de res', 'Cruz', 1245.66),
#  ('Mantequilla', 'Jiménez', 1245.19),
#  ('Semillas', 'Velázquez', 1244.95),
#  ('Leche', 'Torres', 1243.58),
#  ('Cerdo', 'Ruiz', 1240.56),
#  ('Bolsas de basura', 'González', 1240.55),
#  ('Agua', 'Serrano', 1239.35),
#  ('Mantequilla', 'Molina', 1237.42),
#  ('Lechuga', 'López', 1236.8),
#  ('Tomate', 'Cabrera', 1235.91),
#  ('Colonia', 'Aguilar', 1232.6),
#  ('Desinfectante', 'Ruiz', 1232.18),
#  ('Leche', 'Santos', 1231.99),
#  ('Jabón líquido', 'Salinas', 1231.12),
#  ('Pollo', 'Domínguez', 1230.21),
#  ('Platos desechables', 'Rodríguez', 1229.37),
#  ('Refresco', 'Martínez', 1229.36),
#  ('Pilas', 'Salinas', 1228.67),
#  ('Banana', 'Torres', 1227.9),
#  ('Pilas', 'Torres', 1227.6),
#  ('Lechuga', 'Vázquez', 1226.93),
#  ('Leche', 'Ruiz', 1226.53),
#  ('Tomate', 'Campos', 1225.61),
#  ('Lechuga', 'Romero', 1222.27),
#  ('Cebolla', 'Méndez', 1220.87),
#  ('Pilas', 'Navarro', 1220.66),
#  ('Desinfectante', 'Molina', 1220.63),
#  ('Pollo', 'Romero', 1220.27),
#  ('Cerdo', 'González', 1220.22),
#  ('Cerdo', 'Álvarez', 1219.72),
#  ('Jugo de naranja', 'Reyes', 1218.88),
#  ('Velas', 'Moreno', 1218.54),
#  ('Cerveza', 'Rodríguez', 1217.13),
#  ('Chuletas', 'Jiménez', 1216.37),
#  ('Bolsas de basura', 'Carrillo', 1215.09),
#  ('Colonia', 'Guzmán', 1214.87),
#  ('Zanahoria', 'Díaz', 1214.29),
#  ('Cerdo', 'Delgado', 1214.05),
#  ('Pollo', 'Cabrera', 1213.74),
#  ('Desinfectante', 'Campos', 1213.14),
#  ('Uva', 'Carrillo', 1211.79),
#  ('Jugo de naranja', 'Reyes', 1211.51),
#  ('Semillas', 'Ortiz', 1210.32),
#  ('Bolsas de basura', 'Santos', 1209.61),
#  ('Banana', 'Delgado', 1206.74),
#  ('Detergente', 'Fernández', 1206.53),
#  ('Mantequilla', 'Campos', 1206.17),
#  ('Naranja', 'Jiménez', 1203.97),
#  ('Crema hidratante', 'Domínguez', 1203.6),
#  ('Cerdo', 'Domínguez', 1203.23),
#  ('Pilas', 'Velázquez', 1202.84),
#  ('Lechuga', 'Ruiz', 1202.18),
#  ('Manzana', 'Ramos', 1200.49),
#  ('Cerveza', 'García', 1200.44),
#  ('Crema hidratante', 'Ruiz', 1196.24),
#  ('Chocolate', 'Lara', 1195.26),
#  ('Carne de res', 'Hernández', 1192.72),
#  ('Tomate', 'Moreno', 1192.32),
#  ('Zanahoria', 'Peña', 1191.52),
#  ('Mantequilla', 'Cabrera', 1189.29),
#  ('Tierra para macetas', 'Salinas', 1188.7),
#  ('Naranja', 'García', 1187.98),
#  ('Crema hidratante', 'Hernández', 1187.29),
#  ('Queso', 'Ramos', 1185.3),
#  ('Banana', 'Jiménez', 1184.78),
#  ('Champú', 'Ramírez', 1184.48),
#  ('Queso', 'Fuentes', 1184.07),
#  ('Manzana', 'Romero', 1182.79),
#  ('Bolsas de basura', 'Velázquez', 1181.29),
#  ('Carne de res', 'Méndez', 1180.39),
#  ('Desinfectante', 'Chávez', 1180.22),
#  ('Champú', 'Hernández', 1179.2),
#  ('Fertilizante', 'Chávez', 1179.01),
#  ('Tomate', 'Montes', 1178.71),
#  ('Champú', 'Molina', 1177.93),
#  ('Tierra para macetas', 'Santos', 1177.09),
#  ('Naranja', 'Romero', 1175.67),
#  ('Desinfectante', 'Rodríguez', 1173.79),
#  ('Tierra para macetas', 'Cruz', 1172.64),
#  ('Cerveza', 'Esquivel', 1172.09),
#  ('Zanahoria', 'Flores', 1169.96),
#  ('Velas', 'Medina', 1168.61),
#  ('Uva', 'Paredes', 1166.72),
#  ('Manzana', 'Medina', 1164.6),
#  ('Cerveza', 'García', 1163.64),
#  ('Refresco', 'Delgado', 1162.53),
#  ('Cerveza', 'González', 1162.43),
#  ('Tierra para macetas', 'Flores', 1162.2),
#  ('Cerveza', 'Fuentes', 1161.43),
#  ('Carne de res', 'Cabrera', 1160.97),
#  ('Semillas', 'Chávez', 1160.88),
#  ('Carne de res', 'Fuentes', 1160.76),
#  ('Manzana', 'Salinas', 1160.08),
#  ('Chuletas', 'Álvarez', 1159.23),
#  ('Pilas', 'Medina', 1159.06),
#  ('Desinfectante', 'Hernández', 1158.94),
#  ('Semillas', 'Delgado', 1158.93),
#  ('Desinfectante', 'Cabrera', 1158.81),
#  ('Leche', 'Rubio', 1158.63),
#  ('Bolsas de basura', 'Esquivel', 1157.16),
#  ('Fertilizante', 'Hernández', 1155.88),
#  ('Chicles', 'Aguilar', 1155.31),
#  ('Banana', 'Aguilar', 1153.4),
#  ('Colonia', 'Ortiz', 1152.45),
#  ('Zanahoria', 'García', 1152.09),
#  ('Agua', 'Rodríguez', 1151.76),
#  ('Mantequilla', 'Serrano', 1151.03),
#  ('Colonia', 'Serrano', 1149.63),
#  ('Tomate', 'Chávez', 1149.43),
#  ('Fertilizante', 'Reyes', 1149.43),
#  ('Jugo de naranja', 'Carrillo', 1148.15),
#  ('Velas', 'Sánchez', 1145.42),
#  ('Jugo de naranja', 'Paredes', 1145.29),
#  ('Esponjas', 'Fernández', 1144.78),
#  ('Tomate', 'Fernández', 1144.27),
#  ('Detergente', 'Reyes', 1143.24),
#  ('Chicles', 'González', 1143.01),
#  ('Crema hidratante', 'Chávez', 1142.95),
#  ('Leche', 'Rubio', 1141.51),
#  ('Jugo de naranja', 'Carrillo', 1141.18),
#  ('Champú', 'Hernández', 1141.18),
#  ('Yogur', 'Cabrera', 1141.01),
#  ('Champú', 'Jiménez', 1140.97),
#  ('Cerdo', 'Flores', 1140.67),
#  ('Pollo', 'Peña', 1139.23),
#  ('Lechuga', 'Jiménez', 1138.77),
#  ('Fertilizante', 'Reyes', 1137.95),
#  ('Platos desechables', 'Hernández', 1137.25),
#  ('Uva', 'Molina', 1136.02),
#  ('Esponjas', 'Reyes', 1133.79),
#  ('Chicles', 'Jiménez', 1133.31),
#  ('Chicles', 'Jiménez', 1132.74),
#  ('Velas', 'Ramos', 1132.1),
#  ('Carne de res', 'Medina', 1131.99),
#  ('Jabón líquido', 'García', 1131.09),
#  ('Refresco', 'Velázquez', 1130.86),
#  ('Mantequilla', 'Campos', 1130.54),
#  ('Mantequilla', 'Castro', 1130.5),
#  ('Cerveza', 'Ortiz', 1130.02),
#  ('Agua', 'Ramírez', 1129.22),
#  ('Bolsas de basura', 'Fuentes', 1128.37),
#  ('Banana', 'Santos', 1127.98),
#  ('Fertilizante', 'Serrano', 1125.48),
#  ('Desodorante', 'Navarro', 1125.03),
#  ('Tierra para macetas', 'Domínguez', 1125.0),
#  ('Bolsas de basura', 'Domínguez', 1123.61),
#  ('Naranja', 'Fuentes', 1122.42),
#  ('Mantequilla', 'Carrillo', 1121.94),
#  ('Chicles', 'Medina', 1121.67),
#  ('Platos desechables', 'García', 1118.31),
#  ('Desinfectante', 'Guzmán', 1118.12),
#  ('Cerveza', 'Moreno', 1117.55),
#  ('Chocolate', 'Velázquez', 1116.34),
#  ('Esponjas', 'Díaz', 1116.24),
#  ('Chuletas', 'Medina', 1115.75),
#  ('Cerveza', 'Vázquez', 1113.6),
#  ('Bolsas de basura', 'Esquivel', 1111.89),
#  ('Zanahoria', 'Reyes', 1110.6),
#  ('Lechuga', 'Vázquez', 1109.58),
#  ('Pilas', 'Hernández', 1109.39),
#  ('Uva', 'Ortiz', 1108.44),
#  ('Cerdo', 'Ramírez', 1107.95),
#  ('Mantequilla', 'Cabrera', 1107.17),
#  ('Lechuga', 'Méndez', 1106.83),
#  ('Desodorante', 'López', 1106.68),
#  ('Fertilizante', 'Pérez', 1106.13),
#  ('Papas fritas', 'Ruiz', 1106.06),
#  ('Lechuga', 'Salinas', 1105.84),
#  ('Manzana', 'Cruz', 1105.16),
#  ('Chicles', 'Díaz', 1104.85),
#  ('Platos desechables', 'Méndez', 1104.6),
#  ('Colonia', 'Flores', 1103.51),
#  ('Detergente', 'Álvarez', 1102.81),
#  ('Queso', 'Cortés', 1102.23),
#  ('Papas fritas', 'Rubio', 1101.79),
#  ('Semillas', 'Santos', 1101.14),
#  ('Mantequilla', 'García', 1100.6),
#  ('Agua', 'Serrano', 1098.5),
#  ('Mantequilla', 'Ortiz', 1097.92),
#  ('Pollo', 'Méndez', 1097.6),
#  ('Platos desechables', 'Lara', 1095.98),
#  ('Mantequilla', 'Molina', 1094.36),
#  ('Zanahoria', 'Ramírez', 1094.21),
#  ('Tomate', 'Medina', 1093.79),
#  ('Regadera', 'Santos', 1092.44),
#  ('Desodorante', 'Pérez', 1092.12),
#  ('Cerdo', 'Jiménez', 1091.18),
#  ('Cerdo', 'Hernández', 1091.11),
#  ('Carne de res', 'Carrillo', 1090.81),
#  ('Champú', 'Pérez', 1090.23),
#  ('Mantequilla', 'Domínguez', 1090.06),
#  ('Zanahoria', 'Guzmán', 1089.66),
#  ('Papas fritas', 'Rodríguez', 1088.54),
#  ('Tierra para macetas', 'Cruz', 1087.8),
#  ('Manzana', 'Flores', 1086.37),
#  ('Jugo de naranja', 'Medina', 1086.18),
#  ('Platos desechables', 'Torres', 1085.09),
#  ('Fertilizante', 'Rodríguez', 1081.29),
#  ('Tierra para macetas', 'Navarro', 1081.19),
#  ('Naranja', 'Álvarez', 1080.43),
#  ('Lechuga', 'Fuentes', 1080.08),
#  ('Chuletas', 'Díaz', 1079.29),
#  ('Tomate', 'Ramos', 1078.21),
#  ('Cerveza', 'Pérez', 1078.04),
#  ('Colonia', 'Esquivel', 1078.02),
#  ('Bolsas de basura', 'Romero', 1077.05),
#  ('Cerdo', 'Jiménez', 1076.37),
#  ('Zanahoria', 'Rodríguez', 1075.51),
#  ('Bolsas de basura', 'Flores', 1075.06),
#  ('Carne de res', 'Aguilar', 1074.94),
#  ('Galletas', 'Rodríguez', 1072.04),
#  ('Chocolate', 'Flores', 1070.28),
#  ('Banana', 'Cruz', 1069.62),
#  ('Pollo', 'Velázquez', 1068.25),
#  ('Cerdo', 'Domínguez', 1068.23),
#  ('Velas', 'Esquivel', 1067.63),
#  ('Colonia', 'Guzmán', 1066.85),
#  ('Yogur', 'Ramos', 1065.71),
#  ('Champú', 'Cruz', 1063.13),
#  ('Uva', 'Jiménez', 1062.11),
#  ('Manzana', 'Cruz', 1061.57),
#  ('Queso', 'Méndez', 1060.46),
#  ('Cerdo', 'Reyes', 1059.99),
#  ('Velas', 'Fuentes', 1059.69),
#  ('Papas fritas', 'Medina', 1057.3),
#  ('Jugo de naranja', 'Romero', 1055.65),
#  ('Uva', 'Ramos', 1054.78),
#  ('Jabón líquido', 'Guzmán', 1054.53),
#  ('Platos desechables', 'Fuentes', 1054.51),
#  ('Refresco', 'Rodríguez', 1054.15),
#  ('Refresco', 'Ramírez', 1052.91),
#  ('Fertilizante', 'Medina', 1051.35),
#  ('Manzana', 'Jiménez', 1050.31),
#  ('Platos desechables', 'Hernández', 1049.96),
#  ('Tomate', 'Castro', 1049.66),
#  ('Chicles', 'Álvarez', 1049.1),
#  ('Champú', 'Cruz', 1047.98),
#  ('Cerdo', 'Lara', 1044.55),
#  ('Carne de res', 'López', 1044.0),
#  ('Uva', 'Paredes', 1043.44),
#  ('Velas', 'Chávez', 1043.16),
#  ('Cerdo', 'Ramírez', 1041.89),
#  ('Tierra para macetas', 'Montes', 1041.48),
#  ('Tierra para macetas', 'Sánchez', 1039.6),
#  ('Bolsas de basura', 'Molina', 1038.75),
#  ('Manzana', 'Velázquez', 1038.47),
#  ('Galletas', 'Cortés', 1038.07),
#  ('Esponjas', 'Fuentes', 1035.59),
#  ('Bolsas de basura', 'Medina', 1035.42),
#  ('Mantequilla', 'Flores', 1035.15),
#  ('Semillas', 'Montes', 1034.79),
#  ('Mantequilla', 'Ramírez', 1034.53),
#  ('Naranja', 'Santos', 1034.47),
#  ('Chuletas', 'Jiménez', 1033.31),
#  ('Tierra para macetas', 'Martínez', 1032.9),
#  ('Pollo', 'Martínez', 1031.25),
#  ('Mantequilla', 'García', 1030.82),
#  ('Uva', 'Cruz', 1029.48),
#  ('Pollo', 'Domínguez', 1028.16),
#  ('Colonia', 'Lara', 1027.2),
#  ('Velas', 'Méndez', 1026.99),
#  ('Champú', 'Ortiz', 1026.95),
#  ('Cerdo', 'Ortiz', 1026.16),
#  ('Semillas', 'Castro', 1026.05),
#  ('Velas', 'Pérez', 1025.26),
#  ('Yogur', 'Romero', 1023.19),
#  ('Regadera', 'Castro', 1022.79),
#  ('Chocolate', 'Ortiz', 1021.39),
#  ('Chuletas', 'Torres', 1021.13),
#  ('Manzana', 'Ruiz', 1020.6),
#  ('Zanahoria', 'Velázquez', 1020.54),
#  ('Galletas', 'Paredes', 1020.44),
#  ('Colonia', 'Reyes', 1015.07),
#  ('Leche', 'Santos', 1013.0),
#  ('Bolsas de basura', 'Navarro', 1012.16),
#  ('Refresco', 'Vázquez', 1011.21),
#  ('Refresco', 'Reyes', 1008.13),
#  ('Semillas', 'Sánchez', 1008.09),
#  ('Detergente', 'Molina', 1006.99),
#  ('Carne de res', 'Campos', 1006.39),
#  ('Bolsas de basura', 'Esquivel', 1005.6),
#  ('Detergente', 'Serrano', 1005.41),
#  ('Uva', 'Jiménez', 1004.75),
#  ('Queso', 'Molina', 1004.23),
#  ('Galletas', 'Aguilar', 1003.57),
#  ('Mantequilla', 'Ortiz', 1003.43),
#  ('Refresco', 'Ramírez', 1003.16),
#  ('Queso', 'Velázquez', 1002.47),
#  ('Chicles', 'Díaz', 1002.12),
#  ('Uva', 'González', 1001.31),
#  ('Platos desechables', 'López', 1001.08),
#  ('Lechuga', 'Esquivel', 1000.94),
#  ('Chicles', 'Fernández', 1000.61),
#  ('Champú', 'Navarro', 999.45),
#  ('Regadera', 'Peña', 998.04),
#  ('Detergente', 'Torres', 997.24),
#  ('Tierra para macetas', 'Hernández', 997.02),
#  ('Galletas', 'Vázquez', 996.66),
#  ('Chicles', 'Fuentes', 996.64),
#  ('Chuletas', 'Romero', 994.87),
#  ('Chocolate', 'Serrano', 994.75),
#  ('Cebolla', 'Flores', 994.25),
#  ('Pilas', 'Lara', 993.01),
#  ('Pilas', 'Jiménez', 992.43),
#  ('Chocolate', 'Esquivel', 991.57),
#  ('Cerdo', 'Pérez', 990.72),
#  ('Tomate', 'Álvarez', 989.41),
#  ('Desodorante', 'Romero', 988.76),
#  ('Cerdo', 'Rodríguez', 988.28),
#  ('Uva', 'Peña', 988.06),
#  ('Chicles', 'Pérez', 988.04),
#  ('Yogur', 'González', 986.5),
#  ('Detergente', 'Cruz', 986.01),
#  ('Refresco', 'Rodríguez', 985.82),
#  ('Velas', 'Guzmán', 985.53),
#  ('Desinfectante', 'Domínguez', 984.19),
#  ('Platos desechables', 'Moreno', 983.77),
#  ('Colonia', 'Fernández', 983.56),
#  ('Desodorante', 'Guzmán', 982.82),
#  ('Yogur', 'López', 982.79),
#  ('Tierra para macetas', 'Cruz', 982.65),
#  ('Cerdo', 'Pérez', 981.46),
#  ('Crema hidratante', 'Martínez', 981.33),
#  ('Lechuga', 'Fernández', 981.05),
#  ('Desodorante', 'Castro', 979.96),
#  ('Uva', 'González', 978.73),
#  ('Tomate', 'Castro', 978.59),
#  ('Crema hidratante', 'Aguilar', 978.55),
#  ('Desodorante', 'Reyes', 978.14),
#  ('Naranja', 'Serrano', 977.78),
#  ('Jabón líquido', 'Ramírez', 975.37),
#  ('Galletas', 'Fuentes', 975.26),
#  ('Mantequilla', 'Aguilar', 974.91),
#  ('Galletas', 'Cabrera', 973.61),
#  ('Pilas', 'Domínguez', 973.25),
#  ('Pollo', 'López', 973.13),
#  ('Zanahoria', 'Chávez', 972.54),
#  ('Cerveza', 'Campos', 972.47),
#  ('Chicles', 'Ramos', 972.27),
#  ('Leche', 'Jiménez', 972.03),
#  ('Tierra para macetas', 'Carrillo', 971.05),
#  ('Yogur', 'Montes', 967.95),
#  ('Galletas', 'Moreno', 967.48),
#  ('Velas', 'Cabrera', 967.34),
#  ('Semillas', 'Velázquez', 967.03),
#  ('Velas', 'Cruz', 966.58),
#  ('Pollo', 'Chávez', 966.49),
#  ('Bolsas de basura', 'Peña', 966.46),
#  ('Crema hidratante', 'Domínguez', 966.44),
#  ('Fertilizante', 'Montes', 966.31),
#  ('Desinfectante', 'González', 965.63),
#  ('Pilas', 'Cortés', 965.34),
#  ('Bolsas de basura', 'Guzmán', 965.32),
#  ('Bolsas de basura', 'Ruiz', 964.62),
#  ('Queso', 'Ramírez', 964.11),
#  ('Crema hidratante', 'Díaz', 963.71),
#  ('Naranja', 'Guzmán', 962.43),
#  ('Velas', 'Aguilar', 961.83),
#  ('Chuletas', 'Guzmán', 961.11),
#  ('Semillas', 'Campos', 958.51),
#  ('Uva', 'Navarro', 958.23),
#  ('Jugo de naranja', 'Fuentes', 957.79),
#  ('Tierra para macetas', 'Fernández', 957.43),
#  ('Tomate', 'Molina', 956.71),
#  ('Fertilizante', 'Flores', 956.61),
#  ('Pilas', 'Lara', 955.62),
#  ('Lechuga', 'Jiménez', 954.24),
#  ('Velas', 'Cortés', 954.1),
#  ('Jabón líquido', 'Lara', 953.46),
#  ('Refresco', 'Chávez', 953.36),
#  ('Mantequilla', 'García', 953.01),
#  ('Semillas', 'Fuentes', 952.82),
#  ('Esponjas', 'Díaz', 952.34),
#  ('Jabón líquido', 'González', 951.17),
#  ('Chocolate', 'Fernández', 950.24),
#  ('Regadera', 'Medina', 947.97),
#  ('Chuletas', 'Santos', 947.73),
#  ('Detergente', 'Paredes', 947.53),
#  ('Banana', 'Vázquez', 946.89),
#  ('Agua', 'Ruiz', 946.72),
#  ('Velas', 'Pérez', 946.47),
#  ('Pilas', 'Santos', 944.61),
#  ('Refresco', 'Ortiz', 942.38),
#  ('Crema hidratante', 'Lara', 940.88),
#  ('Platos desechables', 'González', 940.87),
#  ('Mantequilla', 'González', 940.46),
#  ('Manzana', 'Sánchez', 940.21),
#  ('Carne de res', 'Jiménez', 939.88),
#  ('Manzana', 'López', 939.67),
#  ('Chuletas', 'Serrano', 937.5),
#  ('Galletas', 'González', 937.39),
#  ('Tierra para macetas', 'Flores', 936.3),
#  ('Banana', 'Flores', 935.51),
#  ('Banana', 'Medina', 935.13),
#  ('Bolsas de basura', 'Martínez', 934.72),
#  ('Refresco', 'González', 934.01),
#  ('Papas fritas', 'Fernández', 933.01),
#  ('Leche', 'Pérez', 932.88),
#  ('Cerveza', 'Cortés', 932.31),
#  ('Lechuga', 'Aguilar', 932.04),
#  ('Yogur', 'Vázquez', 931.59),
#  ('Velas', 'Salinas', 931.3),
#  ('Chocolate', 'Ramos', 929.78),
#  ('Manzana', 'Delgado', 928.53),
#  ('Pilas', 'Delgado', 927.7),
#  ('Tomate', 'Cruz', 926.77),
#  ('Colonia', 'Álvarez', 926.76),
#  ('Lechuga', 'Vázquez', 926.7),
#  ('Regadera', 'González', 926.55),
#  ('Pilas', 'Moreno', 925.23),
#  ('Agua', 'Campos', 924.82),
#  ('Champú', 'Rodríguez', 923.59),
#  ('Crema hidratante', 'Cruz', 923.04),
#  ('Uva', 'Medina', 922.97),
#  ('Cebolla', 'Domínguez', 922.69),
#  ('Banana', 'Cabrera', 922.37),
#  ('Semillas', 'Ramírez', 922.04),
#  ('Fertilizante', 'Rubio', 921.93),
#  ('Jabón líquido', 'Rodríguez', 921.88),
#  ('Zanahoria', 'Álvarez', 921.53),
#  ('Jabón líquido', 'Velázquez', 920.46),
#  ('Colonia', 'Álvarez', 920.44),
#  ('Queso', 'Pérez', 919.42),
#  ('Pilas', 'Medina', 919.11),
#  ('Galletas', 'Campos', 918.93),
#  ('Cebolla', 'Cabrera', 918.46),
#  ('Tierra para macetas', 'Pérez', 917.05),
#  ('Crema hidratante', 'Cabrera', 916.8),
#  ('Cebolla', 'Torres', 916.25),
#  ('Platos desechables', 'Rodríguez', 916.06),
#  ('Tierra para macetas', 'Cabrera', 915.83),
#  ('Uva', 'Santos', 915.64),
#  ('Platos desechables', 'Vázquez', 915.49),
#  ('Naranja', 'Medina', 915.02),
#  ('Carne de res', 'Esquivel', 914.68),
#  ('Semillas', 'Martínez', 914.39),
#  ('Champú', 'Díaz', 912.74),
#  ('Uva', 'Fernández', 912.4),
#  ('Semillas', 'Rubio', 912.19),
#  ('Galletas', 'González', 912.12),
#  ('Semillas', 'López', 911.65),
#  ('Leche', 'Rubio', 910.43),
#  ('Cebolla', 'Romero', 908.73),
#  ('Jabón líquido', 'Salinas', 908.21),
#  ('Queso', 'Santos', 907.52),
#  ('Mantequilla', 'Torres', 906.91),
#  ('Champú', 'Álvarez', 906.34),
#  ('Pilas', 'Ruiz', 906.08),
#  ('Refresco', 'Rubio', 905.97),
#  ('Cebolla', 'Chávez', 905.0),
#  ('Refresco', 'Rubio', 904.95),
#  ('Banana', 'Sánchez', 904.54),
#  ('Colonia', 'Fernández', 904.38),
#  ('Galletas', 'Serrano', 904.12),
#  ('Chocolate', 'Martínez', 903.93),
#  ('Galletas', 'Ramos', 902.96),
#  ('Platos desechables', 'Serrano', 901.86),
#  ('Uva', 'Salinas', 899.93),
#  ('Bolsas de basura', 'López', 898.39),
#  ('Naranja', 'García', 898.11),
#  ('Pollo', 'Martínez', 896.98),
#  ('Semillas', 'Esquivel', 896.7),
#  ('Leche', 'Sánchez', 896.34),
#  ('Velas', 'Méndez', 896.32),
#  ('Banana', 'Romero', 894.66),
#  ('Cerdo', 'Ramos', 894.62),
#  ('Cerveza', 'Cortés', 894.25),
#  ('Detergente', 'Álvarez', 893.51),
#  ('Naranja', 'Cabrera', 893.45),
#  ('Zanahoria', 'Torres', 893.25),
#  ('Champú', 'Reyes', 892.77),
#  ('Uva', 'Rubio', 891.99),
#  ('Desinfectante', 'Ortiz', 891.55),
#  ('Refresco', 'Ramos', 891.42),
#  ('Detergente', 'Esquivel', 890.61),
#  ('Leche', 'Carrillo', 890.46),
#  ('Velas', 'Montes', 888.91),
#  ('Regadera', 'Díaz', 888.54),
#  ('Velas', 'Martínez', 888.33),
#  ('Chuletas', 'Aguilar', 885.18),
#  ('Detergente', 'Méndez', 885.18),
#  ('Refresco', 'Díaz', 885.03),
#  ('Tomate', 'Aguilar', 884.39),
#  ('Papas fritas', 'Cortés', 884.09),
#  ('Regadera', 'Romero', 883.98),
#  ('Cerveza', 'Cortés', 883.68),
#  ('Yogur', 'Santos', 883.66),
#  ('Zanahoria', 'Velázquez', 883.49),
#  ('Galletas', 'Delgado', 883.31),
#  ('Jugo de naranja', 'Esquivel', 882.74),
#  ('Velas', 'González', 881.23),
#  ('Detergente', 'Ramírez', 878.84),
#  ('Desodorante', 'Peña', 878.69),
#  ('Semillas', 'Cortés', 878.22),
#  ('Manzana', 'González', 876.54),
#  ('Pilas', 'Cabrera', 875.25),
#  ...]

# %% [markdown]
# * 5.-Empleados y número de órdenes gestionadas
#
#     * Muestra el nombre del empleado, el puesto y la cantidad de órdenes que ha gestionado.
#     * Utiliza GROUP BY y COUNT.

# %%
sql = ('SELECT e.nombre_empleado AS EMPLEADO, e.puesto AS PUESTO, count(o.id_empleado) AS ORDENES FROM empleados e JOIN ordenes o ON o.id_empleado = e.id_empleado GROUP BY e.id_empleado')
consultas(sql)
# Out:
# [('Mario Guzmán', 'Cajero', 80),
#  ('Irene Ortiz', 'Reponedor', 82),
#  ('Adriana Cortés', 'Encargado de sección', 74),
#  ('David Lara', 'Gerente', 78),
#  ('Laura Aguilar', 'Personal de limpieza', 88),
#  ('Verónica Jiménez', 'Panadero', 72),
#  ('Miguel Cabrera', 'Carnicero', 73),
#  ('Irene Esquivel', 'Pescadero', 75),
#  ('Sofía Romero', 'Frutero', 74),
#  ('Tomás Moreno', 'Charcutero', 70),
#  ('Ana Chávez', 'Jefe de turno', 65),
#  ('Cristian Reyes', 'Operador logístico', 59),
#  ('Jorge Montes', 'Atención al cliente', 85),
#  ('Cristian Cruz', 'Auxiliar de caja', 74),
#  ('Ricardo Fernández', 'Encargado de seguridad', 81),
#  ('David López', 'Responsable de zona', 82),
#  ('Sergio Delgado', 'Jefe de compras', 75),
#  ('Camila Paredes', 'Encargada carnicería', 83),
#  ('José Flores', 'encargado pescadería', 74),
#  ('Mario Serrano', 'Jefe de Limpieza', 68),
#  ('Lucía Fuentes', 'Cajero', 74),
#  ('Diego Lara', 'Reponedor', 68),
#  ('Laura Sánchez', 'Encargado de sección', 63),
#  ('Ricardo Ortiz', 'Gerente', 62),
#  ('Cristian Díaz', 'Personal de limpieza', 51),
#  ('Irene Torres', 'Panadero', 77),
#  ('Natalia Díaz', 'Carnicero', 64),
#  ('Valeria Domínguez', 'Pescadero', 67),
#  ('Tomás Flores', 'Frutero', 71),
#  ('Fernando Pérez', 'Charcutero', 82),
#  ('Lorena Esquivel', 'Jefe de turno', 75),
#  ('Valeria Méndez', 'Operador logístico', 66),
#  ('Miguel Reyes', 'Atención al cliente', 68),
#  ('Gabriela Santos', 'Auxiliar de caja', 80),
#  ('Paula Martínez', 'Encargado de seguridad', 69),
#  ('Sofía Campos', 'Responsable de zona', 82),
#  ('Irene Chávez', 'Jefe de compras', 80),
#  ('Miguel Castro', 'Encargada carnicería', 76),
#  ('Diego Carrillo', 'encargado pescadería', 60),
#  ('Adriana Torres', 'Jefe de Limpieza', 77),
#  ('Daniel Lara', 'Cajero', 79),
#  ('Ricardo Cabrera', 'Reponedor', 69),
#  ('Sara Fernández', 'Encargado de sección', 73),
#  ('María García', 'Gerente', 73),
#  ('Sergio Ortiz', 'Personal de limpieza', 81),
#  ('Francisco Martínez', 'Panadero', 68),
#  ('Sofía Montes', 'Carnicero', 75),
#  ('Elena López', 'Pescadero', 85),
#  ('Andrés Molina', 'Frutero', 62),
#  ('Manuel Sánchez', 'Charcutero', 69),
#  ('Clara Torres', 'Jefe de turno', 76),
#  ('Javier Pérez', 'Operador logístico', 58),
#  ('David Peña', 'Atención al cliente', 77),
#  ('Cristian Ortiz', 'Auxiliar de caja', 67),
#  ('Carla González', 'Encargado de seguridad', 61),
#  ('Manuel Méndez', 'Responsable de zona', 71),
#  ('Pablo Lara', 'Jefe de compras', 65),
#  ('Luis Díaz', 'Encargada carnicería', 72),
#  ('Elena Montes', 'encargado pescadería', 64),
#  ('Carmen Delgado', 'Jefe de Limpieza', 68),
#  ('Natalia Navarro', 'Cajero', 75),
#  ('Jorge Martínez', 'Reponedor', 84),
#  ('Jorge Jiménez', 'Encargado de sección', 61),
#  ('Valeria Torres', 'Gerente', 65),
#  ('Hugo Montes', 'Personal de limpieza', 69),
#  ('Fernando Romero', 'Panadero', 83),
#  ('Julia Santos', 'Carnicero', 78),
#  ('Samuel González', 'Pescadero', 63),
#  ('Carmen García', 'Frutero', 62),
#  ('Carlos Castro', 'Charcutero', 92),
#  ('Jorge Pérez', 'Jefe de turno', 58),
#  ('Valeria Rodríguez', 'Operador logístico', 64),
#  ('Eva Delgado', 'Atención al cliente', 73),
#  ('Raúl Carrillo', 'Auxiliar de caja', 64),
#  ('Ana Ortiz', 'Encargado de seguridad', 64),
#  ('Gabriela Reyes', 'Responsable de zona', 76),
#  ('Hugo Torres', 'Jefe de compras', 64),
#  ('Javier Martínez', 'Encargada carnicería', 69),
#  ('Camila López', 'encargado pescadería', 58),
#  ('Tomás Domínguez', 'Jefe de Limpieza', 65),
#  ('Sergio Carrillo', 'Cajero', 68),
#  ('Paula Serrano', 'Reponedor', 78),
#  ('Tomás Peña', 'Encargado de sección', 61),
#  ('Eduardo Cabrera', 'Gerente', 56),
#  ('Carla López', 'Personal de limpieza', 64),
#  ('Irene Navarro', 'Panadero', 86),
#  ('Ángel Molina', 'Carnicero', 72),
#  ('María Velázquez', 'Pescadero', 74),
#  ('Daniel Sánchez', 'Frutero', 69),
#  ('Miguel Méndez', 'Charcutero', 69),
#  ('Natalia Hernández', 'Jefe de turno', 67),
#  ('Carmen Serrano', 'Operador logístico', 55),
#  ('Camila Carrillo', 'Atención al cliente', 56),
#  ('Carlos González', 'Auxiliar de caja', 82),
#  ('Andrea Hernández', 'Encargado de seguridad', 70),
#  ('Laura Ramírez', 'Responsable de zona', 72),
#  ('María Delgado', 'Jefe de compras', 71),
#  ('Ricardo Jiménez', 'Encargada carnicería', 67),
#  ('Javier Velázquez', 'encargado pescadería', 72),
#  ('Camila Ruiz', 'Jefe de Limpieza', 72),
#  ('Natalia Paredes', 'Cajero', 89),
#  ('José Aguilar', 'Reponedor', 59),
#  ('Cristian Vázquez', 'Encargado de sección', 64),
#  ('Sergio Rodríguez', 'Gerente', 79),
#  ('Hugo Moreno', 'Personal de limpieza', 67),
#  ('Gabriela Torres', 'Panadero', 84),
#  ('Pablo Reyes', 'Carnicero', 69),
#  ('Francisco Carrillo', 'Pescadero', 80),
#  ('Camila Esquivel', 'Frutero', 71),
#  ('Paula Cortés', 'Charcutero', 72),
#  ('Patricia Santos', 'Jefe de turno', 78),
#  ('Carmen Ortiz', 'Operador logístico', 82),
#  ('Diana Ramos', 'Atención al cliente', 72),
#  ('David Castro', 'Auxiliar de caja', 60),
#  ('Ana Cruz', 'Encargado de seguridad', 56),
#  ('Cristian Fernández', 'Responsable de zona', 80),
#  ('Mario Serrano', 'Jefe de compras', 68),
#  ('Daniel Cabrera', 'Encargada carnicería', 80),
#  ('Andrés Montes', 'encargado pescadería', 56),
#  ('Miguel Pérez', 'Jefe de Limpieza', 68),
#  ('Mario Paredes', 'Cajero', 79),
#  ('Isabel Santos', 'Reponedor', 75),
#  ('Ángel Carrillo', 'Encargado de sección', 75),
#  ('Gabriela Cruz', 'Gerente', 77),
#  ('Sergio Ortiz', 'Personal de limpieza', 72),
#  ('María Ortiz', 'Panadero', 59),
#  ('José González', 'Carnicero', 68),
#  ('Adriana Velázquez', 'Pescadero', 97),
#  ('Gabriela Ramírez', 'Frutero', 66),
#  ('Gabriela Sánchez', 'Charcutero', 61),
#  ('Marta Montes', 'Jefe de turno', 92),
#  ('Luis Moreno', 'Operador logístico', 66),
#  ('Laura Jiménez', 'Atención al cliente', 65),
#  ('Diana Chávez', 'Auxiliar de caja', 75),
#  ('Jorge Castro', 'Encargado de seguridad', 68),
#  ('Carlos Delgado', 'Responsable de zona', 65),
#  ('David Castro', 'Jefe de compras', 69),
#  ('Daniel Guzmán', 'Encargada carnicería', 77),
#  ('Raúl Sánchez', 'encargado pescadería', 89),
#  ('Ángel Díaz', 'Jefe de Limpieza', 66)]

# %% [markdown]
# * 6.-Ordenes filtradas por fecha y tienda
#
#     * Muestra todas las órdenes que se realizaron en un rango de fechas determinado (ej.: del 1 de enero de 2025 al 31 de enero de 2025) y en una tienda específica.
#     * Incluye datos de la tienda y del cliente.

# %%
sql = ("SELECT t.id_tienda, t.nombre_tienda AS tienda, o.id_orden AS factura, o.fecha_orden AS fecha, concat(c.first_name,' ',c.last_name) AS cliente FROM tiendas t JOIN empleados e ON t.id_tienda = e.id_tienda JOIN ordenes o ON o.id_empleado = e.id_empleado JOIN clientes c ON c.id_cliente = o.id_cliente WHERE T.id_tienda = 1 and o.fecha_orden > '2024-01-31' and o.fecha_orden < '2024-03-01' ORDER BY o.fecha_orden;")
consultas(sql)
# Out:
# [(1, 'Tienda Centro', 788, datetime.date(2024, 2, 1), 'Cebolla Méndez'),
#  (1, 'Tienda Centro', 790, datetime.date(2024, 2, 1), 'Refresco Montes'),
#  (1, 'Tienda Centro', 797, datetime.date(2024, 2, 1), 'Mantequilla Vázquez'),
#  (1, 'Tienda Centro', 798, datetime.date(2024, 2, 1), 'Cebolla Fernández'),
#  (1,
#   'Tienda Centro',
#   807,
#   datetime.date(2024, 2, 2),
#   'Crema hidratante Serrano'),
#  (1, 'Tienda Centro', 817, datetime.date(2024, 2, 2), 'Cebolla Martínez'),
#  (1, 'Tienda Centro', 824, datetime.date(2024, 2, 2), 'Manzana Carrillo'),
#  (1, 'Tienda Centro', 827, datetime.date(2024, 2, 3), 'Velas Navarro'),
#  (1, 'Tienda Centro', 831, datetime.date(2024, 2, 3), 'Chuletas Álvarez'),
#  (1, 'Tienda Centro', 833, datetime.date(2024, 2, 3), 'Leche Rubio'),
#  (1, 'Tienda Centro', 836, datetime.date(2024, 2, 3), 'Refresco Díaz'),
#  (1, 'Tienda Centro', 844, datetime.date(2024, 2, 3), 'Carne de res Esquivel'),
#  (1, 'Tienda Centro', 853, datetime.date(2024, 2, 3), 'Desodorante Santos'),
#  (1, 'Tienda Centro', 857, datetime.date(2024, 2, 4), 'Leche Ruiz'),
#  (1,
#   'Tienda Centro',
#   859,
#   datetime.date(2024, 2, 4),
#   'Bolsas de basura López'),
#  (1, 'Tienda Centro', 871, datetime.date(2024, 2, 4), 'Pollo Lara'),
#  (1, 'Tienda Centro', 878, datetime.date(2024, 2, 5), 'Colonia Serrano'),
#  (1,
#   'Tienda Centro',
#   879,
#   datetime.date(2024, 2, 5),
#   'Jugo de naranja Serrano'),
#  (1,
#   'Tienda Centro',
#   885,
#   datetime.date(2024, 2, 5),
#   'Bolsas de basura Vázquez'),
#  (1,
#   'Tienda Centro',
#   888,
#   datetime.date(2024, 2, 5),
#   'Jugo de naranja Moreno'),
#  (1, 'Tienda Centro', 903, datetime.date(2024, 2, 6), 'Chuletas Esquivel'),
#  (1, 'Tienda Centro', 905, datetime.date(2024, 2, 6), 'Queso López'),
#  (1, 'Tienda Centro', 918, datetime.date(2024, 2, 6), 'Detergente Rodríguez'),
#  (1, 'Tienda Centro', 937, datetime.date(2024, 2, 7), 'Velas López'),
#  (1, 'Tienda Centro', 948, datetime.date(2024, 2, 8), 'Naranja López'),
#  (1,
#   'Tienda Centro',
#   950,
#   datetime.date(2024, 2, 8),
#   'Tierra para macetas Serrano'),
#  (1, 'Tienda Centro', 960, datetime.date(2024, 2, 8), 'Fertilizante Moreno'),
#  (1, 'Tienda Centro', 965, datetime.date(2024, 2, 8), 'Papas fritas Ortiz'),
#  (1, 'Tienda Centro', 978, datetime.date(2024, 2, 9), 'Esponjas Esquivel'),
#  (1, 'Tienda Centro', 982, datetime.date(2024, 2, 9), 'Leche Molina'),
#  (1, 'Tienda Centro', 983, datetime.date(2024, 2, 9), 'Galletas Aguilar'),
#  (1, 'Tienda Centro', 984, datetime.date(2024, 2, 9), 'Esponjas Campos'),
#  (1, 'Tienda Centro', 985, datetime.date(2024, 2, 9), 'Uva López'),
#  (1, 'Tienda Centro', 988, datetime.date(2024, 2, 9), 'Manzana Martínez'),
#  (1,
#   'Tienda Centro',
#   991,
#   datetime.date(2024, 2, 9),
#   'Platos desechables Salinas'),
#  (1,
#   'Tienda Centro',
#   994,
#   datetime.date(2024, 2, 9),
#   'Platos desechables Molina'),
#  (1, 'Tienda Centro', 1004, datetime.date(2024, 2, 10), 'Manzana Flores'),
#  (1, 'Tienda Centro', 1011, datetime.date(2024, 2, 10), 'Velas Jiménez'),
#  (1, 'Tienda Centro', 1019, datetime.date(2024, 2, 10), 'Refresco Ortiz'),
#  (1,
#   'Tienda Centro',
#   1029,
#   datetime.date(2024, 2, 11),
#   'Jabón líquido Salinas'),
#  (1, 'Tienda Centro', 1041, datetime.date(2024, 2, 11), 'Chuletas Flores'),
#  (1, 'Tienda Centro', 1043, datetime.date(2024, 2, 11), 'Yogur García'),
#  (1, 'Tienda Centro', 1067, datetime.date(2024, 2, 12), 'Cerveza Cortés'),
#  (1, 'Tienda Centro', 1069, datetime.date(2024, 2, 12), 'Velas Reyes'),
#  (1, 'Tienda Centro', 1074, datetime.date(2024, 2, 12), 'Leche Aguilar'),
#  (1, 'Tienda Centro', 1085, datetime.date(2024, 2, 13), 'Zanahoria Montes'),
#  (1, 'Tienda Centro', 1090, datetime.date(2024, 2, 13), 'Yogur Sánchez'),
#  (1, 'Tienda Centro', 1091, datetime.date(2024, 2, 13), 'Desinfectante López'),
#  (1, 'Tienda Centro', 1101, datetime.date(2024, 2, 13), 'Zanahoria Pérez'),
#  (1, 'Tienda Centro', 1107, datetime.date(2024, 2, 13), 'Leche Hernández'),
#  (1, 'Tienda Centro', 1115, datetime.date(2024, 2, 14), 'Galletas Jiménez'),
#  (1, 'Tienda Centro', 1124, datetime.date(2024, 2, 14), 'Tomate Romero'),
#  (1, 'Tienda Centro', 1132, datetime.date(2024, 2, 14), 'Chicles Salinas'),
#  (1, 'Tienda Centro', 1141, datetime.date(2024, 2, 14), 'Fertilizante Flores'),
#  (1, 'Tienda Centro', 1144, datetime.date(2024, 2, 15), 'Pollo Méndez'),
#  (1, 'Tienda Centro', 1146, datetime.date(2024, 2, 15), 'Naranja Ruiz'),
#  (1, 'Tienda Centro', 1147, datetime.date(2024, 2, 15), 'Uva López'),
#  (1, 'Tienda Centro', 1158, datetime.date(2024, 2, 15), 'Colonia Navarro'),
#  (1,
#   'Tienda Centro',
#   1165,
#   datetime.date(2024, 2, 15),
#   'Platos desechables Romero'),
#  (1, 'Tienda Centro', 1169, datetime.date(2024, 2, 15), 'Uva Paredes'),
#  (1, 'Tienda Centro', 1182, datetime.date(2024, 2, 16), 'Chuletas Álvarez'),
#  (1,
#   'Tienda Centro',
#   1192,
#   datetime.date(2024, 2, 16),
#   'Tierra para macetas López'),
#  (1, 'Tienda Centro', 1198, datetime.date(2024, 2, 16), 'Refresco González'),
#  (1, 'Tienda Centro', 1200, datetime.date(2024, 2, 16), 'Papas fritas Campos'),
#  (1,
#   'Tienda Centro',
#   1201,
#   datetime.date(2024, 2, 16),
#   'Carne de res Carrillo'),
#  (1, 'Tienda Centro', 1206, datetime.date(2024, 2, 17), 'Velas Jiménez'),
#  (1, 'Tienda Centro', 1218, datetime.date(2024, 2, 17), 'Esponjas Pérez'),
#  (1, 'Tienda Centro', 1222, datetime.date(2024, 2, 17), 'Chicles Rodríguez'),
#  (1, 'Tienda Centro', 1223, datetime.date(2024, 2, 17), 'Chocolate Ortiz'),
#  (1, 'Tienda Centro', 1228, datetime.date(2024, 2, 18), 'Cebolla Ruiz'),
#  (1, 'Tienda Centro', 1257, datetime.date(2024, 2, 19), 'Detergente Fuentes'),
#  (1, 'Tienda Centro', 1260, datetime.date(2024, 2, 19), 'Galletas Ramos'),
#  (1, 'Tienda Centro', 1264, datetime.date(2024, 2, 19), 'Tomate Campos'),
#  (1, 'Tienda Centro', 1267, datetime.date(2024, 2, 19), 'Cerdo Ruiz'),
#  (1, 'Tienda Centro', 1269, datetime.date(2024, 2, 19), 'Pilas Díaz'),
#  (1, 'Tienda Centro', 1273, datetime.date(2024, 2, 19), 'Mantequilla Lara'),
#  (1, 'Tienda Centro', 1275, datetime.date(2024, 2, 19), 'Chocolate Hernández'),
#  (1, 'Tienda Centro', 1282, datetime.date(2024, 2, 20), 'Chicles Campos'),
#  (1, 'Tienda Centro', 1285, datetime.date(2024, 2, 20), 'Colonia Álvarez'),
#  (1,
#   'Tienda Centro',
#   1291,
#   datetime.date(2024, 2, 20),
#   'Desinfectante Molina'),
#  (1, 'Tienda Centro', 1307, datetime.date(2024, 2, 20), 'Mantequilla Torres'),
#  (1, 'Tienda Centro', 1312, datetime.date(2024, 2, 21), 'Carne de res Ortiz'),
#  (1,
#   'Tienda Centro',
#   1314,
#   datetime.date(2024, 2, 21),
#   'Bolsas de basura Cruz'),
#  (1,
#   'Tienda Centro',
#   1340,
#   datetime.date(2024, 2, 22),
#   'Jabón líquido Ramírez'),
#  (1, 'Tienda Centro', 1343, datetime.date(2024, 2, 22), 'Fertilizante Cruz'),
#  (1, 'Tienda Centro', 1349, datetime.date(2024, 2, 22), 'Mantequilla Romero'),
#  (1,
#   'Tienda Centro',
#   1352,
#   datetime.date(2024, 2, 22),
#   'Bolsas de basura Fernández'),
#  (1,
#   'Tienda Centro',
#   1357,
#   datetime.date(2024, 2, 22),
#   'Tierra para macetas Pérez'),
#  (1, 'Tienda Centro', 1366, datetime.date(2024, 2, 23), 'Zanahoria Cabrera'),
#  (1, 'Tienda Centro', 1377, datetime.date(2024, 2, 23), 'Detergente Ramírez'),
#  (1, 'Tienda Centro', 1378, datetime.date(2024, 2, 23), 'Cebolla Jiménez'),
#  (1, 'Tienda Centro', 1384, datetime.date(2024, 2, 23), 'Pilas Martínez'),
#  (1, 'Tienda Centro', 1389, datetime.date(2024, 2, 23), 'Leche García'),
#  (1, 'Tienda Centro', 1394, datetime.date(2024, 2, 24), 'Agua Hernández'),
#  (1, 'Tienda Centro', 1397, datetime.date(2024, 2, 24), 'Zanahoria Cabrera'),
#  (1, 'Tienda Centro', 1398, datetime.date(2024, 2, 24), 'Pilas Cabrera'),
#  (1, 'Tienda Centro', 1400, datetime.date(2024, 2, 24), 'Banana Vázquez'),
#  (1, 'Tienda Centro', 1402, datetime.date(2024, 2, 24), 'Fertilizante Moreno'),
#  (1, 'Tienda Centro', 1403, datetime.date(2024, 2, 24), 'Esponjas Aguilar'),
#  (1, 'Tienda Centro', 1417, datetime.date(2024, 2, 25), 'Banana Jiménez'),
#  (1, 'Tienda Centro', 1418, datetime.date(2024, 2, 25), 'Zanahoria Hernández'),
#  (1, 'Tienda Centro', 1423, datetime.date(2024, 2, 25), 'Pollo Martínez'),
#  (1, 'Tienda Centro', 1425, datetime.date(2024, 2, 25), 'Chocolate Martínez'),
#  (1, 'Tienda Centro', 1437, datetime.date(2024, 2, 26), 'Lechuga Jiménez'),
#  (1,
#   'Tienda Centro',
#   1455,
#   datetime.date(2024, 2, 26),
#   'Crema hidratante Fuentes'),
#  (1, 'Tienda Centro', 1461, datetime.date(2024, 2, 27), 'Cerveza García'),
#  (1, 'Tienda Centro', 1475, datetime.date(2024, 2, 27), 'Mantequilla Aguilar'),
#  (1, 'Tienda Centro', 1479, datetime.date(2024, 2, 27), 'Zanahoria García'),
#  (1, 'Tienda Centro', 1483, datetime.date(2024, 2, 27), 'Zanahoria Velázquez'),
#  (1,
#   'Tienda Centro',
#   1498,
#   datetime.date(2024, 2, 28),
#   'Jabón líquido Chávez'),
#  (1, 'Tienda Centro', 1514, datetime.date(2024, 2, 28), 'Lechuga Salinas'),
#  (1,
#   'Tienda Centro',
#   1516,
#   datetime.date(2024, 2, 28),
#   'Crema hidratante Cruz'),
#  (1, 'Tienda Centro', 1520, datetime.date(2024, 2, 28), 'Fertilizante Ortiz'),
#  (1, 'Tienda Centro', 1529, datetime.date(2024, 2, 29), 'Naranja Jiménez'),
#  (1, 'Tienda Centro', 1532, datetime.date(2024, 2, 29), 'Zanahoria Velázquez'),
#  (1, 'Tienda Centro', 1546, datetime.date(2024, 2, 29), 'Naranja Guzmán')]

# %% [markdown]
# * 7.-Ranking de productos más vendidos en cada tienda
#
#
#     * Para cada tienda, muestra los 3 productos más vendidos (en términos de cantidad total).
#     * Tendrás que unir tiendas, empleados, ordenes y detalle_orden, además de productos.
#     * Usa GROUP BY y ordena por la cantidad sumada (y opcionalmente, un LIMIT 3).

# %%
		
sql = ('WITH ranking_productos AS (SELECT t.nombre_tienda, p.nombre_producto, SUM(do.cantidad) AS total_vendido, ROW_NUMBER() OVER (PARTITION BY t.id_tienda ORDER BY SUM(do.cantidad) DESC) AS ranking FROM tiendas t JOIN empleados e ON t.id_tienda = e.id_tienda JOIN ordenes o ON e.id_empleado = o.id_empleado JOIN detalle_orden do ON o.id_orden = do.id_orden JOIN productos p ON do.id_producto = p.id_producto GROUP BY t.id_tienda, t.nombre_tienda, p.id_producto, p.nombre_producto) SELECT nombre_tienda, nombre_producto, total_vendido FROM ranking_productos WHERE ranking <= 3 ORDER BY nombre_tienda, ranking;')
consultas(sql)
# Out:
# [('Central Tiendas', 'Semillas', 1560.0),
#  ('Central Tiendas', 'Pilas', 1412.0),
#  ('Central Tiendas', 'Chocolate', 1390.0),
#  ('Tienda Centro', 'Zanahoria', 1479.0),
#  ('Tienda Centro', 'Platos desechables', 1424.0),
#  ('Tienda Centro', 'Chocolate', 1389.0),
#  ('Tienda Este', 'Desinfectante', 1291.0),
#  ('Tienda Este', 'Esponjas', 1265.0),
#  ('Tienda Este', 'Chicles', 1234.0),
#  ('Tienda Norte', 'Jugo de naranja', 1307.0),
#  ('Tienda Norte', 'Carne de res', 1297.0),
#  ('Tienda Norte', 'Chocolate', 1287.0),
#  ('Tienda Oeste', 'Cerveza', 1578.0),
#  ('Tienda Oeste', 'Tierra para macetas', 1410.0),
#  ('Tienda Oeste', 'Cerdo', 1397.0),
#  ('Tienda Poniente', 'Tierra para macetas', 1440.0),
#  ('Tienda Poniente', 'Papas fritas', 1433.0),
#  ('Tienda Poniente', 'Uva', 1391.0),
#  ('Tienda Sur', 'Semillas', 1422.0),
#  ('Tienda Sur', 'Crema hidratante', 1411.0),
#  ('Tienda Sur', 'Champú', 1336.0)]
