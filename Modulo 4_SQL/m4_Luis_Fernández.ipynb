# %% [markdown]
# ## 1.- Crear Base de Datos

# %% [markdown]
# * Crear con código SQL una base de datos llamada supermercado.
# * Código Python con mysql connector que ejecute el SQL para borrar y generar la base de datos vacía

# %%
# Ejercicio 1 - Crear base de datos estudiantes
import mysql.connector as con
def crear_bd(sql):
    try:
       connection = con.connect(
            host="localhost",
            port="3306",
            user="root",
            password="ADMIN",
            database='supermercado'
        )
       cursor = connection.cursor()
       cursor.execute(sql)
       
    except con.Error as error:
      print(f"Ha ocurrido un error: {error}") 
      if connection:
         connection.rollback()
         return 0
    finally:
        if cursor: 
            cursor.close()
        if connection:
            connection.close()

# %%
sql = "DROP DATABASE IF EXISTS supermercado; CREATE DATABASE IF NOT EXISTS supermercado;"

# %%
crear_bd(sql)

# %% [markdown]
# # Tablas SQL

# %% [markdown]
# * Tiendas
#
#    * id_tienda (PRIMARY KEY)
#    * nombre_tienda
#    * direccion
#    * ciudad

# %%
sql = "CREATE TABLE IF NOT EXISTS tiendas (id_tienda INT AUTO_INCREMENT PRIMARY KEY, nombre_tienda VARCHAR(100) NOT NULL, dirección VARCHAR(80), ciudad VARCHAR(50) NOT NULL);"

# %%
crear_bd(sql)

# %% [markdown]
# * Empleados
#     * id_empleado (PRIMARY KEY)
#     * nombre_empleado
#     * puesto (ej.: Cajero, Gerente, Reponedor)
#     * id_tienda (FOREIGN KEY que hace referencia a tiendas.id_tienda)

# %%
sql = "CREATE TABLE IF NOT EXISTS empleados (id_empleado INT AUTO_INCREMENT PRIMARY KEY, nombre_empleado VARCHAR(100) NOT NULL, puesto VARCHAR(60), id_tienda INT NOT NULL, FOREIGN KEY (id_tienda) REFERENCES tiendas(id_tienda) ON DELETE CASCADE);"

# %%
crear_bd(sql)

# %% [markdown]
# * Categorias
#     * id_categoria (PRIMARY KEY)
#     * nombre_categoria

# %%
sql = "CREATE TABLE IF NOT EXISTS categorias (id_categoria INT AUTO_INCREMENT PRIMARY KEY, nombre_categoria VARCHAR(60));"

# %%
crear_bd(sql)

# %% [markdown]
# * Productos
#     * id_producto (PRIMARY KEY)
#     * nombre_producto
#     * precio
#     * stock
#     * id_categoria (FOREIGN KEY que hace referencia a categorias.id_categoria)

# %%
sql = "CREATE TABLE IF NOT EXISTS productos (id_producto INT AUTO_INCREMENT PRIMARY KEY, nombre_producto VARCHAR(70), precio FLOAT(8,2), stock INT, id_categoria INT NOT NULL, FOREIGN KEY (id_categoria) REFERENCES categorias(id_categoria));"

# %%
crear_bd(sql)

# %% [markdown]
# * Clientes
#     * id_cliente (PRIMARY KEY)
#     * first_name
#     * last_name
#     * email
#     * codigo_postal

# %%
sql = "CREATE TABLE IF NOT EXISTS clientes (id_cliente INT AUTO_INCREMENT PRIMARY KEY, first_name VARCHAR(50), last_name VARCHAR(50), email VARCHAR(100), codigo_postal INT);"

# %%
crear_bd(sql)

# %% [markdown]
# * Ordenes
#     * id_orden (PRIMARY KEY)
#     * id_cliente (FOREIGN KEY que hace referencia a clientes.id_cliente)
#     * id_empleado (FOREIGN KEY que hace referencia a empleados.id_empleado)
#     * fecha_orden
#     * metodo_pago (una enum que solo admita tres valores Tarjeta, Efectivo)

# %%
sql = "CREATE TABLE IF NOT EXISTS ordenes (id_orden INT AUTO_INCREMENT PRIMARY KEY, id_cliente INT, id_empleado INT, fecha_orden DATE, metodo_pago ENUM('Tarjeta', 'Efectivo') DEFAULT 'Efectivo', FOREIGN KEY (id_cliente) REFERENCES clientes(id_cliente), FOREIGN KEY (id_empleado) REFERENCES empleados(id_empleado));"

# %%
crear_bd(sql)

# %% [markdown]
# * Detalle_orden
#     * id_detalle (PRIMARY KEY)
#     * id_orden (FOREIGN KEY que hace referencia a ordenes.id_orden) NOT NULL
#     * id_producto (FOREIGN KEY que hace referencia a productos.id_producto) NOT NULL
#     * cantidad
#     * precio_unitario: mismo precio que en la tabla producto
#     * descuento (podría ser NULL si no se aplica)

# %%
sql = "CREATE TABLE IF NOT EXISTS detalle_orden (id_detalle INT AUTO_INCREMENT PRIMARY KEY, id_orden INT NOT NULL, id_producto INT NOT NULL, cantidad FLOAT(8,2), precio_unitario FLOAT(8,2), descuento TINYINT, FOREIGN KEY (id_orden) REFERENCES ordenes(id_orden), FOREIGN KEY (id_producto) REFERENCES productos(id_producto));"

# %%
crear_bd(sql)

# %% [markdown]
# # Tablas

# %% [markdown]
# ## 2.- Generar datos demo desde Python

# %%
def insertar_dataframe(df, table_name):
    try:
        connection = con.connect(
            host="localhost",
            port="3306",
            user="root",
            password="ADMIN",
            database='supermercado'
        )
        cursor = connection.cursor()
        
        columns = ','.join(df.columns)
        placeholders = ','.join(['%s'] * len(df.columns))
        sql = f'INSERT INTO {table_name} ({columns}) VALUES ({placeholders});'
    
        rows = [tuple(row) for index, row in df.iterrows()] # lista de tuplas con los datos del dataframe

        cursor.executemany(sql, rows)
        
        connection.commit()
        return cursor.rowcount
    except con.Error as error:
        print(f"Ha ocurrido un error: {error}")
        if connection:
            connection.rollback()
        return 0
    finally:
        if cursor: 
            cursor.close()
        if connection:
            connection.close()

# %% [markdown]
# * Tabla Tiendas

# %%
import pandas as pd
import random
import datetime

tiendas = ['Tienda Centro','Tienda Norte','Tienda Sur','Tienda Poniente','Tienda Este','Tienda Oeste','Central Tiendas']
tiendas

dirección = ['Avd.Centro,nº1','Calle Norte, nº2','Calle Sur, nº3', 'Avd. Poniente, nº4','Calle Este, nº5','Calle Oeste, nº6', 'Crta.Central, Km10']
   
dirección

# Ciudad

ciudad= ['Almería','Girona','Murcia','Barcelona','Orense','Gijón','Madrid' ] 
ciudad 

# Creamos un DataFrame 

df_tiendas = pd.DataFrame(zip(tiendas, dirección, ciudad),
             columns= ['nombre_tienda', 'dirección', 'ciudad']) # El comando Zip empaqueta todas las variante hemos hecho | y con columns damos nombres a las columnas

# Añadir columna Pk:

df_tiendas = df_tiendas.reset_index().rename({'index': 'id_tienda'}, axis=1)
df_tiendas['id_tienda'] = df_tiendas['id_tienda'] + 1
df_tiendas
# Out:
#    id_tienda    nombre_tienda           dirección     ciudad
# 0          1    Tienda Centro      Avd.Centro,nº1    Almería
# 1          2     Tienda Norte    Calle Norte, nº2     Girona
# 2          3       Tienda Sur      Calle Sur, nº3     Murcia
# 3          4  Tienda Poniente  Avd. Poniente, nº4  Barcelona
# 4          5      Tienda Este     Calle Este, nº5     Orense
# 5          6     Tienda Oeste    Calle Oeste, nº6      Gijón
# 6          7  Central Tiendas  Crta.Central, Km10     Madrid

# %%
insertar_dataframe(df_tiendas, 'tiendas')
# Out:
# 7

# %% [markdown]
# * Tabla Empleados

# %%
# Creamos lista de empleados | Nombre,Apellidos,Función
empleados = list()
nombres = ['Alejandro', 'María', 'Carlos', 'Lucía', 'Fernando', 'Isabel', 'Javier', 'Ana', 'Miguel', 'Sofía', 'José', 'Clara', 'Luis', 'Elena', 'Daniel', 'Marta', 'Andrés', 'Laura', 'Raúl', 'Paula', 'Manuel', 'Sara', 'Pablo', 'Julia', 'Sergio', 'Valeria', 'Tomás', 'Adriana', 'Eduardo', 'Camila', 'Francisco', 'Diana', 'Ricardo', 'Patricia', 'Ángel', 'Carla', 'Diego', 'Irene', 'Samuel', 'Eva', 'David', 'Andrea', 'Hugo', 'Verónica', 'Cristian', 'Gabriela', 'Mario', 'Natalia', 'Jorge', 'Lorena', 'Rubén', 'Carmen']
apellidos = ['García', 'Martínez', 'López', 'Sánchez', 'Pérez', 'González', 'Rodríguez', 'Fernández', 'Hernández', 'Jiménez', 'Ruiz', 'Díaz', 'Moreno', 'Álvarez', 'Romero', 'Torres', 'Vázquez', 'Domínguez', 'Ramos', 'Ramírez', 'Castro', 'Ortiz', 'Rubio', 'Molina', 'Delgado', 'Cruz', 'Flores', 'Navarro', 'Cabrera', 'Campos', 'Peña', 'Aguilar', 'Santos', 'Reyes', 'Méndez', 'Medina', 'Paredes', 'Serrano', 'Cortés', 'Carrillo', 'Ortiz', 'Velázquez', 'Chávez', 'Guzmán', 'Salinas', 'Esquivel', 'Lara', 'Fuentes', 'Montes']
función = ["Cajero", "Reponedor", "Encargado de sección", "Gerente", "Personal de limpieza", "Panadero", "Carnicero", "Pescadero", "Frutero", "Charcutero", "Jefe de turno", "Operador logístico", "Atención al cliente", "Auxiliar de caja", "Encargado de seguridad","Responsable de zona","Jefe de compras","Encargada carnicería","encargado pescadería","Jefe de Limpieza"]
for tienda in df_tiendas['id_tienda']:
    for empleado in range(20):
        nombre_empleado = (random.choice(nombres) + ' ' + random.choice(apellidos))
        puesto = función[empleado]
        id_tienda = tienda
        empleados.append([nombre_empleado, puesto, id_tienda])
        
# Creamos un DataFrame         
df_empleados = pd.DataFrame(empleados, columns=['nombre_empleado', 'puesto', 'id_tienda'])
        
df_empleados = df_empleados.reset_index().rename({'index': 'id_empleado'}, axis=1)
df_empleados['id_empleado'] = df_empleados['id_empleado'] + 1
df_empleados
# Out:
#      id_empleado   nombre_empleado                puesto  id_tienda
# 0              1       Marta Ortiz                Cajero          1
# 1              2  Francisco García             Reponedor          1
# 2              3      Diego Méndez  Encargado de sección          1
# 3              4      Hugo Sánchez               Gerente          1
# 4              5    Ricardo Chávez  Personal de limpieza          1
# ..           ...               ...                   ...        ...
# 135          136     Diego Salinas   Responsable de zona          7
# 136          137  Ricardo González       Jefe de compras          7
# 137          138    Gabriela Reyes  Encargada carnicería          7
# 138          139        Carla Ruiz  encargado pescadería          7
# 139          140     Carmen Guzmán      Jefe de Limpieza          7
#
# [140 rows x 4 columns]

# %%
insertar_dataframe(df_empleados, "empleados")
# Out:
# 140

# %% [markdown]
# * Tabla Categorías

# %%
categorias = ['Lácteos','Pescados','Carnes','Verduras','Frutas','Bollería y Pan','Refrescos','Vinos','Alcohol','Congelados']

df_categorias= pd.DataFrame(categorias,columns= ['nombre_categoria'])

# Añadir columna pk:

df_categorias = df_categorias.reset_index().rename({'index': 'id_categoria'}, axis=1)
df_categorias['id_categoria'] = df_categorias['id_categoria'] + 1
df_categorias
# Out:
#    id_categoria nombre_categoria
# 0             1          Lácteos
# 1             2         Pescados
# 2             3           Carnes
# 3             4         Verduras
# 4             5           Frutas
# 5             6   Bollería y Pan
# 6             7        Refrescos
# 7             8            Vinos
# 8             9          Alcohol
# 9            10       Congelados

# %%
insertar_dataframe(df_categorias, 'categorias')
# Out:
# 10

# %% [markdown]
# * Productos
#
#     * id_producto: valores enteros consecutivos (1, 2, 3...).
#     * nombre_producto: nombres como “Leche Entera”, “Manzana Roja”, “Refresco de Cola”, etc.
#     * precio: valores DECIMAL entre 0.50 y 50.00, por ejemplo.
#     * stock: valores INT entre 0 y 500 (o el rango que quieras).
#     * id_categoria: debe hacer referencia a las categorías que hayas definido (1, 2, 3, etc.).

# %%
# Listado de productos

# generar columna id_producto
nombres = ["Leche", "Yogur", "Queso", "Mantequilla", "Pollo", "Carne de res", "Cerdo", "Chuletas", "Manzana", "Banana", "Naranja", "Uva", "Zanahoria", "Tomate", "Lechuga", "Cebolla", "Agua", "Jugo de naranja", "Refresco", "Cerveza", "Papas fritas", "Chocolate", "Galletas", "Chicles", "Velas", "Platos desechables", "Bolsas de basura", "Pilas", "Detergente", "Jabón líquido", "Esponjas", "Desinfectante", "Champú", "Colonia", "Crema hidratante", "Desodorante", "Tierra para macetas", "Fertilizante", "Semillas", "Regadera"]
precios, lista_categorias, stock = list(), list(), list()
cantidad = len(nombres)
for _ in range(cantidad):
    precios.append(random.uniform(0.50, 10.50))
    stock.append(random.randint(0, 500))
for categ in df_categorias['id_categoria']:
    for i in range(4):
        lista_categorias.append(categ)
lista_categorias        
df_productos = pd.DataFrame(zip(nombres, precios, stock, lista_categorias), columns=['nombre_producto', 'precio', 'stock', 'id_categoria'])    
df_productos = df_productos.reset_index().rename({'index': 'id_producto'}, axis=1)
df_productos['id_producto'] = df_productos['id_producto'] + 1
df_productos
# Out:
#     id_producto      nombre_producto     precio  stock  id_categoria
# 0             1                Leche   6.445136    105             1
# 1             2                Yogur   6.207857    137             1
# 2             3                Queso   7.783960     52             1
# 3             4          Mantequilla   2.433183     41             1
# 4             5                Pollo  10.249431    106             2
# 5             6         Carne de res   2.615310    475             2
# 6             7                Cerdo   5.079113    116             2
# 7             8             Chuletas   2.256076    119             2
# 8             9              Manzana   8.907087    379             3
# 9            10               Banana   2.796899    408             3
# 10           11              Naranja   8.642637    500             3
# 11           12                  Uva   8.152836    131             3
# 12           13            Zanahoria   2.347095    397             4
# 13           14               Tomate   5.982700    138             4
# 14           15              Lechuga   4.989659    199             4
# 15           16              Cebolla   1.158131    401             4
# 16           17                 Agua   4.415957    254             5
# 17           18      Jugo de naranja   8.994806    245             5
# 18           19             Refresco   9.888601    295             5
# 19           20              Cerveza   6.194774    396             5
# 20           21         Papas fritas   7.864921    250             6
# 21           22            Chocolate   3.554086    400             6
# 22           23             Galletas   5.047426     97             6
# 23           24              Chicles   2.124405    484             6
# 24           25                Velas   7.660686    344             7
# 25           26   Platos desechables   4.057346    422             7
# 26           27     Bolsas de basura   5.603922    176             7
# 27           28                Pilas   4.095979    413             7
# 28           29           Detergente   4.843336    373             8
# 29           30        Jabón líquido   0.674148    330             8
# 30           31             Esponjas   6.856686      6             8
# 31           32        Desinfectante   9.217801    459             8
# 32           33               Champú   5.297965    447             9
# 33           34              Colonia   9.262326    341             9
# 34           35     Crema hidratante   7.873164    130             9
# 35           36          Desodorante   1.537251    103             9
# 36           37  Tierra para macetas   5.792149    268            10
# 37           38         Fertilizante   6.715852    294            10
# 38           39             Semillas   6.794064    376            10
# 39           40             Regadera   4.795184    221            10

# %%
insertar_dataframe(df_productos, 'productos')
# Out:
# 40

# %% [markdown]
# * Clientes
#
#     * id_cliente: valores enteros consecutivos (1, 2, 3...).
#     * nombre_cliente: nombres y apellidos ficticios (p. ej. “Carlos López”, “María Gil”).
#     * email: podrías generar correos ficticios (p. ej. “carlos.lopez@test.com”).
#     * telefono: número de 9 o 10 dígitos (dependiendo del país).
#     * direccion: calles y números ficticios (p. ej. “Av. Siempre Viva 742”).

# %%
# generar columna cliente
nombre_cliente, apellido_cliente, email, postal, cliente_completo = list(), list(), list(), list(), list()
calles = ("Av. Libertad", "Calle Mayor", "Paseo de la Reforma", "Calle Real", "Av. de la Constitución", "Calle del Sol", "Calle de la Luna", "Calle los Pinos", "Calle de la Paz", "Calle Olivo", "Calle Cedro", "Calle Nogal", "Av. de las Flores", "Paseo del Prado", "Calle del Río", "Av. Central", "Calle Primavera", "Calle Otoño", "Calle Invierno", "Calle Verano", "Calle Granada", "Calle Sevilla", "Calle Córdoba", "Calle Málaga", "Calle Valencia", "Calle Zaragoza", "Calle Alicante", "Av. de los Ángeles", "Calle del Carmen", "Calle San Miguel", "Calle San Juan", "Calle del Pilar", "Calle Santa Teresa", "Calle San Francisco", "Calle de la Sierra", "Calle del Mar", "Av. del Norte", "Av. del Sur", "Calle del Este", "Calle del Oeste", "Calle Diamante", "Calle Esmeralda", "Calle Rubí", "Calle Zafiro", "Calle Ámbar", "Calle Turquesa", "Calle Topacio", "Calle Perla", "Calle Horizonte", "Calle Amanecer")
for _ in range(2000):
    nom = random.choice(nombres)
    nombre_cliente.append(nom)
    ape = random.choice(apellidos)
    apellido_cliente.append(ape)
    email.append((f'{nom}.{ape}@mail.com'))
    postal.append(random.randint(0000, 11900))
    
df_clientes = pd.DataFrame(zip(nombre_cliente, apellido_cliente, email, postal), columns=['first_name', 'last_name', 'email', 'codigo_postal']) 
df_clientes = df_clientes.reset_index().rename({'index': 'id_cliente'}, axis=1)
df_clientes['id_cliente'] = df_clientes['id_cliente'] + 1
df_clientes
# Out:
#       id_cliente       first_name  last_name                            email  \
# 0              1    Desinfectante      Ramos     Desinfectante.Ramos@mail.com
# 1              2  Jugo de naranja     Moreno  Jugo de naranja.Moreno@mail.com
# 2              3            Leche     García            Leche.García@mail.com
# 3              4     Carne de res    Serrano    Carne de res.Serrano@mail.com
# 4              5  Jugo de naranja     Campos  Jugo de naranja.Campos@mail.com
# ...          ...              ...        ...                              ...
# 1995        1996          Manzana     Moreno          Manzana.Moreno@mail.com
# 1996        1997      Desodorante       Cruz        Desodorante.Cruz@mail.com
# 1997        1998      Mantequilla  Rodríguez   Mantequilla.Rodríguez@mail.com
# 1998        1999           Champú       Peña             Champú.Peña@mail.com
# 1999        2000           Champú      López            Champú.López@mail.com
#
#       codigo_postal
# 0              7028
# 1              4220
# 2              9665
# 3              6357
# 4              3618
# ...             ...
# 1995           6856
# 1996           1260
# 1997           4033
# 1998           9518
# 1999           9646
#
# [2000 rows x 5 columns]

# %%
insertar_dataframe(df_clientes, 'clientes')
# Out:
# 2000

# %% [markdown]
# * Orden
#     * id_orden: Valores enteros consecutivos
#     * id_cliente: Referencias de los Ids existentes en la tabla Clientes
#     * id_empleado: Refeferencias de los Ids existentes en la tabla Empleados
#     * fecha_orden: Generar fechas aleatorias o secuenciales
#     * metodo_pago: Escoger entre tarjeta o efectivo

# %%
# generar columna id_orden
from datetime import timedelta


cliente, emplea, fecha, metodo = list(), list(), list(), list()
fechas = [datetime.datetime(year=2024, month=1, day=1) + timedelta(days=numero) for numero in range(395)]
for _ in range(10000):
    cliente.append(random.choice(df_clientes['id_cliente']))
    emplea.append(random.choice(df_empleados['id_empleado']))
    fecha.append(random.choice(fechas))
    metodo.append(random.choices(['Tarjeta', 'Efectivo'], weights=[0.65, 0.35])[0])

fecha.sort()
df_ordenes = pd.DataFrame(zip(cliente, emplea, fecha, metodo), columns=['id_cliente', 'id_empleado', 'fecha_orden', 'metodo_pago'])

df_ordenes.sort_values('fecha_orden', inplace=True)
df_ordenes = df_ordenes.reset_index().rename({'index': 'id_orden'}, axis=1)
df_ordenes['id_orden'] = df_ordenes['id_orden'] + 1
df_ordenes.sort_values('id_orden', inplace=True)
df_ordenes.head(50)
# Out:
#     id_orden  id_cliente  id_empleado fecha_orden metodo_pago
# 0          1         303          128  2024-01-01     Tarjeta
# 16         2        1896          125  2024-01-01     Tarjeta
# 17         3        1208           95  2024-01-01    Efectivo
# 22         4         852           99  2024-01-01     Tarjeta
# 19         5        1174           59  2024-01-01     Tarjeta
# 20         6        1417          105  2024-01-01     Tarjeta
# 21         7         364          100  2024-01-01     Tarjeta
# 28         8         691           66  2024-01-01    Efectivo
# 23         9        1367           32  2024-01-01     Tarjeta
# 24        10        1515          122  2024-01-01     Tarjeta
# 25        11         698           77  2024-01-01    Efectivo
# 26        12         674          117  2024-01-01     Tarjeta
# 27        13         621           20  2024-01-01     Tarjeta
# 15        14        1092           74  2024-01-01     Tarjeta
# 18        15         689          125  2024-01-01     Tarjeta
# 13        16        1369           65  2024-01-01    Efectivo
# 12        17         584            1  2024-01-01    Efectivo
# 11        18         507           89  2024-01-01    Efectivo
# 10        19          61           40  2024-01-01     Tarjeta
# 14        20        1088           59  2024-01-01     Tarjeta
# 9         21        1950          109  2024-01-01    Efectivo
# 8         22         276          100  2024-01-01    Efectivo
# 7         23        1053           86  2024-01-01    Efectivo
# 6         24         452            3  2024-01-01     Tarjeta
# 5         25        1410          134  2024-01-01     Tarjeta
# 4         26        1192          109  2024-01-01     Tarjeta
# 3         27         367           43  2024-01-01     Tarjeta
# 2         28        1618          113  2024-01-01     Tarjeta
# 1         29         787           26  2024-01-01     Tarjeta
# 48        30         365           57  2024-01-02    Efectivo
# 47        31         823           78  2024-01-02     Tarjeta
# 39        32         694           89  2024-01-02     Tarjeta
# 46        33        1271           18  2024-01-02    Efectivo
# 45        34         233           57  2024-01-02     Tarjeta
# 44        35        1523           43  2024-01-02     Tarjeta
# 43        36         106           92  2024-01-02    Efectivo
# 42        37         729           91  2024-01-02     Tarjeta
# 41        38          35          106  2024-01-02    Efectivo
# 40        39         431           63  2024-01-02     Tarjeta
# 49        40         115           82  2024-01-02    Efectivo
# 38        41        1249           90  2024-01-02    Efectivo
# 29        42        1062           76  2024-01-02     Tarjeta
# 37        43        1944          140  2024-01-02    Efectivo
# 36        44        1812           86  2024-01-02     Tarjeta
# 35        45         375            6  2024-01-02     Tarjeta
# 34        46        1063           95  2024-01-02     Tarjeta
# 33        47         518           21  2024-01-02     Tarjeta
# 32        48        1316          114  2024-01-02     Tarjeta
# 31        49        1511          117  2024-01-02     Tarjeta
# 30        50         723           33  2024-01-02     Tarjeta

# %%
insertar_dataframe(df_ordenes, 'ordenes')
# Out:
# 10000

# %% [markdown]
# * Detalles de ordenes
#     * id_detalle: Valores enterors consecutivos
#     * id_orden: Referencia al Id de alguna orden válida
#     * id_producto: Referencia al ID
#     * Cantidad: Valores entre 1 y 20
#     * Precio_unitario: Usando en mismo precio está en la tabla productos
#     * Descuento: Valores Decimales bajos

# %%
# generar columna id_detalle

orden_completa = list()
productos = df_productos['id_producto']
orden_20 = df_ordenes['id_orden']

for orden in df_ordenes['id_orden']:
    ordenes = orden
    producto = (int(random.choice(productos)))
    cant = random.randint(1, 20)
    valor = float(df_productos['precio'][df_productos['id_producto'] == producto].iloc[0])
    descuento = random.uniform(0, 0.25)
    orden_completa.append([ordenes, producto, cant, round(valor, 2), round(descuento, 2)])   
    
for orden in range(20000):
    ordenes = random.choice(orden_20)
    producto = (int(random.choice(productos)))
    cant = random.randint(1, 20)
    valor = float(df_productos['precio'][df_productos['id_producto'] == producto].iloc[0])
    descuento = random.uniform(0, 0.25)
    orden_completa.append([ordenes, producto, cant, round(valor,2), round(descuento, 2)])   
    
df_detalle_orden = pd.DataFrame(orden_completa, columns=['id_orden', 'id_producto', 'cantidad', 'precio_unitario', 'descuento'])

df_detalle_orden = df_detalle_orden.reset_index().rename({'index': 'id_detalle'}, axis=1)
df_detalle_orden['id_detalle'] = df_detalle_orden['id_detalle'] + 1
df_detalle_orden
# Out:
#        id_detalle  id_orden  id_producto  cantidad  precio_unitario  descuento
# 0               1         1            9         9             8.91       0.03
# 1               2         2           26        16             4.06       0.24
# 2               3         3           25        11             7.66       0.22
# 3               4         4           19         8             9.89       0.08
# 4               5         5           17         8             4.42       0.12
# ...           ...       ...          ...       ...              ...        ...
# 29995       29996      5378           21        12             7.86       0.01
# 29996       29997       256           23         5             5.05       0.03
# 29997       29998      3432            7        19             5.08       0.09
# 29998       29999      1654           29        14             4.84       0.22
# 29999       30000      4065           26        20             4.06       0.02
#
# [30000 rows x 6 columns]

# %%
insertar_dataframe(df_detalle_orden, 'detalle_orden')
# Out:
# 30000

# %% [markdown]
# ## 3.- Consultas SQL

# %%
def consultas(sql):
    try:
        connection = con.connect(
            host="localhost",
            port="3306",
            user="root",
            password="ADMIN",
            database='supermercado'
        )
        cursor = connection.cursor()
        cursor.execute(sql)
        return cursor.fetchall()
    except con.Error as error:
        print(f"Ha ocurrido un error: {error}")
        if connection:
            connection.rollback()
        return 0
    finally:
        if cursor: 
            cursor.close()
        if connection:
            connection.close()

# %% [markdown]
# * 1.-Listado de órdenes con detalles de cliente y empleado
#
#     * Muestra el ID de la orden, la fecha, el nombre del cliente, el nombre del empleado que atendió la compra y el método de pago.
#     * Utiliza un JOIN entre las tablas ordenes, clientes y empleados

# %%
sql = ('SELECT o.id_orden, o.fecha_orden, c.first_name, c.last_name, e.nombre_empleado, o.metodo_pago FROM ordenes o JOIN clientes c ON c.id_cliente = o.id_cliente JOIN empleados e ON e.id_empleado = o.id_empleado ORDER BY o.id_orden;') 
consultas(sql)
# Out:
# [(1,
#   datetime.date(2024, 1, 1),
#   'Manzana',
#   'Guzmán',
#   'Adriana Rubio',
#   'Tarjeta'),
#  (2,
#   datetime.date(2024, 1, 1),
#   'Yogur',
#   'Sánchez',
#   'Daniel Serrano',
#   'Tarjeta'),
#  (3, datetime.date(2024, 1, 1), 'Agua', 'Ortiz', 'Raúl Serrano', 'Efectivo'),
#  (4,
#   datetime.date(2024, 1, 1),
#   'Papas fritas',
#   'Delgado',
#   'Fernando Castro',
#   'Tarjeta'),
#  (5,
#   datetime.date(2024, 1, 1),
#   'Esponjas',
#   'Serrano',
#   'Julia Fuentes',
#   'Tarjeta'),
#  (6,
#   datetime.date(2024, 1, 1),
#   'Chuletas',
#   'García',
#   'Adriana Navarro',
#   'Tarjeta'),
#  (7,
#   datetime.date(2024, 1, 1),
#   'Detergente',
#   'Delgado',
#   'Ana Velázquez',
#   'Tarjeta'),
#  (8,
#   datetime.date(2024, 1, 1),
#   'Manzana',
#   'Cabrera',
#   'Javier García',
#   'Efectivo'),
#  (9,
#   datetime.date(2024, 1, 1),
#   'Platos desechables',
#   'Ruiz',
#   'Carlos Torres',
#   'Tarjeta'),
#  (10,
#   datetime.date(2024, 1, 1),
#   'Galletas',
#   'Aguilar',
#   'José Ramírez',
#   'Tarjeta'),
#  (11,
#   datetime.date(2024, 1, 1),
#   'Refresco',
#   'Aguilar',
#   'Diana Navarro',
#   'Efectivo'),
#  (12,
#   datetime.date(2024, 1, 1),
#   'Tomate',
#   'Romero',
#   'Luis Esquivel',
#   'Tarjeta'),
#  (13,
#   datetime.date(2024, 1, 1),
#   'Uva',
#   'Salinas',
#   'Isabel Carrillo',
#   'Tarjeta'),
#  (14, datetime.date(2024, 1, 1), 'Queso', 'Guzmán', 'Hugo Guzmán', 'Tarjeta'),
#  (15,
#   datetime.date(2024, 1, 1),
#   'Semillas',
#   'Romero',
#   'Daniel Serrano',
#   'Tarjeta'),
#  (16,
#   datetime.date(2024, 1, 1),
#   'Naranja',
#   'Reyes',
#   'Pablo Jiménez',
#   'Efectivo'),
#  (17,
#   datetime.date(2024, 1, 1),
#   'Lechuga',
#   'Flores',
#   'Marta Ortiz',
#   'Efectivo'),
#  (18,
#   datetime.date(2024, 1, 1),
#   'Uva',
#   'Cortés',
#   'Eduardo Flores',
#   'Efectivo'),
#  (19,
#   datetime.date(2024, 1, 1),
#   'Cebolla',
#   'Vázquez',
#   'Ana Fernández',
#   'Tarjeta'),
#  (20,
#   datetime.date(2024, 1, 1),
#   'Desinfectante',
#   'Aguilar',
#   'Julia Fuentes',
#   'Tarjeta'),
#  (21,
#   datetime.date(2024, 1, 1),
#   'Pollo',
#   'Hernández',
#   'Lucía López',
#   'Efectivo'),
#  (22,
#   datetime.date(2024, 1, 1),
#   'Carne de res',
#   'Castro',
#   'Ana Velázquez',
#   'Efectivo'),
#  (23, datetime.date(2024, 1, 1), 'Velas', 'Ortiz', 'Carla Méndez', 'Efectivo'),
#  (24,
#   datetime.date(2024, 1, 1),
#   'Manzana',
#   'Delgado',
#   'Diego Méndez',
#   'Tarjeta'),
#  (25,
#   datetime.date(2024, 1, 1),
#   'Chuletas',
#   'Romero',
#   'Paula Ortiz',
#   'Tarjeta'),
#  (26, datetime.date(2024, 1, 1), 'Manzana', 'Peña', 'Lucía López', 'Tarjeta'),
#  (27,
#   datetime.date(2024, 1, 1),
#   'Semillas',
#   'González',
#   'Elena Cabrera',
#   'Tarjeta'),
#  (28,
#   datetime.date(2024, 1, 1),
#   'Jabón líquido',
#   'Méndez',
#   'Daniel Ruiz',
#   'Tarjeta'),
#  (29,
#   datetime.date(2024, 1, 1),
#   'Jugo de naranja',
#   'González',
#   'Manuel Ramos',
#   'Tarjeta'),
#  (30,
#   datetime.date(2024, 1, 2),
#   'Desodorante',
#   'Romero',
#   'Carlos Esquivel',
#   'Efectivo'),
#  (31,
#   datetime.date(2024, 1, 2),
#   'Platos desechables',
#   'Esquivel',
#   'Samuel Sánchez',
#   'Tarjeta'),
#  (32,
#   datetime.date(2024, 1, 2),
#   'Desinfectante',
#   'Cruz',
#   'Eduardo Flores',
#   'Tarjeta'),
#  (33,
#   datetime.date(2024, 1, 2),
#   'Cerveza',
#   'Peña',
#   'Raúl González',
#   'Efectivo'),
#  (34,
#   datetime.date(2024, 1, 2),
#   'Jabón líquido',
#   'Cortés',
#   'Carlos Esquivel',
#   'Tarjeta'),
#  (35,
#   datetime.date(2024, 1, 2),
#   'Chocolate',
#   'Rodríguez',
#   'Elena Cabrera',
#   'Tarjeta'),
#  (36,
#   datetime.date(2024, 1, 2),
#   'Esponjas',
#   'Pérez',
#   'Carmen González',
#   'Efectivo'),
#  (37,
#   datetime.date(2024, 1, 2),
#   'Refresco',
#   'Reyes',
#   'Laura Ortiz',
#   'Tarjeta'),
#  (38,
#   datetime.date(2024, 1, 2),
#   'Banana',
#   'Santos',
#   'Luis Salinas',
#   'Efectivo'),
#  (39,
#   datetime.date(2024, 1, 2),
#   'Jabón líquido',
#   'Chávez',
#   'Cristian Díaz',
#   'Tarjeta'),
#  (40,
#   datetime.date(2024, 1, 2),
#   'Chicles',
#   'Navarro',
#   'Lucía Pérez',
#   'Efectivo'),
#  (41,
#   datetime.date(2024, 1, 2),
#   'Chicles',
#   'Chávez',
#   'Jorge Rodríguez',
#   'Efectivo'),
#  (42, datetime.date(2024, 1, 2), 'Champú', 'Guzmán', 'Laura López', 'Tarjeta'),
#  (43,
#   datetime.date(2024, 1, 2),
#   'Tomate',
#   'Hernández',
#   'Carmen Guzmán',
#   'Efectivo'),
#  (44,
#   datetime.date(2024, 1, 2),
#   'Papas fritas',
#   'Reyes',
#   'Carla Méndez',
#   'Tarjeta'),
#  (45,
#   datetime.date(2024, 1, 2),
#   'Tomate',
#   'Paredes',
#   'David Rubio',
#   'Tarjeta'),
#  (46,
#   datetime.date(2024, 1, 2),
#   'Esponjas',
#   'Ruiz',
#   'Raúl Serrano',
#   'Tarjeta'),
#  (47,
#   datetime.date(2024, 1, 2),
#   'Yogur',
#   'Cortés',
#   'Carla Cabrera',
#   'Tarjeta'),
#  (48,
#   datetime.date(2024, 1, 2),
#   'Manzana',
#   'Guzmán',
#   'María Castro',
#   'Tarjeta'),
#  (49,
#   datetime.date(2024, 1, 2),
#   'Semillas',
#   'Cruz',
#   'Luis Esquivel',
#   'Tarjeta'),
#  (50,
#   datetime.date(2024, 1, 2),
#   'Manzana',
#   'Torres',
#   'Sara Fernández',
#   'Tarjeta'),
#  (51,
#   datetime.date(2024, 1, 3),
#   'Chuletas',
#   'Moreno',
#   'Carlos Torres',
#   'Efectivo'),
#  (52,
#   datetime.date(2024, 1, 3),
#   'Cebolla',
#   'Santos',
#   'Pablo Jiménez',
#   'Efectivo'),
#  (53,
#   datetime.date(2024, 1, 3),
#   'Carne de res',
#   'García',
#   'Clara Cabrera',
#   'Tarjeta'),
#  (54, datetime.date(2024, 1, 3), 'Pollo', 'Méndez', 'Sofía Lara', 'Efectivo'),
#  (55,
#   datetime.date(2024, 1, 3),
#   'Zanahoria',
#   'Ruiz',
#   'Francisco Romero',
#   'Tarjeta'),
#  (56, datetime.date(2024, 1, 3), 'Manzana', 'Ortiz', 'Carlos Lara', 'Tarjeta'),
#  (57,
#   datetime.date(2024, 1, 3),
#   'Pilas',
#   'Fernández',
#   'Adriana Guzmán',
#   'Tarjeta'),
#  (58,
#   datetime.date(2024, 1, 3),
#   'Tomate',
#   'Torres',
#   'Ana Velázquez',
#   'Tarjeta'),
#  (59,
#   datetime.date(2024, 1, 3),
#   'Chicles',
#   'Fernández',
#   'Julia Carrillo',
#   'Tarjeta'),
#  (60,
#   datetime.date(2024, 1, 3),
#   'Semillas',
#   'Esquivel',
#   'Diana Peña',
#   'Tarjeta'),
#  (61,
#   datetime.date(2024, 1, 3),
#   'Champú',
#   'Santos',
#   'Carmen González',
#   'Tarjeta'),
#  (62,
#   datetime.date(2024, 1, 3),
#   'Jugo de naranja',
#   'Ortiz',
#   'Samuel Fernández',
#   'Tarjeta'),
#  (63, datetime.date(2024, 1, 3), 'Uva', 'Esquivel', 'Diana Campos', 'Tarjeta'),
#  (64,
#   datetime.date(2024, 1, 3),
#   'Leche',
#   'Pérez',
#   'Irene Hernández',
#   'Tarjeta'),
#  (65,
#   datetime.date(2024, 1, 3),
#   'Queso',
#   'Carrillo',
#   'Irene Hernández',
#   'Tarjeta'),
#  (66,
#   datetime.date(2024, 1, 3),
#   'Cebolla',
#   'Molina',
#   'Cristian Rodríguez',
#   'Tarjeta'),
#  (67, datetime.date(2024, 1, 3), 'Pollo', 'Moreno', 'Mario Torres', 'Tarjeta'),
#  (68,
#   datetime.date(2024, 1, 3),
#   'Cerveza',
#   'Cruz',
#   'Carmen Guzmán',
#   'Efectivo'),
#  (69,
#   datetime.date(2024, 1, 3),
#   'Jabón líquido',
#   'Hernández',
#   'Irene Molina',
#   'Tarjeta'),
#  (70,
#   datetime.date(2024, 1, 3),
#   'Detergente',
#   'Hernández',
#   'Jorge Rodríguez',
#   'Efectivo'),
#  (71,
#   datetime.date(2024, 1, 3),
#   'Mantequilla',
#   'Rodríguez',
#   'Tomás Rubio',
#   'Tarjeta'),
#  (72,
#   datetime.date(2024, 1, 3),
#   'Esponjas',
#   'Molina',
#   'Irene Martínez',
#   'Tarjeta'),
#  (73,
#   datetime.date(2024, 1, 3),
#   'Queso',
#   'Moreno',
#   'Clara Delgado',
#   'Efectivo'),
#  (74,
#   datetime.date(2024, 1, 3),
#   'Papas fritas',
#   'Montes',
#   'Hugo Díaz',
#   'Efectivo'),
#  (75,
#   datetime.date(2024, 1, 3),
#   'Carne de res',
#   'Cruz',
#   'Raúl López',
#   'Efectivo'),
#  (76, datetime.date(2024, 1, 3), 'Queso', 'Lara', 'Lucía López', 'Efectivo'),
#  (77,
#   datetime.date(2024, 1, 3),
#   'Tomate',
#   'Romero',
#   'Eduardo Ortiz',
#   'Tarjeta'),
#  (78,
#   datetime.date(2024, 1, 3),
#   'Cerdo',
#   'Lara',
#   'Ricardo Campos',
#   'Efectivo'),
#  (79,
#   datetime.date(2024, 1, 3),
#   'Bolsas de basura',
#   'Campos',
#   'Eva Santos',
#   'Efectivo'),
#  (80,
#   datetime.date(2024, 1, 4),
#   'Lechuga',
#   'Sánchez',
#   'Adriana Guzmán',
#   'Tarjeta'),
#  (81,
#   datetime.date(2024, 1, 4),
#   'Esponjas',
#   'Delgado',
#   'Irene Hernández',
#   'Efectivo'),
#  (82,
#   datetime.date(2024, 1, 4),
#   'Cerveza',
#   'Cortés',
#   'Francisco Romero',
#   'Tarjeta'),
#  (83,
#   datetime.date(2024, 1, 4),
#   'Cerveza',
#   'Cortés',
#   'Carla Méndez',
#   'Tarjeta'),
#  (84, datetime.date(2024, 1, 4), 'Cerveza', 'Chávez', 'Sofía Lara', 'Tarjeta'),
#  (85, datetime.date(2024, 1, 4), 'Pollo', 'Lara', 'Sara Peña', 'Tarjeta'),
#  (86,
#   datetime.date(2024, 1, 4),
#   'Carne de res',
#   'Ortiz',
#   'Sara Salinas',
#   'Efectivo'),
#  (87,
#   datetime.date(2024, 1, 4),
#   'Banana',
#   'Fernández',
#   'Clara Salinas',
#   'Efectivo'),
#  (88,
#   datetime.date(2024, 1, 4),
#   'Yogur',
#   'Ortiz',
#   'Pablo Jiménez',
#   'Efectivo'),
#  (89,
#   datetime.date(2024, 1, 4),
#   'Semillas',
#   'Esquivel',
#   'Clara Delgado',
#   'Tarjeta'),
#  (90,
#   datetime.date(2024, 1, 4),
#   'Jugo de naranja',
#   'García',
#   'Daniel Aguilar',
#   'Efectivo'),
#  (91,
#   datetime.date(2024, 1, 4),
#   'Tomate',
#   'Torres',
#   'Jorge Cortés',
#   'Efectivo'),
#  (92,
#   datetime.date(2024, 1, 4),
#   'Jugo de naranja',
#   'Ramos',
#   'Lorena Rodríguez',
#   'Tarjeta'),
#  (93,
#   datetime.date(2024, 1, 4),
#   'Cerdo',
#   'Sánchez',
#   'Tomás Fernández',
#   'Tarjeta'),
#  (94,
#   datetime.date(2024, 1, 4),
#   'Naranja',
#   'Molina',
#   'Lucía López',
#   'Tarjeta'),
#  (95,
#   datetime.date(2024, 1, 4),
#   'Galletas',
#   'Martínez',
#   'Sofía Montes',
#   'Tarjeta'),
#  (96, datetime.date(2024, 1, 4), 'Esponjas', 'Torres', 'José Cruz', 'Tarjeta'),
#  (97,
#   datetime.date(2024, 1, 4),
#   'Carne de res',
#   'Ramos',
#   'David Santos',
#   'Efectivo'),
#  (98,
#   datetime.date(2024, 1, 4),
#   'Desodorante',
#   'Romero',
#   'Andrea Santos',
#   'Efectivo'),
#  (99,
#   datetime.date(2024, 1, 4),
#   'Esponjas',
#   'Cortés',
#   'Irene Martínez',
#   'Tarjeta'),
#  (100,
#   datetime.date(2024, 1, 4),
#   'Bolsas de basura',
#   'Medina',
#   'Francisco Romero',
#   'Tarjeta'),
#  (101,
#   datetime.date(2024, 1, 4),
#   'Chocolate',
#   'Rodríguez',
#   'Sara Moreno',
#   'Tarjeta'),
#  (102,
#   datetime.date(2024, 1, 4),
#   'Esponjas',
#   'Cortés',
#   'Andrés Ortiz',
#   'Tarjeta'),
#  (103,
#   datetime.date(2024, 1, 4),
#   'Tomate',
#   'Ortiz',
#   'Elena Guzmán',
#   'Tarjeta'),
#  (104,
#   datetime.date(2024, 1, 4),
#   'Zanahoria',
#   'Ortiz',
#   'Gabriela Reyes',
#   'Tarjeta'),
#  (105,
#   datetime.date(2024, 1, 4),
#   'Leche',
#   'Ruiz',
#   'Francisco Romero',
#   'Efectivo'),
#  (106,
#   datetime.date(2024, 1, 5),
#   'Papas fritas',
#   'Romero',
#   'Laura López',
#   'Tarjeta'),
#  (107,
#   datetime.date(2024, 1, 5),
#   'Leche',
#   'Cortés',
#   'María Castro',
#   'Tarjeta'),
#  (108,
#   datetime.date(2024, 1, 5),
#   'Detergente',
#   'Carrillo',
#   'Samuel Fernández',
#   'Tarjeta'),
#  (109,
#   datetime.date(2024, 1, 5),
#   'Yogur',
#   'Velázquez',
#   'Diana Serrano',
#   'Tarjeta'),
#  (110,
#   datetime.date(2024, 1, 5),
#   'Naranja',
#   'Molina',
#   'Cristian Campos',
#   'Efectivo'),
#  (111,
#   datetime.date(2024, 1, 5),
#   'Tierra para macetas',
#   'Romero',
#   'Diana Romero',
#   'Tarjeta'),
#  (112,
#   datetime.date(2024, 1, 5),
#   'Jugo de naranja',
#   'Álvarez',
#   'Carmen Guzmán',
#   'Tarjeta'),
#  (113,
#   datetime.date(2024, 1, 5),
#   'Tierra para macetas',
#   'Paredes',
#   'Francisco Romero',
#   'Tarjeta'),
#  (114,
#   datetime.date(2024, 1, 5),
#   'Zanahoria',
#   'Campos',
#   'Sara Domínguez',
#   'Efectivo'),
#  (115,
#   datetime.date(2024, 1, 5),
#   'Velas',
#   'Romero',
#   'Paula Ortiz',
#   'Efectivo'),
#  (116,
#   datetime.date(2024, 1, 5),
#   'Leche',
#   'Martínez',
#   'Eduardo Ortiz',
#   'Tarjeta'),
#  (117,
#   datetime.date(2024, 1, 5),
#   'Regadera',
#   'Rodríguez',
#   'Adriana Guzmán',
#   'Tarjeta'),
#  (118,
#   datetime.date(2024, 1, 5),
#   'Chuletas',
#   'Álvarez',
#   'Pablo Jiménez',
#   'Efectivo'),
#  (119,
#   datetime.date(2024, 1, 5),
#   'Detergente',
#   'Ortiz',
#   'Camila Fernández',
#   'Tarjeta'),
#  (120,
#   datetime.date(2024, 1, 5),
#   'Detergente',
#   'Ortiz',
#   'María Martínez',
#   'Efectivo'),
#  (121,
#   datetime.date(2024, 1, 5),
#   'Mantequilla',
#   'Salinas',
#   'Andrea Vázquez',
#   'Tarjeta'),
#  (122,
#   datetime.date(2024, 1, 5),
#   'Champú',
#   'Aguilar',
#   'Ana Velázquez',
#   'Tarjeta'),
#  (123,
#   datetime.date(2024, 1, 5),
#   'Jugo de naranja',
#   'Lara',
#   'Carlos Torres',
#   'Tarjeta'),
#  (124,
#   datetime.date(2024, 1, 5),
#   'Tomate',
#   'Ortiz',
#   'Andrea Santos',
#   'Tarjeta'),
#  (125,
#   datetime.date(2024, 1, 5),
#   'Leche',
#   'Navarro',
#   'Daniel Ramírez',
#   'Tarjeta'),
#  (126, datetime.date(2024, 1, 6), 'Banana', 'Lara', 'Julia Campos', 'Tarjeta'),
#  (127,
#   datetime.date(2024, 1, 6),
#   'Manzana',
#   'Jiménez',
#   'Raúl López',
#   'Tarjeta'),
#  (128,
#   datetime.date(2024, 1, 6),
#   'Platos desechables',
#   'Cruz',
#   'Clara Delgado',
#   'Tarjeta'),
#  (129,
#   datetime.date(2024, 1, 6),
#   'Cerveza',
#   'Jiménez',
#   'Francisco García',
#   'Efectivo'),
#  (130,
#   datetime.date(2024, 1, 6),
#   'Chuletas',
#   'Romero',
#   'Laura Ortiz',
#   'Tarjeta'),
#  (131,
#   datetime.date(2024, 1, 6),
#   'Galletas',
#   'Flores',
#   'Ana Guzmán',
#   'Efectivo'),
#  (132,
#   datetime.date(2024, 1, 6),
#   'Cebolla',
#   'Aguilar',
#   'Diana Peña',
#   'Tarjeta'),
#  (133, datetime.date(2024, 1, 6), 'Chicles', 'López', 'Raúl Reyes', 'Tarjeta'),
#  (134,
#   datetime.date(2024, 1, 6),
#   'Tierra para macetas',
#   'Montes',
#   'Lucía Pérez',
#   'Efectivo'),
#  (135,
#   datetime.date(2024, 1, 6),
#   'Regadera',
#   'Cortés',
#   'Andrea Santos',
#   'Tarjeta'),
#  (136,
#   datetime.date(2024, 1, 6),
#   'Agua',
#   'García',
#   'Diego Salinas',
#   'Efectivo'),
#  (137,
#   datetime.date(2024, 1, 6),
#   'Tomate',
#   'Medina',
#   'Paula Ortiz',
#   'Tarjeta'),
#  (138,
#   datetime.date(2024, 1, 6),
#   'Naranja',
#   'Reyes',
#   'Diana Romero',
#   'Tarjeta'),
#  (139,
#   datetime.date(2024, 1, 6),
#   'Platos desechables',
#   'Paredes',
#   'Daniel Serrano',
#   'Tarjeta'),
#  (140,
#   datetime.date(2024, 1, 6),
#   'Bolsas de basura',
#   'Martínez',
#   'Samuel González',
#   'Efectivo'),
#  (141,
#   datetime.date(2024, 1, 6),
#   'Tierra para macetas',
#   'Ortiz',
#   'Diego Sánchez',
#   'Tarjeta'),
#  (142,
#   datetime.date(2024, 1, 6),
#   'Mantequilla',
#   'Pérez',
#   'Diana Navarro',
#   'Tarjeta'),
#  (143,
#   datetime.date(2024, 1, 6),
#   'Mantequilla',
#   'Navarro',
#   'Lucía Campos',
#   'Tarjeta'),
#  (144,
#   datetime.date(2024, 1, 6),
#   'Semillas',
#   'Ortiz',
#   'Elena Guzmán',
#   'Tarjeta'),
#  (145,
#   datetime.date(2024, 1, 6),
#   'Chicles',
#   'Carrillo',
#   'Andrés Ortiz',
#   'Tarjeta'),
#  (146,
#   datetime.date(2024, 1, 7),
#   'Bolsas de basura',
#   'Lara',
#   'Carmen González',
#   'Efectivo'),
#  (147,
#   datetime.date(2024, 1, 7),
#   'Manzana',
#   'Fuentes',
#   'Julia Campos',
#   'Tarjeta'),
#  (148,
#   datetime.date(2024, 1, 7),
#   'Crema hidratante',
#   'Peña',
#   'Carla Méndez',
#   'Efectivo'),
#  (149,
#   datetime.date(2024, 1, 7),
#   'Tomate',
#   'Molina',
#   'Carlos Delgado',
#   'Tarjeta'),
#  (150,
#   datetime.date(2024, 1, 7),
#   'Detergente',
#   'Delgado',
#   'Carla Ruiz',
#   'Efectivo'),
#  (151,
#   datetime.date(2024, 1, 7),
#   'Champú',
#   'Ortiz',
#   'Andrea Vázquez',
#   'Tarjeta'),
#  (152,
#   datetime.date(2024, 1, 7),
#   'Jugo de naranja',
#   'Álvarez',
#   'Tomás Fernández',
#   'Tarjeta'),
#  (153,
#   datetime.date(2024, 1, 7),
#   'Banana',
#   'Cabrera',
#   'Laura López',
#   'Tarjeta'),
#  (154,
#   datetime.date(2024, 1, 7),
#   'Cebolla',
#   'Ramos',
#   'Diana Romero',
#   'Tarjeta'),
#  (155,
#   datetime.date(2024, 1, 7),
#   'Platos desechables',
#   'Rubio',
#   'Ricardo Álvarez',
#   'Tarjeta'),
#  (156,
#   datetime.date(2024, 1, 7),
#   'Esponjas',
#   'Aguilar',
#   'Carmen Guzmán',
#   'Efectivo'),
#  (157,
#   datetime.date(2024, 1, 7),
#   'Cerveza',
#   'Jiménez',
#   'Paula Ortiz',
#   'Tarjeta'),
#  (158,
#   datetime.date(2024, 1, 7),
#   'Zanahoria',
#   'Rodríguez',
#   'Raúl López',
#   'Efectivo'),
#  (159,
#   datetime.date(2024, 1, 7),
#   'Banana',
#   'Molina',
#   'Lucía López',
#   'Tarjeta'),
#  (160,
#   datetime.date(2024, 1, 7),
#   'Champú',
#   'García',
#   'Raúl Reyes',
#   'Efectivo'),
#  (161, datetime.date(2024, 1, 7), 'Colonia', 'Cruz', 'Carlos Lara', 'Tarjeta'),
#  (162,
#   datetime.date(2024, 1, 7),
#   'Queso',
#   'Serrano',
#   'Francisco Romero',
#   'Tarjeta'),
#  (163, datetime.date(2024, 1, 7), 'Pollo', 'Díaz', 'Diego Ortiz', 'Tarjeta'),
#  (164,
#   datetime.date(2024, 1, 7),
#   'Regadera',
#   'Peña',
#   'Hugo Sánchez',
#   'Efectivo'),
#  (165,
#   datetime.date(2024, 1, 7),
#   'Champú',
#   'Moreno',
#   'Ricardo Álvarez',
#   'Tarjeta'),
#  (166,
#   datetime.date(2024, 1, 7),
#   'Tomate',
#   'Martínez',
#   'Pablo Jiménez',
#   'Efectivo'),
#  (167,
#   datetime.date(2024, 1, 7),
#   'Desodorante',
#   'Cruz',
#   'Elena Cabrera',
#   'Tarjeta'),
#  (168,
#   datetime.date(2024, 1, 8),
#   'Velas',
#   'Peña',
#   'Clara Cabrera',
#   'Efectivo'),
#  (169,
#   datetime.date(2024, 1, 8),
#   'Detergente',
#   'Campos',
#   'Julia Fuentes',
#   'Tarjeta'),
#  (170,
#   datetime.date(2024, 1, 8),
#   'Queso',
#   'Aguilar',
#   'Daniel Serrano',
#   'Efectivo'),
#  (171,
#   datetime.date(2024, 1, 8),
#   'Semillas',
#   'Martínez',
#   'Andrés Ortiz',
#   'Tarjeta'),
#  (172,
#   datetime.date(2024, 1, 8),
#   'Chuletas',
#   'Flores',
#   'Clara Álvarez',
#   'Tarjeta'),
#  (173,
#   datetime.date(2024, 1, 8),
#   'Colonia',
#   'Domínguez',
#   'Javier Cruz',
#   'Tarjeta'),
#  (174,
#   datetime.date(2024, 1, 8),
#   'Esponjas',
#   'Ruiz',
#   'Andrea Santos',
#   'Tarjeta'),
#  (175,
#   datetime.date(2024, 1, 8),
#   'Leche',
#   'Cortés',
#   'Raúl González',
#   'Tarjeta'),
#  (176,
#   datetime.date(2024, 1, 8),
#   'Leche',
#   'Fuentes',
#   'Eduardo Ortiz',
#   'Efectivo'),
#  (177,
#   datetime.date(2024, 1, 8),
#   'Galletas',
#   'López',
#   'Gabriela Reyes',
#   'Tarjeta'),
#  (178,
#   datetime.date(2024, 1, 8),
#   'Cerdo',
#   'Ortiz',
#   'Carlos Torres',
#   'Efectivo'),
#  (179,
#   datetime.date(2024, 1, 8),
#   'Carne de res',
#   'Cruz',
#   'Cristian Rodríguez',
#   'Efectivo'),
#  (180,
#   datetime.date(2024, 1, 8),
#   'Bolsas de basura',
#   'Campos',
#   'Daniel Ruiz',
#   'Tarjeta'),
#  (181,
#   datetime.date(2024, 1, 8),
#   'Regadera',
#   'Guzmán',
#   'Adriana Navarro',
#   'Tarjeta'),
#  (182,
#   datetime.date(2024, 1, 8),
#   'Desinfectante',
#   'Chávez',
#   'Clara Álvarez',
#   'Tarjeta'),
#  (183,
#   datetime.date(2024, 1, 8),
#   'Cerdo',
#   'Castro',
#   'Samuel Fernández',
#   'Efectivo'),
#  (184,
#   datetime.date(2024, 1, 8),
#   'Tomate',
#   'Ramírez',
#   'Ana Guzmán',
#   'Efectivo'),
#  (185,
#   datetime.date(2024, 1, 8),
#   'Queso',
#   'Hernández',
#   'Sara Moreno',
#   'Efectivo'),
#  (186,
#   datetime.date(2024, 1, 8),
#   'Mantequilla',
#   'Torres',
#   'Daniel Serrano',
#   'Tarjeta'),
#  (187,
#   datetime.date(2024, 1, 8),
#   'Cebolla',
#   'Paredes',
#   'Francisco Romero',
#   'Efectivo'),
#  (188,
#   datetime.date(2024, 1, 8),
#   'Fertilizante',
#   'Díaz',
#   'Ricardo Campos',
#   'Tarjeta'),
#  (189,
#   datetime.date(2024, 1, 8),
#   'Uva',
#   'González',
#   'Cristian Díaz',
#   'Efectivo'),
#  (190,
#   datetime.date(2024, 1, 9),
#   'Manzana',
#   'Ortiz',
#   'Laura Ortiz',
#   'Efectivo'),
#  (191, datetime.date(2024, 1, 9), 'Banana', 'Santos', 'Sara Peña', 'Tarjeta'),
#  (192,
#   datetime.date(2024, 1, 9),
#   'Jabón líquido',
#   'Hernández',
#   'Javier García',
#   'Efectivo'),
#  (193,
#   datetime.date(2024, 1, 9),
#   'Carne de res',
#   'Reyes',
#   'Camila Fernández',
#   'Efectivo'),
#  (194,
#   datetime.date(2024, 1, 9),
#   'Detergente',
#   'Cruz',
#   'Ana Guzmán',
#   'Efectivo'),
#  (195,
#   datetime.date(2024, 1, 9),
#   'Refresco',
#   'Aguilar',
#   'Sara Moreno',
#   'Tarjeta'),
#  (196,
#   datetime.date(2024, 1, 9),
#   'Lechuga',
#   'Paredes',
#   'Raúl López',
#   'Tarjeta'),
#  (197,
#   datetime.date(2024, 1, 9),
#   'Jugo de naranja',
#   'Delgado',
#   'Laura López',
#   'Tarjeta'),
#  (198,
#   datetime.date(2024, 1, 9),
#   'Cerdo',
#   'Cabrera',
#   'Pablo Jiménez',
#   'Efectivo'),
#  (199,
#   datetime.date(2024, 1, 9),
#   'Semillas',
#   'Sánchez',
#   'Laura López',
#   'Tarjeta'),
#  (200,
#   datetime.date(2024, 1, 9),
#   'Refresco',
#   'Chávez',
#   'Carmen González',
#   'Tarjeta'),
#  (201,
#   datetime.date(2024, 1, 9),
#   'Champú',
#   'Vázquez',
#   'Ricardo Campos',
#   'Tarjeta'),
#  (202,
#   datetime.date(2024, 1, 9),
#   'Chuletas',
#   'Pérez',
#   'Carmen González',
#   'Efectivo'),
#  (203,
#   datetime.date(2024, 1, 9),
#   'Papas fritas',
#   'Delgado',
#   'Miguel Flores',
#   'Tarjeta'),
#  (204,
#   datetime.date(2024, 1, 9),
#   'Jabón líquido',
#   'Rodríguez',
#   'Isabel Carrillo',
#   'Tarjeta'),
#  (205, datetime.date(2024, 1, 9), 'Pollo', 'Pérez', 'Raúl López', 'Efectivo'),
#  (206,
#   datetime.date(2024, 1, 9),
#   'Jugo de naranja',
#   'Moreno',
#   'Diana Serrano',
#   'Efectivo'),
#  (207,
#   datetime.date(2024, 1, 9),
#   'Agua',
#   'García',
#   'Lorena Rodríguez',
#   'Efectivo'),
#  (208,
#   datetime.date(2024, 1, 9),
#   'Galletas',
#   'Navarro',
#   'Carmen González',
#   'Tarjeta'),
#  (209,
#   datetime.date(2024, 1, 9),
#   'Banana',
#   'Hernández',
#   'Adriana Esquivel',
#   'Efectivo'),
#  (210,
#   datetime.date(2024, 1, 9),
#   'Semillas',
#   'Medina',
#   'Manuel Ramos',
#   'Tarjeta'),
#  (211,
#   datetime.date(2024, 1, 9),
#   'Queso',
#   'Santos',
#   'Sara Salinas',
#   'Tarjeta'),
#  (212,
#   datetime.date(2024, 1, 9),
#   'Crema hidratante',
#   'Hernández',
#   'Carmen Medina',
#   'Tarjeta'),
#  (213,
#   datetime.date(2024, 1, 10),
#   'Tierra para macetas',
#   'Navarro',
#   'Julia Campos',
#   'Efectivo'),
#  (214,
#   datetime.date(2024, 1, 10),
#   'Bolsas de basura',
#   'Ruiz',
#   'Francisco Romero',
#   'Tarjeta'),
#  (215,
#   datetime.date(2024, 1, 10),
#   'Chuletas',
#   'Sánchez',
#   'Eva López',
#   'Tarjeta'),
#  (216,
#   datetime.date(2024, 1, 10),
#   'Manzana',
#   'Moreno',
#   'Samuel Sánchez',
#   'Efectivo'),
#  (217,
#   datetime.date(2024, 1, 10),
#   'Tomate',
#   'Molina',
#   'Adriana Guzmán',
#   'Efectivo'),
#  (218,
#   datetime.date(2024, 1, 10),
#   'Banana',
#   'Ramírez',
#   'Diana Serrano',
#   'Tarjeta'),
#  (219,
#   datetime.date(2024, 1, 10),
#   'Chicles',
#   'Navarro',
#   'María Martínez',
#   'Tarjeta'),
#  (220,
#   datetime.date(2024, 1, 10),
#   'Pilas',
#   'Álvarez',
#   'Luis Ortiz',
#   'Tarjeta'),
#  (221,
#   datetime.date(2024, 1, 10),
#   'Semillas',
#   'Martínez',
#   'Carlos Delgado',
#   'Tarjeta'),
#  (222,
#   datetime.date(2024, 1, 10),
#   'Colonia',
#   'Domínguez',
#   'Diego López',
#   'Efectivo'),
#  (223,
#   datetime.date(2024, 1, 10),
#   'Semillas',
#   'Martínez',
#   'Clara Álvarez',
#   'Efectivo'),
#  (224,
#   datetime.date(2024, 1, 10),
#   'Refresco',
#   'Santos',
#   'Adriana Rubio',
#   'Tarjeta'),
#  (225,
#   datetime.date(2024, 1, 10),
#   'Tomate',
#   'Pérez',
#   'Julia Campos',
#   'Tarjeta'),
#  (226,
#   datetime.date(2024, 1, 10),
#   'Desinfectante',
#   'Ramírez',
#   'Paula Ortiz',
#   'Tarjeta'),
#  (227,
#   datetime.date(2024, 1, 10),
#   'Banana',
#   'Rodríguez',
#   'Diego Cortés',
#   'Tarjeta'),
#  (228,
#   datetime.date(2024, 1, 10),
#   'Cerdo',
#   'Ortiz',
#   'Samuel Fernández',
#   'Tarjeta'),
#  (229,
#   datetime.date(2024, 1, 10),
#   'Papas fritas',
#   'García',
#   'Mario Torres',
#   'Efectivo'),
#  (230,
#   datetime.date(2024, 1, 10),
#   'Leche',
#   'García',
#   'Lorena Rodríguez',
#   'Efectivo'),
#  (231,
#   datetime.date(2024, 1, 10),
#   'Chuletas',
#   'Sánchez',
#   'Francisco Romero',
#   'Tarjeta'),
#  (232,
#   datetime.date(2024, 1, 10),
#   'Velas',
#   'Romero',
#   'José Santos',
#   'Tarjeta'),
#  (233,
#   datetime.date(2024, 1, 10),
#   'Zanahoria',
#   'Domínguez',
#   'Isabel Carrillo',
#   'Tarjeta'),
#  (234,
#   datetime.date(2024, 1, 10),
#   'Zanahoria',
#   'Campos',
#   'Irene Hernández',
#   'Tarjeta'),
#  (235,
#   datetime.date(2024, 1, 10),
#   'Bolsas de basura',
#   'Cruz',
#   'Ricardo González',
#   'Tarjeta'),
#  (236, datetime.date(2024, 1, 10), 'Queso', 'Reyes', 'Laura López', 'Tarjeta'),
#  (237,
#   datetime.date(2024, 1, 10),
#   'Desodorante',
#   'Rubio',
#   'Laura Ortiz',
#   'Tarjeta'),
#  (238,
#   datetime.date(2024, 1, 10),
#   'Chicles',
#   'Aguilar',
#   'David Hernández',
#   'Efectivo'),
#  (239,
#   datetime.date(2024, 1, 10),
#   'Crema hidratante',
#   'Flores',
#   'Pablo Jiménez',
#   'Efectivo'),
#  (240,
#   datetime.date(2024, 1, 11),
#   'Desodorante',
#   'Campos',
#   'Diana Peña',
#   'Efectivo'),
#  (241,
#   datetime.date(2024, 1, 11),
#   'Zanahoria',
#   'Domínguez',
#   'Raúl González',
#   'Efectivo'),
#  (242, datetime.date(2024, 1, 11), 'Uva', 'Esquivel', 'Eva López', 'Efectivo'),
#  (243,
#   datetime.date(2024, 1, 11),
#   'Manzana',
#   'Romero',
#   'Jorge Rodríguez',
#   'Efectivo'),
#  (244,
#   datetime.date(2024, 1, 11),
#   'Carne de res',
#   'Molina',
#   'Carlos Pérez',
#   'Tarjeta'),
#  (245,
#   datetime.date(2024, 1, 11),
#   'Uva',
#   'Ramos',
#   'Cristian Flores',
#   'Efectivo'),
#  (246,
#   datetime.date(2024, 1, 11),
#   'Detergente',
#   'Díaz',
#   'Ricardo Serrano',
#   'Tarjeta'),
#  (247,
#   datetime.date(2024, 1, 11),
#   'Desodorante',
#   'Sánchez',
#   'Paula Ortiz',
#   'Efectivo'),
#  (248,
#   datetime.date(2024, 1, 11),
#   'Cerdo',
#   'Lara',
#   'Carlos Torres',
#   'Tarjeta'),
#  (249,
#   datetime.date(2024, 1, 11),
#   'Galletas',
#   'Torres',
#   'Manuel Ramos',
#   'Efectivo'),
#  (250,
#   datetime.date(2024, 1, 11),
#   'Esponjas',
#   'Moreno',
#   'Elena Guzmán',
#   'Efectivo'),
#  (251,
#   datetime.date(2024, 1, 11),
#   'Regadera',
#   'Chávez',
#   'Daniel Aguilar',
#   'Efectivo'),
#  (252,
#   datetime.date(2024, 1, 11),
#   'Cebolla',
#   'Rodríguez',
#   'Ricardo González',
#   'Tarjeta'),
#  (253,
#   datetime.date(2024, 1, 11),
#   'Detergente',
#   'Jiménez',
#   'Carlos Delgado',
#   'Tarjeta'),
#  (254,
#   datetime.date(2024, 1, 11),
#   'Chuletas',
#   'López',
#   'Carla Cabrera',
#   'Tarjeta'),
#  (255,
#   datetime.date(2024, 1, 11),
#   'Naranja',
#   'Ramírez',
#   'Ricardo Álvarez',
#   'Tarjeta'),
#  (256,
#   datetime.date(2024, 1, 11),
#   'Zanahoria',
#   'Montes',
#   'Sara Moreno',
#   'Efectivo'),
#  (257,
#   datetime.date(2024, 1, 11),
#   'Esponjas',
#   'Fuentes',
#   'Sara Moreno',
#   'Tarjeta'),
#  (258,
#   datetime.date(2024, 1, 11),
#   'Chocolate',
#   'Ortiz',
#   'Luis Navarro',
#   'Efectivo'),
#  (259,
#   datetime.date(2024, 1, 11),
#   'Zanahoria',
#   'Castro',
#   'Sara Moreno',
#   'Efectivo'),
#  (260,
#   datetime.date(2024, 1, 11),
#   'Fertilizante',
#   'Lara',
#   'José Cruz',
#   'Tarjeta'),
#  (261,
#   datetime.date(2024, 1, 11),
#   'Desodorante',
#   'Ortiz',
#   'Diana Romero',
#   'Efectivo'),
#  (262,
#   datetime.date(2024, 1, 12),
#   'Cebolla',
#   'Rubio',
#   'Irene Ruiz',
#   'Tarjeta'),
#  (263,
#   datetime.date(2024, 1, 12),
#   'Cerveza',
#   'Moreno',
#   'Ana Guzmán',
#   'Efectivo'),
#  (264,
#   datetime.date(2024, 1, 12),
#   'Yogur',
#   'Salinas',
#   'Francisco Romero',
#   'Tarjeta'),
#  (265,
#   datetime.date(2024, 1, 12),
#   'Champú',
#   'Carrillo',
#   'Marta Ortiz',
#   'Tarjeta'),
#  (266,
#   datetime.date(2024, 1, 12),
#   'Velas',
#   'González',
#   'Diana Romero',
#   'Tarjeta'),
#  (267,
#   datetime.date(2024, 1, 12),
#   'Crema hidratante',
#   'Díaz',
#   'Samuel Sánchez',
#   'Efectivo'),
#  (268,
#   datetime.date(2024, 1, 12),
#   'Zanahoria',
#   'Molina',
#   'Pablo Ramírez',
#   'Tarjeta'),
#  (269, datetime.date(2024, 1, 12), 'Yogur', 'Cruz', 'Mario Ortiz', 'Tarjeta'),
#  (270,
#   datetime.date(2024, 1, 12),
#   'Jugo de naranja',
#   'Cruz',
#   'Samuel Fernández',
#   'Efectivo'),
#  (271,
#   datetime.date(2024, 1, 12),
#   'Agua',
#   'Álvarez',
#   'Carlos Delgado',
#   'Tarjeta'),
#  (272,
#   datetime.date(2024, 1, 12),
#   'Manzana',
#   'Aguilar',
#   'Ricardo González',
#   'Tarjeta'),
#  (273,
#   datetime.date(2024, 1, 12),
#   'Yogur',
#   'Sánchez',
#   'Diego Cortés',
#   'Tarjeta'),
#  (274,
#   datetime.date(2024, 1, 12),
#   'Naranja',
#   'Peña',
#   'Sara Domínguez',
#   'Tarjeta'),
#  (275,
#   datetime.date(2024, 1, 12),
#   'Jabón líquido',
#   'Hernández',
#   'Andrea Santos',
#   'Tarjeta'),
#  (276,
#   datetime.date(2024, 1, 12),
#   'Cebolla',
#   'Paredes',
#   'Carla Cabrera',
#   'Efectivo'),
#  (277,
#   datetime.date(2024, 1, 12),
#   'Pollo',
#   'García',
#   'Pablo Ramírez',
#   'Tarjeta'),
#  (278,
#   datetime.date(2024, 1, 12),
#   'Papas fritas',
#   'Santos',
#   'Tomás Fernández',
#   'Tarjeta'),
#  (279,
#   datetime.date(2024, 1, 12),
#   'Desodorante',
#   'López',
#   'Lucía Pérez',
#   'Tarjeta'),
#  (280,
#   datetime.date(2024, 1, 12),
#   'Banana',
#   'Lara',
#   'Samuel Fernández',
#   'Tarjeta'),
#  (281,
#   datetime.date(2024, 1, 12),
#   'Esponjas',
#   'Fuentes',
#   'Gabriela Reyes',
#   'Tarjeta'),
#  (282,
#   datetime.date(2024, 1, 12),
#   'Esponjas',
#   'Jiménez',
#   'Hugo Sánchez',
#   'Tarjeta'),
#  (283,
#   datetime.date(2024, 1, 12),
#   'Esponjas',
#   'Cortés',
#   'Tomás Fernández',
#   'Tarjeta'),
#  (284,
#   datetime.date(2024, 1, 12),
#   'Bolsas de basura',
#   'Peña',
#   'Luis Esquivel',
#   'Tarjeta'),
#  (285,
#   datetime.date(2024, 1, 12),
#   'Esponjas',
#   'Torres',
#   'Daniel Serrano',
#   'Tarjeta'),
#  (286,
#   datetime.date(2024, 1, 12),
#   'Esponjas',
#   'García',
#   'Adriana González',
#   'Efectivo'),
#  (287,
#   datetime.date(2024, 1, 12),
#   'Desodorante',
#   'Rubio',
#   'Eva Montes',
#   'Efectivo'),
#  (288,
#   datetime.date(2024, 1, 12),
#   'Semillas',
#   'González',
#   'Laura Ortiz',
#   'Efectivo'),
#  (289,
#   datetime.date(2024, 1, 12),
#   'Chicles',
#   'Cabrera',
#   'Laura González',
#   'Efectivo'),
#  (290,
#   datetime.date(2024, 1, 12),
#   'Queso',
#   'Santos',
#   'Jorge Rodríguez',
#   'Tarjeta'),
#  (291,
#   datetime.date(2024, 1, 13),
#   'Chocolate',
#   'Méndez',
#   'Hugo Sánchez',
#   'Efectivo'),
#  (292,
#   datetime.date(2024, 1, 13),
#   'Semillas',
#   'Ramos',
#   'Eduardo Flores',
#   'Efectivo'),
#  (293,
#   datetime.date(2024, 1, 13),
#   'Desodorante',
#   'Reyes',
#   'Lucía Campos',
#   'Tarjeta'),
#  (294,
#   datetime.date(2024, 1, 13),
#   'Tomate',
#   'Rubio',
#   'Samuel Sánchez',
#   'Efectivo'),
#  (295,
#   datetime.date(2024, 1, 13),
#   'Colonia',
#   'Esquivel',
#   'Laura González',
#   'Efectivo'),
#  (296,
#   datetime.date(2024, 1, 13),
#   'Refresco',
#   'Moreno',
#   'Mario Ortiz',
#   'Tarjeta'),
#  (297,
#   datetime.date(2024, 1, 13),
#   'Cerveza',
#   'Aguilar',
#   'Jorge Rodríguez',
#   'Tarjeta'),
#  (298,
#   datetime.date(2024, 1, 13),
#   'Agua',
#   'Jiménez',
#   'Laura González',
#   'Tarjeta'),
#  (299,
#   datetime.date(2024, 1, 13),
#   'Regadera',
#   'Ruiz',
#   'Mario Torres',
#   'Efectivo'),
#  (300,
#   datetime.date(2024, 1, 13),
#   'Queso',
#   'Hernández',
#   'Sofía Lara',
#   'Tarjeta'),
#  (301,
#   datetime.date(2024, 1, 13),
#   'Crema hidratante',
#   'Esquivel',
#   'David Hernández',
#   'Tarjeta'),
#  (302,
#   datetime.date(2024, 1, 13),
#   'Bolsas de basura',
#   'Salinas',
#   'David Rubio',
#   'Tarjeta'),
#  (303,
#   datetime.date(2024, 1, 13),
#   'Esponjas',
#   'Delgado',
#   'Francisco García',
#   'Tarjeta'),
#  (304,
#   datetime.date(2024, 1, 13),
#   'Colonia',
#   'Sánchez',
#   'Cristian Díaz',
#   'Tarjeta'),
#  (305,
#   datetime.date(2024, 1, 13),
#   'Jabón líquido',
#   'Ortiz',
#   'Javier Cruz',
#   'Tarjeta'),
#  (306,
#   datetime.date(2024, 1, 13),
#   'Crema hidratante',
#   'Ortiz',
#   'Andrea Vázquez',
#   'Tarjeta'),
#  (307,
#   datetime.date(2024, 1, 13),
#   'Refresco',
#   'Aguilar',
#   'Ana González',
#   'Efectivo'),
#  (308,
#   datetime.date(2024, 1, 13),
#   'Uva',
#   'Torres',
#   'Lorena Rodríguez',
#   'Tarjeta'),
#  (309,
#   datetime.date(2024, 1, 13),
#   'Agua',
#   'Lara',
#   'Carlos Jiménez',
#   'Tarjeta'),
#  (310,
#   datetime.date(2024, 1, 13),
#   'Chicles',
#   'Méndez',
#   'Marta Ortiz',
#   'Efectivo'),
#  (311,
#   datetime.date(2024, 1, 13),
#   'Cebolla',
#   'Santos',
#   'Lucía Campos',
#   'Efectivo'),
#  (312,
#   datetime.date(2024, 1, 13),
#   'Papas fritas',
#   'Flores',
#   'Andrea Vázquez',
#   'Tarjeta'),
#  (313,
#   datetime.date(2024, 1, 13),
#   'Tomate',
#   'Flores',
#   'Julia Fuentes',
#   'Efectivo'),
#  (314,
#   datetime.date(2024, 1, 13),
#   'Semillas',
#   'Flores',
#   'Mario Ortiz',
#   'Efectivo'),
#  (315,
#   datetime.date(2024, 1, 13),
#   'Leche',
#   'Guzmán',
#   'María Castro',
#   'Efectivo'),
#  (316, datetime.date(2024, 1, 13), 'Agua', 'Moreno', 'Raúl Reyes', 'Tarjeta'),
#  (317,
#   datetime.date(2024, 1, 14),
#   'Tomate',
#   'López',
#   'Diego Sánchez',
#   'Efectivo'),
#  (318,
#   datetime.date(2024, 1, 14),
#   'Regadera',
#   'Díaz',
#   'Patricia Domínguez',
#   'Efectivo'),
#  (319,
#   datetime.date(2024, 1, 14),
#   'Manzana',
#   'Cabrera',
#   'Carlos Jiménez',
#   'Tarjeta'),
#  (320,
#   datetime.date(2024, 1, 14),
#   'Tomate',
#   'Pérez',
#   'Clara Salinas',
#   'Tarjeta'),
#  (321,
#   datetime.date(2024, 1, 14),
#   'Regadera',
#   'Molina',
#   'Mario Torres',
#   'Tarjeta'),
#  (322,
#   datetime.date(2024, 1, 14),
#   'Yogur',
#   'Ortiz',
#   'Mario Torres',
#   'Efectivo'),
#  (323,
#   datetime.date(2024, 1, 14),
#   'Papas fritas',
#   'Flores',
#   'Javier Cruz',
#   'Tarjeta'),
#  (324,
#   datetime.date(2024, 1, 14),
#   'Semillas',
#   'Esquivel',
#   'Diego Méndez',
#   'Efectivo'),
#  (325,
#   datetime.date(2024, 1, 14),
#   'Leche',
#   'Álvarez',
#   'Carla Flores',
#   'Tarjeta'),
#  (326,
#   datetime.date(2024, 1, 14),
#   'Champú',
#   'Moreno',
#   'Diana Peña',
#   'Tarjeta'),
#  (327,
#   datetime.date(2024, 1, 14),
#   'Yogur',
#   'Salinas',
#   'Samuel Fernández',
#   'Efectivo'),
#  (328,
#   datetime.date(2024, 1, 14),
#   'Semillas',
#   'Díaz',
#   'Pablo Jiménez',
#   'Tarjeta'),
#  (329,
#   datetime.date(2024, 1, 14),
#   'Naranja',
#   'Peña',
#   'Camila Fernández',
#   'Efectivo'),
#  (330,
#   datetime.date(2024, 1, 14),
#   'Mantequilla',
#   'Navarro',
#   'Clara Cabrera',
#   'Tarjeta'),
#  (331,
#   datetime.date(2024, 1, 14),
#   'Platos desechables',
#   'Domínguez',
#   'Irene Hernández',
#   'Efectivo'),
#  (332,
#   datetime.date(2024, 1, 14),
#   'Cebolla',
#   'López',
#   'Cristian Rodríguez',
#   'Tarjeta'),
#  (333,
#   datetime.date(2024, 1, 14),
#   'Mantequilla',
#   'Ramírez',
#   'Jorge Cortés',
#   'Efectivo'),
#  (334,
#   datetime.date(2024, 1, 14),
#   'Tierra para macetas',
#   'Delgado',
#   'María Castro',
#   'Efectivo'),
#  (335,
#   datetime.date(2024, 1, 14),
#   'Galletas',
#   'Ortiz',
#   'Verónica Álvarez',
#   'Tarjeta'),
#  (336,
#   datetime.date(2024, 1, 14),
#   'Cerveza',
#   'Flores',
#   'Paula Ortiz',
#   'Tarjeta'),
#  (337,
#   datetime.date(2024, 1, 14),
#   'Tomate',
#   'Navarro',
#   'Sara Peña',
#   'Tarjeta'),
#  (338,
#   datetime.date(2024, 1, 14),
#   'Fertilizante',
#   'Martínez',
#   'Ana González',
#   'Tarjeta'),
#  (339,
#   datetime.date(2024, 1, 15),
#   'Bolsas de basura',
#   'Montes',
#   'Pablo Jiménez',
#   'Efectivo'),
#  (340,
#   datetime.date(2024, 1, 15),
#   'Papas fritas',
#   'Romero',
#   'Samuel Fernández',
#   'Efectivo'),
#  (341,
#   datetime.date(2024, 1, 15),
#   'Zanahoria',
#   'Ortiz',
#   'Sara Fernández',
#   'Efectivo'),
#  (342,
#   datetime.date(2024, 1, 15),
#   'Colonia',
#   'Carrillo',
#   'David Montes',
#   'Tarjeta'),
#  (343,
#   datetime.date(2024, 1, 15),
#   'Cebolla',
#   'Vázquez',
#   'Julia Carrillo',
#   'Tarjeta'),
#  (344,
#   datetime.date(2024, 1, 15),
#   'Crema hidratante',
#   'Hernández',
#   'Laura Ortiz',
#   'Tarjeta'),
#  (345,
#   datetime.date(2024, 1, 15),
#   'Champú',
#   'Guzmán',
#   'Ricardo Álvarez',
#   'Tarjeta'),
#  (346,
#   datetime.date(2024, 1, 15),
#   'Manzana',
#   'Torres',
#   'Hugo Sánchez',
#   'Tarjeta'),
#  (347,
#   datetime.date(2024, 1, 15),
#   'Banana',
#   'Santos',
#   'Eva Montes',
#   'Tarjeta'),
#  (348, datetime.date(2024, 1, 15), 'Pollo', 'Reyes', 'Raúl López', 'Efectivo'),
#  (349,
#   datetime.date(2024, 1, 15),
#   'Mantequilla',
#   'López',
#   'Diego Ortiz',
#   'Efectivo'),
#  (350,
#   datetime.date(2024, 1, 15),
#   'Crema hidratante',
#   'Ramírez',
#   'Lucía Campos',
#   'Tarjeta'),
#  (351,
#   datetime.date(2024, 1, 15),
#   'Fertilizante',
#   'Fernández',
#   'María Castro',
#   'Efectivo'),
#  (352,
#   datetime.date(2024, 1, 15),
#   'Crema hidratante',
#   'Hernández',
#   'Clara Cabrera',
#   'Tarjeta'),
#  (353,
#   datetime.date(2024, 1, 15),
#   'Uva',
#   'Montes',
#   'Samuel González',
#   'Efectivo'),
#  (354,
#   datetime.date(2024, 1, 15),
#   'Pollo',
#   'Ramírez',
#   'Elena Guzmán',
#   'Efectivo'),
#  (355,
#   datetime.date(2024, 1, 15),
#   'Cebolla',
#   'Martínez',
#   'Hugo Sánchez',
#   'Tarjeta'),
#  (356,
#   datetime.date(2024, 1, 15),
#   'Pilas',
#   'Ortiz',
#   'Cristian Paredes',
#   'Tarjeta'),
#  (357,
#   datetime.date(2024, 1, 15),
#   'Semillas',
#   'Martínez',
#   'Daniel Aguilar',
#   'Efectivo'),
#  (358,
#   datetime.date(2024, 1, 15),
#   'Agua',
#   'Chávez',
#   'Diego Cortés',
#   'Tarjeta'),
#  (359,
#   datetime.date(2024, 1, 15),
#   'Chuletas',
#   'Vázquez',
#   'Adriana González',
#   'Efectivo'),
#  (360,
#   datetime.date(2024, 1, 15),
#   'Pilas',
#   'Chávez',
#   'Adriana Esquivel',
#   'Efectivo'),
#  (361,
#   datetime.date(2024, 1, 15),
#   'Leche',
#   'Carrillo',
#   'Mario Torres',
#   'Tarjeta'),
#  (362,
#   datetime.date(2024, 1, 15),
#   'Chicles',
#   'Ramírez',
#   'Carla Flores',
#   'Tarjeta'),
#  (363,
#   datetime.date(2024, 1, 15),
#   'Tomate',
#   'Hernández',
#   'Carlos Lara',
#   'Tarjeta'),
#  (364,
#   datetime.date(2024, 1, 15),
#   'Jugo de naranja',
#   'Álvarez',
#   'Fernando Castro',
#   'Tarjeta'),
#  (365,
#   datetime.date(2024, 1, 15),
#   'Mantequilla',
#   'Martínez',
#   'Adriana Rubio',
#   'Tarjeta'),
#  (366,
#   datetime.date(2024, 1, 15),
#   'Uva',
#   'Torres',
#   'Miguel Flores',
#   'Efectivo'),
#  (367,
#   datetime.date(2024, 1, 15),
#   'Cebolla',
#   'García',
#   'Lorena Rodríguez',
#   'Efectivo'),
#  (368,
#   datetime.date(2024, 1, 16),
#   'Tomate',
#   'Navarro',
#   'Luis Esquivel',
#   'Efectivo'),
#  (369,
#   datetime.date(2024, 1, 16),
#   'Papas fritas',
#   'Moreno',
#   'Luis Navarro',
#   'Tarjeta'),
#  (370,
#   datetime.date(2024, 1, 16),
#   'Champú',
#   'Cortés',
#   'Javier Cruz',
#   'Efectivo'),
#  (371,
#   datetime.date(2024, 1, 16),
#   'Regadera',
#   'Carrillo',
#   'Carlos Torres',
#   'Efectivo'),
#  (372,
#   datetime.date(2024, 1, 16),
#   'Pollo',
#   'Pérez',
#   'Patricia Domínguez',
#   'Tarjeta'),
#  (373,
#   datetime.date(2024, 1, 16),
#   'Jugo de naranja',
#   'Velázquez',
#   'Samuel Fernández',
#   'Tarjeta'),
#  (374,
#   datetime.date(2024, 1, 16),
#   'Zanahoria',
#   'Martínez',
#   'Andrea Vázquez',
#   'Tarjeta'),
#  (375,
#   datetime.date(2024, 1, 16),
#   'Jabón líquido',
#   'Molina',
#   'Raúl Serrano',
#   'Efectivo'),
#  (376,
#   datetime.date(2024, 1, 16),
#   'Zanahoria',
#   'Romero',
#   'Carlos Esquivel',
#   'Tarjeta'),
#  (377,
#   datetime.date(2024, 1, 16),
#   'Zanahoria',
#   'García',
#   'Carlos Pérez',
#   'Tarjeta'),
#  (378,
#   datetime.date(2024, 1, 16),
#   'Semillas',
#   'Martínez',
#   'Clara Cabrera',
#   'Tarjeta'),
#  (379,
#   datetime.date(2024, 1, 16),
#   'Pollo',
#   'Cabrera',
#   'David Santos',
#   'Tarjeta'),
#  (380,
#   datetime.date(2024, 1, 16),
#   'Tomate',
#   'Ramírez',
#   'Daniel Ramírez',
#   'Tarjeta'),
#  (381,
#   datetime.date(2024, 1, 16),
#   'Jugo de naranja',
#   'Jiménez',
#   'Carmen Medina',
#   'Tarjeta'),
#  (382,
#   datetime.date(2024, 1, 16),
#   'Queso',
#   'Montes',
#   'Diego Cortés',
#   'Efectivo'),
#  (383,
#   datetime.date(2024, 1, 16),
#   'Regadera',
#   'Sánchez',
#   'Paula Ortiz',
#   'Efectivo'),
#  (384,
#   datetime.date(2024, 1, 16),
#   'Agua',
#   'Ramírez',
#   'David Hernández',
#   'Efectivo'),
#  (385,
#   datetime.date(2024, 1, 16),
#   'Agua',
#   'Sánchez',
#   'Diego Fuentes',
#   'Efectivo'),
#  (386,
#   datetime.date(2024, 1, 16),
#   'Zanahoria',
#   'Cabrera',
#   'Luis Ortiz',
#   'Tarjeta'),
#  (387,
#   datetime.date(2024, 1, 16),
#   'Pilas',
#   'Molina',
#   'Jorge Rodríguez',
#   'Tarjeta'),
#  (388,
#   datetime.date(2024, 1, 16),
#   'Velas',
#   'Vázquez',
#   'Diego Méndez',
#   'Efectivo'),
#  (389,
#   datetime.date(2024, 1, 16),
#   'Pilas',
#   'Hernández',
#   'Marta Ortiz',
#   'Efectivo'),
#  (390,
#   datetime.date(2024, 1, 16),
#   'Colonia',
#   'Medina',
#   'Ana González',
#   'Tarjeta'),
#  (391,
#   datetime.date(2024, 1, 16),
#   'Colonia',
#   'Medina',
#   'Eva Santos',
#   'Tarjeta'),
#  (392,
#   datetime.date(2024, 1, 16),
#   'Leche',
#   'Vázquez',
#   'Clara Álvarez',
#   'Tarjeta'),
#  (393,
#   datetime.date(2024, 1, 16),
#   'Leche',
#   'Carrillo',
#   'Pablo Jiménez',
#   'Efectivo'),
#  (394,
#   datetime.date(2024, 1, 16),
#   'Semillas',
#   'Peña',
#   'Irene Hernández',
#   'Tarjeta'),
#  (395,
#   datetime.date(2024, 1, 16),
#   'Tierra para macetas',
#   'Rodríguez',
#   'Miguel Flores',
#   'Efectivo'),
#  (396,
#   datetime.date(2024, 1, 17),
#   'Papas fritas',
#   'Flores',
#   'David Rubio',
#   'Tarjeta'),
#  (397,
#   datetime.date(2024, 1, 17),
#   'Leche',
#   'Paredes',
#   'Carla Cabrera',
#   'Tarjeta'),
#  (398,
#   datetime.date(2024, 1, 17),
#   'Jabón líquido',
#   'Moreno',
#   'Hugo Guzmán',
#   'Efectivo'),
#  (399,
#   datetime.date(2024, 1, 17),
#   'Champú',
#   'Esquivel',
#   'Clara Cabrera',
#   'Tarjeta'),
#  (400, datetime.date(2024, 1, 17), 'Tomate', 'López', 'Eva Montes', 'Tarjeta'),
#  (401,
#   datetime.date(2024, 1, 17),
#   'Pilas',
#   'Martínez',
#   'Eva Santos',
#   'Tarjeta'),
#  (402,
#   datetime.date(2024, 1, 17),
#   'Galletas',
#   'Carrillo',
#   'Diego Salinas',
#   'Efectivo'),
#  (403,
#   datetime.date(2024, 1, 17),
#   'Carne de res',
#   'Serrano',
#   'Raúl López',
#   'Tarjeta'),
#  (404,
#   datetime.date(2024, 1, 17),
#   'Regadera',
#   'Carrillo',
#   'Adriana González',
#   'Efectivo'),
#  (405,
#   datetime.date(2024, 1, 17),
#   'Tomate',
#   'Ramos',
#   'Javier Cruz',
#   'Tarjeta'),
#  (406,
#   datetime.date(2024, 1, 17),
#   'Mantequilla',
#   'Reyes',
#   'Ana Velázquez',
#   'Tarjeta'),
#  (407,
#   datetime.date(2024, 1, 17),
#   'Chicles',
#   'Moreno',
#   'Diego Fuentes',
#   'Efectivo'),
#  (408,
#   datetime.date(2024, 1, 17),
#   'Chicles',
#   'Martínez',
#   'Sara Domínguez',
#   'Tarjeta'),
#  (409,
#   datetime.date(2024, 1, 17),
#   'Lechuga',
#   'Guzmán',
#   'Irene Molina',
#   'Tarjeta'),
#  (410,
#   datetime.date(2024, 1, 17),
#   'Pilas',
#   'Hernández',
#   'Eva Montes',
#   'Efectivo'),
#  (411,
#   datetime.date(2024, 1, 17),
#   'Yogur',
#   'Martínez',
#   'Adriana González',
#   'Tarjeta'),
#  (412,
#   datetime.date(2024, 1, 17),
#   'Galletas',
#   'Ortiz',
#   'Irene Hernández',
#   'Tarjeta'),
#  (413,
#   datetime.date(2024, 1, 18),
#   'Zanahoria',
#   'Martínez',
#   'Diego Cortés',
#   'Tarjeta'),
#  (414,
#   datetime.date(2024, 1, 18),
#   'Lechuga',
#   'García',
#   'Francisco Romero',
#   'Tarjeta'),
#  (415,
#   datetime.date(2024, 1, 18),
#   'Crema hidratante',
#   'Ortiz',
#   'Ricardo Chávez',
#   'Tarjeta'),
#  (416,
#   datetime.date(2024, 1, 18),
#   'Mantequilla',
#   'Domínguez',
#   'Sara Salinas',
#   'Efectivo'),
#  (417,
#   datetime.date(2024, 1, 18),
#   'Chicles',
#   'Vázquez',
#   'Cristian Flores',
#   'Tarjeta'),
#  (418,
#   datetime.date(2024, 1, 18),
#   'Naranja',
#   'Cortés',
#   'José Santos',
#   'Efectivo'),
#  (419,
#   datetime.date(2024, 1, 18),
#   'Platos desechables',
#   'Cortés',
#   'Miguel Flores',
#   'Tarjeta'),
#  (420,
#   datetime.date(2024, 1, 18),
#   'Pollo',
#   'Domínguez',
#   'Eduardo Flores',
#   'Tarjeta'),
#  (421,
#   datetime.date(2024, 1, 18),
#   'Jugo de naranja',
#   'Lara',
#   'Tomás Rubio',
#   'Tarjeta'),
#  (422,
#   datetime.date(2024, 1, 18),
#   'Crema hidratante',
#   'Díaz',
#   'Carla Flores',
#   'Tarjeta'),
#  (423,
#   datetime.date(2024, 1, 18),
#   'Lechuga',
#   'Fernández',
#   'Daniel Ramírez',
#   'Tarjeta'),
#  (424,
#   datetime.date(2024, 1, 18),
#   'Papas fritas',
#   'Sánchez',
#   'Carmen González',
#   'Efectivo'),
#  (425,
#   datetime.date(2024, 1, 18),
#   'Mantequilla',
#   'Salinas',
#   'Daniel Ruiz',
#   'Efectivo'),
#  (426,
#   datetime.date(2024, 1, 18),
#   'Pollo',
#   'Ramírez',
#   'Diana Romero',
#   'Efectivo'),
#  (427,
#   datetime.date(2024, 1, 18),
#   'Cerveza',
#   'Ruiz',
#   'Carlos Jiménez',
#   'Tarjeta'),
#  (428,
#   datetime.date(2024, 1, 18),
#   'Cebolla',
#   'Paredes',
#   'David Rubio',
#   'Tarjeta'),
#  (429,
#   datetime.date(2024, 1, 18),
#   'Chuletas',
#   'Cruz',
#   'Cristian Rodríguez',
#   'Tarjeta'),
#  (430,
#   datetime.date(2024, 1, 18),
#   'Papas fritas',
#   'Álvarez',
#   'Adriana González',
#   'Tarjeta'),
#  (431,
#   datetime.date(2024, 1, 18),
#   'Mantequilla',
#   'Ramírez',
#   'Carla Flores',
#   'Efectivo'),
#  (432,
#   datetime.date(2024, 1, 18),
#   'Pollo',
#   'Pérez',
#   'Ana Velázquez',
#   'Tarjeta'),
#  (433,
#   datetime.date(2024, 1, 18),
#   'Papas fritas',
#   'González',
#   'Andrés Ortiz',
#   'Tarjeta'),
#  (434,
#   datetime.date(2024, 1, 18),
#   'Tomate',
#   'Reyes',
#   'Adriana González',
#   'Tarjeta'),
#  (435,
#   datetime.date(2024, 1, 18),
#   'Cerveza',
#   'Peña',
#   'Clara Salinas',
#   'Efectivo'),
#  (436,
#   datetime.date(2024, 1, 18),
#   'Chocolate',
#   'García',
#   'Diego Fuentes',
#   'Efectivo'),
#  (437,
#   datetime.date(2024, 1, 18),
#   'Champú',
#   'González',
#   'José Ramírez',
#   'Efectivo'),
#  (438,
#   datetime.date(2024, 1, 18),
#   'Naranja',
#   'Ortiz',
#   'Irene Molina',
#   'Tarjeta'),
#  (439,
#   datetime.date(2024, 1, 18),
#   'Banana',
#   'Molina',
#   'Adriana Navarro',
#   'Tarjeta'),
#  (440, datetime.date(2024, 1, 18), 'Pollo', 'Navarro', 'José Cruz', 'Tarjeta'),
#  (441,
#   datetime.date(2024, 1, 18),
#   'Tierra para macetas',
#   'Delgado',
#   'Carla Méndez',
#   'Tarjeta'),
#  (442,
#   datetime.date(2024, 1, 18),
#   'Colonia',
#   'López',
#   'Jorge Rodríguez',
#   'Tarjeta'),
#  (443,
#   datetime.date(2024, 1, 19),
#   'Agua',
#   'Vázquez',
#   'David Rubio',
#   'Efectivo'),
#  (444,
#   datetime.date(2024, 1, 19),
#   'Yogur',
#   'Cruz',
#   'Francisco García',
#   'Efectivo'),
#  (445,
#   datetime.date(2024, 1, 19),
#   'Esponjas',
#   'Jiménez',
#   'Raúl Reyes',
#   'Efectivo'),
#  (446,
#   datetime.date(2024, 1, 19),
#   'Champú',
#   'Serrano',
#   'Tomás Fernández',
#   'Tarjeta'),
#  (447, datetime.date(2024, 1, 19), 'Queso', 'Rubio', 'Laura López', 'Tarjeta'),
#  (448,
#   datetime.date(2024, 1, 19),
#   'Zanahoria',
#   'Campos',
#   'Adriana González',
#   'Efectivo'),
#  (449,
#   datetime.date(2024, 1, 19),
#   'Banana',
#   'Ruiz',
#   'David Santos',
#   'Tarjeta'),
#  (450,
#   datetime.date(2024, 1, 19),
#   'Pilas',
#   'Hernández',
#   'Cristian Campos',
#   'Tarjeta'),
#  (451,
#   datetime.date(2024, 1, 19),
#   'Uva',
#   'Ruiz',
#   'Tomás Fernández',
#   'Efectivo'),
#  (452,
#   datetime.date(2024, 1, 19),
#   'Uva',
#   'Ruiz',
#   'Carlos Delgado',
#   'Efectivo'),
#  (453,
#   datetime.date(2024, 1, 19),
#   'Galletas',
#   'Navarro',
#   'Lucía Pérez',
#   'Tarjeta'),
#  (454,
#   datetime.date(2024, 1, 19),
#   'Yogur',
#   'Moreno',
#   'Francisco García',
#   'Efectivo'),
#  (455, datetime.date(2024, 1, 19), 'Velas', 'Medina', 'Sara Peña', 'Efectivo'),
#  (456,
#   datetime.date(2024, 1, 19),
#   'Manzana',
#   'Campos',
#   'Andrés Ortiz',
#   'Tarjeta'),
#  (457,
#   datetime.date(2024, 1, 19),
#   'Pollo',
#   'Paredes',
#   'Cristian Paredes',
#   'Tarjeta'),
#  (458,
#   datetime.date(2024, 1, 19),
#   'Colonia',
#   'Ramírez',
#   'Carmen Guzmán',
#   'Tarjeta'),
#  (459,
#   datetime.date(2024, 1, 19),
#   'Papas fritas',
#   'Romero',
#   'Luis Navarro',
#   'Tarjeta'),
#  (460,
#   datetime.date(2024, 1, 19),
#   'Pollo',
#   'González',
#   'Diego Méndez',
#   'Tarjeta'),
#  (461,
#   datetime.date(2024, 1, 19),
#   'Velas',
#   'Torres',
#   'Cristian Campos',
#   'Tarjeta'),
#  (462,
#   datetime.date(2024, 1, 19),
#   'Tierra para macetas',
#   'Vázquez',
#   'Pablo Jiménez',
#   'Tarjeta'),
#  (463,
#   datetime.date(2024, 1, 19),
#   'Leche',
#   'Serrano',
#   'Ricardo Serrano',
#   'Tarjeta'),
#  (464,
#   datetime.date(2024, 1, 19),
#   'Platos desechables',
#   'González',
#   'Luis Navarro',
#   'Tarjeta'),
#  (465,
#   datetime.date(2024, 1, 19),
#   'Agua',
#   'Domínguez',
#   'Diego Sánchez',
#   'Efectivo'),
#  (466,
#   datetime.date(2024, 1, 19),
#   'Desinfectante',
#   'Ruiz',
#   'Carlos Torres',
#   'Tarjeta'),
#  (467,
#   datetime.date(2024, 1, 19),
#   'Agua',
#   'Fuentes',
#   'María Martínez',
#   'Tarjeta'),
#  (468,
#   datetime.date(2024, 1, 19),
#   'Tierra para macetas',
#   'Fernández',
#   'Cristian Campos',
#   'Tarjeta'),
#  (469,
#   datetime.date(2024, 1, 19),
#   'Detergente',
#   'Medina',
#   'Elena Guzmán',
#   'Efectivo'),
#  (470, datetime.date(2024, 1, 19), 'Agua', 'Lara', 'Javier Cruz', 'Tarjeta'),
#  (471,
#   datetime.date(2024, 1, 19),
#   'Regadera',
#   'Méndez',
#   'Andrés Ortiz',
#   'Tarjeta'),
#  (472,
#   datetime.date(2024, 1, 19),
#   'Desinfectante',
#   'Ramírez',
#   'Clara Delgado',
#   'Efectivo'),
#  (473,
#   datetime.date(2024, 1, 19),
#   'Tierra para macetas',
#   'Chávez',
#   'Julia Fuentes',
#   'Tarjeta'),
#  (474,
#   datetime.date(2024, 1, 19),
#   'Jugo de naranja',
#   'Hernández',
#   'Laura Ortiz',
#   'Efectivo'),
#  (475,
#   datetime.date(2024, 1, 19),
#   'Papas fritas',
#   'Montes',
#   'Ana Guzmán',
#   'Tarjeta'),
#  (476,
#   datetime.date(2024, 1, 19),
#   'Chuletas',
#   'Sánchez',
#   'Diego López',
#   'Tarjeta'),
#  (477,
#   datetime.date(2024, 1, 20),
#   'Chicles',
#   'Paredes',
#   'Ana Martínez',
#   'Tarjeta'),
#  (478,
#   datetime.date(2024, 1, 20),
#   'Mantequilla',
#   'Méndez',
#   'Lucía Campos',
#   'Tarjeta'),
#  (479,
#   datetime.date(2024, 1, 20),
#   'Naranja',
#   'Cruz',
#   'Cristian Flores',
#   'Tarjeta'),
#  (480,
#   datetime.date(2024, 1, 20),
#   'Cebolla',
#   'Velázquez',
#   'Irene Molina',
#   'Tarjeta'),
#  (481,
#   datetime.date(2024, 1, 20),
#   'Banana',
#   'Molina',
#   'Marta Ortiz',
#   'Tarjeta'),
#  (482,
#   datetime.date(2024, 1, 20),
#   'Agua',
#   'Peña',
#   'Cristian Flores',
#   'Tarjeta'),
#  (483,
#   datetime.date(2024, 1, 20),
#   'Colonia',
#   'Flores',
#   'Luis Esquivel',
#   'Tarjeta'),
#  (484,
#   datetime.date(2024, 1, 20),
#   'Regadera',
#   'Medina',
#   'Elena Álvarez',
#   'Tarjeta'),
#  (485,
#   datetime.date(2024, 1, 20),
#   'Agua',
#   'Cabrera',
#   'Carlos Lara',
#   'Tarjeta'),
#  (486,
#   datetime.date(2024, 1, 20),
#   'Cerdo',
#   'Sánchez',
#   'Laura López',
#   'Efectivo'),
#  (487,
#   datetime.date(2024, 1, 20),
#   'Mantequilla',
#   'Martínez',
#   'Diego López',
#   'Tarjeta'),
#  (488,
#   datetime.date(2024, 1, 20),
#   'Regadera',
#   'Ruiz',
#   'Diego Cortés',
#   'Efectivo'),
#  (489,
#   datetime.date(2024, 1, 20),
#   'Velas',
#   'Campos',
#   'Elena Guzmán',
#   'Tarjeta'),
#  (490,
#   datetime.date(2024, 1, 20),
#   'Cebolla',
#   'González',
#   'Eduardo Ortiz',
#   'Tarjeta'),
#  (491,
#   datetime.date(2024, 1, 20),
#   'Yogur',
#   'González',
#   'Adriana Navarro',
#   'Tarjeta'),
#  (492,
#   datetime.date(2024, 1, 20),
#   'Cerveza',
#   'Ortiz',
#   'Carla Ruiz',
#   'Tarjeta'),
#  (493,
#   datetime.date(2024, 1, 20),
#   'Chocolate',
#   'López',
#   'Camila Fernández',
#   'Tarjeta'),
#  (494,
#   datetime.date(2024, 1, 20),
#   'Agua',
#   'Sánchez',
#   'David Delgado',
#   'Tarjeta'),
#  (495, datetime.date(2024, 1, 20), 'Velas', 'Ruiz', 'Irene Ruiz', 'Efectivo'),
#  (496,
#   datetime.date(2024, 1, 20),
#   'Regadera',
#   'López',
#   'Ricardo Campos',
#   'Tarjeta'),
#  (497, datetime.date(2024, 1, 21), 'Velas', 'Ramos', 'Ana Guzmán', 'Tarjeta'),
#  (498,
#   datetime.date(2024, 1, 21),
#   'Jugo de naranja',
#   'Santos',
#   'Clara Cabrera',
#   'Tarjeta'),
#  (499,
#   datetime.date(2024, 1, 21),
#   'Agua',
#   'García',
#   'Manuel Ortiz',
#   'Tarjeta'),
#  (500,
#   datetime.date(2024, 1, 21),
#   'Zanahoria',
#   'Aguilar',
#   'Ana Martínez',
#   'Tarjeta'),
#  (501,
#   datetime.date(2024, 1, 21),
#   'Jugo de naranja',
#   'Serrano',
#   'Samuel Sánchez',
#   'Efectivo'),
#  (502,
# ...
#   'Tierra para macetas',
#   'González',
#   'Tomás Fernández',
#   'Tarjeta'),
#  (833,
#   datetime.date(2024, 2, 1),
#   'Jugo de naranja',
#   'Reyes',
#   'Camila Fernández',
#   'Tarjeta'),
#  (834,
#   datetime.date(2024, 2, 1),
#   'Jugo de naranja',
#   'Velázquez',
#   'Hugo Sánchez',
#   'Efectivo'),
#  (835,
#   datetime.date(2024, 2, 1),
#   'Detergente',
#   'Domínguez',
#   'Carlos Torres',
#   'Efectivo'),
#  (836,
#   datetime.date(2024, 2, 1),
#   'Lechuga',
#   'Pérez',
#   'Andrea Vázquez',
#   'Tarjeta'),
#  (837,
#   datetime.date(2024, 2, 1),
#   'Chicles',
#   'Serrano',
#   'Eduardo Ortiz',
#   'Tarjeta'),
#  (838,
#   datetime.date(2024, 2, 1),
#   'Lechuga',
#   'Velázquez',
#   'Cristian Rodríguez',
#   'Tarjeta'),
#  (839,
#   datetime.date(2024, 2, 1),
#   'Cerveza',
#   'Delgado',
#   'David Rubio',
#   'Tarjeta'),
#  (840,
#   datetime.date(2024, 2, 1),
#   'Refresco',
#   'Carrillo',
#   'María Castro',
#   'Tarjeta'),
#  (841,
#   datetime.date(2024, 2, 1),
#   'Refresco',
#   'Jiménez',
#   'Laura López',
#   'Efectivo'),
#  (842,
#   datetime.date(2024, 2, 1),
#   'Zanahoria',
#   'López',
#   'Clara Álvarez',
#   'Efectivo'),
#  (843,
#   datetime.date(2024, 2, 1),
#   'Platos desechables',
#   'Velázquez',
#   'Manuel Ramos',
#   'Efectivo'),
#  (844,
#   datetime.date(2024, 2, 2),
#   'Regadera',
#   'Peña',
#   'Hugo Guzmán',
#   'Tarjeta'),
#  (845,
#   datetime.date(2024, 2, 2),
#   'Chuletas',
#   'González',
#   'Francisco García',
#   'Efectivo'),
#  (846,
#   datetime.date(2024, 2, 2),
#   'Lechuga',
#   'Santos',
#   'Ana Fernández',
#   'Tarjeta'),
#  (847,
#   datetime.date(2024, 2, 2),
#   'Desodorante',
#   'Esquivel',
#   'Samuel González',
#   'Tarjeta'),
#  (848, datetime.date(2024, 2, 2), 'Champú', 'Peña', 'Hugo Sánchez', 'Tarjeta'),
#  (849,
#   datetime.date(2024, 2, 2),
#   'Cerveza',
#   'Peña',
#   'Jorge Cortés',
#   'Tarjeta'),
#  (850,
#   datetime.date(2024, 2, 2),
#   'Desodorante',
#   'Díaz',
#   'Raúl Serrano',
#   'Tarjeta'),
#  (851,
#   datetime.date(2024, 2, 2),
#   'Colonia',
#   'Díaz',
#   'Pablo Ramírez',
#   'Tarjeta'),
#  (852,
#   datetime.date(2024, 2, 2),
#   'Chuletas',
#   'Ortiz',
#   'María Pérez',
#   'Efectivo'),
#  (853,
#   datetime.date(2024, 2, 2),
#   'Mantequilla',
#   'Rodríguez',
#   'Ricardo Álvarez',
#   'Efectivo'),
#  (854,
#   datetime.date(2024, 2, 2),
#   'Chicles',
#   'Díaz',
#   'Andrea Vázquez',
#   'Efectivo'),
#  (855,
#   datetime.date(2024, 2, 2),
#   'Pollo',
#   'Méndez',
#   'Pablo Ramírez',
#   'Efectivo'),
#  (856,
#   datetime.date(2024, 2, 2),
#   'Banana',
#   'Flores',
#   'Jorge Rodríguez',
#   'Tarjeta'),
#  (857,
#   datetime.date(2024, 2, 2),
#   'Mantequilla',
#   'Díaz',
#   'David Delgado',
#   'Tarjeta'),
#  (858,
#   datetime.date(2024, 2, 2),
#   'Regadera',
#   'Peña',
#   'David Rubio',
#   'Tarjeta'),
#  (859,
#   datetime.date(2024, 2, 2),
#   'Semillas',
#   'Esquivel',
#   'Diego Salinas',
#   'Tarjeta'),
#  (860,
#   datetime.date(2024, 2, 2),
#   'Cerdo',
#   'Rodríguez',
#   'Cristian Campos',
#   'Tarjeta'),
#  (861,
#   datetime.date(2024, 2, 2),
#   'Jugo de naranja',
#   'Moreno',
#   'Julia Carrillo',
#   'Tarjeta'),
#  (862,
#   datetime.date(2024, 2, 2),
#   'Jugo de naranja',
#   'Castro',
#   'Jorge Cortés',
#   'Tarjeta'),
#  (863,
#   datetime.date(2024, 2, 2),
#   'Refresco',
#   'Fuentes',
#   'Adriana Navarro',
#   'Tarjeta'),
#  (864,
#   datetime.date(2024, 2, 2),
#   'Cebolla',
#   'Martínez',
#   'Carmen González',
#   'Tarjeta'),
#  (865,
#   datetime.date(2024, 2, 3),
#   'Zanahoria',
#   'Romero',
#   'Raúl Serrano',
#   'Tarjeta'),
#  (866,
#   datetime.date(2024, 2, 3),
#   'Pollo',
#   'Méndez',
#   'Diana Campos',
#   'Efectivo'),
#  (867,
#   datetime.date(2024, 2, 3),
#   'Cerveza',
#   'Navarro',
#   'Adriana Guzmán',
#   'Tarjeta'),
#  (868,
#   datetime.date(2024, 2, 3),
#   'Mantequilla',
#   'Navarro',
#   'Ricardo González',
#   'Efectivo'),
#  (869,
#   datetime.date(2024, 2, 3),
#   'Chocolate',
#   'Torres',
#   'Eva Santos',
#   'Efectivo'),
#  (870,
#   datetime.date(2024, 2, 3),
#   'Pollo',
#   'Hernández',
#   'Ricardo González',
#   'Tarjeta'),
#  (871,
#   datetime.date(2024, 2, 3),
#   'Colonia',
#   'Navarro',
#   'David Montes',
#   'Tarjeta'),
#  (872,
#   datetime.date(2024, 2, 3),
#   'Banana',
#   'Díaz',
#   'Carmen Medina',
#   'Tarjeta'),
#  (873, datetime.date(2024, 2, 3), 'Pollo', 'Peña', 'Carlos Pérez', 'Efectivo'),
#  (874,
#   datetime.date(2024, 2, 3),
#   'Lechuga',
#   'García',
#   'Paula Ortiz',
#   'Efectivo'),
#  (875, datetime.date(2024, 2, 3), 'Pilas', 'Ortiz', 'Ana Martínez', 'Tarjeta'),
#  (876, datetime.date(2024, 2, 3), 'Yogur', 'Ortiz', 'Javier Cruz', 'Tarjeta'),
#  (877,
#   datetime.date(2024, 2, 3),
#   'Pollo',
#   'Campos',
#   'Francisco García',
#   'Efectivo'),
#  (878,
#   datetime.date(2024, 2, 3),
#   'Semillas',
#   'Peña',
#   'María Pérez',
#   'Tarjeta'),
#  (879,
#   datetime.date(2024, 2, 3),
#   'Chocolate',
#   'Campos',
#   'Jorge Rodríguez',
#   'Tarjeta'),
#  (880, datetime.date(2024, 2, 3), 'Uva', 'Pérez', 'Raúl González', 'Tarjeta'),
#  (881,
#   datetime.date(2024, 2, 3),
#   'Zanahoria',
#   'Romero',
#   'Eva Montes',
#   'Tarjeta'),
#  (882,
#   datetime.date(2024, 2, 3),
#   'Desinfectante',
#   'Esquivel',
#   'Lucía Pérez',
#   'Efectivo'),
#  (883,
#   datetime.date(2024, 2, 3),
#   'Mantequilla',
#   'Navarro',
#   'Ricardo Chávez',
#   'Efectivo'),
#  (884,
#   datetime.date(2024, 2, 3),
#   'Chocolate',
#   'Ortiz',
#   'Samuel González',
#   'Tarjeta'),
#  (885,
#   datetime.date(2024, 2, 3),
#   'Pollo',
#   'Torres',
#   'Eduardo Ortiz',
#   'Tarjeta'),
#  (886,
#   datetime.date(2024, 2, 3),
#   'Desodorante',
#   'Campos',
#   'Ricardo Campos',
#   'Tarjeta'),
#  (887,
#   datetime.date(2024, 2, 3),
#   'Fertilizante',
#   'López',
#   'Hugo Guzmán',
#   'Tarjeta'),
#  (888, datetime.date(2024, 2, 3), 'Regadera', 'Díaz', 'Raúl López', 'Tarjeta'),
#  (889,
#   datetime.date(2024, 2, 3),
#   'Champú',
#   'Santos',
#   'Julia Campos',
#   'Efectivo'),
#  (890,
#   datetime.date(2024, 2, 3),
#   'Cebolla',
#   'Castro',
#   'Diana Navarro',
#   'Efectivo'),
#  (891,
#   datetime.date(2024, 2, 4),
#   'Bolsas de basura',
#   'Navarro',
#   'Diana Romero',
#   'Tarjeta'),
#  (892,
#   datetime.date(2024, 2, 4),
#   'Cerdo',
#   'Cabrera',
#   'Sara Moreno',
#   'Tarjeta'),
#  (893,
#   datetime.date(2024, 2, 4),
#   'Jugo de naranja',
#   'Sánchez',
#   'Javier García',
#   'Tarjeta'),
#  (894,
#   datetime.date(2024, 2, 4),
#   'Refresco',
#   'Santos',
#   'Eva Montes',
#   'Efectivo'),
#  (895,
#   datetime.date(2024, 2, 4),
#   'Desodorante',
#   'Rubio',
#   'Eva Montes',
#   'Efectivo'),
#  (896,
#   datetime.date(2024, 2, 4),
#   'Papas fritas',
#   'Rubio',
#   'Carla Flores',
#   'Efectivo'),
#  (897,
#   datetime.date(2024, 2, 4),
#   'Uva',
#   'Delgado',
#   'Javier García',
#   'Tarjeta'),
#  (898,
#   datetime.date(2024, 2, 4),
#   'Cerdo',
#   'Aguilar',
#   'Elena Álvarez',
#   'Tarjeta'),
#  (899,
#   datetime.date(2024, 2, 4),
#   'Colonia',
#   'Guzmán',
#   'Hugo Díaz',
#   'Efectivo'),
#  (900,
#   datetime.date(2024, 2, 4),
#   'Leche',
#   'Cortés',
#   'Ricardo Álvarez',
#   'Efectivo'),
#  (901,
#   datetime.date(2024, 2, 4),
#   'Colonia',
#   'Reyes',
#   'Hugo Sánchez',
#   'Efectivo'),
#  (902,
#   datetime.date(2024, 2, 4),
#   'Desinfectante',
#   'González',
#   'Carmen Medina',
#   'Efectivo'),
#  (903,
#   datetime.date(2024, 2, 4),
#   'Zanahoria',
#   'Vázquez',
#   'Cristian Campos',
#   'Tarjeta'),
#  (904,
#   datetime.date(2024, 2, 4),
#   'Tierra para macetas',
#   'Delgado',
#   'José Ramírez',
#   'Tarjeta'),
#  (905,
#   datetime.date(2024, 2, 4),
#   'Jugo de naranja',
#   'Cabrera',
#   'Isabel Carrillo',
#   'Tarjeta'),
#  (906,
#   datetime.date(2024, 2, 4),
#   'Zanahoria',
#   'García',
#   'Sara Montes',
#   'Tarjeta'),
#  (907, datetime.date(2024, 2, 4), 'Uva', 'Delgado', 'Hugo Sánchez', 'Tarjeta'),
#  (908,
#   datetime.date(2024, 2, 4),
#   'Papas fritas',
#   'Rubio',
#   'Laura López',
#   'Efectivo'),
#  (909,
#   datetime.date(2024, 2, 4),
#   'Refresco',
#   'Paredes',
#   'Adriana Rubio',
#   'Efectivo'),
#  (910,
#   datetime.date(2024, 2, 4),
#   'Jugo de naranja',
#   'Velázquez',
#   'Isabel Carrillo',
#   'Efectivo'),
#  (911,
#   datetime.date(2024, 2, 4),
#   'Cerveza',
#   'Campos',
#   'Sara Fernández',
#   'Efectivo'),
#  (912,
#   datetime.date(2024, 2, 4),
#   'Pilas',
#   'Hernández',
#   'Samuel Sánchez',
#   'Tarjeta'),
#  (913,
#   datetime.date(2024, 2, 4),
#   'Desodorante',
#   'Rodríguez',
#   'Sara Moreno',
#   'Tarjeta'),
#  (914, datetime.date(2024, 2, 4), 'Pollo', 'Navarro', 'Eva Santos', 'Tarjeta'),
#  (915, datetime.date(2024, 2, 4), 'Banana', 'Flores', 'Raúl Reyes', 'Tarjeta'),
#  (916,
#   datetime.date(2024, 2, 4),
#   'Tierra para macetas',
#   'Montes',
#   'Daniel Serrano',
#   'Efectivo'),
#  (917,
#   datetime.date(2024, 2, 5),
#   'Pollo',
#   'Castro',
#   'Irene Martínez',
#   'Tarjeta'),
#  (918, datetime.date(2024, 2, 5), 'Uva', 'Guzmán', 'Sofía Montes', 'Efectivo'),
#  (919,
#   datetime.date(2024, 2, 5),
#   'Refresco',
#   'Jiménez',
#   'Cristian Paredes',
#   'Tarjeta'),
#  (920, datetime.date(2024, 2, 5), 'Uva', 'Ruiz', 'Samuel Sánchez', 'Tarjeta'),
#  (921, datetime.date(2024, 2, 5), 'Velas', 'Ramos', 'Laura Ortiz', 'Tarjeta'),
#  (922,
#   datetime.date(2024, 2, 5),
#   'Chocolate',
#   'Molina',
#   'Marta Ortiz',
#   'Tarjeta'),
#  (923,
#   datetime.date(2024, 2, 5),
#   'Lechuga',
#   'Medina',
#   'Tomás Fernández',
#   'Tarjeta'),
#  (924,
#   datetime.date(2024, 2, 5),
#   'Pilas',
#   'Medina',
#   'Carla Flores',
#   'Efectivo'),
#  (925,
#   datetime.date(2024, 2, 5),
#   'Bolsas de basura',
#   'Navarro',
#   'Eva Santos',
#   'Tarjeta'),
#  (926,
#   datetime.date(2024, 2, 5),
#   'Refresco',
#   'García',
#   'Manuel Ortiz',
#   'Efectivo'),
#  (927,
#   datetime.date(2024, 2, 5),
#   'Tierra para macetas',
#   'Ortiz',
#   'Cristian Campos',
#   'Tarjeta'),
#  (928,
#   datetime.date(2024, 2, 5),
#   'Bolsas de basura',
#   'Salinas',
#   'Pablo Ramírez',
#   'Efectivo'),
#  (929,
#   datetime.date(2024, 2, 5),
#   'Cerdo',
#   'Rodríguez',
#   'David Hernández',
#   'Tarjeta'),
#  (930,
#   datetime.date(2024, 2, 5),
#   'Jabón líquido',
#   'Rodríguez',
#   'Carlos Pérez',
#   'Efectivo'),
#  (931,
#   datetime.date(2024, 2, 5),
#   'Chocolate',
#   'Reyes',
#   'Diego Sánchez',
#   'Efectivo'),
#  (932,
#   datetime.date(2024, 2, 5),
#   'Esponjas',
#   'Lara',
#   'Carmen González',
#   'Tarjeta'),
#  (933,
#   datetime.date(2024, 2, 5),
#   'Detergente',
#   'González',
#   'José Ramírez',
#   'Tarjeta'),
#  (934,
#   datetime.date(2024, 2, 6),
#   'Cerdo',
#   'González',
#   'Paula Ortiz',
#   'Tarjeta'),
#  (935,
#   datetime.date(2024, 2, 6),
#   'Naranja',
#   'Torres',
#   'Clara Cabrera',
#   'Tarjeta'),
#  (936,
#   datetime.date(2024, 2, 6),
#   'Esponjas',
#   'Fuentes',
#   'Clara Cabrera',
#   'Efectivo'),
#  (937,
#   datetime.date(2024, 2, 6),
#   'Cerveza',
#   'Serrano',
#   'Laura González',
#   'Efectivo'),
#  (938,
#   datetime.date(2024, 2, 6),
#   'Velas',
#   'Moreno',
#   'Sofía Delgado',
#   'Efectivo'),
#  (939,
#   datetime.date(2024, 2, 6),
#   'Cerveza',
#   'Vázquez',
#   'Sara Montes',
#   'Tarjeta'),
#  (940, datetime.date(2024, 2, 6), 'Yogur', 'Lara', 'Eva Montes', 'Tarjeta'),
#  (941,
#   datetime.date(2024, 2, 6),
#   'Detergente',
#   'Flores',
#   'Ana Guzmán',
#   'Efectivo'),
#  (942,
#   datetime.date(2024, 2, 6),
#   'Jabón líquido',
#   'Guzmán',
#   'Camila Fernández',
#   'Tarjeta'),
#  (943,
#   datetime.date(2024, 2, 6),
#   'Chocolate',
#   'Romero',
#   'Ana Fernández',
#   'Efectivo'),
#  (944, datetime.date(2024, 2, 6), 'Semillas', 'Díaz', 'Raúl López', 'Tarjeta'),
#  (945,
#   datetime.date(2024, 2, 6),
#   'Manzana',
#   'Ruiz',
#   'Carmen Medina',
#   'Tarjeta'),
#  (946, datetime.date(2024, 2, 6), 'Chuletas', 'Peña', 'Sara Peña', 'Tarjeta'),
#  (947,
#   datetime.date(2024, 2, 6),
#   'Semillas',
#   'Santos',
#   'Diego López',
#   'Efectivo'),
#  (948,
#   datetime.date(2024, 2, 6),
#   'Pollo',
#   'Navarro',
#   'Tomás Rubio',
#   'Tarjeta'),
#  (949, datetime.date(2024, 2, 6), 'Tomate', 'Rubio', 'Sara Moreno', 'Tarjeta'),
#  (950,
#   datetime.date(2024, 2, 6),
#   'Jugo de naranja',
#   'Castro',
#   'Ana Martínez',
#   'Tarjeta'),
#  (951, datetime.date(2024, 2, 6), 'Pollo', 'Peña', 'Diego Ortiz', 'Efectivo'),
#  (952,
#   datetime.date(2024, 2, 6),
#   'Galletas',
#   'Hernández',
#   'Patricia Domínguez',
#   'Efectivo'),
#  (953,
#   datetime.date(2024, 2, 6),
#   'Lechuga',
#   'Fuentes',
#   'Sara Montes',
#   'Tarjeta'),
#  (954,
#   datetime.date(2024, 2, 6),
#   'Lechuga',
#   'Montes',
#   'Isabel Carrillo',
#   'Efectivo'),
#  (955,
#   datetime.date(2024, 2, 6),
#   'Queso',
#   'Fuentes',
#   'Samuel González',
#   'Tarjeta'),
#  (956,
#   datetime.date(2024, 2, 6),
#   'Leche',
#   'Castro',
#   'Andrea Santos',
#   'Tarjeta'),
#  (957,
#   datetime.date(2024, 2, 6),
#   'Manzana',
#   'Guzmán',
#   'Cristian Campos',
#   'Tarjeta'),
#  (958,
#   datetime.date(2024, 2, 7),
#   'Semillas',
#   'Cruz',
#   'Cristian Campos',
#   'Tarjeta'),
#  (959,
#   datetime.date(2024, 2, 7),
#   'Jabón líquido',
#   'Moreno',
#   'Andrea Vázquez',
#   'Tarjeta'),
#  (960,
#   datetime.date(2024, 2, 7),
#   'Jabón líquido',
#   'Flores',
#   'Cristian Paredes',
#   'Tarjeta'),
#  (961,
#   datetime.date(2024, 2, 7),
#   'Lechuga',
#   'Santos',
#   'Laura Ortiz',
#   'Efectivo'),
#  (962,
#   datetime.date(2024, 2, 7),
#   'Mantequilla',
#   'Sánchez',
#   'Elena Álvarez',
#   'Efectivo'),
#  (963,
#   datetime.date(2024, 2, 7),
#   'Desinfectante',
#   'Ramírez',
#   'Hugo Sánchez',
#   'Tarjeta'),
#  (964,
#   datetime.date(2024, 2, 7),
#   'Galletas',
#   'Torres',
#   'Tomás Rubio',
#   'Efectivo'),
#  (965,
#   datetime.date(2024, 2, 7),
#   'Regadera',
#   'Montes',
#   'Samuel Sánchez',
#   'Tarjeta'),
#  (966,
#   datetime.date(2024, 2, 7),
#   'Fertilizante',
#   'Moreno',
#   'Laura Ortiz',
#   'Efectivo'),
#  (967,
#   datetime.date(2024, 2, 7),
#   'Banana',
#   'Montes',
#   'Diego Fuentes',
#   'Tarjeta'),
#  (968,
#   datetime.date(2024, 2, 7),
#   'Fertilizante',
#   'Delgado',
#   'Mario Ortiz',
#   'Tarjeta'),
#  (969,
#   datetime.date(2024, 2, 7),
#   'Naranja',
#   'Molina',
#   'Verónica Álvarez',
#   'Efectivo'),
#  (970,
#   datetime.date(2024, 2, 8),
#   'Lechuga',
#   'Cruz',
#   'Samuel González',
#   'Tarjeta'),
#  (971, datetime.date(2024, 2, 8), 'Queso', 'Reyes', 'Laura Ortiz', 'Tarjeta'),
#  (972,
#   datetime.date(2024, 2, 8),
#   'Tomate',
#   'Cortés',
#   'Diana Serrano',
#   'Tarjeta'),
#  (973,
#   datetime.date(2024, 2, 8),
#   'Chuletas',
#   'Peña',
#   'Diego Méndez',
#   'Tarjeta'),
#  (974,
#   datetime.date(2024, 2, 8),
#   'Fertilizante',
#   'Fernández',
#   'Clara Álvarez',
#   'Tarjeta'),
#  (975,
#   datetime.date(2024, 2, 8),
#   'Queso',
#   'Sánchez',
#   'Gabriela Reyes',
#   'Tarjeta'),
#  (976,
#   datetime.date(2024, 2, 8),
#   'Jugo de naranja',
#   'Santos',
#   'Laura González',
#   'Tarjeta'),
#  (977,
#   datetime.date(2024, 2, 8),
#   'Mantequilla',
#   'Ortiz',
#   'David Hernández',
#   'Efectivo'),
#  (978, datetime.date(2024, 2, 8), 'Cerveza', 'Ramos', 'Irene Ruiz', 'Tarjeta'),
#  (979,
#   datetime.date(2024, 2, 8),
#   'Refresco',
#   'Castro',
#   'Andrés Ortiz',
#   'Tarjeta'),
#  (980, datetime.date(2024, 2, 8), 'Yogur', 'Castro', 'Raúl López', 'Efectivo'),
#  (981,
#   datetime.date(2024, 2, 8),
#   'Semillas',
#   'Ruiz',
#   'Luis Esquivel',
#   'Tarjeta'),
#  (982,
#   datetime.date(2024, 2, 8),
#   'Mantequilla',
#   'Santos',
#   'Cristian Campos',
#   'Efectivo'),
#  (983,
#   datetime.date(2024, 2, 8),
#   'Champú',
#   'Rubio',
#   'Cristian Rodríguez',
#   'Tarjeta'),
#  (984,
#   datetime.date(2024, 2, 8),
#   'Semillas',
#   'Aguilar',
#   'Carla Méndez',
#   'Tarjeta'),
#  (985,
#   datetime.date(2024, 2, 8),
#   'Tierra para macetas',
#   'Delgado',
#   'Sofía Montes',
#   'Tarjeta'),
#  (986,
#   datetime.date(2024, 2, 8),
#   'Detergente',
#   'Flores',
#   'Lucía Pérez',
#   'Tarjeta'),
#  (987,
#   datetime.date(2024, 2, 8),
#   'Galletas',
#   'Ortiz',
#   'María Pérez',
#   'Efectivo'),
#  (988,
#   datetime.date(2024, 2, 8),
#   'Velas',
#   'Rubio',
#   'Luis Salinas',
#   'Efectivo'),
#  (989,
#   datetime.date(2024, 2, 8),
#   'Cebolla',
#   'Reyes',
#   'Diego Cortés',
#   'Efectivo'),
#  (990,
#   datetime.date(2024, 2, 8),
#   'Carne de res',
#   'García',
#   'Elena Álvarez',
#   'Tarjeta'),
#  (991,
#   datetime.date(2024, 2, 8),
#   'Refresco',
#   'García',
#   'Carla Cabrera',
#   'Tarjeta'),
#  (992,
#   datetime.date(2024, 2, 8),
#   'Agua',
#   'Álvarez',
#   'Diana Serrano',
#   'Tarjeta'),
#  (993,
#   datetime.date(2024, 2, 8),
#   'Jugo de naranja',
#   'Montes',
#   'Samuel Fernández',
#   'Efectivo'),
#  (994,
#   datetime.date(2024, 2, 9),
#   'Tomate',
#   'Domínguez',
#   'Mario Torres',
#   'Tarjeta'),
#  (995,
#   datetime.date(2024, 2, 9),
#   'Champú',
#   'Cruz',
#   'Samuel González',
#   'Efectivo'),
#  (996,
#   datetime.date(2024, 2, 9),
#   'Cebolla',
#   'Paredes',
#   'Laura Ortiz',
#   'Efectivo'),
#  (997,
#   datetime.date(2024, 2, 9),
#   'Velas',
#   'Ortiz',
#   'Elena Álvarez',
#   'Tarjeta'),
#  (998,
#   datetime.date(2024, 2, 9),
#   'Tomate',
#   'Romero',
#   'Adriana Esquivel',
#   'Efectivo'),
#  (999, datetime.date(2024, 2, 9), 'Velas', 'Serrano', 'Ana Guzmán', 'Tarjeta'),
#  (1000,
#   datetime.date(2024, 2, 9),
#   'Mantequilla',
#   'Salinas',
#   'Carla Ruiz',
#   'Efectivo'),
#  ...]

# %% [markdown]
# * 2.- Productos con stock bajo
#
#     * Filtra aquellos productos cuyo stock sea menor a 10.
#     * Muestra nombre del producto, categoría y stock.

# %%
sql = ('SELECT p.nombre_producto, c.nombre_categoria, p.stock FROM productos p JOIN categorias c ON p.id_categoria = c.id_categoria WHERE p.stock < 10;')
consultas(sql)
# Out:
# [('Esponjas', 'Vinos', 6)]

# %% [markdown]
# * 3.-Ventas totales por categoría
#
#     * Muestra el nombre de la categoría y la suma total de las ventas (ej.: multiplicando cantidad * precio_unitario) para cada categoría.
#     * Realiza el JOIN con detalle_orden, productos y categorias.
#     * Utiliza agrupación (GROUP BY).

# %%
sql = ('SELECT c.nombre_categoria as categoria, sum((d.precio_unitario * ( 1 - d.descuento)) * d.cantidad) as ventas FROM categorias c JOIN productos p ON p.id_categoria = c.id_categoria JOIN detalle_orden d ON d.id_producto = p.id_producto GROUP BY c.id_categoria;')
consultas(sql)
# Out:
# [('Lácteos', 183177.56),
#  ('Pescados', 167649.91),
#  ('Carnes', 223654.87),
#  ('Verduras', 113402.88),
#  ('Frutas', 232117.31),
#  ('Bollería y Pan', 142723.49),
#  ('Refrescos', 165615.18),
#  ('Vinos', 168907.7),
#  ('Alcohol', 188422.02),
#  ('Congelados', 190887.71)]

# %% [markdown]
# * 4.-Clientes con mayores gastos acumulados
#
#
#     * Muestra el nombre del cliente y el monto total que ha gastado (suma de todas sus órdenes).
#     * Asegúrate de tener en cuenta posibles descuentos (descuento) si se ha definido. Por ejemplo, la fórmula podría ser (cantidad * precio_unitario) - descuento.
#     * Ordena el resultado de mayor a menor gasto acumulado.

# %%
sql = ('SELECT c.first_name as nombre, c.last_name as apellido, sum((d.precio_unitario * ( 1 - d.descuento)) * d.cantidad) as compras FROM clientes c JOIN ordenes o ON c.id_cliente = o.id_cliente JOIN detalle_orden d ON d.id_orden = o.id_orden GROUP BY c.id_cliente ORDER BY sum((d.precio_unitario * ( 1 - d.descuento)) * d.cantidad) DESC;')
consultas(sql)
# Out:
# [('Semillas', 'Medina', 2862.24),
#  ('Desinfectante', 'Méndez', 2803.18),
#  ('Leche', 'Carrillo', 2774.45),
#  ('Mantequilla', 'Pérez', 2709.77),
#  ('Refresco', 'García', 2590.51),
#  ('Papas fritas', 'Sánchez', 2570.63),
#  ('Carne de res', 'García', 2549.28),
#  ('Banana', 'Hernández', 2506.61),
#  ('Refresco', 'Moreno', 2473.48),
#  ('Chicles', 'Vázquez', 2470.09),
#  ('Cerveza', 'Aguilar', 2441.22),
#  ('Cerdo', 'González', 2437.66),
#  ('Manzana', 'Ortiz', 2427.23),
#  ('Jugo de naranja', 'Moreno', 2416.44),
#  ('Jugo de naranja', 'Ortiz', 2366.45),
#  ('Cebolla', 'Santos', 2365.27),
#  ('Pollo', 'Méndez', 2365.2),
#  ('Tierra para macetas', 'Navarro', 2347.43),
#  ('Yogur', 'Vázquez', 2315.88),
#  ('Platos desechables', 'Paredes', 2260.85),
#  ('Banana', 'Delgado', 2229.75),
#  ('Cebolla', 'Rodríguez', 2219.67),
#  ('Carne de res', 'Flores', 2210.13),
#  ('Pollo', 'Castro', 2189.6),
#  ('Regadera', 'López', 2180.13),
#  ('Yogur', 'Lara', 2149.12),
#  ('Yogur', 'Ruiz', 2140.76),
#  ('Manzana', 'Cabrera', 2108.18),
#  ('Cerdo', 'Castro', 2106.47),
#  ('Mantequilla', 'Salinas', 2098.3),
#  ('Banana', 'García', 2084.59),
#  ('Queso', 'Romero', 2076.66),
#  ('Detergente', 'Peña', 2065.99),
#  ('Tierra para macetas', 'Delgado', 2060.64),
#  ('Fertilizante', 'Domínguez', 2054.0),
#  ('Queso', 'Ramírez', 2049.61),
#  ('Colonia', 'Ruiz', 2041.39),
#  ('Pilas', 'Álvarez', 2037.56),
#  ('Cebolla', 'Rodríguez', 2033.35),
#  ('Champú', 'Ramos', 2030.25),
#  ('Cerveza', 'Delgado', 2027.46),
#  ('Cebolla', 'Paredes', 2025.72),
#  ('Jugo de naranja', 'Montes', 2023.63),
#  ('Chuletas', 'Torres', 2013.16),
#  ('Detergente', 'Medina', 2000.23),
#  ('Detergente', 'Lara', 1987.66),
#  ('Chicles', 'Cabrera', 1986.24),
#  ('Semillas', 'Cruz', 1981.05),
#  ('Papas fritas', 'Torres', 1980.18),
#  ('Chicles', 'Jiménez', 1967.55),
#  ('Velas', 'Ruiz', 1966.94),
#  ('Manzana', 'Moreno', 1961.98),
#  ('Chuletas', 'Hernández', 1959.08),
#  ('Semillas', 'Martínez', 1953.47),
#  ('Manzana', 'González', 1951.27),
#  ('Queso', 'Molina', 1948.57),
#  ('Champú', 'Reyes', 1916.14),
#  ('Pilas', 'Rodríguez', 1911.63),
#  ('Tierra para macetas', 'Ortiz', 1907.32),
#  ('Semillas', 'Ramírez', 1895.02),
#  ('Cebolla', 'López', 1888.94),
#  ('Galletas', 'Carrillo', 1886.57),
#  ('Colonia', 'Domínguez', 1881.11),
#  ('Regadera', 'Montes', 1879.54),
#  ('Uva', 'Fuentes', 1879.45),
#  ('Pilas', 'Cabrera', 1878.76),
#  ('Esponjas', 'Fuentes', 1876.61),
#  ('Queso', 'Flores', 1873.14),
#  ('Manzana', 'Jiménez', 1868.77),
#  ('Champú', 'Álvarez', 1868.76),
#  ('Tomate', 'Ramírez', 1868.54),
#  ('Cebolla', 'García', 1867.62),
#  ('Jugo de naranja', 'González', 1858.05),
#  ('Esponjas', 'Ruiz', 1855.43),
#  ('Regadera', 'Flores', 1848.31),
#  ('Esponjas', 'Pérez', 1846.97),
#  ('Refresco', 'Ortiz', 1840.13),
#  ('Cebolla', 'Aguilar', 1836.98),
#  ('Tomate', 'Navarro', 1831.95),
#  ('Jabón líquido', 'Aguilar', 1831.36),
#  ('Agua', 'Flores', 1830.41),
#  ('Yogur', 'Delgado', 1823.56),
#  ('Manzana', 'Pérez', 1822.78),
#  ('Cerveza', 'Paredes', 1822.46),
#  ('Uva', 'Cortés', 1810.64),
#  ('Lechuga', 'Fuentes', 1809.45),
#  ('Tomate', 'García', 1807.91),
#  ('Desodorante', 'Campos', 1795.83),
#  ('Colonia', 'Medina', 1788.41),
#  ('Mantequilla', 'Delgado', 1786.0),
#  ('Fertilizante', 'Peña', 1785.24),
#  ('Banana', 'González', 1784.62),
#  ('Naranja', 'Rubio', 1781.38),
#  ('Colonia', 'Romero', 1772.32),
#  ('Esponjas', 'Peña', 1765.68),
#  ('Detergente', 'Chávez', 1764.51),
#  ('Mantequilla', 'Sánchez', 1760.37),
#  ('Platos desechables', 'Torres', 1760.22),
#  ('Jabón líquido', 'Hernández', 1758.36),
#  ('Manzana', 'Romero', 1757.88),
#  ('Naranja', 'Reyes', 1757.69),
#  ('Desodorante', 'Romero', 1754.31),
#  ('Zanahoria', 'Romero', 1753.73),
#  ('Colonia', 'Molina', 1749.88),
#  ('Pollo', 'Serrano', 1748.95),
#  ('Detergente', 'Esquivel', 1741.79),
#  ('Chicles', 'López', 1740.83),
#  ('Tomate', 'Ramos', 1738.97),
#  ('Jugo de naranja', 'Sánchez', 1737.3),
#  ('Pollo', 'Reyes', 1737.21),
#  ('Uva', 'Vázquez', 1727.88),
#  ('Galletas', 'López', 1724.74),
#  ('Zanahoria', 'Ortiz', 1724.13),
#  ('Agua', 'Fuentes', 1722.3),
#  ('Queso', 'Ramírez', 1720.91),
#  ('Regadera', 'Vázquez', 1720.73),
#  ('Tierra para macetas', 'Montes', 1711.46),
#  ('Desodorante', 'Torres', 1710.26),
#  ('Carne de res', 'Ramírez', 1705.85),
#  ('Regadera', 'Peña', 1703.91),
#  ('Chocolate', 'Serrano', 1698.58),
#  ('Fertilizante', 'Díaz', 1686.41),
#  ('Crema hidratante', 'Vázquez', 1683.92),
#  ('Jugo de naranja', 'Montes', 1683.83),
#  ('Mantequilla', 'Martínez', 1678.28),
#  ('Tierra para macetas', 'Fernández', 1677.52),
#  ('Crema hidratante', 'Díaz', 1673.22),
#  ('Champú', 'Moreno', 1670.9),
#  ('Pollo', 'González', 1669.69),
#  ('Detergente', 'Ortiz', 1666.87),
#  ('Desodorante', 'Hernández', 1665.19),
#  ('Galletas', 'Flores', 1664.53),
#  ('Refresco', 'Guzmán', 1661.81),
#  ('Colonia', 'Reyes', 1657.45),
#  ('Tierra para macetas', 'Ramos', 1653.97),
#  ('Semillas', 'Ortiz', 1653.35),
#  ('Manzana', 'Flores', 1649.84),
#  ('Carne de res', 'Vázquez', 1648.55),
#  ('Chuletas', 'Montes', 1647.21),
#  ('Crema hidratante', 'Esquivel', 1644.85),
#  ('Leche', 'Cortés', 1644.01),
#  ('Jabón líquido', 'Cortés', 1643.49),
#  ('Chocolate', 'Cabrera', 1635.46),
#  ('Yogur', 'Cruz', 1631.37),
#  ('Tomate', 'Rubio', 1630.36),
#  ('Desodorante', 'Sánchez', 1629.01),
#  ('Cebolla', 'Álvarez', 1627.79),
#  ('Pilas', 'Montes', 1627.61),
#  ('Cerdo', 'Montes', 1624.85),
#  ('Yogur', 'Flores', 1623.44),
#  ('Colonia', 'Navarro', 1616.04),
#  ('Pollo', 'Chávez', 1612.06),
#  ('Desinfectante', 'Ruiz', 1611.12),
#  ('Desinfectante', 'Salinas', 1609.5),
#  ('Mantequilla', 'Díaz', 1608.56),
#  ('Papas fritas', 'González', 1607.94),
#  ('Pollo', 'Jiménez', 1604.68),
#  ('Agua', 'Jiménez', 1603.29),
#  ('Lechuga', 'Rubio', 1597.78),
#  ('Naranja', 'Cruz', 1595.12),
#  ('Cebolla', 'Castro', 1593.26),
#  ('Agua', 'Vázquez', 1587.61),
#  ('Chuletas', 'González', 1587.5),
#  ('Fertilizante', 'Campos', 1585.25),
#  ('Esponjas', 'Paredes', 1584.92),
#  ('Agua', 'Montes', 1581.97),
#  ('Desodorante', 'Díaz', 1580.62),
#  ('Cerveza', 'Campos', 1577.6),
#  ('Mantequilla', 'Navarro', 1576.46),
#  ('Leche', 'Rubio', 1574.46),
#  ('Papas fritas', 'Romero', 1572.48),
#  ('Champú', 'Peña', 1572.45),
#  ('Desinfectante', 'Ramírez', 1572.15),
#  ('Cerveza', 'Chávez', 1568.7),
#  ('Mantequilla', 'Paredes', 1568.69),
#  ('Fertilizante', 'Fernández', 1566.47),
#  ('Colonia', 'Cabrera', 1561.98),
#  ('Lechuga', 'Guzmán', 1561.94),
#  ('Bolsas de basura', 'Ruiz', 1561.86),
#  ('Naranja', 'Santos', 1561.78),
#  ('Colonia', 'Ramírez', 1561.11),
#  ('Detergente', 'Montes', 1558.6),
#  ('Chicles', 'Chávez', 1551.6),
#  ('Naranja', 'Salinas', 1546.56),
#  ('Jabón líquido', 'Rodríguez', 1545.71),
#  ('Esponjas', 'López', 1544.13),
#  ('Manzana', 'Ramírez', 1543.26),
#  ('Fertilizante', 'Moreno', 1541.37),
#  ('Galletas', 'Ramírez', 1540.49),
#  ('Pilas', 'Martínez', 1539.48),
#  ('Yogur', 'Velázquez', 1538.32),
#  ('Semillas', 'Velázquez', 1535.27),
#  ('Desodorante', 'Navarro', 1533.49),
#  ('Esponjas', 'Molina', 1533.31),
#  ('Esponjas', 'Fernández', 1532.82),
#  ('Carne de res', 'Reyes', 1531.43),
#  ('Desodorante', 'Rubio', 1530.89),
#  ('Chocolate', 'Torres', 1529.67),
#  ('Jabón líquido', 'Cortés', 1527.39),
#  ('Bolsas de basura', 'Montes', 1526.98),
#  ('Fertilizante', 'Fernández', 1526.76),
#  ('Banana', 'Santos', 1526.74),
#  ('Manzana', 'Delgado', 1521.72),
#  ('Semillas', 'Pérez', 1519.32),
#  ('Cerveza', 'Cabrera', 1517.6),
#  ('Tomate', 'Martínez', 1517.46),
#  ('Desodorante', 'Campos', 1517.3),
#  ('Cerdo', 'Lara', 1514.08),
#  ('Lechuga', 'Guzmán', 1510.66),
#  ('Leche', 'Castro', 1508.02),
#  ('Jugo de naranja', 'Vázquez', 1506.6),
#  ('Leche', 'Domínguez', 1506.56),
#  ('Agua', 'Díaz', 1504.18),
#  ('Papas fritas', 'Flores', 1500.43),
#  ('Pollo', 'Pérez', 1498.79),
#  ('Mantequilla', 'Álvarez', 1498.62),
#  ('Leche', 'Carrillo', 1495.66),
#  ('Jugo de naranja', 'Rodríguez', 1492.72),
#  ('Pilas', 'Hernández', 1492.27),
#  ('Uva', 'Montes', 1489.18),
#  ('Tomate', 'Medina', 1488.39),
#  ('Detergente', 'Reyes', 1487.26),
#  ('Carne de res', 'Castro', 1484.43),
#  ('Chicles', 'Chávez', 1484.04),
#  ('Refresco', 'Castro', 1483.99),
#  ('Fertilizante', 'Díaz', 1481.95),
#  ('Queso', 'Pérez', 1481.1),
#  ('Uva', 'Montes', 1480.01),
#  ('Agua', 'Méndez', 1479.39),
#  ('Semillas', 'Ramos', 1476.68),
#  ('Semillas', 'Martínez', 1476.36),
#  ('Semillas', 'Sánchez', 1473.97),
#  ('Desinfectante', 'Campos', 1472.08),
#  ('Galletas', 'Navarro', 1471.22),
#  ('Yogur', 'Sánchez', 1468.46),
#  ('Manzana', 'Montes', 1467.69),
#  ('Uva', 'Guzmán', 1467.27),
#  ('Carne de res', 'Flores', 1466.39),
#  ('Colonia', 'Guzmán', 1463.31),
#  ('Queso', 'Chávez', 1462.59),
#  ('Tomate', 'López', 1461.09),
#  ('Desinfectante', 'Ruiz', 1460.87),
#  ('Pollo', 'López', 1459.94),
#  ('Pilas', 'Hernández', 1458.21),
#  ('Tomate', 'Molina', 1458.16),
#  ('Esponjas', 'Esquivel', 1457.2),
#  ('Tomate', 'Ortiz', 1457.0),
#  ('Chicles', 'González', 1455.27),
#  ('Regadera', 'Hernández', 1453.34),
#  ('Lechuga', 'Ruiz', 1450.32),
#  ('Agua', 'Molina', 1447.24),
#  ('Velas', 'Cruz', 1447.16),
#  ('Esponjas', 'Chávez', 1446.44),
#  ('Jabón líquido', 'Moreno', 1443.9),
#  ('Yogur', 'Salinas', 1443.4),
#  ('Refresco', 'Álvarez', 1442.4),
#  ('Yogur', 'Reyes', 1440.73),
#  ('Mantequilla', 'Navarro', 1440.48),
#  ('Velas', 'Ramos', 1438.44),
#  ('Queso', 'Rubio', 1436.74),
#  ('Chocolate', 'Cortés', 1434.87),
#  ('Cerdo', 'Ramírez', 1433.77),
#  ('Pilas', 'Reyes', 1433.58),
#  ('Pilas', 'Campos', 1433.38),
#  ('Crema hidratante', 'Martínez', 1433.14),
#  ('Esponjas', 'Torres', 1432.06),
#  ('Semillas', 'Santos', 1429.52),
#  ('Regadera', 'Ramírez', 1429.18),
#  ('Chuletas', 'García', 1427.87),
#  ('Manzana', 'Ruiz', 1426.0),
#  ('Cebolla', 'Martínez', 1425.22),
#  ('Leche', 'Campos', 1420.89),
#  ('Naranja', 'Rubio', 1419.57),
#  ('Manzana', 'Peña', 1417.12),
#  ('Detergente', 'Flores', 1416.64),
#  ('Chuletas', 'Romero', 1416.57),
#  ('Semillas', 'Guzmán', 1416.31),
#  ('Pollo', 'Navarro', 1415.86),
#  ('Agua', 'Chávez', 1413.47),
#  ('Tierra para macetas', 'Serrano', 1413.3),
#  ('Cebolla', 'Ramos', 1412.65),
#  ('Cebolla', 'Aguilar', 1412.51),
#  ('Chicles', 'Álvarez', 1411.23),
#  ('Pilas', 'Molina', 1409.08),
#  ('Chuletas', 'Sánchez', 1408.15),
#  ('Carne de res', 'Álvarez', 1405.52),
#  ('Leche', 'Guzmán', 1404.61),
#  ('Semillas', 'Domínguez', 1404.33),
#  ('Naranja', 'Aguilar', 1403.36),
#  ('Desodorante', 'Moreno', 1399.55),
#  ('Banana', 'Lara', 1397.65),
#  ('Chocolate', 'López', 1397.55),
#  ('Desinfectante', 'Cruz', 1397.13),
#  ('Yogur', 'Carrillo', 1394.42),
#  ('Chocolate', 'Rodríguez', 1392.28),
#  ('Agua', 'Vázquez', 1392.15),
#  ('Tomate', 'Rubio', 1391.86),
#  ('Cerdo', 'Domínguez', 1386.25),
#  ('Tierra para macetas', 'Lara', 1385.66),
#  ('Carne de res', 'Ruiz', 1382.05),
#  ('Cebolla', 'Ortiz', 1380.87),
#  ('Champú', 'Sánchez', 1380.45),
#  ('Chuletas', 'Carrillo', 1379.15),
#  ('Champú', 'González', 1378.69),
#  ('Refresco', 'Montes', 1377.53),
#  ('Chocolate', 'Castro', 1377.2),
#  ('Desinfectante', 'Cruz', 1376.52),
#  ('Tomate', 'Torres', 1374.81),
#  ('Platos desechables', 'Medina', 1373.98),
#  ('Jugo de naranja', 'Fuentes', 1371.78),
#  ('Colonia', 'Cortés', 1371.52),
#  ('Platos desechables', 'Guzmán', 1370.62),
#  ('Regadera', 'Velázquez', 1370.12),
#  ('Bolsas de basura', 'Salinas', 1369.86),
#  ('Tierra para macetas', 'Chávez', 1368.94),
#  ('Tomate', 'Chávez', 1367.85),
#  ('Esponjas', 'Rodríguez', 1367.56),
#  ('Desodorante', 'Santos', 1366.24),
#  ('Zanahoria', 'Serrano', 1364.24),
#  ('Papas fritas', 'Rubio', 1363.83),
#  ('Queso', 'Guzmán', 1363.03),
#  ('Pollo', 'Esquivel', 1363.02),
#  ('Colonia', 'Medina', 1361.64),
#  ('Jugo de naranja', 'Moreno', 1358.75),
#  ('Champú', 'Rubio', 1356.64),
#  ('Banana', 'Rubio', 1354.78),
#  ('Manzana', 'Moreno', 1354.51),
#  ('Colonia', 'López', 1354.44),
#  ('Yogur', 'Romero', 1353.1),
#  ('Mantequilla', 'Martínez', 1352.34),
#  ('Semillas', 'Aguilar', 1351.73),
#  ('Naranja', 'Torres', 1350.51),
#  ('Bolsas de basura', 'Aguilar', 1347.56),
#  ('Galletas', 'Ortiz', 1346.31),
#  ('Desodorante', 'Rubio', 1345.18),
#  ('Carne de res', 'Navarro', 1344.83),
#  ('Esponjas', 'García', 1344.62),
#  ('Fertilizante', 'Cabrera', 1341.83),
#  ('Queso', 'Fuentes', 1339.78),
#  ('Chicles', 'Moreno', 1338.72),
#  ('Chicles', 'Torres', 1337.58),
#  ('Refresco', 'Ramos', 1336.81),
#  ('Uva', 'Ramos', 1336.73),
#  ('Jugo de naranja', 'Álvarez', 1336.66),
#  ('Platos desechables', 'Serrano', 1335.92),
#  ('Papas fritas', 'Cruz', 1335.37),
#  ('Regadera', 'Vázquez', 1335.26),
#  ('Carne de res', 'Cruz', 1334.05),
#  ('Detergente', 'Cruz', 1333.44),
#  ('Carne de res', 'Moreno', 1333.41),
#  ('Queso', 'García', 1332.56),
#  ('Colonia', 'Montes', 1332.06),
#  ('Agua', 'Ortiz', 1330.53),
#  ('Jabón líquido', 'Jiménez', 1330.16),
#  ('Champú', 'García', 1329.49),
#  ('Champú', 'Esquivel', 1328.12),
#  ('Jugo de naranja', 'García', 1326.18),
#  ('Fertilizante', 'Chávez', 1326.05),
#  ('Bolsas de basura', 'González', 1323.71),
#  ('Mantequilla', 'Pérez', 1322.11),
#  ('Tierra para macetas', 'Vázquez', 1321.89),
#  ('Detergente', 'Fernández', 1320.54),
#  ('Platos desechables', 'Montes', 1320.38),
#  ('Lechuga', 'Velázquez', 1319.65),
#  ('Chicles', 'Fernández', 1318.85),
#  ('Champú', 'Medina', 1318.18),
#  ('Cerveza', 'Serrano', 1317.35),
#  ('Champú', 'Flores', 1315.08),
#  ('Uva', 'Paredes', 1314.09),
#  ('Colonia', 'Cruz', 1313.56),
#  ('Banana', 'Montes', 1313.38),
#  ('Uva', 'Fuentes', 1312.51),
#  ('Chocolate', 'Reyes', 1311.63),
#  ('Desinfectante', 'González', 1311.57),
#  ('Desinfectante', 'Chávez', 1310.78),
#  ('Regadera', 'Ruiz', 1310.62),
#  ('Champú', 'García', 1309.4),
#  ('Queso', 'Montes', 1309.12),
#  ('Pilas', 'Medina', 1307.7),
#  ('Tierra para macetas', 'Chávez', 1301.94),
#  ('Jugo de naranja', 'Fernández', 1300.75),
#  ('Cerveza', 'Reyes', 1300.28),
#  ('Detergente', 'Domínguez', 1299.41),
#  ('Agua', 'Cruz', 1299.27),
#  ('Carne de res', 'Hernández', 1298.55),
#  ('Tierra para macetas', 'Romero', 1296.15),
#  ('Banana', 'Flores', 1295.89),
#  ('Tomate', 'Rubio', 1295.52),
#  ('Tierra para macetas', 'Navarro', 1295.23),
#  ('Desodorante', 'Reyes', 1294.6),
#  ('Chicles', 'Castro', 1294.44),
#  ('Naranja', 'Esquivel', 1293.66),
#  ('Tierra para macetas', 'Carrillo', 1291.78),
#  ('Chuletas', 'Peña', 1290.98),
#  ('Banana', 'Cabrera', 1290.18),
#  ('Tierra para macetas', 'Ortiz', 1289.9),
#  ('Detergente', 'Rodríguez', 1289.57),
#  ('Papas fritas', 'Jiménez', 1289.19),
#  ('Bolsas de basura', 'Esquivel', 1288.74),
#  ('Yogur', 'Rubio', 1288.19),
#  ('Jabón líquido', 'Ortiz', 1287.97),
#  ('Zanahoria', 'Ruiz', 1283.21),
#  ('Tomate', 'Álvarez', 1282.24),
#  ('Papas fritas', 'Rodríguez', 1281.63),
#  ('Champú', 'Serrano', 1281.57),
#  ('Queso', 'García', 1281.35),
#  ('Chicles', 'Chávez', 1280.94),
#  ('Papas fritas', 'Flores', 1280.74),
#  ('Tomate', 'Hernández', 1279.39),
#  ('Cerdo', 'Ortiz', 1278.64),
#  ('Yogur', 'Cortés', 1277.94),
#  ('Galletas', 'Martínez', 1276.88),
#  ('Refresco', 'Chávez', 1276.76),
#  ('Desodorante', 'Díaz', 1276.57),
#  ('Cebolla', 'Esquivel', 1274.07),
#  ('Cerdo', 'Salinas', 1273.68),
#  ('Queso', 'Montes', 1273.39),
#  ('Queso', 'Santos', 1272.16),
#  ('Pollo', 'Hernández', 1271.61),
#  ('Banana', 'López', 1270.63),
#  ('Uva', 'Ruiz', 1270.14),
#  ('Papas fritas', 'López', 1269.88),
#  ('Velas', 'González', 1269.3),
#  ('Mantequilla', 'Paredes', 1269.15),
#  ('Chuletas', 'Paredes', 1267.72),
#  ('Cebolla', 'Cabrera', 1265.27),
#  ('Esponjas', 'Lara', 1265.09),
#  ('Chicles', 'Navarro', 1263.26),
#  ('Leche', 'Álvarez', 1262.78),
#  ('Refresco', 'Sánchez', 1260.83),
#  ('Banana', 'Álvarez', 1260.75),
#  ('Detergente', 'Ortiz', 1259.7),
#  ('Pollo', 'Peña', 1259.2),
#  ('Tomate', 'Flores', 1258.87),
#  ('Esponjas', 'Cruz', 1253.36),
#  ('Jugo de naranja', 'Velázquez', 1252.54),
#  ('Leche', 'Fuentes', 1251.63),
#  ('Platos desechables', 'Velázquez', 1250.92),
#  ('Banana', 'Sánchez', 1250.31),
#  ('Tierra para macetas', 'Paredes', 1248.64),
#  ('Queso', 'Carrillo', 1243.46),
#  ('Detergente', 'Ramos', 1240.37),
#  ('Colonia', 'Lara', 1240.21),
#  ('Papas fritas', 'Moreno', 1240.0),
#  ('Manzana', 'Rodríguez', 1238.96),
#  ('Desodorante', 'González', 1238.83),
#  ('Zanahoria', 'Rubio', 1236.3),
#  ('Yogur', 'Salinas', 1235.03),
#  ('Agua', 'Ramírez', 1234.95),
#  ('Colonia', 'Esquivel', 1234.33),
#  ('Carne de res', 'Ramos', 1233.35),
#  ('Detergente', 'Cruz', 1231.58),
#  ('Champú', 'Cortés', 1231.34),
#  ('Jugo de naranja', 'Sánchez', 1229.87),
#  ('Semillas', 'Esquivel', 1229.61),
#  ('Manzana', 'Molina', 1229.27),
#  ('Cerveza', 'Peña', 1226.99),
#  ('Cerveza', 'Esquivel', 1225.29),
#  ('Regadera', 'Medina', 1223.74),
#  ('Jabón líquido', 'Moreno', 1223.35),
#  ('Cebolla', 'Delgado', 1223.03),
#  ('Chicles', 'Martínez', 1221.52),
#  ('Uva', 'Moreno', 1218.97),
#  ('Refresco', 'Navarro', 1217.06),
#  ('Queso', 'Aguilar', 1216.95),
#  ('Tierra para macetas', 'Montes', 1216.13),
#  ('Chuletas', 'Peña', 1214.69),
#  ('Cerdo', 'Díaz', 1213.31),
#  ('Jugo de naranja', 'Delgado', 1213.18),
#  ('Papas fritas', 'López', 1212.48),
#  ('Champú', 'Ortiz', 1212.0),
#  ('Esponjas', 'Pérez', 1211.74),
#  ('Yogur', 'Paredes', 1211.06),
#  ('Semillas', 'Ramos', 1210.14),
#  ('Esponjas', 'Carrillo', 1209.38),
#  ('Lechuga', 'Fernández', 1208.48),
#  ('Regadera', 'Díaz', 1208.24),
#  ('Semillas', 'González', 1206.37),
#  ('Uva', 'Chávez', 1205.65),
#  ('Chuletas', 'Romero', 1204.26),
#  ('Carne de res', 'Medina', 1204.06),
#  ('Tomate', 'Carrillo', 1201.9),
#  ('Zanahoria', 'Ruiz', 1201.34),
#  ('Crema hidratante', 'Flores', 1201.12),
#  ('Detergente', 'Vázquez', 1200.07),
#  ('Esponjas', 'Rodríguez', 1200.03),
#  ('Desinfectante', 'Castro', 1199.21),
#  ('Platos desechables', 'Pérez', 1198.4),
#  ('Fertilizante', 'Lara', 1197.51),
#  ('Zanahoria', 'Domínguez', 1197.48),
#  ('Manzana', 'Méndez', 1196.56),
#  ('Yogur', 'Sánchez', 1196.53),
#  ('Jugo de naranja', 'Velázquez', 1195.91),
#  ('Cebolla', 'Martínez', 1193.33),
#  ('Lechuga', 'Cruz', 1191.17),
#  ('Agua', 'Salinas', 1191.15),
#  ('Semillas', 'Cruz', 1189.9),
#  ('Jugo de naranja', 'González', 1188.39),
#  ('Zanahoria', 'Domínguez', 1187.02),
#  ('Crema hidratante', 'Torres', 1183.63),
#  ('Papas fritas', 'Delgado', 1182.76),
#  ('Cerdo', 'Cabrera', 1181.88),
#  ('Uva', 'Esquivel', 1181.58),
#  ('Bolsas de basura', 'Díaz', 1181.5),
#  ('Jabón líquido', 'Hernández', 1180.93),
#  ('Regadera', 'Carrillo', 1180.93),
#  ('Fertilizante', 'López', 1179.87),
#  ('Carne de res', 'Molina', 1179.61),
#  ('Bolsas de basura', 'García', 1179.45),
#  ('Esponjas', 'Lara', 1178.98),
#  ('Crema hidratante', 'Rubio', 1172.38),
#  ('Chuletas', 'Fernández', 1171.21),
#  ('Velas', 'López', 1169.27),
#  ('Galletas', 'Navarro', 1166.68),
#  ('Desodorante', 'Esquivel', 1166.26),
#  ('Jabón líquido', 'Méndez', 1166.24),
#  ('Galletas', 'Velázquez', 1163.67),
#  ('Carne de res', 'Jiménez', 1163.5),
#  ('Chicles', 'Aguilar', 1163.33),
#  ('Zanahoria', 'Jiménez', 1163.21),
#  ('Lechuga', 'Díaz', 1161.61),
#  ('Papas fritas', 'García', 1161.08),
#  ('Fertilizante', 'Cruz', 1160.84),
#  ('Regadera', 'Cortés', 1160.15),
#  ('Bolsas de basura', 'Navarro', 1154.97),
#  ('Naranja', 'Cortés', 1153.98),
#  ('Regadera', 'Sánchez', 1153.42),
#  ('Agua', 'Lara', 1153.4),
#  ('Jugo de naranja', 'Flores', 1151.01),
#  ('Carne de res', 'Campos', 1145.49),
#  ('Regadera', 'Rubio', 1144.5),
#  ('Cerveza', 'Romero', 1143.8),
#  ('Queso', 'Ortiz', 1143.05),
#  ('Banana', 'Ramírez', 1138.91),
#  ('Bolsas de basura', 'Serrano', 1137.44),
#  ('Regadera', 'Sánchez', 1136.99),
#  ('Champú', 'Guzmán', 1136.96),
#  ('Lechuga', 'Peña', 1136.7),
#  ('Carne de res', 'Ramírez', 1135.95),
#  ('Jugo de naranja', 'Castro', 1135.49),
#  ('Tierra para macetas', 'Díaz', 1135.33),
#  ('Mantequilla', 'Torres', 1134.76),
#  ('Velas', 'Romero', 1134.14),
#  ('Yogur', 'Cruz', 1133.81),
#  ('Crema hidratante', 'Álvarez', 1133.12),
#  ('Mantequilla', 'Sánchez', 1132.83),
#  ('Chocolate', 'Lara', 1132.25),
#  ('Jabón líquido', 'Martínez', 1131.53),
#  ('Cerveza', 'Campos', 1128.84),
#  ('Crema hidratante', 'Hernández', 1127.8),
#  ('Cebolla', 'Reyes', 1127.15),
#  ('Crema hidratante', 'Díaz', 1125.94),
#  ('Esponjas', 'Ramos', 1125.57),
#  ('Papas fritas', 'Romero', 1125.33),
#  ('Uva', 'Salinas', 1124.99),
#  ('Bolsas de basura', 'Paredes', 1124.77),
#  ('Jabón líquido', 'Serrano', 1124.0),
#  ('Yogur', 'Navarro', 1121.35),
#  ('Uva', 'Hernández', 1121.3),
#  ('Bolsas de basura', 'Díaz', 1121.16),
#  ('Cebolla', 'Santos', 1120.71),
#  ('Banana', 'Ruiz', 1119.55),
#  ('Refresco', 'Fernández', 1119.06),
#  ('Agua', 'Álvarez', 1118.9),
#  ('Crema hidratante', 'Molina', 1118.65),
#  ('Tierra para macetas', 'Peña', 1113.85),
#  ('Refresco', 'Serrano', 1113.85),
#  ('Champú', 'Velázquez', 1113.18),
#  ('Cerdo', 'Sánchez', 1112.33),
#  ('Jugo de naranja', 'Jiménez', 1111.87),
#  ('Banana', 'Santos', 1111.43),
#  ('Chocolate', 'Ramos', 1110.86),
#  ('Jugo de naranja', 'Rubio', 1110.84),
#  ('Zanahoria', 'Hernández', 1110.61),
#  ('Esponjas', 'Jiménez', 1109.33),
#  ('Fertilizante', 'Moreno', 1109.01),
#  ('Semillas', 'Romero', 1108.51),
#  ('Jabón líquido', 'Navarro', 1106.59),
#  ('Chicles', 'Serrano', 1105.57),
#  ('Agua', 'García', 1105.29),
#  ('Jugo de naranja', 'Lara', 1104.61),
#  ('Pollo', 'Santos', 1103.85),
#  ('Semillas', 'Díaz', 1103.56),
#  ('Uva', 'Cruz', 1102.86),
#  ('Cerveza', 'Flores', 1102.18),
#  ('Champú', 'Aguilar', 1101.83),
#  ('Lechuga', 'Díaz', 1100.48),
#  ('Cebolla', 'González', 1098.84),
#  ('Banana', 'Moreno', 1098.6),
#  ('Pollo', 'Torres', 1098.07),
#  ('Galletas', 'Ortiz', 1096.31),
#  ('Detergente', 'Campos', 1095.48),
#  ('Yogur', 'Ortiz', 1094.63),
#  ('Desinfectante', 'Reyes', 1094.41),
#  ('Desinfectante', 'Méndez', 1092.97),
#  ('Lechuga', 'Velázquez', 1091.99),
#  ('Platos desechables', 'Moreno', 1090.81),
#  ('Manzana', 'Ramos', 1090.49),
#  ('Tomate', 'Reyes', 1090.07),
#  ('Esponjas', 'Cabrera', 1089.06),
#  ('Crema hidratante', 'Santos', 1088.63),
#  ('Platos desechables', 'González', 1088.47),
#  ('Yogur', 'Ortiz', 1086.81),
#  ('Tomate', 'Molina', 1084.67),
#  ('Agua', 'Cabrera', 1084.1),
#  ('Fertilizante', 'Méndez', 1083.1),
#  ('Desodorante', 'Navarro', 1083.1),
#  ('Chicles', 'García', 1082.9),
#  ('Esponjas', 'Cortés', 1082.55),
#  ('Leche', 'Navarro', 1081.74),
#  ('Semillas', 'Paredes', 1081.72),
#  ('Jugo de naranja', 'Delgado', 1081.67),
#  ('Fertilizante', 'Ramos', 1080.51),
#  ('Velas', 'Fuentes', 1079.78),
#  ('Esponjas', 'Méndez', 1079.78),
#  ('Colonia', 'Ramos', 1079.69),
#  ('Carne de res', 'Santos', 1079.32),
#  ('Esponjas', 'Lara', 1078.93),
#  ('Jabón líquido', 'Salinas', 1077.93),
#  ('Banana', 'Álvarez', 1075.75),
#  ('Zanahoria', 'Romero', 1075.74),
#  ('Jabón líquido', 'Salinas', 1075.41),
#  ('Yogur', 'Moreno', 1073.96),
#  ('Bolsas de basura', 'González', 1073.47),
#  ('Agua', 'Carrillo', 1072.07),
#  ('Lechuga', 'Navarro', 1072.06),
#  ('Refresco', 'Moreno', 1071.74),
#  ('Manzana', 'Velázquez', 1069.09),
#  ('Desodorante', 'Santos', 1067.05),
#  ('Leche', 'Fernández', 1065.67),
#  ('Agua', 'Jiménez', 1064.95),
#  ('Carne de res', 'Velázquez', 1063.67),
#  ('Pilas', 'Santos', 1063.12),
#  ('Jugo de naranja', 'Domínguez', 1060.57),
#  ('Jugo de naranja', 'González', 1060.03),
#  ('Regadera', 'Peña', 1059.72),
#  ('Cebolla', 'Flores', 1059.66),
#  ('Chicles', 'Ramírez', 1059.02),
#  ('Pollo', 'Paredes', 1058.47),
#  ('Fertilizante', 'Fernández', 1058.23),
#  ('Semillas', 'Esquivel', 1057.12),
#  ('Lechuga', 'Díaz', 1055.78),
#  ('Esponjas', 'Aguilar', 1055.05),
#  ('Jabón líquido', 'Rodríguez', 1054.87),
#  ('Queso', 'Serrano', 1054.02),
#  ('Colonia', 'Ortiz', 1052.99),
#  ('Pilas', 'Guzmán', 1051.61),
#  ('Bolsas de basura', 'Méndez', 1051.39),
#  ('Cerveza', 'Cruz', 1051.12),
#  ('Bolsas de basura', 'Montes', 1050.1),
#  ('Leche', 'Ruiz', 1046.6),
#  ('Cerveza', 'Jiménez', 1043.56),
#  ('Esponjas', 'Martínez', 1043.37),
#  ('Tierra para macetas', 'Delgado', 1037.56),
#  ('Mantequilla', 'Carrillo', 1037.5),
#  ('Cerveza', 'Rodríguez', 1037.09),
#  ('Galletas', 'Aguilar', 1037.0),
#  ('Chocolate', 'Ortiz', 1036.58),
#  ('Detergente', 'Lara', 1036.13),
#  ('Bolsas de basura', 'Cabrera', 1036.07),
#  ('Desinfectante', 'Ortiz', 1035.18),
#  ('Pilas', 'Ramos', 1033.63),
#  ('Esponjas', 'Torres', 1033.25),
#  ('Velas', 'Serrano', 1033.24),
#  ('Leche', 'García', 1032.66),
#  ('Cerdo', 'Jiménez', 1029.75),
#  ('Cebolla', 'Guzmán', 1029.34),
#  ('Leche', 'Álvarez', 1029.18),
#  ('Platos desechables', 'González', 1028.8),
#  ('Papas fritas', 'Santos', 1027.57),
#  ('Chicles', 'Ramírez', 1027.56),
#  ('Platos desechables', 'Castro', 1027.27),
#  ('Colonia', 'Campos', 1026.38),
#  ('Leche', 'Ortiz', 1026.3),
#  ('Jabón líquido', 'Ramos', 1025.9),
#  ('Desodorante', 'Montes', 1025.46),
#  ('Platos desechables', 'Molina', 1024.58),
#  ('Galletas', 'Ruiz', 1023.6),
#  ('Chocolate', 'Castro', 1023.26),
#  ('Chocolate', 'García', 1022.63),
#  ('Uva', 'Lara', 1022.34),
#  ('Crema hidratante', 'Hernández', 1022.32),
#  ('Chuletas', 'Ortiz', 1022.24),
#  ('Pollo', 'Hernández', 1020.7),
#  ('Chicles', 'Domínguez', 1020.39),
#  ('Cebolla', 'Rubio', 1016.37),
#  ('Banana', 'Ramos', 1015.75),
#  ('Chuletas', 'Navarro', 1014.81),
#  ('Champú', 'Cabrera', 1014.17),
#  ('Refresco', 'Carrillo', 1013.88),
#  ('Uva', 'Jiménez', 1012.9),
#  ('Leche', 'Molina', 1012.59),
#  ('Agua', 'Medina', 1011.87),
#  ('Mantequilla', 'Domínguez', 1011.75),
#  ('Yogur', 'Fernández', 1010.87),
#  ('Champú', 'Peña', 1010.76),
#  ('Cerdo', 'Guzmán', 1010.36),
#  ('Desodorante', 'Rubio', 1010.0),
#  ('Banana', 'Esquivel', 1009.95),
#  ('Tomate', 'Delgado', 1009.9),
#  ('Agua', 'Navarro', 1009.65),
#  ('Chuletas', 'Moreno', 1009.61),
#  ('Chuletas', 'Vázquez', 1009.34),
#  ('Queso', 'Rubio', 1009.24),
#  ('Esponjas', 'Méndez', 1008.66),
#  ('Jabón líquido', 'Cabrera', 1008.52),
#  ('Colonia', 'Fernández', 1008.13),
#  ('Champú', 'Cruz', 1007.77),
#  ('Chocolate', 'Navarro', 1007.18),
#  ('Jabón líquido', 'González', 1006.68),
#  ('Manzana', 'Rubio', 1006.53),
#  ('Cebolla', 'Ramos', 1006.12),
#  ('Agua', 'García', 1005.77),
#  ('Jugo de naranja', 'Martínez', 1005.23),
#  ('Agua', 'Montes', 1004.87),
#  ('Chuletas', 'Pérez', 1004.23),
#  ('Uva', 'Álvarez', 1003.72),
#  ('Queso', 'Santos', 1003.38),
#  ('Desodorante', 'Cruz', 1003.11),
#  ('Jabón líquido', 'Chávez', 1001.85),
#  ('Mantequilla', 'Ruiz', 1001.8),
#  ('Tierra para macetas', 'Santos', 1001.67),
#  ('Fertilizante', 'Montes', 1001.14),
#  ('Cebolla', 'Esquivel', 1000.29),
#  ('Desodorante', 'López', 999.13),
#  ('Platos desechables', 'Cruz', 998.3),
#  ('Agua', 'Reyes', 998.23),
#  ('Queso', 'Lara', 997.78),
#  ('Chuletas', 'Sánchez', 997.71),
#  ('Desinfectante', 'Flores', 997.23),
#  ('Pollo', 'Fuentes', 997.01),
#  ('Zanahoria', 'Molina', 996.96),
#  ('Cerdo', 'Aguilar', 996.0),
#  ('Agua', 'Cortés', 995.12),
#  ('Colonia', 'Díaz', 994.36),
#  ('Galletas', 'Flores', 994.35),
#  ('Detergente', 'González', 992.59),
#  ('Velas', 'Jiménez', 992.24),
#  ('Naranja', 'Montes', 991.66),
#  ('Detergente', 'Campos', 990.86),
#  ('Chicles', 'Serrano', 989.43),
#  ('Desodorante', 'Martínez', 987.71),
#  ('Cerveza', 'Hernández', 986.9),
#  ('Chuletas', 'Salinas', 986.54),
#  ('Uva', 'Esquivel', 986.37),
#  ('Crema hidratante', 'Montes', 986.09),
#  ('Jugo de naranja', 'Ramos', 985.22),
#  ('Champú', 'Vázquez', 985.19),
#  ('Champú', 'Domínguez', 984.95),
#  ('Papas fritas', 'Fuentes', 984.3),
#  ('Uva', 'Ramos', 983.87),
#  ('Carne de res', 'Rubio', 983.86),
#  ('Chocolate', 'Flores', 983.31),
#  ('Fertilizante', 'Hernández', 982.9),
#  ('Banana', 'González', 982.31),
#  ('Lechuga', 'Velázquez', 982.02),
#  ('Jabón líquido', 'Díaz', 981.98),
#  ('Bolsas de basura', 'Serrano', 981.91),
#  ('Mantequilla', 'Santos', 981.6),
#  ('Naranja', 'Ortiz', 981.55),
#  ('Chuletas', 'López', 981.48),
#  ('Detergente', 'Lara', 981.1),
#  ('Platos desechables', 'Peña', 980.9),
#  ('Velas', 'Paredes', 980.35),
#  ('Lechuga', 'Guzmán', 979.62),
#  ('Naranja', 'Chávez', 979.55),
#  ('Champú', 'Peña', 978.95),
#  ('Agua', 'Jiménez', 978.84),
#  ('Manzana', 'Moreno', 975.71),
#  ('Agua', 'Lara', 975.47),
#  ('Naranja', 'Molina', 974.59),
#  ('Semillas', 'Flores', 973.57),
#  ('Jugo de naranja', 'Cabrera', 971.69),
#  ('Agua', 'Velázquez', 971.58),
#  ('Regadera', 'Hernández', 971.57),
#  ('Jabón líquido', 'Ortiz', 971.01),
#  ('Zanahoria', 'Fernández', 970.81),
#  ('Papas fritas', 'Fernández', 969.57),
#  ('Velas', 'Medina', 968.15),
#  ('Lechuga', 'Pérez', 968.13),
#  ('Naranja', 'López', 968.11),
#  ('Regadera', 'Ramírez', 968.03),
#  ('Desinfectante', 'Ortiz', 967.44),
#  ('Semillas', 'Esquivel', 966.13),
#  ('Cerdo', 'Ortiz', 962.49),
#  ('Agua', 'Paredes', 961.34),
#  ('Banana', 'Molina', 960.69),
#  ('Semillas', 'Sánchez', 960.59),
#  ('Pollo', 'González', 959.95),
#  ('Carne de res', 'Santos', 959.57),
#  ('Mantequilla', 'Rodríguez', 956.47),
#  ('Jugo de naranja', 'Medina', 955.02),
#  ('Pollo', 'Méndez', 954.67),
#  ('Regadera', 'Ruiz', 954.01),
#  ('Cebolla', 'Ortiz', 952.15),
#  ('Lechuga', 'Romero', 951.9),
#  ('Naranja', 'Ramírez', 951.38),
#  ('Detergente', 'Aguilar', 949.6),
#  ('Lechuga', 'López', 949.51),
#  ('Mantequilla', 'Ramírez', 948.98),
#  ('Velas', 'Salinas', 947.26),
#  ('Jugo de naranja', 'Hernández', 946.75),
#  ('Desinfectante', 'Campos', 946.62),
#  ('Yogur', 'Esquivel', 945.31),
#  ('Yogur', 'González', 944.87),
#  ('Galletas', 'Torres', 944.84),
#  ('Agua', 'Guzmán', 943.84),
#  ('Crema hidratante', 'Cabrera', 943.76),
#  ('Carne de res', 'Domínguez', 942.26),
#  ('Cerdo', 'Ortiz', 940.7),
#  ('Manzana', 'Aguilar', 940.19),
#  ('Semillas', 'Ramos', 939.86),
#  ('Carne de res', 'Domínguez', 939.61),
#  ('Semillas', 'Díaz', 938.93),
#  ('Tierra para macetas', 'Rodríguez', 938.66),
#  ('Pilas', 'Ortiz', 938.01),
#  ('Tierra para macetas', 'Ortiz', 937.56),
#  ('Semillas', 'González', 937.07),
#  ('Desinfectante', 'Navarro', 936.53),
#  ('Semillas', 'Martínez', 936.45),
#  ('Chocolate', 'González', 935.65),
#  ('Tomate', 'Ortiz', 934.54),
#  ('Colonia', 'Méndez', 933.66),
#  ('Cerdo', 'García', 932.9),
#  ('Chocolate', 'Reyes', 932.78),
#  ('Chocolate', 'Montes', 931.76),
#  ('Detergente', 'Carrillo', 930.2),
#  ('Leche', 'Serrano', 929.91),
#  ('Chocolate', 'Molina', 929.6),
#  ('Detergente', 'Hernández', 928.68),
#  ('Papas fritas', 'Serrano', 927.27),
#  ('Jugo de naranja', 'Guzmán', 927.18),
#  ('Cerdo', 'Ruiz', 927.0),
#  ('Platos desechables', 'Medina', 925.25),
#  ('Mantequilla', 'García', 925.16),
#  ('Manzana', 'Torres', 925.12),
#  ('Platos desechables', 'Méndez', 925.02),
#  ('Jugo de naranja', 'Rubio', 924.95),
#  ('Carne de res', 'Cortés', 924.75),
#  ('Naranja', 'Cabrera', 924.7),
#  ('Agua', 'Campos', 924.58),
#  ('Platos desechables', 'Serrano', 924.15),
#  ('Cebolla', 'Velázquez', 923.02),
#  ('Cebolla', 'García', 922.43),
#  ('Naranja', 'Santos', 921.5),
#  ('Refresco', 'Romero', 920.89),
#  ('Zanahoria', 'García', 920.82),
#  ('Colonia', 'Medina', 920.7),
#  ('Papas fritas', 'Sánchez', 919.25),
#  ('Tierra para macetas', 'Cortés', 918.96),
#  ('Colonia', 'López', 918.71),
#  ('Refresco', 'Aguilar', 918.18),
#  ('Fertilizante', 'Moreno', 917.72),
#  ('Pilas', 'Navarro', 917.61),
#  ('Chuletas', 'Rubio', 917.52),
#  ('Chicles', 'Rubio', 916.75),
#  ('Refresco', 'Rubio', 916.54),
#  ('Desodorante', 'López', 916.53),
#  ('Leche', 'López', 916.52),
#  ('Galletas', 'Molina', 916.22),
#  ('Papas fritas', 'Montes', 915.72),
#  ('Cebolla', 'Paredes', 914.04),
#  ('Jugo de naranja', 'Castro', 912.26),
#  ('Detergente', 'Díaz', 911.85),
#  ('Agua', 'Navarro', 911.7),
#  ('Refresco', 'Moreno', 911.3),
#  ('Naranja', 'Aguilar', 910.12),
#  ('Manzana', 'Fuentes', 909.51),
#  ('Desodorante', 'Cabrera', 907.92),
#  ('Jabón líquido', 'Ortiz', 907.54),
#  ('Cerdo', 'Sánchez', 907.04),
#  ('Semillas', 'Peña', 907.01),
#  ('Mantequilla', 'Domínguez', 905.71),
#  ('Banana', 'Cortés', 905.35),
#  ('Chuletas', 'Velázquez', 904.91),
#  ('Desinfectante', 'Sánchez', 904.74),
#  ('Semillas', 'Martínez', 904.3),
#  ('Zanahoria', 'Martínez', 903.42),
#  ('Mantequilla', 'Lara', 903.42),
#  ('Zanahoria', 'Campos', 902.69),
#  ('Pollo', 'Ramírez', 901.54),
#  ('Cerveza', 'Reyes', 901.3),
#  ('Yogur', 'Lara', 900.78),
#  ('Pollo', 'Ramírez', 900.02),
#  ('Chicles', 'Delgado', 899.05),
#  ('Crema hidratante', 'Ramírez', 898.83),
#  ('Refresco', 'Ortiz', 898.33),
#  ('Naranja', 'Navarro', 898.24),
#  ('Mantequilla', 'Méndez', 897.05),
#  ('Chocolate', 'Santos', 896.36),
#  ('Fertilizante', 'Fuentes', 896.0),
#  ('Jabón líquido', 'Méndez', 895.14),
#  ('Chocolate', 'Méndez', 895.08),
#  ('Esponjas', 'Aguilar', 894.55),
#  ('Jabón líquido', 'Delgado', 894.4),
#  ('Carne de res', 'Ortiz', 893.23),
#  ('Chuletas', 'Guzmán', 892.82),
#  ('Cerveza', 'Carrillo', 892.45),
#  ('Chocolate', 'Romero', 892.32),
#  ('Pollo', 'Rodríguez', 891.9),
#  ('Bolsas de basura', 'Medina', 891.43),
#  ('Crema hidratante', 'Cortés', 891.41),
#  ('Leche', 'Lara', 891.27),
#  ('Refresco', 'Vázquez', 891.24),
#  ('Cebolla', 'González', 890.88),
#  ('Chuletas', 'Sánchez', 889.7),
#  ('Colonia', 'Campos', 888.56),
#  ('Semillas', 'Ruiz', 888.08),
#  ('Zanahoria', 'González', 887.34),
#  ('Cerdo', 'González', 887.29),
#  ('Regadera', 'Álvarez', 887.11),
#  ('Regadera', 'Medina', 886.69),
#  ('Cerveza', 'Campos', 886.65),
#  ('Leche', 'Cabrera', 886.61),
#  ('Mantequilla', 'Chávez', 886.47),
#  ('Platos desechables', 'Ramos', 885.04),
#  ('Bolsas de basura', 'Cabrera', 884.56),
#  ('Chocolate', 'Molina', 884.41),
#  ('Bolsas de basura', 'Lara', 884.16),
#  ('Pilas', 'Fernández', 882.14),
#  ('Desodorante', 'Campos', 881.71),
#  ('Cebolla', 'Rodríguez', 881.4),
#  ('Platos desechables', 'Cortés', 879.53),
#  ('Crema hidratante', 'Castro', 878.21),
#  ('Champú', 'Fernández', 878.07),
#  ('Crema hidratante', 'Ortiz', 875.73),
#  ('Velas', 'Ramos', 875.09),
#  ('Velas', 'Romero', 874.09),
#  ('Desinfectante', 'Castro', 873.61),
#  ('Pilas', 'Álvarez', 873.29),
#  ('Galletas', 'Martínez', 872.87),
#  ('Galletas', 'Guzmán', 872.2),
#  ('Jabón líquido', 'Velázquez', 871.98),
#  ('Pollo', 'Domínguez', 871.63),
#  ('Velas', 'Rubio', 871.16),
#  ('Cebolla', 'Martínez', 869.88),
#  ('Tomate', 'Jiménez', 869.3),
#  ('Papas fritas', 'Ortiz', 868.72),
#  ('Pollo', 'Chávez', 868.21),
#  ('Mantequilla', 'Reyes', 867.81),
#  ('Colonia', 'Ortiz', 867.02),
#  ('Refresco', 'García', 866.79),
#  ('Manzana', 'Velázquez', 865.99),
#  ('Semillas', 'Díaz', 865.49),
#  ('Uva', 'Martínez', 864.03),
#  ('Pollo', 'Pérez', 863.99),
#  ('Esponjas', 'Lara', 863.58),
#  ('Manzana', 'Cabrera', 863.25),
#  ('Semillas', 'Navarro', 862.51),
#  ('Papas fritas', 'Ortiz', 862.48),
#  ('Carne de res', 'Delgado', 862.13),
#  ('Pollo', 'Navarro', 861.99),
#  ('Manzana', 'Hernández', 861.87),
#  ('Detergente', 'Molina', 861.78),
#  ('Cebolla', 'Guzmán', 859.8),
#  ('Refresco', 'Carrillo', 858.65),
#  ('Pilas', 'Moreno', 858.37),
#  ('Fertilizante', 'Medina', 858.06),
#  ('Tomate', 'Reyes', 857.95),
#  ('Jabón líquido', 'Flores', 857.89),
#  ('Agua', 'Ramos', 857.77),
#  ('Uva', 'Delgado', 857.3),
#  ('Velas', 'Vázquez', 855.99),
#  ('Papas fritas', 'Campos', 854.26),
#  ('Regadera', 'Pérez', 853.98),
#  ('Manzana', 'Jiménez', 853.01),
#  ('Papas fritas', 'Hernández', 852.34),
#  ('Crema hidratante', 'López', 851.89),
#  ('Desinfectante', 'Peña', 851.69),
#  ('Cerveza', 'Montes', 851.52),
#  ('Chocolate', 'Esquivel', 851.4),
#  ('Queso', 'Hernández', 851.08),
#  ('Cerdo', 'Chávez', 850.58),
#  ('Lechuga', 'Santos', 849.96),
#  ('Tomate', 'Pérez', 848.51),
#  ('Velas', 'Aguilar', 846.89),
#  ('Chuletas', 'Cruz', 845.92),
#  ('Jugo de naranja', 'Moreno', 845.67),
#  ('Pilas', 'Reyes', 845.53),
#  ('Desinfectante', 'Salinas', 845.38),
#  ('Agua', 'Delgado', 845.01),
#  ('Champú', 'Castro', 844.91),
#  ('Bolsas de basura', 'Peña', 844.43),
#  ('Naranja', 'Fernández', 843.4),
#  ('Pollo', 'Domínguez', 843.39),
#  ('Fertilizante', 'Ramírez', 843.37),
#  ('Zanahoria', 'Díaz', 843.37),
#  ('Tierra para macetas', 'Torres', 842.95),
#  ('Zanahoria', 'Reyes', 842.47),
#  ('Cebolla', 'Velázquez', 842.3),
#  ('Queso', 'Moreno', 842.29),
#  ('Carne de res', 'Ramos', 842.11),
#  ('Colonia', 'Ramírez', 841.65),
#  ('Agua', 'Ruiz', 841.46),
#  ('Banana', 'Ramírez', 841.33),
#  ('Tierra para macetas', 'Molina', 839.89),
#  ('Zanahoria', 'Ramírez', 839.21),
#  ('Galletas', 'Ramos', 834.6),
#  ('Carne de res', 'Campos', 833.5),
#  ('Queso', 'Fuentes', 833.26),
#  ...]

# %% [markdown]
# * 5.-Empleados y número de órdenes gestionadas
#
#     * Muestra el nombre del empleado, el puesto y la cantidad de órdenes que ha gestionado.
#     * Utiliza GROUP BY y COUNT.

# %%
sql = ('')
consultas(sql)
# Out:
# Ha ocurrido un error: No result set to fetch from
# 0

# %% [markdown]
# * 6.-Ordenes filtradas por fecha y tienda
#
#     * Muestra todas las órdenes que se realizaron en un rango de fechas determinado (ej.: del 1 de enero de 2025 al 31 de enero de 2025) y en una tienda específica.
#     * Incluye datos de la tienda y del cliente.

# %% [markdown]
# * 7.-Ranking de productos más vendidos en cada tienda
#
#
#     * Para cada tienda, muestra los 3 productos más vendidos (en términos de cantidad total).
#     * Tendrás que unir tiendas, empleados, ordenes y detalle_orden, además de productos.
#     * Usa GROUP BY y ordena por la cantidad sumada (y opcionalmente, un LIMIT 3).
